# %%
# Code for extracting the daily ATMO score for each station in ATMO GRAND EST (Région: GRAND EST)

# %%
# Installing required packages
import pandas as pd

import os

# Base directory path
base_path = ".\data\raw\Données de la qualité de l'air (Indicateurs SOMO35 et ATMO)\"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_24808\2375524138.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# PM10 ATMO GRAND EST

# File path to the data
PM10_ATMO_GRAND_EST_file_path = os.path.join(base_path, "PM10 Moyenne Journalière\Export Moy. journalière - PM10 - ATMO GRAND EST.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM10 = pd.read_csv(PM10_ATMO_GRAND_EST_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM10.head())

# Sample ATMO subscore dictionary for PM10 (Moyenne journalière)
ATMO_subscore_PM10 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 20.0), (20.0, 40.0), (40.0, 50.0), (50.0, 100.0), (100.0, 150.0), (150.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM10 = pd.DataFrame(ATMO_subscore_PM10)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM10['Range'] = ATMO_subscore_df_PM10['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM10 measurement
def assign_subscore_PM10(valeur):
    for index, row in ATMO_subscore_df_PM10.iterrows():  
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM10['ATMO sub-score'] = df_PM10['valeur'].apply(assign_subscore_PM10)  

# Display the updated DataFrame
print(df_PM10.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
#
#             Zas code site            nom site type d'implantation Polluant  \
# 0      ZAG METZ   FR01011         Metz-Centre             Urbaine     PM10
# 1      ZAG METZ   FR01012          Metz-Borny             Urbaine     PM10
# 2  ZR GRAND-EST   FR01014      Pont-à-Mousson             Urbaine     PM10
# 3      ZAG METZ   FR01019  Thionville-Piscine             Urbaine     PM10
# 4      ZAG METZ   FR01020   Thionville-Centre             Urbaine     PM10
#
#   type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0             Fond  ...   10.0    10.012500           µg-m3           100.0
# 1             Fond  ...   12.0    11.975000           µg-m3           100.0
# 2             Fond  ...   19.0    19.339130           µg-m3            96.0
# 3             Fond  ...   14.0    13.545833           µg-m3           100.0
# 4             Fond  ...   17.0    16.537500           µg-m3           100.0
#
#    couverture temporelle couverture de données  code qualité  validité  \
# 0                    100                 100.0             A         1
# 1                    100                 100.0             A         1
# 2                    100                  96.0             A         1
# 3                    100                 100.0             A         1
# 4                    100                 100.0             A         1
#
#     Latitude Longitude
# 0  49.119442  6.180833
# 1  49.110283  6.223336
# 2  48.915000  6.058336
# 3  49.368610  6.160831
# 4  49.358337  6.156942
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
#
#             Zas code site            nom site type d'implantation Polluant  \
# 0      ZAG METZ   FR01011         Metz-Centre             Urbaine     PM10
# 1      ZAG METZ   FR01012          Metz-Borny             Urbaine     PM10
# 2  ZR GRAND-EST   FR01014      Pont-à-Mousson             Urbaine     PM10
# 3      ZAG METZ   FR01019  Thionville-Piscine             Urbaine     PM10
# 4      ZAG METZ   FR01020   Thionville-Centre             Urbaine     PM10
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0             Fond  ...    10.012500           µg-m3          100.0
# 1             Fond  ...    11.975000           µg-m3          100.0
# 2             Fond  ...    19.339130           µg-m3           96.0
# 3             Fond  ...    13.545833           µg-m3          100.0
# 4             Fond  ...    16.537500           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                   96.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  49.119442   6.180833            1.0
# 1  49.110283   6.223336            1.0
# 2  48.915000   6.058336            1.0
# 3  49.368610   6.160831            1.0
# 4  49.358337   6.156942            1.0
#
# [5 rows x 24 columns]

# %%
# PM2.5 ATMO GRAND EST

# File path to the data
PM25_ATMO_GRAND_EST_file_path = os.path.join(base_path, "PM2.5 Moyenne Journalière\Export Moy. journalière - PM2.5 - ATMO GRAND EST.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM25 = pd.read_csv(PM25_ATMO_GRAND_EST_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM25.head())

# Sample ATMO subscore dictionary for PM2.5 (Moyenne journalière)
ATMO_subscore_PM25 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 10.0), (10.0, 20.0), (20.0, 25.0), (25.0, 50.0), (50.0, 75.0), (75.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM25 = pd.DataFrame(ATMO_subscore_PM25)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM25['Range'] = ATMO_subscore_df_PM25['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM2.5 measurement
def assign_subscore_PM25(valeur):
    for index, row in ATMO_subscore_df_PM25.iterrows(): 
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM25['ATMO sub-score'] = df_PM25['valeur'].apply(assign_subscore_PM25)  

# Display the updated DataFrame
print(df_PM25.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAR01
#
#             Zas code site              nom site type d'implantation Polluant  \
# 0      ZAG METZ   FR01011           Metz-Centre             Urbaine    PM2.5
# 1      ZAG METZ   FR01020     Thionville-Centre             Urbaine    PM2.5
# 2  ZR GRAND-EST   FR01065  Belleville sur Meuse             Urbaine    PM2.5
# 3  ZR GRAND-EST   FR14008                 REVIN    Rurale nationale    PM2.5
# 4     ZAR REIMS   FR14011                DOUMER             Urbaine    PM2.5
#
#   type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0             Fond  ...    5.2     5.237500           µg-m3           100.0
# 1             Fond  ...    5.6     5.570833           µg-m3           100.0
# 2           Trafic  ...    7.0     7.020833           µg-m3           100.0
# 3             Fond  ...    6.2     6.187500           µg-m3           100.0
# 4           Trafic  ...    5.2     5.216667           µg-m3           100.0
#
#    couverture temporelle couverture de données  code qualité  validité  \
# 0                    100                 100.0             A         1
# 1                    100                 100.0             A         1
# 2                    100                 100.0             A         1
# 3                    100                 100.0             A         1
# 4                    100                 100.0             A         1
#
#     Latitude Longitude
# 0  49.119442  6.180833
# 1  49.358337  6.156942
# 2  49.167780  5.387461
# 3  49.907780  4.630000
# 4  49.250732  4.023064
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAR01
#
#             Zas code site              nom site type d'implantation Polluant  \
# 0      ZAG METZ   FR01011           Metz-Centre             Urbaine    PM2.5
# 1      ZAG METZ   FR01020     Thionville-Centre             Urbaine    PM2.5
# 2  ZR GRAND-EST   FR01065  Belleville sur Meuse             Urbaine    PM2.5
# 3  ZR GRAND-EST   FR14008                 REVIN    Rurale nationale    PM2.5
# 4     ZAR REIMS   FR14011                DOUMER             Urbaine    PM2.5
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0             Fond  ...     5.237500           µg-m3          100.0
# 1             Fond  ...     5.570833           µg-m3          100.0
# 2           Trafic  ...     7.020833           µg-m3          100.0
# 3             Fond  ...     6.187500           µg-m3          100.0
# 4           Trafic  ...     5.216667           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  49.119442   6.180833            1.0
# 1  49.358337   6.156942            1.0
# 2  49.167780   5.387461            1.0
# 3  49.907780   4.630000            1.0
# 4  49.250732   4.023064            1.0
#
# [5 rows x 24 columns]

# %%
# NO2 ATMO GRAND EST

# File path to the data
NO2_ATMO_GRAND_EST_file_path = os.path.join(base_path, "NO2 Max Horaire Journalier\Export Max. journalier moy. hor. - NO2 - ATMO GRAND EST.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_NO2 = pd.read_csv(NO2_ATMO_GRAND_EST_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_NO2.head())

# Sample ATMO subscore dictionary for NO2 (Max horaire journalier)
ATMO_subscore_NO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 40.0), (40.0, 90.0), (90.0, 120.0), (120.0, 230.0), (230.0, 340.0), (340.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_NO2 = pd.DataFrame(ATMO_subscore_NO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_NO2['Range'] = ATMO_subscore_df_NO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of NO2 measurement
def assign_subscore_NO2(valeur):
    for index, row in ATMO_subscore_df_NO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_NO2['ATMO sub-score'] = df_NO2['valeur'].apply(assign_subscore_NO2)

# Display the updated DataFrame
print(df_NO2.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
#
#             Zas code site            nom site     type d'implantation  \
# 0      ZAG METZ   FR01011         Metz-Centre                 Urbaine
# 1      ZAG METZ   FR01012          Metz-Borny                 Urbaine
# 2  ZR GRAND-EST   FR01016               Atton  Rurale près des villes
# 3      ZAG METZ   FR01018       Scy-Chazelles             Périurbaine
# 4      ZAG METZ   FR01019  Thionville-Piscine                 Urbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0      NO2             Fond  ...   18.7       18.700           µg-m3
# 1      NO2             Fond  ...    8.2        8.175           µg-m3
# 2      NO2     Industrielle  ...   24.2       24.200           µg-m3
# 3      NO2             Fond  ...   17.8       17.800           µg-m3
# 4      NO2             Fond  ...   35.3       35.300           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             A
# 1           100.0                    100                 100.0             A
# 2           100.0                    100                 100.0             A
# 3           100.0                    100                 100.0             A
# 4           100.0                    100                 100.0             A
#
#    validité   Latitude Longitude
# 0         1  49.119442  6.180833
# 1         1  49.110283  6.223336
# 2         1  48.886387  6.093611
# 3         1  49.107502  6.122775
# 4         1  49.368610  6.160831
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
#
#             Zas code site            nom site     type d'implantation  \
# 0      ZAG METZ   FR01011         Metz-Centre                 Urbaine
# 1      ZAG METZ   FR01012          Metz-Borny                 Urbaine
# 2  ZR GRAND-EST   FR01016               Atton  Rurale près des villes
# 3      ZAG METZ   FR01018       Scy-Chazelles             Périurbaine
# 4      ZAG METZ   FR01019  Thionville-Piscine                 Urbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0      NO2             Fond  ...       18.700           µg-m3          100.0
# 1      NO2             Fond  ...        8.175           µg-m3          100.0
# 2      NO2     Industrielle  ...       24.200           µg-m3          100.0
# 3      NO2             Fond  ...       17.800           µg-m3          100.0
# 4      NO2             Fond  ...       35.300           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  49.119442   6.180833            1.0
# 1  49.110283   6.223336            1.0
# 2  48.886387   6.093611            1.0
# 3  49.107502   6.122775            1.0
# 4  49.368610   6.160831            1.0
#
# [5 rows x 24 columns]

# %%
# O3 ATMO GRAND EST

# File path to the data
O3_ATMO_GRAND_EST_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - ATMO GRAND EST.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_ATMO_GRAND_EST_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Sample ATMO subscore dictionary for O3 (Max horaire journalier)
ATMO_subscore_O3 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 50.0), (50.0, 100.0), (100.0, 130.0), (130.0, 240.0), (240.0, 380.0), (380.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_O3 = pd.DataFrame(ATMO_subscore_O3)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_O3['Range'] = ATMO_subscore_df_O3['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of O3 measurement
def assign_subscore_O3(valeur):
    for index, row in ATMO_subscore_df_O3.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_O3['ATMO sub-score'] = df_O3['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAR01
#
#             Zas code site           nom site type d'implantation Polluant  \
# 0      ZAG METZ   FR01011        Metz-Centre             Urbaine       O3
# 1      ZAG METZ   FR01018      Scy-Chazelles         Périurbaine       O3
# 2      ZAG METZ   FR01020  Thionville-Centre             Urbaine       O3
# 3  ZR GRAND-EST   FR14008              REVIN    Rurale nationale       O3
# 4     ZAR REIMS   FR14010            BETHENY         Périurbaine       O3
#
#   type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0             Fond  ...   58.9       58.900           µg-m3           100.0
# 1             Fond  ...   73.1       73.125           µg-m3           100.0
# 2             Fond  ...   56.2       56.175           µg-m3           100.0
# 3             Fond  ...   55.5       55.525           µg-m3           100.0
# 4             Fond  ...   59.5       59.475           µg-m3           100.0
#
#    couverture temporelle couverture de données  code qualité  validité  \
# 0                    100                 100.0             A         1
# 1                    100                 100.0             A         1
# 2                    100                 100.0             R         1
# 3                    100                 100.0             A         1
# 4                    100                 100.0             R         1
#
#     Latitude Longitude
# 0  49.119442  6.180833
# 1  49.107502  6.122775
# 2  49.358337  6.156942
# 3  49.907780  4.630000
# 4  49.282220  4.051111
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAR01
#
#             Zas code site           nom site type d'implantation Polluant  \
# 0      ZAG METZ   FR01011        Metz-Centre             Urbaine       O3
# 1      ZAG METZ   FR01018      Scy-Chazelles         Périurbaine       O3
# 2      ZAG METZ   FR01020  Thionville-Centre             Urbaine       O3
# 3  ZR GRAND-EST   FR14008              REVIN    Rurale nationale       O3
# 4     ZAR REIMS   FR14010            BETHENY         Périurbaine       O3
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0             Fond  ...       58.900           µg-m3          100.0
# 1             Fond  ...       73.125           µg-m3          100.0
# 2             Fond  ...       56.175           µg-m3          100.0
# 3             Fond  ...       55.525           µg-m3          100.0
# 4             Fond  ...       59.475           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            R         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            R         1
#
#     Latitude  Longitude ATMO sub-score
# 0  49.119442   6.180833              2
# 1  49.107502   6.122775              2
# 2  49.358337   6.156942              2
# 3  49.907780   4.630000              2
# 4  49.282220   4.051111              2
#
# [5 rows x 24 columns]

# %%
# SO2 ATMO GRAND EST

# File path to the data
SO2_ATMO_GRAND_EST_file_path = os.path.join(base_path, "SO2 Max Horaire Journalier\Export Max. journalier moy. hor. - SO2 - ATMO GRAND EST.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_SO2 = pd.read_csv(SO2_ATMO_GRAND_EST_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_SO2.head())

# Sample ATMO subscore dictionary for SO2 (Max horaire journalier)
ATMO_subscore_SO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 100.0), (100.0, 200.0), (200.0, 350.0), (350.0, 500.0), (500.0, 750.0), (750.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_SO2 = pd.DataFrame(ATMO_subscore_SO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_SO2['Range'] = ATMO_subscore_df_SO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of SO2 measurement
def assign_subscore_SO2(valeur):
    for index, row in ATMO_subscore_df_SO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_SO2['ATMO sub-score'] = df_SO2['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_SO2.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
#
#             Zas code site             nom site type d'implantation Polluant  \
# 0     ZAR REIMS   FR14012         Jean d Aulan             Urbaine      SO2
# 1  ZR GRAND-EST   FR16052                Thann             Urbaine      SO2
# 2  ZR GRAND-EST   FR16067        Vieux Thann 3             Urbaine      SO2
# 3  ZR GRAND-EST   FR22009  Ecole de Carling(9)         Périurbaine      SO2
# 4  ZR GRAND-EST   FR30027              Frolois             Urbaine      SO2
#
#   type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0             Fond  ...    0.2        0.150           µg-m3           100.0
# 1     Industrielle  ...    1.6        1.550           µg-m3           100.0
# 2             Fond  ...    1.6        1.625           µg-m3           100.0
# 3     Industrielle  ...    2.7        2.700           µg-m3            96.0
# 4     Industrielle  ...    2.7        2.700           µg-m3           100.0
#
#    couverture temporelle couverture de données  code qualité  validité  \
# 0                    100                 100.0             R         1
# 1                    100                 100.0             R         1
# 2                    100                 100.0             R         1
# 3                    100                  96.0             A         1
# 4                    100                 100.0             R         1
#
#     Latitude Longitude
# 0  49.224167  4.020556
# 1  47.810932  7.105553
# 2  47.802210  7.122844
# 3  49.165726  6.716886
# 4  48.565445  6.129578
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
#
#             Zas code site             nom site type d'implantation Polluant  \
# 0     ZAR REIMS   FR14012         Jean d Aulan             Urbaine      SO2
# 1  ZR GRAND-EST   FR16052                Thann             Urbaine      SO2
# 2  ZR GRAND-EST   FR16067        Vieux Thann 3             Urbaine      SO2
# 3  ZR GRAND-EST   FR22009  Ecole de Carling(9)         Périurbaine      SO2
# 4  ZR GRAND-EST   FR30027              Frolois             Urbaine      SO2
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0             Fond  ...        0.150           µg-m3          100.0
# 1     Industrielle  ...        1.550           µg-m3          100.0
# 2             Fond  ...        1.625           µg-m3          100.0
# 3     Industrielle  ...        2.700           µg-m3           96.0
# 4     Industrielle  ...        2.700           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            R         1
# 1                    100                  100.0            R         1
# 2                    100                  100.0            R         1
# 3                    100                   96.0            A         1
# 4                    100                  100.0            R         1
#
#     Latitude  Longitude ATMO sub-score
# 0  49.224167   4.020556            1.0
# 1  47.810932   7.105553            1.0
# 2  47.802210   7.122844            1.0
# 3  49.165726   6.716886            1.0
# 4  48.565445   6.129578            1.0
#
# [5 rows x 24 columns]

# %%
# Combining 5 (if not missing) dataframes
# Concatenate DataFrames along the rows (stack them vertically)
combined_df_ATMO_GRAND_EST = pd.concat([df_PM10, df_PM25, df_NO2, df_O3, df_SO2], axis=0) #

# If you want to reset the index of the combined DataFrame
combined_df_ATMO_GRAND_EST.reset_index(drop=True, inplace=True)

# Renaming the ATMO subscore column to 'ATMO Score'
combined_df_ATMO_GRAND_EST = combined_df_ATMO_GRAND_EST.rename(columns={'ATMO sub-score': 'ATMO Score'})

# Printing the first five rows as a sanity check
print(combined_df_ATMO_GRAND_EST.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZAG02
#
#             Zas code site            nom site type d'implantation Polluant  \
# 0      ZAG METZ   FR01011         Metz-Centre             Urbaine     PM10
# 1      ZAG METZ   FR01012          Metz-Borny             Urbaine     PM10
# 2  ZR GRAND-EST   FR01014      Pont-à-Mousson             Urbaine     PM10
# 3      ZAG METZ   FR01019  Thionville-Piscine             Urbaine     PM10
# 4      ZAG METZ   FR01020   Thionville-Centre             Urbaine     PM10
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0             Fond  ...    10.012500           µg-m3          100.0
# 1             Fond  ...    11.975000           µg-m3          100.0
# 2             Fond  ...    19.339130           µg-m3           96.0
# 3             Fond  ...    13.545833           µg-m3          100.0
# 4             Fond  ...    16.537500           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                   96.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO Score
# 0  49.119442   6.180833        1.0
# 1  49.110283   6.223336        1.0
# 2  48.915000   6.058336        1.0
# 3  49.368610   6.160831        1.0
# 4  49.358337   6.156942        1.0
#
# [5 rows x 24 columns]

# %%
# Find the index of rows with maximum 'ATMO Score' within each group
idx_max_scores = combined_df_ATMO_GRAND_EST.groupby(['nom site', 'Date de fin'])['ATMO Score'].idxmax()

# Select rows with the maximum 'ATMO Score' using the index
final_df_ATMO_GRAND_EST = combined_df_ATMO_GRAND_EST.loc[idx_max_scores]

# Reset index if needed
final_df_ATMO_GRAND_EST.reset_index(drop=True, inplace=True)

# %%
# Downloading the final dataframe of Daily ATMO Score in ATMO GRAND EST to csv
final_df_ATMO_GRAND_EST.to_csv('final_df_ATMO_GRAND_EST.csv', index=False, encoding = 'latin1')

# %%
# Constructing indicator for ATMO GRAND EST

# File path to the data
ATMO_GRAND_EST_file_path = os.path.join(base_path, "final_df_ATMO_GRAND_EST.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_ATMO = pd.read_csv(ATMO_GRAND_EST_file_path, delimiter=',', encoding = 'latin1')

print(df_ATMO.head())

counts = df_ATMO.groupby('nom site')['ATMO Score'].value_counts().reset_index(name='counts')
#print(counts)

#result = pd.merge(counts, df_ATMO[["Organisme", "type d'implantation", "Latitude", "Longitude"]], on='nom site', how='left')
#print(result)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_ATMO.groupby('nom site').first().reset_index()
#print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(counts, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score_y'], axis = 1)
print(result)
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO GRAND EST  FR44ZRE01
# 1  2023/01/02 00:00:00  2023/01/02 23:59:59  ATMO GRAND EST  FR44ZRE01
# 2  2023/01/03 00:00:00  2023/01/03 23:59:59  ATMO GRAND EST  FR44ZRE01
# 3  2023/01/04 00:00:00  2023/01/04 23:59:59  ATMO GRAND EST  FR44ZRE01
# 4  2023/01/05 00:00:00  2023/01/05 23:59:59  ATMO GRAND EST  FR44ZRE01
#
#             Zas code site nom site     type d'implantation Polluant  \
# 0  ZR GRAND-EST   FR01016    Atton  Rurale près des villes      NO2
# 1  ZR GRAND-EST   FR01016    Atton  Rurale près des villes      NO2
# 2  ZR GRAND-EST   FR01016    Atton  Rurale près des villes      NO2
# 3  ZR GRAND-EST   FR01016    Atton  Rurale près des villes      NO2
# 4  ZR GRAND-EST   FR01016    Atton  Rurale près des villes      NO2
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0     Industrielle  ...       24.200           µg-m3          100.0
# 1     Industrielle  ...       19.000           µg-m3          100.0
# 2     Industrielle  ...       39.275           µg-m3          100.0
# 3     Industrielle  ...        3.825           µg-m3          100.0
# 4     Industrielle  ...       14.750           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO Score
# 0  48.886387   6.093611        1.0
# 1  48.886387   6.093611        1.0
# 2  48.886387   6.093611        1.0
# 3  48.886387   6.093611        1.0
# 4  48.886387   6.093611        1.0
#
# [5 rows x 24 columns]
#            nom site  ATMO Score_x  counts       Organisme   code zas  \
# 0             Atton           1.0     313  ATMO GRAND EST  FR44ZRE01
# 1             Atton           2.0      50  ATMO GRAND EST  FR44ZRE01
# 2           BETHENY           2.0     292  ATMO GRAND EST  FR44ZAR01
# 3           BETHENY           3.0      49  ATMO GRAND EST  FR44ZAR01
# 4           BETHENY           4.0      14  ATMO GRAND EST  FR44ZAR01
# ..              ...           ...     ...             ...        ...
# 212   Vieux Thann 3           6.0       1  ATMO GRAND EST  FR44ZRE01
# 213  Vosges du Nord           2.0     243  ATMO GRAND EST  FR44ZRE01
# 214  Vosges du Nord           3.0      69  ATMO GRAND EST  FR44ZRE01
# 215  Vosges du Nord           4.0      26  ATMO GRAND EST  FR44ZRE01
# 216  Vosges du Nord           1.0      24  ATMO GRAND EST  FR44ZRE01
#
#               Zas code site     type d'implantation Polluant type d'influence  \
# 0    ZR GRAND-EST   FR01016  Rurale près des villes      NO2     Industrielle
# 1    ZR GRAND-EST   FR01016  Rurale près des villes      NO2     Industrielle
# 2       ZAR REIMS   FR14010             Périurbaine       O3             Fond
# 3       ZAR REIMS   FR14010             Périurbaine       O3             Fond
# 4       ZAR REIMS   FR14010             Périurbaine       O3             Fond
# ..            ...       ...                     ...      ...              ...
# 212  ZR GRAND-EST   FR16067                 Urbaine      SO2             Fond
# 213  ZR GRAND-EST   FR16031        Rurale régionale       O3             Fond
# 214  ZR GRAND-EST   FR16031        Rurale régionale       O3             Fond
# 215  ZR GRAND-EST   FR16031        Rurale régionale       O3             Fond
# 216  ZR GRAND-EST   FR16031        Rurale régionale       O3             Fond
#
#      ... valeur valeur brute unité de mesure  taux de saisie  \
# 0    ...   24.2       24.200           µg-m3           100.0
# 1    ...   24.2       24.200           µg-m3           100.0
# 2    ...   59.5       59.475           µg-m3           100.0
# 3    ...   59.5       59.475           µg-m3           100.0
# 4    ...   59.5       59.475           µg-m3           100.0
# ..   ...    ...          ...             ...             ...
# 212  ...    1.6        1.625           µg-m3           100.0
# 213  ...   67.8       67.800           µg-m3           100.0
# 214  ...   67.8       67.800           µg-m3           100.0
# 215  ...   67.8       67.800           µg-m3           100.0
# 216  ...   67.8       67.800           µg-m3           100.0
#
#      couverture temporelle couverture de données  code qualité  validité  \
# 0                      100                 100.0             A         1
# 1                      100                 100.0             A         1
# 2                      100                 100.0             R         1
# 3                      100                 100.0             R         1
# 4                      100                 100.0             R         1
# ..                     ...                   ...           ...       ...
# 212                    100                 100.0             R         1
# 213                    100                 100.0             A         1
# 214                    100                 100.0             A         1
# 215                    100                 100.0             A         1
# 216                    100                 100.0             A         1
#
#       Latitude Longitude
# 0    48.886387  6.093611
# 1    48.886387  6.093611
# 2    49.282220  4.051111
# 3    49.282220  4.051111
# 4    49.282220  4.051111
# ..         ...       ...
# 212  47.802210  7.122844
# 213  48.857310  7.314175
# 214  48.857310  7.314175
# 215  48.857310  7.314175
# 216  48.857310  7.314175
#
# [217 rows x 23 columns]

# %%
# Group the DataFrame by 'nom' and calculate the total counts for each 'nom'
total_counts_by_nom = result.groupby('nom site')['counts'].sum()

# Filter the DataFrame to include only rows where the score is equal to or greater than 3
filtered_result = result[result['ATMO Score_x'] >= 3]

# Group the filtered DataFrame by 'nom' and calculate the counts equal to or greater than 3 for each 'nom'
counts_greater_than_3_by_nom = filtered_result.groupby('nom site')['counts'].sum()

# Calculate the ratio of counts greater than or equal to 3 over total counts for each 'nom'
ratio_counts_greater_than_3 = (counts_greater_than_3_by_nom / total_counts_by_nom).fillna(0)

# Display the resulting Series
print(ratio_counts_greater_than_3)

# Merge the site-specific information with the counts DataFrame
ratio_counts_greater_than_3_df = pd.merge(ratio_counts_greater_than_3, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score'], axis = 1)
ratio_counts_greater_than_3_df = ratio_counts_greater_than_3_df.rename(columns={'counts': 'indicator'})
print(ratio_counts_greater_than_3_df)
# Out:
# nom site
# Atton                                    0.000000
# BETHENY                                  0.172603
# Belleville sur Meuse                     0.032877
# C.C.3 Frontières                         0.002778
# CHALONS                                  0.164384
# CHARLEVILLE                              0.186301
# Capitainerie                             0.167123
# Chalampé                                 0.002740
# Colmar Centre                            0.008219
# Colmar Sud                               0.260274
# DOUMER                                   0.115068
# Donon Vosges Moyennes 2                  0.194521
# Ecole de Carling(9)                      0.011050
# Epinal                                   0.167123
# Fléville                                 0.008219
# Frolois                                  0.010959
# HAYANGE-MARSPICH                         0.010989
# Haguenau-Place marché aux bestiaux       0.282192
# Heming                                   0.008219
# Hotel Districal                          0.005495
# Jean d Aulan                             0.178571
# Jonville en Woevre                       0.232877
# LA TOUR                                  0.000000
# Luneville                                0.038356
# Metz- Pont Grilles                       0.013699
# Metz-Borny                               0.002740
# Metz-Centre                              0.164420
# Mulhouse Est                             0.230137
# Mulhouse Nord                            0.032877
# Mulhouse Sud 2                           0.249315
# Mulhouse-Briand                          0.098630
# Nancy-Brabois 2                          0.205479
# Nancy-Charles III                        0.205479
# Nancy-Libération                         0.032877
# Neuves-Maisons                           0.038356
# Nord-Est Alsace                          0.213699
# Pont-à-Mousson                           0.008219
# REVIN                                    0.172603
# Rempart Perrier                          0.046575
# SCHOENECK (19)                           0.000000
# ST PARRES AUX TERTRE                     0.131507
# STE SAVINE                               0.038567
# Schlucht                                 0.186301
# Scy-Chazelles                            0.164384
# Spicheren(14)                            0.000000
# St DIZIER L. Michel                      0.183562
# Station de FORBACH                       0.254795
# Strasbourg A35                           0.109589
# Strasbourg A35 Remparts                  0.161644
# Strasbourg Clemenceau                    0.131507
# Strasbourg Neudorf Ecoquartier Danube    0.079452
# Strasbourg Nord                          0.238356
# Strasbourg Sud 2                         0.244505
# Thann                                    0.002755
# Thionville-Centre                        0.024658
# Thionville-Garche                        0.260234
# Thionville-Piscine                       0.000000
# Troyes La Tour                           0.000000
# Vieux Thann 3                            0.008357
# Vosges du Nord                           0.262431
# Name: counts, dtype: float64
#                                  nom site  indicator       Organisme  \
# 0                                   Atton   0.000000  ATMO GRAND EST
# 1                                 BETHENY   0.172603  ATMO GRAND EST
# 2                    Belleville sur Meuse   0.032877  ATMO GRAND EST
# 3                        C.C.3 Frontières   0.002778  ATMO GRAND EST
# 4                                 CHALONS   0.164384  ATMO GRAND EST
# 5                             CHARLEVILLE   0.186301  ATMO GRAND EST
# 6                            Capitainerie   0.167123  ATMO GRAND EST
# 7                                Chalampé   0.002740  ATMO GRAND EST
# 8                           Colmar Centre   0.008219  ATMO GRAND EST
# 9                              Colmar Sud   0.260274  ATMO GRAND EST
# 10                                 DOUMER   0.115068  ATMO GRAND EST
# 11                Donon Vosges Moyennes 2   0.194521  ATMO GRAND EST
# 12                    Ecole de Carling(9)   0.011050  ATMO GRAND EST
# 13                                 Epinal   0.167123  ATMO GRAND EST
# 14                               Fléville   0.008219  ATMO GRAND EST
# 15                                Frolois   0.010959  ATMO GRAND EST
# 16                       HAYANGE-MARSPICH   0.010989  ATMO GRAND EST
# 17     Haguenau-Place marché aux bestiaux   0.282192  ATMO GRAND EST
# 18                                 Heming   0.008219  ATMO GRAND EST
# 19                        Hotel Districal   0.005495  ATMO GRAND EST
# 20                           Jean d Aulan   0.178571  ATMO GRAND EST
# 21                     Jonville en Woevre   0.232877  ATMO GRAND EST
# 22                                LA TOUR   0.000000  ATMO GRAND EST
# 23                              Luneville   0.038356  ATMO GRAND EST
# 24                     Metz- Pont Grilles   0.013699  ATMO GRAND EST
# 25                             Metz-Borny   0.002740  ATMO GRAND EST
# 26                            Metz-Centre   0.164420  ATMO GRAND EST
# 27                           Mulhouse Est   0.230137  ATMO GRAND EST
# 28                          Mulhouse Nord   0.032877  ATMO GRAND EST
# 29                         Mulhouse Sud 2   0.249315  ATMO GRAND EST
# 30                        Mulhouse-Briand   0.098630  ATMO GRAND EST
# 31                        Nancy-Brabois 2   0.205479  ATMO GRAND EST
# 32                      Nancy-Charles III   0.205479  ATMO GRAND EST
# 33                       Nancy-Libération   0.032877  ATMO GRAND EST
# 34                         Neuves-Maisons   0.038356  ATMO GRAND EST
# 35                        Nord-Est Alsace   0.213699  ATMO GRAND EST
# 36                         Pont-à-Mousson   0.008219  ATMO GRAND EST
# 37                                  REVIN   0.172603  ATMO GRAND EST
# 38                        Rempart Perrier   0.046575  ATMO GRAND EST
# 39                         SCHOENECK (19)   0.000000  ATMO GRAND EST
# 40                   ST PARRES AUX TERTRE   0.131507  ATMO GRAND EST
# 41                             STE SAVINE   0.038567  ATMO GRAND EST
# 42                               Schlucht   0.186301  ATMO GRAND EST
# 43                          Scy-Chazelles   0.164384  ATMO GRAND EST
# 44                          Spicheren(14)   0.000000  ATMO GRAND EST
# 45                    St DIZIER L. Michel   0.183562  ATMO GRAND EST
# 46                     Station de FORBACH   0.254795  ATMO GRAND EST
# 47                         Strasbourg A35   0.109589  ATMO GRAND EST
# 48                Strasbourg A35 Remparts   0.161644  ATMO GRAND EST
# 49                  Strasbourg Clemenceau   0.131507  ATMO GRAND EST
# 50  Strasbourg Neudorf Ecoquartier Danube   0.079452  ATMO GRAND EST
# 51                        Strasbourg Nord   0.238356  ATMO GRAND EST
# 52                       Strasbourg Sud 2   0.244505  ATMO GRAND EST
# 53                                  Thann   0.002755  ATMO GRAND EST
# 54                      Thionville-Centre   0.024658  ATMO GRAND EST
# 55                      Thionville-Garche   0.260234  ATMO GRAND EST
# 56                     Thionville-Piscine   0.000000  ATMO GRAND EST
# 57                        Troyes La Tour    0.000000  ATMO GRAND EST
# 58                          Vieux Thann 3   0.008357  ATMO GRAND EST
# 59                         Vosges du Nord   0.262431  ATMO GRAND EST
#
#      code zas             Zas code site     type d'implantation Polluant  \
# 0   FR44ZRE01    ZR GRAND-EST   FR01016  Rurale près des villes      NO2
# 1   FR44ZAR01       ZAR REIMS   FR14010             Périurbaine       O3
# 2   FR44ZRE01    ZR GRAND-EST   FR01065                 Urbaine      NO2
# 3   FR44ZRE01    ZR GRAND-EST   FR16060             Périurbaine     PM10
# 4   FR44ZRE01    ZR GRAND-EST   FR14022                 Urbaine       O3
# 5   FR44ZRE01    ZR GRAND-EST   FR14051                 Urbaine       O3
# 6   FR44ZRE01    ZR GRAND-EST   FR14029             Périurbaine       O3
# 7   FR44ZRE01    ZR GRAND-EST   FR16059  Rurale près des villes      NO2
# 8   FR44ZRE01    ZR GRAND-EST   FR16054                 Urbaine     PM10
# 9   FR44ZRE01    ZR GRAND-EST   FR16064             Périurbaine       O3
# 10  FR44ZAR01       ZAR REIMS   FR14011                 Urbaine     PM10
# 11  FR44ZRE01    ZR GRAND-EST   FR16302        Rurale nationale       O3
# 12  FR44ZRE01    ZR GRAND-EST   FR22009             Périurbaine     PM10
# 13  FR44ZRE01    ZR GRAND-EST   FR30019                 Urbaine       O3
# 14  FR44ZAG03       ZAG NANCY   FR30021             Périurbaine     PM10
# 15  FR44ZRE01    ZR GRAND-EST   FR30027                 Urbaine     PM10
# 16  FR44ZAG02        ZAG METZ   FR01059             Périurbaine     PM10
# 17  FR44ZRE01    ZR GRAND-EST   FR42011                 Urbaine    PM2.5
# 18  FR44ZRE01    ZR GRAND-EST   FR30032  Rurale près des villes     PM10
# 19  FR44ZAG03       ZAG NANCY   FR30016                 Urbaine      NO2
# 20  FR44ZAR01       ZAR REIMS   FR14012                 Urbaine    PM2.5
# 21  FR44ZRE01    ZR GRAND-EST   FR30033        Rurale régionale       O3
# 22  FR44ZRE01    ZR GRAND-EST   FR14031                 Urbaine     PM10
# 23  FR44ZRE01    ZR GRAND-EST   FR30026                 Urbaine    PM2.5
# 24  FR44ZAG02        ZAG METZ   FR01064                 Urbaine      NO2
# 25  FR44ZAG02        ZAG METZ   FR01012                 Urbaine     PM10
# 26  FR44ZAG02        ZAG METZ   FR01011                 Urbaine       O3
# 27  FR44ZRE01    ZR GRAND-EST   FR16065             Périurbaine       O3
# 28  FR44ZRE01    ZR GRAND-EST   FR16057                 Urbaine     PM10
# 29  FR44ZRE01    ZR GRAND-EST   FR16066                 Urbaine     PM10
# 30  FR44ZRE01    ZR GRAND-EST   FR16069                 Urbaine      NO2
# 31  FR44ZAG03       ZAG NANCY   FR30037             Périurbaine       O3
# 32  FR44ZAG03       ZAG NANCY   FR30034                 Urbaine       O3
# 33  FR44ZAG03       ZAG NANCY   FR30036                 Urbaine    PM2.5
# 34  FR44ZAG03       ZAG NANCY   FR30030                 Urbaine     PM10
# 35  FR44ZRE01    ZR GRAND-EST   FR16017        Rurale régionale       O3
# 36  FR44ZRE01    ZR GRAND-EST   FR01014                 Urbaine     PM10
# 37  FR44ZRE01    ZR GRAND-EST   FR14008        Rurale nationale       O3
# 38  FR44ZRE01    ZR GRAND-EST   FR14028                 Urbaine     PM10
# 39  FR44ZRE01    ZR GRAND-EST   FR22019             Périurbaine     PM10
# 40  FR44ZRE01    ZR GRAND-EST   FR14032             Périurbaine       O3
# 41  FR44ZRE01    ZR GRAND-EST   FR14033                 Urbaine     PM10
# 42  FR44ZRE01    ZR GRAND-EST   FR30028  Rurale près des villes       O3
# 43  FR44ZAG02        ZAG METZ   FR01018             Périurbaine       O3
# 44  FR44ZRE01    ZR GRAND-EST   FR22014             Périurbaine      NO2
# 45  FR44ZRE01    ZR GRAND-EST   FR14042                 Urbaine       O3
# 46  FR44ZRE01    ZR GRAND-EST   FR22054                 Urbaine       O3
# 47  FR44ZAG01  ZAG STRASBOURG   FR16040                 Urbaine      NO2
# 48  FR44ZAG01  ZAG STRASBOURG   FR16215                 Urbaine      NO2
# 49  FR44ZAG01  ZAG STRASBOURG   FR16034                 Urbaine      NO2
# 50  FR44ZAG01  ZAG STRASBOURG   FR42010                 Urbaine     PM10
# 51  FR44ZAG01  ZAG STRASBOURG   FR16029                 Urbaine     PM10
# 52  FR44ZAG01  ZAG STRASBOURG   FR16041             Périurbaine       O3
# 53  FR44ZRE01    ZR GRAND-EST   FR16052                 Urbaine      SO2
# 54  FR44ZAG02        ZAG METZ   FR01020                 Urbaine      NO2
# 55  FR44ZAG02        ZAG METZ   FR01021             Périurbaine       O3
# 56  FR44ZAG02        ZAG METZ   FR01019                 Urbaine     PM10
# 57  FR44ZRE01    ZR GRAND-EST   FR14031                 Urbaine      NO2
# 58  FR44ZRE01    ZR GRAND-EST   FR16067                 Urbaine      SO2
# 59  FR44ZRE01    ZR GRAND-EST   FR16031        Rurale régionale       O3
#
#    type d'influence Réglementaire  ... valeur valeur brute  unité de mesure  \
# 0      Industrielle           Oui  ...   24.2    24.200000            µg-m3
# 1              Fond           Oui  ...   59.5    59.475000            µg-m3
# 2            Trafic           Oui  ...   45.1    45.125000            µg-m3
# 3              Fond           Oui  ...   52.0    52.170833            µg-m3
# 4              Fond           Oui  ...   59.6    59.600000            µg-m3
# 5              Fond           Oui  ...   56.5    56.450000            µg-m3
# 6              Fond           Oui  ...   62.2    62.225000            µg-m3
# 7      Industrielle           Oui  ...   49.7    49.675000            µg-m3
# 8              Fond           Oui  ...   20.0    20.179167            µg-m3
# 9              Fond           Oui  ...   55.7    55.675000            µg-m3
# 10           Trafic           Oui  ...   14.0    13.666667            µg-m3
# 11             Fond           Oui  ...   73.7    73.700000            µg-m3
# 12     Industrielle           Oui  ...   14.0    14.200000            µg-m3
# 13             Fond           Oui  ...   60.5    60.500000            µg-m3
# 14             Fond           Oui  ...   16.0    15.858333            µg-m3
# 15     Industrielle           Oui  ...   18.0    17.862500            µg-m3
# 16     Industrielle           Oui  ...   12.0    11.516667            µg-m3
# 17             Fond           Oui  ...   13.0    12.654167            µg-m3
# 18     Industrielle           Oui  ...   24.0    23.579167            µg-m3
# 19           Trafic           Oui  ...   14.1    14.100000            µg-m3
# 20             Fond           Oui  ...   11.0    11.158333            µg-m3
# 21             Fond           Oui  ...   61.9    61.875000            µg-m3
# 22             Fond           Oui  ...   11.0    11.212500            µg-m3
# 23           Trafic           Oui  ...   11.0    11.210526            µg-m3
# 24           Trafic           Oui  ...   45.5    45.500000            µg-m3
# 25             Fond           Oui  ...   12.0    11.975000            µg-m3
# 26             Fond           Oui  ...   58.9    58.900000            µg-m3
# 27             Fond           Oui  ...   64.9    64.850000            µg-m3
# 28             Fond           Oui  ...   21.0    21.075000            µg-m3
# 29             Fond           Oui  ...   25.0    25.379167            µg-m3
# 30           Trafic           Oui  ...  102.1   102.100000            µg-m3
# 31             Fond           Oui  ...   65.7    65.700000            µg-m3
# 32             Fond           Oui  ...   62.3    62.300000            µg-m3
# 33           Trafic           Oui  ...    9.8     9.762500            µg-m3
# 34     Industrielle           Oui  ...   21.0    21.270833            µg-m3
# 35             Fond           Oui  ...   60.0    59.975000            µg-m3
# 36             Fond           Oui  ...   19.0    19.339130            µg-m3
# 37             Fond           Oui  ...   55.5    55.525000            µg-m3
# 38           Trafic           Oui  ...   14.0    14.329167            µg/m3
# 39             Fond           Oui  ...   16.0    16.308333            µg-m3
# 40             Fond           Oui  ...   54.9    54.925000            µg-m3
# 41             Fond           Oui  ...   12.0    11.575000            µg-m3
# 42             Fond           Oui  ...   77.5    77.450000            µg-m3
# 43             Fond           Oui  ...   73.1    73.125000            µg-m3
# 44             Fond           Oui  ...    6.5     6.450000            µg-m3
# 45             Fond           Oui  ...   65.4    65.400000            µg-m3
# 46             Fond           Oui  ...   67.6    67.600000            µg-m3
# 47           Trafic           Oui  ...   87.9    87.925000            µg-m3
# 48           Trafic           Oui  ...   95.8    95.775000            µg-m3
# 49           Trafic           Oui  ...   94.6    94.575000            µg-m3
# 50             Fond           Oui  ...   23.0    23.141667            µg-m3
# 51             Fond           Oui  ...   23.0    22.737500            µg-m3
# 52             Fond           Oui  ...   49.1    49.100000            µg-m3
# 53     Industrielle           Oui  ...    1.6     1.550000            µg-m3
# 54             Fond           Oui  ...   40.1    40.125000            µg-m3
# 55             Fond           Oui  ...   68.4    68.375000            µg-m3
# 56             Fond           Oui  ...   14.0    13.545833            µg-m3
# 57             Fond           Oui  ...    8.6     8.600000            µg-m3
# 58             Fond           Oui  ...    1.6     1.625000            µg-m3
# 59             Fond           Oui  ...   67.8    67.800000            µg-m3
#
#     taux de saisie couverture temporelle  couverture de données  code qualité  \
# 0            100.0                   100                  100.0             A
# 1            100.0                   100                  100.0             R
# 2            100.0                   100                  100.0             A
# 3            100.0                   100                  100.0             A
# 4            100.0                   100                  100.0             R
# 5            100.0                   100                  100.0             R
# 6            100.0                   100                  100.0             A
# 7            100.0                   100                  100.0             A
# 8            100.0                   100                  100.0             A
# 9             96.0                   100                   96.0             A
# 10           100.0                   100                  100.0             A
# 11           100.0                   100                  100.0             A
# 12           100.0                   100                  100.0             A
# 13           100.0                   100                  100.0             A
# 14           100.0                   100                  100.0             A
# 15           100.0                   100                  100.0             A
# 16           100.0                   100                  100.0             A
# 17           100.0                   100                  100.0             A
# 18           100.0                   100                  100.0             A
# 19           100.0                   100                  100.0             A
# 20           100.0                   100                  100.0             A
# 21            96.0                   100                   96.0             A
# 22           100.0                   100                  100.0             A
# 23            79.0                   100                   79.0             R
# 24           100.0                   100                  100.0             A
# 25           100.0                   100                  100.0             A
# 26           100.0                   100                  100.0             A
# 27           100.0                   100                  100.0             A
# 28           100.0                   100                  100.0             A
# 29           100.0                   100                  100.0             A
# 30           100.0                   100                  100.0             A
# 31           100.0                   100                  100.0             A
# 32           100.0                   100                  100.0             R
# 33           100.0                   100                  100.0             A
# 34           100.0                   100                  100.0             A
# 35           100.0                   100                  100.0             A
# 36            96.0                   100                   96.0             A
# 37           100.0                   100                  100.0             A
# 38           100.0                   100                  100.0             A
# 39           100.0                   100                  100.0             A
# 40           100.0                   100                  100.0             R
# 41           100.0                   100                  100.0             A
# 42           100.0                   100                  100.0             A
# 43           100.0                   100                  100.0             A
# 44           100.0                   100                  100.0             A
# 45           100.0                   100                  100.0             A
# 46            96.0                   100                   96.0             A
# 47           100.0                   100                  100.0             A
# 48           100.0                   100                  100.0             A
# 49           100.0                   100                  100.0             A
# 50           100.0                   100                  100.0             A
# 51           100.0                   100                  100.0             A
# 52           100.0                   100                  100.0             A
# 53           100.0                   100                  100.0             R
# 54           100.0                   100                  100.0             A
# 55            54.0                   100                   54.0             N
# 56           100.0                   100                  100.0             A
# 57           100.0                   100                  100.0             A
# 58           100.0                   100                  100.0             R
# 59           100.0                   100                  100.0             A
#
#     validité   Latitude  Longitude
# 0          1  48.886387   6.093611
# 1          1  49.282220   4.051111
# 2          1  49.167780   5.387461
# 3          1  47.594913   7.568175
# 4          1  48.962223   4.360000
# 5          1  49.745277   4.719167
# 6          1  48.726600   4.594781
# 7          1  47.820248   7.538683
# 8          1  48.074642   7.350667
# 9          1  48.065414   7.333139
# 10         1  49.250732   4.023064
# 11         1  48.492992   7.129800
# 12         1  49.165726   6.716886
# 13         1  48.172780   6.452811
# 14         1  48.621502   6.194922
# 15         1  48.565445   6.129578
# 16         1  49.337400   6.082070
# 17         1  48.818352   7.786409
# 18         1  48.694725   6.965275
# 19         1  48.685856   6.175111
# 20         1  49.224167   4.020556
# 21         1  49.065830   5.785556
# 22         1  48.301666   4.076944
# 23         1  48.584824   6.483900
# 24         1  49.125080   6.181219
# 25         1  49.110283   6.223336
# 26         1  49.119442   6.180833
# 27         1  47.723106   7.341603
# 28         1  47.757435   7.347294
# 29         1  47.737415   7.309075
# 30         1  47.747684   7.321364
# 31         1  48.656944   6.136022
# 32         1  48.688170   6.190431
# 33         1  48.697080   6.154194
# 34         1  48.614914   6.107672
# 35         1  48.919357   8.158458
# 36         1  48.915000   6.058336
# 37         1  49.907780   4.630000
# 38         1  49.046100   3.955911
# 39         1  49.220364   6.925833
# 40         1  48.299168   4.117222
# 41         1  48.295002   4.050278
# 42         1  48.051117   7.011114
# 43         1  49.107502   6.122775
# 44         1  49.195390   6.957444
# 45         1  48.645836   4.966111
# 46         1  49.187420   6.910867
# 47         1  48.575985   7.727478
# 48         1  48.588056   7.729722
# 49         1  48.590430   7.744983
# 50         1  48.572808   7.767833
# 51         1  48.610363   7.781631
# 52         1  48.515700   7.687819
# 53         1  47.810932   7.105553
# 54         1  49.358337   6.156942
# 55        -1  49.394444   6.201392
# 56         1  49.368610   6.160831
# 57         1  48.301666   4.076944
# 58         1  47.802210   7.122844
# 59         1  48.857310   7.314175
#
# [60 rows x 22 columns]

# %%
# Downloading the final indicator of ATMO GRAND EST to csv
ratio_counts_greater_than_3_df.to_csv('indicator_ATMO_GRAND_EST.csv', index=False, encoding = 'latin1')

# %%
# -----------------------------------------------------------------------------------------------------------------------------------------------------
#                                                               Sanity Checks
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %%
print(df_PM25['valeur'].head())
# Out:
# 0    5.2
# 1    5.6
# 2    7.0
# 3    6.2
# 4    5.2
# Name: valeur, dtype: float64

# %%
df_PM25['ATMO sub-score'].describe()
# Out:
# count    6851.000000
# mean        1.265655
# std         0.576993
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         4.000000
# Name: ATMO sub-score, dtype: float64

# %%
print(df_PM25['valeur'].head())
# Out:
# 0    5.2
# 1    5.6
# 2    7.0
# 3    6.2
# 4    5.2
# Name: valeur, dtype: float64
