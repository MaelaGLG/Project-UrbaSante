# %%
# Code for extracting the daily ATMO score for each station in ATMO NORMANDIE (Région: NORMANDIE)

# %%
# Installing required packages
import pandas as pd

import os

# Base directory path
base_path = ".\data\raw\Données de la qualité de l'air (Indicateurs SOMO35 et ATMO)\"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11068\2375524138.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# PM10 ATMO NORMANDIE

# File path to the data
PM10_ATMO_NORMANDIE_file_path = os.path.join(base_path, "PM10 Moyenne Journalière\Export Moy. journalière - PM10 - ATMO NORMANDIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM10 = pd.read_csv(PM10_ATMO_NORMANDIE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM10.head())

# Sample ATMO subscore dictionary for PM10 (Moyenne journalière)
ATMO_subscore_PM10 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 20.0), (20.0, 40.0), (40.0, 50.0), (50.0, 100.0), (100.0, 150.0), (150.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM10 = pd.DataFrame(ATMO_subscore_PM10)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM10['Range'] = ATMO_subscore_df_PM10['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM10 measurement
def assign_subscore_PM10(valeur):
    for index, row in ATMO_subscore_df_PM10.iterrows():  
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM10['ATMO sub-score'] = df_PM10['valeur'].apply(assign_subscore_PM10)  

# Display the updated DataFrame
print(df_PM10.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
#
#             Zas code site                   nom site type d'implantation  \
# 0  ZR NORMANDIE   FR05040         Honfleur Sce Tech.             Urbaine
# 1  ZAR LE-HAVRE   FR05074       Le Havre Ec. Herriot             Urbaine
# 2  ZAR LE-HAVRE   FR05083       Gonfreville l Orcher             Urbaine
# 3  ZAR LE-HAVRE   FR05084       NDGravenchon Pasteur             Urbaine
# 4  ZAR LE-HAVRE   FR05089  Le Havre Lafaurie-montant             Urbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0     PM10             Fond  ...   12.0    11.650000           µg-m3
# 1     PM10             Fond  ...   14.0    13.975000           µg-m3
# 2     PM10     Industrielle  ...   10.0     9.829167           µg-m3
# 3     PM10     Industrielle  ...   13.0    12.741667           µg-m3
# 4     PM10           Trafic  ...   15.0    14.987500           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             A
# 1           100.0                    100                 100.0             A
# 2           100.0                    100                 100.0             A
# 3           100.0                    100                 100.0             A
# 4           100.0                    100                 100.0             A
#
#    validité   Latitude Longitude
# 0         1  49.415108  0.243700
# 1         1  49.489630  0.100703
# 2         1  49.502730  0.232486
# 3         1  49.493332  0.571853
# 4         1  49.500187  0.110903
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
#
#             Zas code site                   nom site type d'implantation  \
# 0  ZR NORMANDIE   FR05040         Honfleur Sce Tech.             Urbaine
# 1  ZAR LE-HAVRE   FR05074       Le Havre Ec. Herriot             Urbaine
# 2  ZAR LE-HAVRE   FR05083       Gonfreville l Orcher             Urbaine
# 3  ZAR LE-HAVRE   FR05084       NDGravenchon Pasteur             Urbaine
# 4  ZAR LE-HAVRE   FR05089  Le Havre Lafaurie-montant             Urbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0     PM10             Fond  ...    11.650000           µg-m3          100.0
# 1     PM10             Fond  ...    13.975000           µg-m3          100.0
# 2     PM10     Industrielle  ...     9.829167           µg-m3          100.0
# 3     PM10     Industrielle  ...    12.741667           µg-m3          100.0
# 4     PM10           Trafic  ...    14.987500           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  49.415108   0.243700              1
# 1  49.489630   0.100703              1
# 2  49.502730   0.232486              1
# 3  49.493332   0.571853              1
# 4  49.500187   0.110903              1
#
# [5 rows x 24 columns]

# %%
# PM2.5 ATMO NORMANDIE

# File path to the data
PM25_ATMO_NORMANDIE_file_path = os.path.join(base_path, "PM2.5 Moyenne Journalière\Export Moy. journalière - PM2.5 - ATMO NORMANDIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM25 = pd.read_csv(PM25_ATMO_NORMANDIE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM25.head())

# Sample ATMO subscore dictionary for PM2.5 (Moyenne journalière)
ATMO_subscore_PM25 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 10.0), (10.0, 20.0), (20.0, 25.0), (25.0, 50.0), (50.0, 75.0), (75.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM25 = pd.DataFrame(ATMO_subscore_PM25)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM25['Range'] = ATMO_subscore_df_PM25['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM2.5 measurement
def assign_subscore_PM25(valeur):
    for index, row in ATMO_subscore_df_PM25.iterrows(): 
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM25['ATMO sub-score'] = df_PM25['valeur'].apply(assign_subscore_PM25)  

# Display the updated DataFrame
print(df_PM25.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
#
#             Zas code site                   nom site type d'implantation  \
# 0  ZAR LE-HAVRE   FR05089  Le Havre Lafaurie-montant             Urbaine
# 1  ZAR LE-HAVRE   FR05090       Le Havre ville-haute             Urbaine
# 2      ZAR CAEN   FR21001           Caen Chemin-Vert             Urbaine
# 3  ZR NORMANDIE   FR21021                    Lisieux             Urbaine
# 4  ZR NORMANDIE   FR21031       Alençon Météo-France         Périurbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0    PM2.5           Trafic  ...    5.9     5.941667           µg-m3
# 1    PM2.5             Fond  ...    8.4     8.366667           µg-m3
# 2    PM2.5             Fond  ...    6.5     6.520833           µg-m3
# 3    PM2.5             Fond  ...    7.0     7.045833           µg-m3
# 4    PM2.5             Fond  ...    7.5     7.466667           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             A
# 1           100.0                    100                 100.0             A
# 2           100.0                    100                 100.0             A
# 3           100.0                    100                 100.0             A
# 4           100.0                    100                 100.0             A
#
#    validité   Latitude Longitude
# 0         1  49.500187  0.110903
# 1         1  49.514686  0.100645
# 2         1  49.192220 -0.391111
# 3         1  49.147224  0.227222
# 4         1  48.445553  0.110833
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
#
#             Zas code site                   nom site type d'implantation  \
# 0  ZAR LE-HAVRE   FR05089  Le Havre Lafaurie-montant             Urbaine
# 1  ZAR LE-HAVRE   FR05090       Le Havre ville-haute             Urbaine
# 2      ZAR CAEN   FR21001           Caen Chemin-Vert             Urbaine
# 3  ZR NORMANDIE   FR21021                    Lisieux             Urbaine
# 4  ZR NORMANDIE   FR21031       Alençon Météo-France         Périurbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0    PM2.5           Trafic  ...     5.941667           µg-m3          100.0
# 1    PM2.5             Fond  ...     8.366667           µg-m3          100.0
# 2    PM2.5             Fond  ...     6.520833           µg-m3          100.0
# 3    PM2.5             Fond  ...     7.045833           µg-m3          100.0
# 4    PM2.5             Fond  ...     7.466667           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  49.500187   0.110903            1.0
# 1  49.514686   0.100645            1.0
# 2  49.192220  -0.391111            1.0
# 3  49.147224   0.227222            1.0
# 4  48.445553   0.110833            1.0
#
# [5 rows x 24 columns]

# %%
# NO2 ATMO NORMANDIE

# File path to the data
NO2_ATMO_NORMANDIE_file_path = os.path.join(base_path, "NO2 Max Horaire Journalier\Export Max. journalier moy. hor. - NO2 - ATMO NORMANDIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_NO2 = pd.read_csv(NO2_ATMO_NORMANDIE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_NO2.head())

# Sample ATMO subscore dictionary for NO2 (Max horaire journalier)
ATMO_subscore_NO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 40.0), (40.0, 90.0), (90.0, 120.0), (120.0, 230.0), (230.0, 340.0), (340.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_NO2 = pd.DataFrame(ATMO_subscore_NO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_NO2['Range'] = ATMO_subscore_df_NO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of NO2 measurement
def assign_subscore_NO2(valeur):
    for index, row in ATMO_subscore_df_NO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_NO2['ATMO sub-score'] = df_NO2['valeur'].apply(assign_subscore_NO2)

# Display the updated DataFrame
print(df_NO2.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
#
#             Zas code site                   nom site type d'implantation  \
# 0  ZAR LE-HAVRE   FR05078         Le Havre Massillon             Urbaine
# 1  ZAR LE-HAVRE   FR05083       Gonfreville l Orcher             Urbaine
# 2  ZAR LE-HAVRE   FR05084       NDGravenchon Pasteur             Urbaine
# 3  ZAR LE-HAVRE   FR05089  Le Havre Lafaurie-montant             Urbaine
# 4  ZAR LE-HAVRE   FR05090       Le Havre ville-haute             Urbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0      NO2             Fond  ...   24.3       24.300           µg-m3
# 1      NO2     Industrielle  ...   16.4       16.425           µg-m3
# 2      NO2     Industrielle  ...   39.0       39.025           µg-m3
# 3      NO2           Trafic  ...   25.6       25.625           µg-m3
# 4      NO2             Fond  ...   21.6       21.625           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             R
# 1           100.0                    100                 100.0             R
# 2           100.0                    100                 100.0             R
# 3           100.0                    100                 100.0             R
# 4           100.0                    100                 100.0             R
#
#    validité   Latitude Longitude
# 0         1  49.498300  0.142706
# 1         1  49.502730  0.232486
# 2         1  49.493332  0.571853
# 3         1  49.500187  0.110903
# 4         1  49.514686  0.100645
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
#
#             Zas code site                   nom site type d'implantation  \
# 0  ZAR LE-HAVRE   FR05078         Le Havre Massillon             Urbaine
# 1  ZAR LE-HAVRE   FR05083       Gonfreville l Orcher             Urbaine
# 2  ZAR LE-HAVRE   FR05084       NDGravenchon Pasteur             Urbaine
# 3  ZAR LE-HAVRE   FR05089  Le Havre Lafaurie-montant             Urbaine
# 4  ZAR LE-HAVRE   FR05090       Le Havre ville-haute             Urbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0      NO2             Fond  ...       24.300           µg-m3          100.0
# 1      NO2     Industrielle  ...       16.425           µg-m3          100.0
# 2      NO2     Industrielle  ...       39.025           µg-m3          100.0
# 3      NO2           Trafic  ...       25.625           µg-m3          100.0
# 4      NO2             Fond  ...       21.625           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            R         1
# 1                    100                  100.0            R         1
# 2                    100                  100.0            R         1
# 3                    100                  100.0            R         1
# 4                    100                  100.0            R         1
#
#     Latitude  Longitude ATMO sub-score
# 0  49.498300   0.142706              1
# 1  49.502730   0.232486              1
# 2  49.493332   0.571853              1
# 3  49.500187   0.110903              1
# 4  49.514686   0.100645              1
#
# [5 rows x 24 columns]

# %%
# O3 ATMO NORMANDIE

# File path to the data
O3_ATMO_NORMANDIE_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - ATMO NORMANDIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_ATMO_NORMANDIE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Sample ATMO subscore dictionary for O3 (Max horaire journalier)
ATMO_subscore_O3 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 50.0), (50.0, 100.0), (100.0, 130.0), (130.0, 240.0), (240.0, 380.0), (380.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_O3 = pd.DataFrame(ATMO_subscore_O3)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_O3['Range'] = ATMO_subscore_df_O3['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of O3 measurement
def assign_subscore_O3(valeur):
    for index, row in ATMO_subscore_df_O3.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_O3['ATMO sub-score'] = df_O3['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
#
#             Zas code site              nom site type d'implantation Polluant  \
# 0  ZAR LE-HAVRE   FR05010  St Romain de Colbosc         Périurbaine       O3
# 1  ZR NORMANDIE   FR05040    Honfleur Sce Tech.             Urbaine       O3
# 2  ZAR LE-HAVRE   FR05074  Le Havre Ec. Herriot             Urbaine       O3
# 3  ZR NORMANDIE   FR05082               Touques         Périurbaine       O3
# 4  ZR NORMANDIE   FR05088                Fécamp         Périurbaine       O3
#
#   type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0             Fond  ...   74.7       74.675           µg-m3           100.0
# 1             Fond  ...   75.0       75.000           µg-m3           100.0
# 2             Fond  ...   80.9       80.850           µg-m3           100.0
# 3             Fond  ...   70.5       70.450           µg-m3           100.0
# 4             Fond  ...   81.5       81.500           µg-m3           100.0
#
#    couverture temporelle couverture de données  code qualité  validité  \
# 0                    100                 100.0             A         1
# 1                    100                 100.0             A         1
# 2                    100                 100.0             A         1
# 3                    100                 100.0             A         1
# 4                    100                 100.0             A         1
#
#     Latitude Longitude
# 0  49.528927  0.358733
# 1  49.415108  0.243700
# 2  49.489630  0.100703
# 3  49.348000  0.109253
# 4  49.750000  0.415900
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
#
#             Zas code site              nom site type d'implantation Polluant  \
# 0  ZAR LE-HAVRE   FR05010  St Romain de Colbosc         Périurbaine       O3
# 1  ZR NORMANDIE   FR05040    Honfleur Sce Tech.             Urbaine       O3
# 2  ZAR LE-HAVRE   FR05074  Le Havre Ec. Herriot             Urbaine       O3
# 3  ZR NORMANDIE   FR05082               Touques         Périurbaine       O3
# 4  ZR NORMANDIE   FR05088                Fécamp         Périurbaine       O3
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0             Fond  ...       74.675           µg-m3          100.0
# 1             Fond  ...       75.000           µg-m3          100.0
# 2             Fond  ...       80.850           µg-m3          100.0
# 3             Fond  ...       70.450           µg-m3          100.0
# 4             Fond  ...       81.500           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  49.528927   0.358733              2
# 1  49.415108   0.243700              2
# 2  49.489630   0.100703              2
# 3  49.348000   0.109253              2
# 4  49.750000   0.415900              2
#
# [5 rows x 24 columns]

# %%
# SO2 ATMO NORMANDIE

# File path to the data
SO2_ATMO_NORMANDIE_file_path = os.path.join(base_path, "SO2 Max Horaire Journalier\Export Max. journalier moy. hor. - SO2 - ATMO NORMANDIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_SO2 = pd.read_csv(SO2_ATMO_NORMANDIE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_SO2.head())

# Sample ATMO subscore dictionary for SO2 (Max horaire journalier)
ATMO_subscore_SO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 100.0), (100.0, 200.0), (200.0, 350.0), (350.0, 500.0), (500.0, 750.0), (750.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_SO2 = pd.DataFrame(ATMO_subscore_SO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_SO2['Range'] = ATMO_subscore_df_SO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of SO2 measurement
def assign_subscore_SO2(valeur):
    for index, row in ATMO_subscore_df_SO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_SO2['ATMO sub-score'] = df_SO2['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_SO2.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
#
#             Zas code site              nom site     type d'implantation  \
# 0  ZAR LE-HAVRE   FR05010  St Romain de Colbosc             Périurbaine
# 1  ZAR LE-HAVRE   FR05037         Caucriauville                 Urbaine
# 2  ZR NORMANDIE   FR05040    Honfleur Sce Tech.                 Urbaine
# 3  ZAR LE-HAVRE   FR05056      Quillebeuf Phare  Rurale près des villes
# 4  ZAR LE-HAVRE   FR05069    Tancarville Mairie  Rurale près des villes
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0      SO2             Fond  ...    1.3        1.325           µg-m3
# 1      SO2             Fond  ...    0.8        0.775           µg-m3
# 2      SO2             Fond  ...    0.1        0.125           µg-m3
# 3      SO2     Industrielle  ...    1.8        1.775           µg-m3
# 4      SO2     Industrielle  ...    1.4        1.400           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             A
# 1           100.0                    100                 100.0             R
# 2           100.0                    100                 100.0             A
# 3           100.0                    100                 100.0             A
# 4           100.0                    100                 100.0             A
#
#    validité   Latitude Longitude
# 0         1  49.528927  0.358733
# 1         1  49.503906  0.175731
# 2         1  49.415108  0.243700
# 3         1  49.473720  0.526158
# 4         1  49.487682  0.451756
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
#
#             Zas code site              nom site     type d'implantation  \
# 0  ZAR LE-HAVRE   FR05010  St Romain de Colbosc             Périurbaine
# 1  ZAR LE-HAVRE   FR05037         Caucriauville                 Urbaine
# 2  ZR NORMANDIE   FR05040    Honfleur Sce Tech.                 Urbaine
# 3  ZAR LE-HAVRE   FR05056      Quillebeuf Phare  Rurale près des villes
# 4  ZAR LE-HAVRE   FR05069    Tancarville Mairie  Rurale près des villes
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0      SO2             Fond  ...        1.325           µg-m3          100.0
# 1      SO2             Fond  ...        0.775           µg-m3          100.0
# 2      SO2             Fond  ...        0.125           µg-m3          100.0
# 3      SO2     Industrielle  ...        1.775           µg-m3          100.0
# 4      SO2     Industrielle  ...        1.400           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            R         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  49.528927   0.358733            1.0
# 1  49.503906   0.175731            1.0
# 2  49.415108   0.243700            1.0
# 3  49.473720   0.526158            1.0
# 4  49.487682   0.451756            1.0
#
# [5 rows x 24 columns]

# %%
# Combining 5 (if not missing) dataframes
# Concatenate DataFrames along the rows (stack them vertically)
combined_df_ATMO_NORMANDIE = pd.concat([df_PM10, df_PM25, df_NO2, df_O3, df_SO2], axis=0) #

# If you want to reset the index of the combined DataFrame
combined_df_ATMO_NORMANDIE.reset_index(drop=True, inplace=True)

# Renaming the ATMO subscore column to 'ATMO Score'
combined_df_ATMO_NORMANDIE = combined_df_ATMO_NORMANDIE.rename(columns={'ATMO sub-score': 'ATMO Score'})

# Printing the first five rows as a sanity check
print(combined_df_ATMO_NORMANDIE.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZAR01
#
#             Zas code site                   nom site type d'implantation  \
# 0  ZR NORMANDIE   FR05040         Honfleur Sce Tech.             Urbaine
# 1  ZAR LE-HAVRE   FR05074       Le Havre Ec. Herriot             Urbaine
# 2  ZAR LE-HAVRE   FR05083       Gonfreville l Orcher             Urbaine
# 3  ZAR LE-HAVRE   FR05084       NDGravenchon Pasteur             Urbaine
# 4  ZAR LE-HAVRE   FR05089  Le Havre Lafaurie-montant             Urbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0     PM10             Fond  ...    11.650000           µg-m3          100.0
# 1     PM10             Fond  ...    13.975000           µg-m3          100.0
# 2     PM10     Industrielle  ...     9.829167           µg-m3          100.0
# 3     PM10     Industrielle  ...    12.741667           µg-m3          100.0
# 4     PM10           Trafic  ...    14.987500           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO Score
# 0  49.415108   0.243700        1.0
# 1  49.489630   0.100703        1.0
# 2  49.502730   0.232486        1.0
# 3  49.493332   0.571853        1.0
# 4  49.500187   0.110903        1.0
#
# [5 rows x 24 columns]

# %%
# Find the index of rows with maximum 'ATMO Score' within each group
idx_max_scores = combined_df_ATMO_NORMANDIE.groupby(['nom site', 'Date de fin'])['ATMO Score'].idxmax()

# Select rows with the maximum 'ATMO Score' using the index
final_df_ATMO_NORMANDIE = combined_df_ATMO_NORMANDIE.loc[idx_max_scores]

# Reset index if needed
final_df_ATMO_NORMANDIE.reset_index(drop=True, inplace=True)

# %%
# Downloading the final dataframe of Daily ATMO Score in ATMO NORMANDIE to csv
final_df_ATMO_NORMANDIE.to_csv('final_df_ATMO_NORMANDIE.csv', index=False, encoding = 'latin1')

# %%
# Constructing indicator for ATMO NORMANDIE

# File path to the data
ATMO_NORMANDIE_file_path = os.path.join(base_path, "final_df_ATMO_NORMANDIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_ATMO = pd.read_csv(ATMO_NORMANDIE_file_path, delimiter=',', encoding = 'latin1')

print(df_ATMO.head())

counts = df_ATMO.groupby('nom site')['ATMO Score'].value_counts().reset_index(name='counts')
#print(counts)

#result = pd.merge(counts, df_ATMO[["Organisme", "type d'implantation", "Latitude", "Longitude"]], on='nom site', how='left')
#print(result)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_ATMO.groupby('nom site').first().reset_index()
#print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(counts, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score_y'], axis = 1)
print(result)
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 1  2023/01/02 00:00:00  2023/01/02 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 2  2023/01/03 00:00:00  2023/01/03 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 3  2023/01/04 00:00:00  2023/01/04 23:59:59  ATMO NORMANDIE  FR28ZRE02
# 4  2023/01/05 00:00:00  2023/01/05 23:59:59  ATMO NORMANDIE  FR28ZRE02
#
#             Zas code site              nom site type d'implantation Polluant  \
# 0  ZR NORMANDIE   FR21031  Alençon Météo-France         Périurbaine       O3
# 1  ZR NORMANDIE   FR21031  Alençon Météo-France         Périurbaine      NO2
# 2  ZR NORMANDIE   FR21031  Alençon Météo-France         Périurbaine       O3
# 3  ZR NORMANDIE   FR21031  Alençon Météo-France         Périurbaine       O3
# 4  ZR NORMANDIE   FR21031  Alençon Météo-France         Périurbaine       O3
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0             Fond  ...       73.300           µg-m3          100.0
# 1             Fond  ...       47.650           µg-m3          100.0
# 2             Fond  ...       72.525           µg-m3          100.0
# 3             Fond  ...       74.025           µg-m3          100.0
# 4             Fond  ...       69.575           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            R         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO Score
# 0  48.445553   0.110833        2.0
# 1  48.445553   0.110833        2.0
# 2  48.445553   0.110833        2.0
# 3  48.445553   0.110833        2.0
# 4  48.445553   0.110833        2.0
#
# [5 rows x 24 columns]
#                  nom site  ATMO Score_x  counts       Organisme   code zas  \
# 0    Alençon Météo-France           2.0     301  ATMO NORMANDIE  FR28ZRE02
# 1    Alençon Météo-France           3.0      42  ATMO NORMANDIE  FR28ZRE02
# 2    Alençon Météo-France           4.0      19  ATMO NORMANDIE  FR28ZRE02
# 3    Alençon Météo-France           1.0       3  ATMO NORMANDIE  FR28ZRE02
# 4      Base loisirs Poses           2.0     286  ATMO NORMANDIE  FR28ZRE02
# ..                    ...           ...     ...             ...        ...
# 153    Tancarville Mairie           3.0       2  ATMO NORMANDIE  FR28ZAR01
# 154               Touques           2.0     317  ATMO NORMANDIE  FR28ZRE02
# 155               Touques           3.0      30  ATMO NORMANDIE  FR28ZRE02
# 156               Touques           1.0      13  ATMO NORMANDIE  FR28ZRE02
# 157               Touques           4.0       5  ATMO NORMANDIE  FR28ZRE02
#
#               Zas code site     type d'implantation Polluant type d'influence  \
# 0    ZR NORMANDIE   FR21031             Périurbaine       O3             Fond
# 1    ZR NORMANDIE   FR21031             Périurbaine       O3             Fond
# 2    ZR NORMANDIE   FR21031             Périurbaine       O3             Fond
# 3    ZR NORMANDIE   FR21031             Périurbaine       O3             Fond
# 4    ZR NORMANDIE   FR25049  Rurale près des villes       O3             Fond
# ..            ...       ...                     ...      ...              ...
# 153  ZAR LE-HAVRE   FR05069  Rurale près des villes      SO2     Industrielle
# 154  ZR NORMANDIE   FR05082             Périurbaine       O3             Fond
# 155  ZR NORMANDIE   FR05082             Périurbaine       O3             Fond
# 156  ZR NORMANDIE   FR05082             Périurbaine       O3             Fond
# 157  ZR NORMANDIE   FR05082             Périurbaine       O3             Fond
#
#      ... valeur valeur brute unité de mesure  taux de saisie  \
# 0    ...   73.3        73.30           µg-m3           100.0
# 1    ...   73.3        73.30           µg-m3           100.0
# 2    ...   73.3        73.30           µg-m3           100.0
# 3    ...   73.3        73.30           µg-m3           100.0
# 4    ...   72.6        72.55           µg-m3           100.0
# ..   ...    ...          ...             ...             ...
# 153  ...    1.4         1.40           µg-m3           100.0
# 154  ...   70.5        70.45           µg-m3           100.0
# 155  ...   70.5        70.45           µg-m3           100.0
# 156  ...   70.5        70.45           µg-m3           100.0
# 157  ...   70.5        70.45           µg-m3           100.0
#
#      couverture temporelle couverture de données  code qualité  validité  \
# 0                      100                 100.0             A         1
# 1                      100                 100.0             A         1
# 2                      100                 100.0             A         1
# 3                      100                 100.0             A         1
# 4                      100                 100.0             R         1
# ..                     ...                   ...           ...       ...
# 153                    100                 100.0             A         1
# 154                    100                 100.0             A         1
# 155                    100                 100.0             A         1
# 156                    100                 100.0             A         1
# 157                    100                 100.0             A         1
#
#       Latitude Longitude
# 0    48.445553  0.110833
# 1    48.445553  0.110833
# 2    48.445553  0.110833
# 3    48.445553  0.110833
# 4    49.304870  1.214367
# ..         ...       ...
# 153  49.487682  0.451756
# 154  49.348000  0.109253
# 155  49.348000  0.109253
# 156  49.348000  0.109253
# 157  49.348000  0.109253
#
# [158 rows x 23 columns]

# %%
# Group the DataFrame by 'nom' and calculate the total counts for each 'nom'
total_counts_by_nom = result.groupby('nom site')['counts'].sum()

# Filter the DataFrame to include only rows where the score is equal to or greater than 3
filtered_result = result[result['ATMO Score_x'] >= 3]

# Group the filtered DataFrame by 'nom' and calculate the counts equal to or greater than 3 for each 'nom'
counts_greater_than_3_by_nom = filtered_result.groupby('nom site')['counts'].sum()

# Calculate the ratio of counts greater than or equal to 3 over total counts for each 'nom'
ratio_counts_greater_than_3 = (counts_greater_than_3_by_nom / total_counts_by_nom).fillna(0)

# Display the resulting Series
print(ratio_counts_greater_than_3)

# Merge the site-specific information with the counts DataFrame
ratio_counts_greater_than_3_df = pd.merge(ratio_counts_greater_than_3, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score'], axis = 1)
ratio_counts_greater_than_3_df = ratio_counts_greater_than_3_df.rename(columns={'counts': 'indicator'})
print(ratio_counts_greater_than_3_df)
# Out:
# nom site
# Alençon Météo-France         0.167123
# Base loisirs Poses           0.170799
# Bures-en-bray                0.090379
# Caen Chemin-Vert             0.117808
# Caen Montalivet              0.057803
# Caen Vaucelles               0.000000
# Caucriauville                0.030137
# Centre Hospitalier           0.150685
# Cherbourg Hotel de Ville     0.101370
# Cherbourg PMF                0.022599
# Dieppe Golf                  0.217270
# Dieppe prox-auto             0.055096
# Espace du Palais             0.168508
# Evreux Centre                0.178082
# Fécamp                       0.108939
# Gd Couronne Mairie           0.010959
# Gonfreville l Orcher         0.027397
# Harfleur Ecole Coty          0.000000
# Honfleur Sce Tech.           0.064677
# IFS Caen sud                 0.139726
# La Cerlangue                 0.000000
# La Coulonche MERA            0.161644
# Le Havre Ec. Herriot         0.131507
# Le Havre Lafaurie-montant    0.068493
# Le Havre Massillon           0.008219
# Le Havre ville-haute         0.175342
# Lillebonne                   0.002865
# Lisieux                      0.147945
# Maison Parc Brotonne         0.230769
# Mesnil Esnard                0.142466
# NDGravenchon Pasteur         0.054795
# Ouistreham                   0.131507
# Petit-Quevilly Sud 3         0.173554
# Quillebeuf Phare             0.022535
# Rogerville Mairie            0.000000
# Rouen Proxi Quai de Paris    0.095890
# Saint-Lô Eglise              0.117808
# Sainte Adresse               0.002755
# St Romain de Colbosc         0.105882
# Tancarville Mairie           0.005618
# Touques                      0.095890
# Name: counts, dtype: float64
#                      nom site  indicator       Organisme   code zas  \
# 0        Alençon Météo-France   0.167123  ATMO NORMANDIE  FR28ZRE02
# 1          Base loisirs Poses   0.170799  ATMO NORMANDIE  FR28ZRE02
# 2               Bures-en-bray   0.090379  ATMO NORMANDIE  FR28ZRE02
# 3            Caen Chemin-Vert   0.117808  ATMO NORMANDIE  FR28ZAR02
# 4            Caen Montalivet    0.057803  ATMO NORMANDIE  FR28ZAR02
# 5              Caen Vaucelles   0.000000  ATMO NORMANDIE  FR28ZAR02
# 6               Caucriauville   0.030137  ATMO NORMANDIE  FR28ZAR01
# 7          Centre Hospitalier   0.150685  ATMO NORMANDIE  FR28ZAG01
# 8    Cherbourg Hotel de Ville   0.101370  ATMO NORMANDIE  FR28ZRE02
# 9               Cherbourg PMF   0.022599  ATMO NORMANDIE  FR28ZRE02
# 10                Dieppe Golf   0.217270  ATMO NORMANDIE  FR28ZRE02
# 11           Dieppe prox-auto   0.055096  ATMO NORMANDIE  FR28ZRE02
# 12           Espace du Palais   0.168508  ATMO NORMANDIE  FR28ZAG01
# 13              Evreux Centre   0.178082  ATMO NORMANDIE  FR28ZRE02
# 14                     Fécamp   0.108939  ATMO NORMANDIE  FR28ZRE02
# 15         Gd Couronne Mairie   0.010959  ATMO NORMANDIE  FR28ZAG01
# 16       Gonfreville l Orcher   0.027397  ATMO NORMANDIE  FR28ZAR01
# 17        Harfleur Ecole Coty   0.000000  ATMO NORMANDIE  FR28ZAR01
# 18         Honfleur Sce Tech.   0.064677  ATMO NORMANDIE  FR28ZRE02
# 19               IFS Caen sud   0.139726  ATMO NORMANDIE  FR28ZAR02
# 20               La Cerlangue   0.000000  ATMO NORMANDIE  FR28ZAR01
# 21          La Coulonche MERA   0.161644  ATMO NORMANDIE  FR28ZRE02
# 22       Le Havre Ec. Herriot   0.131507  ATMO NORMANDIE  FR28ZAR01
# 23  Le Havre Lafaurie-montant   0.068493  ATMO NORMANDIE  FR28ZAR01
# 24         Le Havre Massillon   0.008219  ATMO NORMANDIE  FR28ZAR01
# 25       Le Havre ville-haute   0.175342  ATMO NORMANDIE  FR28ZAR01
# 26                 Lillebonne   0.002865  ATMO NORMANDIE  FR28ZAR01
# 27                    Lisieux   0.147945  ATMO NORMANDIE  FR28ZRE02
# 28       Maison Parc Brotonne   0.230769  ATMO NORMANDIE  FR28ZRE02
# 29              Mesnil Esnard   0.142466  ATMO NORMANDIE  FR28ZAG01
# 30       NDGravenchon Pasteur   0.054795  ATMO NORMANDIE  FR28ZAR01
# 31                 Ouistreham   0.131507  ATMO NORMANDIE  FR28ZAR02
# 32       Petit-Quevilly Sud 3   0.173554  ATMO NORMANDIE  FR28ZAG01
# 33           Quillebeuf Phare   0.022535  ATMO NORMANDIE  FR28ZAR01
# 34          Rogerville Mairie   0.000000  ATMO NORMANDIE  FR28ZAR01
# 35  Rouen Proxi Quai de Paris   0.095890  ATMO NORMANDIE  FR28ZAG01
# 36            Saint-Lô Eglise   0.117808  ATMO NORMANDIE  FR28ZRE02
# 37             Sainte Adresse   0.002755  ATMO NORMANDIE  FR28ZAR01
# 38       St Romain de Colbosc   0.105882  ATMO NORMANDIE  FR28ZAR01
# 39         Tancarville Mairie   0.005618  ATMO NORMANDIE  FR28ZAR01
# 40                    Touques   0.095890  ATMO NORMANDIE  FR28ZRE02
#
#              Zas code site     type d'implantation Polluant type d'influence  \
# 0   ZR NORMANDIE   FR21031             Périurbaine       O3             Fond
# 1   ZR NORMANDIE   FR25049  Rurale près des villes       O3             Fond
# 2   ZR NORMANDIE   FR25050        Rurale régionale       O3             Fond
# 3       ZAR CAEN   FR21001                 Urbaine       O3             Fond
# 4       ZAR CAEN   FR21101                 Urbaine     PM10           Trafic
# 5       ZAR CAEN   FR21016                 Urbaine     PM10           Trafic
# 6   ZAR LE-HAVRE   FR05037                 Urbaine      SO2             Fond
# 7      ZAG ROUEN   FR25043                 Urbaine       O3             Fond
# 8   ZR NORMANDIE   FR21038                 Urbaine       O3             Fond
# 9   ZR NORMANDIE   FR21039                 Urbaine     PM10           Trafic
# 10  ZR NORMANDIE   FR25055             Périurbaine       O3             Fond
# 11  ZR NORMANDIE   FR25051                 Urbaine     PM10           Trafic
# 12     ZAG ROUEN   FR25036                 Urbaine       O3             Fond
# 13  ZR NORMANDIE   FR25039                 Urbaine       O3             Fond
# 14  ZR NORMANDIE   FR05088             Périurbaine       O3             Fond
# 15     ZAG ROUEN   FR25035                 Urbaine     PM10     Industrielle
# 16  ZAR LE-HAVRE   FR05083                 Urbaine     PM10     Industrielle
# 17  ZAR LE-HAVRE   FR05070                 Urbaine      SO2             Fond
# 18  ZR NORMANDIE   FR05040                 Urbaine     PM10             Fond
# 19      ZAR CAEN   FR21019                 Urbaine       O3             Fond
# 20  ZAR LE-HAVRE   FR05081  Rurale près des villes      SO2     Industrielle
# 21  ZR NORMANDIE   FR21050        Rurale nationale       O3             Fond
# 22  ZAR LE-HAVRE   FR05074                 Urbaine       O3             Fond
# 23  ZAR LE-HAVRE   FR05089                 Urbaine     PM10           Trafic
# 24  ZAR LE-HAVRE   FR05078                 Urbaine      NO2             Fond
# 25  ZAR LE-HAVRE   FR05090                 Urbaine       O3             Fond
# 26  ZAR LE-HAVRE   FR05085                 Urbaine      SO2     Industrielle
# 27  ZR NORMANDIE   FR21021                 Urbaine       O3             Fond
# 28  ZR NORMANDIE   FR05087        Rurale régionale    PM2.5             Fond
# 29     ZAG ROUEN   FR25040             Périurbaine       O3             Fond
# 30  ZAR LE-HAVRE   FR05084                 Urbaine      SO2     Industrielle
# 31      ZAR CAEN   FR21017             Périurbaine       O3             Fond
# 32     ZAG ROUEN   FR25054                 Urbaine     PM10           Trafic
# 33  ZAR LE-HAVRE   FR05056  Rurale près des villes      SO2     Industrielle
# 34  ZAR LE-HAVRE   FR05080             Périurbaine      SO2     Industrielle
# 35     ZAG ROUEN   FR25053                 Urbaine      NO2           Trafic
# 36  ZR NORMANDIE   FR21040                 Urbaine       O3             Fond
# 37  ZAR LE-HAVRE   FR05072                 Urbaine      SO2             Fond
# 38  ZAR LE-HAVRE   FR05010             Périurbaine       O3             Fond
# 39  ZAR LE-HAVRE   FR05069  Rurale près des villes      SO2     Industrielle
# 40  ZR NORMANDIE   FR05082             Périurbaine       O3             Fond
#
#    Réglementaire  ... valeur valeur brute  unité de mesure  taux de saisie  \
# 0            Oui  ...   73.3    73.300000            µg-m3           100.0
# 1            Oui  ...   72.6    72.550000            µg-m3           100.0
# 2            Oui  ...   76.6    76.600000            µg-m3           100.0
# 3            Oui  ...   75.0    74.950000            µg-m3           100.0
# 4            Oui  ...    0.0     0.000000            µg-m3             0.0
# 5            Oui  ...    0.0     0.000000            µg-m3             0.0
# 6            Oui  ...    0.8     0.775000            µg-m3           100.0
# 7            Oui  ...   78.3    78.325000            µg-m3           100.0
# 8            Oui  ...   78.2    78.200000            µg-m3           100.0
# 9            Oui  ...    0.0     0.000000            µg-m3             0.0
# 10           Oui  ...   73.8    73.775000            µg-m3           100.0
# 11           Oui  ...   12.0    12.000000            µg-m3           100.0
# 12           Oui  ...   72.7    72.725000            µg-m3            92.0
# 13           Oui  ...   73.0    73.025000            µg-m3           100.0
# 14           Oui  ...   81.5    81.500000            µg-m3           100.0
# 15           Oui  ...   15.0    15.050000            µg-m3           100.0
# 16           Oui  ...   10.0     9.829167            µg-m3           100.0
# 17           Oui  ...   12.4    12.350000            µg-m3           100.0
# 18           Oui  ...   12.0    11.650000            µg-m3           100.0
# 19           Oui  ...   76.4    76.425000            µg-m3           100.0
# 20           Oui  ...    0.4     0.350000            µg-m3           100.0
# 21           Oui  ...   75.2    75.200000            µg-m3           100.0
# 22           Oui  ...   80.9    80.850000            µg-m3           100.0
# 23           Oui  ...   15.0    14.987500            µg-m3           100.0
# 24           Oui  ...   24.3    24.300000            µg-m3           100.0
# 25           Oui  ...   82.3    82.325000            µg-m3           100.0
# 26           Oui  ...   15.7    15.700000            µg-m3           100.0
# 27           Oui  ...   71.5    71.525000            µg-m3           100.0
# 28           Oui  ...   10.0    10.266667            µg-m3            38.0
# 29           Oui  ...   76.6    76.600000            µg-m3           100.0
# 30           Oui  ...   53.7    53.725000            µg-m3           100.0
# 31           Oui  ...   76.5    76.500000            µg-m3           100.0
# 32           Oui  ...   12.0    12.283333            µg-m3           100.0
# 33           Oui  ...    1.8     1.775000            µg-m3           100.0
# 34           Oui  ...    5.0     4.950000            µg-m3           100.0
# 35           Oui  ...   44.9    44.850000            µg-m3           100.0
# 36           Oui  ...   77.4    77.425000            µg-m3           100.0
# 37           Oui  ...    1.9     1.875000            µg-m3           100.0
# 38           Oui  ...   74.7    74.675000            µg-m3           100.0
# 39           Oui  ...    1.4     1.400000            µg-m3           100.0
# 40           Oui  ...   70.5    70.450000            µg-m3           100.0
#
#    couverture temporelle  couverture de données  code qualité  validité  \
# 0                    100                  100.0             A         1
# 1                    100                  100.0             R         1
# 2                    100                  100.0             A         1
# 3                    100                  100.0             A         1
# 4                    100                    0.0             N        -1
# 5                    100                    0.0             N        -1
# 6                    100                  100.0             R         1
# 7                    100                  100.0             R         1
# 8                    100                  100.0             A         1
# 9                    100                    0.0             N        -1
# 10                   100                  100.0             R         1
# 11                   100                  100.0             A         1
# 12                   100                   92.0             R         1
# 13                   100                  100.0             A         1
# 14                   100                  100.0             A         1
# 15                   100                  100.0             A         1
# 16                   100                  100.0             A         1
# 17                   100                  100.0             A         1
# 18                   100                  100.0             A         1
# 19                   100                  100.0             A         1
# 20                   100                  100.0             A         1
# 21                   100                  100.0             A         1
# 22                   100                  100.0             A         1
# 23                   100                  100.0             A         1
# 24                   100                  100.0             R         1
# 25                   100                  100.0             A         1
# 26                   100                  100.0             A         1
# 27                   100                  100.0             A         1
# 28                   100                   38.0             N        -1
# 29                   100                  100.0             A         1
# 30                   100                  100.0             A         1
# 31                   100                  100.0             A         1
# 32                   100                  100.0             A         1
# 33                   100                  100.0             A         1
# 34                   100                  100.0             A         1
# 35                   100                  100.0             R         1
# 36                   100                  100.0             A         1
# 37                   100                  100.0             A         1
# 38                   100                  100.0             A         1
# 39                   100                  100.0             A         1
# 40                   100                  100.0             A         1
#
#      Latitude  Longitude
# 0   48.445553   0.110833
# 1   49.304870   1.214367
# 2   49.781220   1.345083
# 3   49.192220  -0.391111
# 4   49.179833  -0.329750
# 5   49.175278  -0.353611
# 6   49.503906   0.175731
# 7   49.400500   1.099042
# 8   49.642250  -1.624361
# 9   49.633889  -1.624722
# 10  49.920492   1.047892
# 11  49.918007   1.073972
# 12  49.442358   1.093789
# 13  49.021340   1.148319
# 14  49.750000   0.415900
# 15  49.358215   1.007853
# 16  49.502730   0.232486
# 17  49.505000   0.201694
# 18  49.415108   0.243700
# 19  49.151670  -0.352778
# 20  49.504036   0.411594
# 21  48.645000  -0.458333
# 22  49.489630   0.100703
# 23  49.500187   0.110903
# 24  49.498300   0.142706
# 25  49.514686   0.100645
# 26  49.512146   0.539036
# 27  49.147224   0.227222
# 28  49.498295   0.758833
# 29  49.406190   1.155150
# 30  49.493332   0.571853
# 31  49.289444  -0.257778
# 32  49.434164   1.067053
# 33  49.473720   0.526158
# 34  49.503620   0.266872
# 35  49.436699   1.098838
# 36  49.116390  -1.084722
# 37  49.503860   0.084614
# 38  49.528927   0.358733
# 39  49.487682   0.451756
# 40  49.348000   0.109253
#
# [41 rows x 22 columns]

# %%
# Downloading the final indicator of ATMO NORMANDIE to csv
ratio_counts_greater_than_3_df.to_csv('indicator_ATMO_NORMANDIE.csv', index=False, encoding = 'latin1')

# %%
# -----------------------------------------------------------------------------------------------------------------------------------------------------
#                                                               Sanity Checks
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %%
print(df_PM25['valeur'].head())
# Out:
# 0    5.9
# 1    8.4
# 2    6.5
# 3    7.0
# 4    7.5
# Name: valeur, dtype: float64

# %%
df_PM25['ATMO sub-score'].describe()
# Out:
# count    5569.000000
# mean        1.298797
# std         0.615999
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         5.000000
# Name: ATMO sub-score, dtype: float64

# %%
print(df_PM25['valeur'].head())
# Out:
# 0    5.9
# 1    8.4
# 2    6.5
# 3    7.0
# 4    7.5
# Name: valeur, dtype: float64
