# %%
# Code for extracting the annual SOMO35 Score for each station in ATMO OCCITANIE (Région: OCCITANIE)

# %%
# Installing required packages
import pandas as pd

import os

# Base directory path
base_path = ".\data\raw\Données de la qualité de l'air (Indicateurs SOMO35 et ATMO)\"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10584\2375524138.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# O3 ATMO OCCITANIE

# File path to the data
O3_ATMO_OCCITANIE_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - ATMO OCCITANIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_ATMO_OCCITANIE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Apply the function to fill in the Subscore column
df_O3['SOMO35 Subscore'] = df_O3['valeur'].apply(lambda x: max(x - 70, 0))

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
#
#                Zas code site                              nom site  \
# 0  ZAG MONTPELLIER   FR08016             Montpellier Prés d'Arènes
# 1  ZAG MONTPELLIER   FR08017  Montpellier Périurbaine Sud (Lattes)
# 2  ZAG MONTPELLIER   FR08018                   Montpellier St Gely
# 3     ZR OCCITANIE   FR08022                    Agathois-piscénois
# 4     ZR OCCITANIE   FR08023                  Biterrois-Narbonnais
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Urbaine       O3             Fond  ...   84.1       84.050
# 1         Périurbaine       O3             Fond  ...   83.4       83.375
# 2         Périurbaine       O3             Fond  ...   79.7       79.675
# 3         Périurbaine       O3             Fond  ...   90.8       90.800
# 4    Rurale régionale       O3             Fond  ...   80.9       80.900
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3            96.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité  Latitude Longitude
# 0                 100.0             R         1   43.5915   3.88681
# 1                  96.0             R         1   43.5705   3.91180
# 2                 100.0             A         1   43.6926   3.80021
# 3                 100.0             A         1   43.2875   3.50484
# 4                 100.0             R         1   43.4068   3.18878
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
#
#                Zas code site                              nom site  \
# 0  ZAG MONTPELLIER   FR08016             Montpellier Prés d'Arènes
# 1  ZAG MONTPELLIER   FR08017  Montpellier Périurbaine Sud (Lattes)
# 2  ZAG MONTPELLIER   FR08018                   Montpellier St Gely
# 3     ZR OCCITANIE   FR08022                    Agathois-piscénois
# 4     ZR OCCITANIE   FR08023                  Biterrois-Narbonnais
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Urbaine       O3             Fond  ...       84.050
# 1         Périurbaine       O3             Fond  ...       83.375
# 2         Périurbaine       O3             Fond  ...       79.675
# 3         Périurbaine       O3             Fond  ...       90.800
# 4    Rurale régionale       O3             Fond  ...       80.900
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3           96.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité  Latitude  Longitude  \
# 0                  100.0            R         1   43.5915    3.88681
# 1                   96.0            R         1   43.5705    3.91180
# 2                  100.0            A         1   43.6926    3.80021
# 3                  100.0            A         1   43.2875    3.50484
# 4                  100.0            R         1   43.4068    3.18878
#
#   SOMO35 Subscore
# 0            14.1
# 1            13.4
# 2             9.7
# 3            20.8
# 4            10.9
#
# [5 rows x 24 columns]

# %%
# Compute sum of SOMO35 Subscore grouped by 'nom site'
sum_by_nom = df_O3.groupby('nom site')['SOMO35 Subscore'].sum()

print(sum_by_nom)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_O3.groupby('nom site').first().reset_index()
print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(sum_by_nom, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'SOMO35 Subscore_y'], axis = 1)
print(result)
# Out:
# nom site
# Agathois-piscénois                      7506.3
# BELESTA EN LAURAGAIS                    6105.4
# Biterrois-Narbonnais                    7453.8
# ECOLE M.JACQUIER                        6155.2
# GAUDONVILLE                             6105.0
# Gard Rhodanien2                         8741.3
# LOURDES LAPACCA                         5620.5
# Montauban                               5469.6
# Montpellier Prés d'Arènes               4370.8
# Montpellier Périurbaine Sud (Lattes)    8582.3
# Montpellier St Gely                     8040.2
# Nimes Gauzy                             7457.9
# Nimes La Calmette                       7614.9
# PEYRUSSE                                4742.0
# Perpignan Les Carmes                    6911.6
# Perpignan St Esteve                     7513.2
# Rodez                                   6690.4
# SICOVAL                                 6383.5
# Stade Travet CASTRES                    7214.9
# Tarbes lycée Dupuy                      5337.5
# Toulouse Berthelot                      6164.4
# Name: SOMO35 Subscore, dtype: float64
#                                 nom site        Date de début  \
# 0                     Agathois-piscénois  2023/01/01 00:00:00
# 1                   BELESTA EN LAURAGAIS  2023/01/01 00:00:00
# 2                   Biterrois-Narbonnais  2023/01/01 00:00:00
# 3                       ECOLE M.JACQUIER  2023/01/01 00:00:00
# 4                            GAUDONVILLE  2023/01/01 00:00:00
# 5                        Gard Rhodanien2  2023/01/01 00:00:00
# 6                        LOURDES LAPACCA  2023/01/01 00:00:00
# 7                              Montauban  2023/01/01 00:00:00
# 8              Montpellier Prés d'Arènes  2023/01/01 00:00:00
# 9   Montpellier Périurbaine Sud (Lattes)  2023/01/01 00:00:00
# 10                   Montpellier St Gely  2023/01/01 00:00:00
# 11                           Nimes Gauzy  2023/01/01 00:00:00
# 12                     Nimes La Calmette  2023/01/01 00:00:00
# 13                              PEYRUSSE  2023/01/01 00:00:00
# 14                  Perpignan Les Carmes  2023/01/01 00:00:00
# 15                   Perpignan St Esteve  2023/01/01 00:00:00
# 16                                 Rodez  2023/01/01 00:00:00
# 17                               SICOVAL  2023/01/01 00:00:00
# 18                  Stade Travet CASTRES  2023/01/01 00:00:00
# 19                    Tarbes lycée Dupuy  2023/01/01 00:00:00
# 20                    Toulouse Berthelot  2023/01/01 00:00:00
#
#             Date de fin       Organisme   code zas              Zas code site  \
# 0   2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01     ZR OCCITANIE   FR08022
# 1   2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01     ZR OCCITANIE   FR12031
# 2   2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01     ZR OCCITANIE   FR08023
# 3   2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG01     ZAG TOULOUSE   FR12004
# 4   2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01     ZR OCCITANIE   FR12029
# 5   2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01     ZR OCCITANIE   FR08209
# 6   2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01     ZR OCCITANIE   FR12042
# 7   2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01     ZR OCCITANIE   FR50060
# 8   2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02  ZAG MONTPELLIER   FR08016
# 9   2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02  ZAG MONTPELLIER   FR08017
# 10  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02  ZAG MONTPELLIER   FR08018
# 11  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR02        ZAR NIMES   FR08614
# 12  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR02        ZAR NIMES   FR08617
# 13  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01     ZR OCCITANIE   FR12020
# 14  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR01    ZAR PERPIGNAN   FR08714
# 15  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR01    ZAR PERPIGNAN   FR08712
# 16  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01     ZR OCCITANIE   FR12095
# 17  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG01     ZAG TOULOUSE   FR12041
# 18  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01     ZR OCCITANIE   FR12053
# 19  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01     ZR OCCITANIE   FR12052
# 20  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG01     ZAG TOULOUSE   FR12030
#
#        type d'implantation Polluant type d'influence  ... valeur brute  \
# 0              Périurbaine       O3             Fond  ...       90.800
# 1         Rurale régionale       O3             Fond  ...       77.100
# 2         Rurale régionale       O3             Fond  ...       80.900
# 3                  Urbaine       O3             Fond  ...       76.650
# 4         Rurale régionale       O3             Fond  ...       63.400
# 5   Rurale près des villes       O3             Fond  ...       69.025
# 6                  Urbaine       O3             Fond  ...       84.525
# 7                  Urbaine       O3             Fond  ...       55.875
# 8                  Urbaine       O3             Fond  ...       84.050
# 9              Périurbaine       O3             Fond  ...       83.375
# 10             Périurbaine       O3             Fond  ...       79.675
# 11                 Urbaine       O3             Fond  ...       71.475
# 12             Périurbaine       O3             Fond  ...       71.175
# 13        Rurale nationale       O3             Fond  ...       53.875
# 14                 Urbaine       O3             Fond  ...       45.425
# 15             Périurbaine       O3             Fond  ...       47.650
# 16                 Urbaine       O3             Fond  ...       82.025
# 17             Périurbaine       O3             Fond  ...       75.675
# 18                 Urbaine       O3             Fond  ...       81.225
# 19                 Urbaine       O3             Fond  ...       64.450
# 20                 Urbaine       O3             Fond  ...       71.425
#
#    unité de mesure taux de saisie  couverture temporelle  \
# 0            µg-m3          100.0                    100
# 1            µg-m3          100.0                    100
# 2            µg-m3          100.0                    100
# 3            µg-m3          100.0                    100
# 4            µg-m3          100.0                    100
# 5            µg-m3          100.0                    100
# 6            µg-m3          100.0                    100
# 7            µg-m3          100.0                    100
# 8            µg-m3          100.0                    100
# 9            µg-m3           96.0                    100
# 10           µg-m3          100.0                    100
# 11           µg-m3          100.0                    100
# 12           µg-m3          100.0                    100
# 13           µg-m3          100.0                    100
# 14           µg-m3          100.0                    100
# 15           µg-m3          100.0                    100
# 16           µg-m3          100.0                    100
# 17           µg-m3          100.0                    100
# 18           µg-m3          100.0                    100
# 19           µg-m3           96.0                    100
# 20           µg-m3          100.0                    100
#
#     couverture de données code qualité  validité   Latitude  Longitude  \
# 0                   100.0            A         1  43.287500   3.504840
# 1                   100.0            A         1  43.441390   1.821944
# 2                   100.0            R         1  43.406800   3.188780
# 3                   100.0            A         1  43.575694   1.418064
# 4                   100.0            A         1  43.883933   0.845617
# 5                   100.0            R         1  43.942600   4.679580
# 6                   100.0            A         1  43.096247  -0.040497
# 7                   100.0            R         1  44.012857   1.375305
# 8                   100.0            R         1  43.591500   3.886810
# 9                    96.0            R         1  43.570500   3.911800
# 10                  100.0            A         1  43.692600   3.800210
# 11                  100.0            A         1  43.834400   4.374400
# 12                  100.0            R         1  43.925400   4.265810
# 13                  100.0            A         1  43.628700   0.179069
# 14                  100.0            A         1  42.695500   2.900530
# 15                  100.0            R         1  42.719800   2.839880
# 16                  100.0            A         1  44.356992   2.570704
# 17                  100.0            R         1  43.457306   1.571469
# 18                  100.0            R         1  43.610497   2.230150
# 19                   96.0            A         1  43.230297   0.062339
# 20                  100.0            A         1  43.587344   1.444003
#
#    SOMO35 Subscore
# 0             20.8
# 1              7.1
# 2             10.9
# 3              6.7
# 4              0.0
# 5              0.0
# 6             14.5
# 7              0.0
# 8             14.1
# 9             13.4
# 10             9.7
# 11             1.5
# 12             1.2
# 13             0.0
# 14             0.0
# 15             0.0
# 16            12.0
# 17             5.7
# 18            11.2
# 19             0.0
# 20             1.4
#
# [21 rows x 24 columns]
#                                 nom site  SOMO35 Subscore_x       Organisme  \
# 0                     Agathois-piscénois             7506.3  ATMO OCCITANIE
# 1                   BELESTA EN LAURAGAIS             6105.4  ATMO OCCITANIE
# 2                   Biterrois-Narbonnais             7453.8  ATMO OCCITANIE
# 3                       ECOLE M.JACQUIER             6155.2  ATMO OCCITANIE
# 4                            GAUDONVILLE             6105.0  ATMO OCCITANIE
# 5                        Gard Rhodanien2             8741.3  ATMO OCCITANIE
# 6                        LOURDES LAPACCA             5620.5  ATMO OCCITANIE
# 7                              Montauban             5469.6  ATMO OCCITANIE
# 8              Montpellier Prés d'Arènes             4370.8  ATMO OCCITANIE
# 9   Montpellier Périurbaine Sud (Lattes)             8582.3  ATMO OCCITANIE
# 10                   Montpellier St Gely             8040.2  ATMO OCCITANIE
# 11                           Nimes Gauzy             7457.9  ATMO OCCITANIE
# 12                     Nimes La Calmette             7614.9  ATMO OCCITANIE
# 13                              PEYRUSSE             4742.0  ATMO OCCITANIE
# 14                  Perpignan Les Carmes             6911.6  ATMO OCCITANIE
# 15                   Perpignan St Esteve             7513.2  ATMO OCCITANIE
# 16                                 Rodez             6690.4  ATMO OCCITANIE
# 17                               SICOVAL             6383.5  ATMO OCCITANIE
# 18                  Stade Travet CASTRES             7214.9  ATMO OCCITANIE
# 19                    Tarbes lycée Dupuy             5337.5  ATMO OCCITANIE
# 20                    Toulouse Berthelot             6164.4  ATMO OCCITANIE
#
#      code zas              Zas code site     type d'implantation Polluant  \
# 0   FR76ZRE01     ZR OCCITANIE   FR08022             Périurbaine       O3
# 1   FR76ZRE01     ZR OCCITANIE   FR12031        Rurale régionale       O3
# 2   FR76ZRE01     ZR OCCITANIE   FR08023        Rurale régionale       O3
# 3   FR76ZAG01     ZAG TOULOUSE   FR12004                 Urbaine       O3
# 4   FR76ZRE01     ZR OCCITANIE   FR12029        Rurale régionale       O3
# 5   FR76ZRE01     ZR OCCITANIE   FR08209  Rurale près des villes       O3
# 6   FR76ZRE01     ZR OCCITANIE   FR12042                 Urbaine       O3
# 7   FR76ZRE01     ZR OCCITANIE   FR50060                 Urbaine       O3
# 8   FR76ZAG02  ZAG MONTPELLIER   FR08016                 Urbaine       O3
# 9   FR76ZAG02  ZAG MONTPELLIER   FR08017             Périurbaine       O3
# 10  FR76ZAG02  ZAG MONTPELLIER   FR08018             Périurbaine       O3
# 11  FR76ZAR02        ZAR NIMES   FR08614                 Urbaine       O3
# 12  FR76ZAR02        ZAR NIMES   FR08617             Périurbaine       O3
# 13  FR76ZRE01     ZR OCCITANIE   FR12020        Rurale nationale       O3
# 14  FR76ZAR01    ZAR PERPIGNAN   FR08714                 Urbaine       O3
# 15  FR76ZAR01    ZAR PERPIGNAN   FR08712             Périurbaine       O3
# 16  FR76ZRE01     ZR OCCITANIE   FR12095                 Urbaine       O3
# 17  FR76ZAG01     ZAG TOULOUSE   FR12041             Périurbaine       O3
# 18  FR76ZRE01     ZR OCCITANIE   FR12053                 Urbaine       O3
# 19  FR76ZRE01     ZR OCCITANIE   FR12052                 Urbaine       O3
# 20  FR76ZAG01     ZAG TOULOUSE   FR12030                 Urbaine       O3
#
#    type d'influence Réglementaire  ... valeur valeur brute  unité de mesure  \
# 0              Fond           Oui  ...   90.8       90.800            µg-m3
# 1              Fond           Oui  ...   77.1       77.100            µg-m3
# 2              Fond           Oui  ...   80.9       80.900            µg-m3
# 3              Fond           Oui  ...   76.7       76.650            µg-m3
# 4              Fond           Oui  ...   63.4       63.400            µg-m3
# 5              Fond           Oui  ...   69.0       69.025            µg-m3
# 6              Fond           Oui  ...   84.5       84.525            µg-m3
# 7              Fond           Oui  ...   55.9       55.875            µg-m3
# 8              Fond           Oui  ...   84.1       84.050            µg-m3
# 9              Fond           Oui  ...   83.4       83.375            µg-m3
# 10             Fond           Oui  ...   79.7       79.675            µg-m3
# 11             Fond           Oui  ...   71.5       71.475            µg-m3
# 12             Fond           Oui  ...   71.2       71.175            µg-m3
# 13             Fond           Oui  ...   53.9       53.875            µg-m3
# 14             Fond           Oui  ...   45.4       45.425            µg-m3
# 15             Fond           Oui  ...   47.7       47.650            µg-m3
# 16             Fond           Oui  ...   82.0       82.025            µg-m3
# 17             Fond           Oui  ...   75.7       75.675            µg-m3
# 18             Fond           Oui  ...   81.2       81.225            µg-m3
# 19             Fond           Oui  ...   64.5       64.450            µg-m3
# 20             Fond           Oui  ...   71.4       71.425            µg-m3
#
#     taux de saisie couverture temporelle  couverture de données  code qualité  \
# 0            100.0                   100                  100.0             A
# 1            100.0                   100                  100.0             A
# 2            100.0                   100                  100.0             R
# 3            100.0                   100                  100.0             A
# 4            100.0                   100                  100.0             A
# 5            100.0                   100                  100.0             R
# 6            100.0                   100                  100.0             A
# 7            100.0                   100                  100.0             R
# 8            100.0                   100                  100.0             R
# 9             96.0                   100                   96.0             R
# 10           100.0                   100                  100.0             A
# 11           100.0                   100                  100.0             A
# 12           100.0                   100                  100.0             R
# 13           100.0                   100                  100.0             A
# 14           100.0                   100                  100.0             A
# 15           100.0                   100                  100.0             R
# 16           100.0                   100                  100.0             A
# 17           100.0                   100                  100.0             R
# 18           100.0                   100                  100.0             R
# 19            96.0                   100                   96.0             A
# 20           100.0                   100                  100.0             A
#
#     validité   Latitude  Longitude
# 0          1  43.287500   3.504840
# 1          1  43.441390   1.821944
# 2          1  43.406800   3.188780
# 3          1  43.575694   1.418064
# 4          1  43.883933   0.845617
# 5          1  43.942600   4.679580
# 6          1  43.096247  -0.040497
# 7          1  44.012857   1.375305
# 8          1  43.591500   3.886810
# 9          1  43.570500   3.911800
# 10         1  43.692600   3.800210
# 11         1  43.834400   4.374400
# 12         1  43.925400   4.265810
# 13         1  43.628700   0.179069
# 14         1  42.695500   2.900530
# 15         1  42.719800   2.839880
# 16         1  44.356992   2.570704
# 17         1  43.457306   1.571469
# 18         1  43.610497   2.230150
# 19         1  43.230297   0.062339
# 20         1  43.587344   1.444003
#
# [21 rows x 22 columns]

# %%
# Downloading the final dataframe of the annual SOMO35 Score in ATMO OCCITANIE to csv
result.to_csv('df_SOMO35_ATMO_OCCITANIE.csv', index=False, encoding = 'latin1')
