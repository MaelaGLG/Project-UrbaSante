# %%
# Code for extracting the annual SOMO35 Score for each station in ATMO BOURGOGNE-FRANCE-COMTÉ (Région: BOURGOGNE-FRANCE-COMTÉ)

# Note: will use abbreviation ATMO BFC

# %%
# Installing required packages
import pandas as pd

import os

# Base directory path
base_path = ".\data\raw\Données de la qualité de l'air (Indicateurs SOMO35 et ATMO)\"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8628\2375524138.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# O3 ATMO BFC

# File path to the data
O3_ATMO_BFC_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - ATMO BFC.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_ATMO_BFC_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Apply the function to fill in the Subscore column
df_O3['SOMO35 Subscore'] = df_O3['valeur'].apply(lambda x: max(x - 70, 0))

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin                     Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO BOURGOGNE-FRANCHE-COMTE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO BOURGOGNE-FRANCHE-COMTE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO BOURGOGNE-FRANCHE-COMTE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO BOURGOGNE-FRANCHE-COMTE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO BOURGOGNE-FRANCHE-COMTE
#
#     code zas                         Zas code site       nom site  \
# 0  FR27ZAR02                   ZAR DIJON   FR26005  Dijon Péjoces
# 1  FR27ZAR02                   ZAR DIJON   FR26010           Daix
# 2  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE   FR26012         Morvan
# 3  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE   FR26017         Nevers
# 4  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE   FR26019        Auxerre
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0         Périurbaine       O3             Fond  ...   71.6       71.550
# 1         Périurbaine       O3             Fond  ...   71.3       71.300
# 2    Rurale nationale       O3             Fond  ...   75.3       75.325
# 3             Urbaine       O3             Fond  ...   68.0       67.950
# 4             Urbaine       O3             Fond  ...   78.4       78.400
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             A         1  47.307368  5.065881
# 1                 100.0             A         1  47.345600  5.002377
# 2                 100.0             A         1  47.274762  4.099476
# 3                 100.0             A         1  46.996828  3.171092
# 4                 100.0             A         1  47.800575  3.576189
#
# [5 rows x 23 columns]
#          Date de début          Date de fin                     Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO BOURGOGNE-FRANCHE-COMTE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO BOURGOGNE-FRANCHE-COMTE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO BOURGOGNE-FRANCHE-COMTE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO BOURGOGNE-FRANCHE-COMTE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO BOURGOGNE-FRANCHE-COMTE
#
#     code zas                         Zas code site       nom site  \
# 0  FR27ZAR02                   ZAR DIJON   FR26005  Dijon Péjoces
# 1  FR27ZAR02                   ZAR DIJON   FR26010           Daix
# 2  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE   FR26012         Morvan
# 3  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE   FR26017         Nevers
# 4  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE   FR26019        Auxerre
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0         Périurbaine       O3             Fond  ...       71.550
# 1         Périurbaine       O3             Fond  ...       71.300
# 2    Rurale nationale       O3             Fond  ...       75.325
# 3             Urbaine       O3             Fond  ...       67.950
# 4             Urbaine       O3             Fond  ...       78.400
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  47.307368   5.065881
# 1                  100.0            A         1  47.345600   5.002377
# 2                  100.0            A         1  47.274762   4.099476
# 3                  100.0            A         1  46.996828   3.171092
# 4                  100.0            A         1  47.800575   3.576189
#
#   SOMO35 Subscore
# 0             1.6
# 1             1.3
# 2             5.3
# 3             0.0
# 4             8.4
#
# [5 rows x 24 columns]

# %%
# Compute sum of SOMO35 Subscore grouped by 'nom site'
sum_by_nom = df_O3.groupby('nom site')['SOMO35 Subscore'].sum()

print(sum_by_nom)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_O3.groupby('nom site').first().reset_index()
print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(sum_by_nom, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'SOMO35 Subscore_y'], axis = 1)
print(result)
# Out:
# nom site
# Auxerre                          6908.0
# Besancon Prevoyance              7390.6
# Champforgueil                    6089.0
# Daix                             7248.4
# Dambenois Citoyen                7170.2
# Dijon Péjoces                    6388.9
# Dole centre                      6388.1
# Lons-le-Saunier CV               7688.3
# Macon Paul Bert                  6970.3
# Montandon Baresans               5398.7
# Montbéliard centre               5845.9
# Montceau-les-Mines 9me écluse    6037.7
# Montfaucon                       8408.7
# Morvan                           7131.7
# Nevers                           5586.9
# Sens                              358.1
# Vesoul Pres Caillet              6736.6
# Name: SOMO35 Subscore, dtype: float64
#                          nom site        Date de début          Date de fin  \
# 0                         Auxerre  2023/01/01 00:00:00  2023/01/01 23:59:59
# 1             Besancon Prevoyance  2023/01/01 00:00:00  2023/01/01 23:59:59
# 2                   Champforgueil  2023/01/01 00:00:00  2023/01/01 23:59:59
# 3                            Daix  2023/01/01 00:00:00  2023/01/01 23:59:59
# 4               Dambenois Citoyen  2023/01/01 00:00:00  2023/01/01 23:59:59
# 5                   Dijon Péjoces  2023/01/01 00:00:00  2023/01/01 23:59:59
# 6                     Dole centre  2023/01/01 00:00:00  2023/01/01 23:59:59
# 7              Lons-le-Saunier CV  2023/01/01 00:00:00  2023/01/01 23:59:59
# 8                 Macon Paul Bert  2023/01/01 00:00:00  2023/01/01 23:59:59
# 9              Montandon Baresans  2023/01/01 00:00:00  2023/01/01 23:59:59
# 10             Montbéliard centre  2023/01/01 00:00:00  2023/01/01 23:59:59
# 11  Montceau-les-Mines 9me écluse  2023/01/01 00:00:00  2023/01/01 23:59:59
# 12                     Montfaucon  2023/01/01 00:00:00  2023/01/01 23:59:59
# 13                         Morvan  2023/01/01 00:00:00  2023/01/01 23:59:59
# 14                         Nevers  2023/01/01 00:00:00  2023/01/01 23:59:59
# 15                           Sens  2023/09/28 00:00:00  2023/09/28 23:59:59
# 16            Vesoul Pres Caillet  2023/01/01 00:00:00  2023/01/01 23:59:59
#
#                        Organisme   code zas                         Zas  \
# 0   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 1   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR03                ZAR BESANCON
# 2   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR04                  ZAR CHALON
# 3   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR02                   ZAR DIJON
# 4   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR01     ZAR BELFORT-MONTBELIARD
# 5   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR02                   ZAR DIJON
# 6   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 7   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 8   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 9   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 10  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR01     ZAR BELFORT-MONTBELIARD
# 11  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 12  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR03                ZAR BESANCON
# 13  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 14  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 15  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 16  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
#
#    code site type d'implantation Polluant type d'influence  ... valeur brute  \
# 0    FR26019             Urbaine       O3             Fond  ...       78.400
# 1    FR82006             Urbaine       O3             Fond  ...       72.825
# 2    FR32002         Périurbaine       O3             Fond  ...       64.375
# 3    FR26010         Périurbaine       O3             Fond  ...       71.300
# 4    FR82012         Périurbaine       O3             Fond  ...       64.250
# 5    FR26005         Périurbaine       O3             Fond  ...       71.550
# 6    FR82040             Urbaine       O3             Fond  ...       70.325
# 7    FR82050             Urbaine       O3             Fond  ...       76.000
# 8    FR32006         Périurbaine       O3             Fond  ...       74.750
# 9    FR82030    Rurale nationale       O3             Fond  ...       78.775
# 10   FR82010             Urbaine       O3             Fond  ...       53.825
# 11   FR32005             Urbaine       O3             Fond  ...       66.300
# 12   FR82005         Périurbaine       O3             Fond  ...       77.650
# 13   FR26012    Rurale nationale       O3             Fond  ...       75.325
# 14   FR26017             Urbaine       O3             Fond  ...       67.950
# 15   FR26016             Urbaine       O3             Fond  ...       57.200
# 16   FR82060             Urbaine       O3             Fond  ...       71.375
#
#    unité de mesure taux de saisie  couverture temporelle  \
# 0            µg-m3          100.0                    100
# 1            µg-m3          100.0                    100
# 2            µg-m3          100.0                    100
# 3            µg-m3          100.0                    100
# 4            µg-m3          100.0                    100
# 5            µg-m3          100.0                    100
# 6            µg-m3          100.0                    100
# 7            µg-m3          100.0                    100
# 8            µg-m3          100.0                    100
# 9            µg-m3          100.0                    100
# 10           µg-m3          100.0                    100
# 11           µg-m3          100.0                    100
# 12           µg-m3          100.0                    100
# 13           µg-m3          100.0                    100
# 14           µg-m3          100.0                    100
# 15           µg-m3           54.0                    100
# 16           µg-m3          100.0                    100
#
#     couverture de données code qualité  validité   Latitude  Longitude  \
# 0                   100.0            A         1  47.800575   3.576189
# 1                   100.0            A         1  47.247400   6.015419
# 2                   100.0            A         1  46.821056   4.835083
# 3                   100.0            A         1  47.345600   5.002377
# 4                   100.0            A         1  47.538193   6.868361
# 5                   100.0            A         1  47.307368   5.065881
# 6                   100.0            A         1  47.096720   5.496389
# 7                   100.0            A         1  46.671321   5.556620
# 8                   100.0            A         1  46.316172   4.839994
# 9                   100.0            A         1  47.294640   6.825861
# 10                  100.0            R         1  47.510307   6.794000
# 11                  100.0            A         1  46.678785   4.366893
# 12                  100.0            A         1  47.234610   6.076472
# 13                  100.0            A         1  47.274762   4.099476
# 14                  100.0            A         1  46.996828   3.171092
# 15                   54.0            N        -1  48.200436   3.277300
# 16                  100.0            A         1  47.620022   6.157642
#
#    SOMO35 Subscore
# 0              8.4
# 1              2.8
# 2              0.0
# 3              1.3
# 4              0.0
# 5              1.6
# 6              0.3
# 7              6.0
# 8              4.8
# 9              8.8
# 10             0.0
# 11             0.0
# 12             7.7
# 13             5.3
# 14             0.0
# 15             0.0
# 16             1.4
#
# [17 rows x 24 columns]
#                          nom site  SOMO35 Subscore_x  \
# 0                         Auxerre             6908.0
# 1             Besancon Prevoyance             7390.6
# 2                   Champforgueil             6089.0
# 3                            Daix             7248.4
# 4               Dambenois Citoyen             7170.2
# 5                   Dijon Péjoces             6388.9
# 6                     Dole centre             6388.1
# 7              Lons-le-Saunier CV             7688.3
# 8                 Macon Paul Bert             6970.3
# 9              Montandon Baresans             5398.7
# 10             Montbéliard centre             5845.9
# 11  Montceau-les-Mines 9me écluse             6037.7
# 12                     Montfaucon             8408.7
# 13                         Morvan             7131.7
# 14                         Nevers             5586.9
# 15                           Sens              358.1
# 16            Vesoul Pres Caillet             6736.6
#
#                        Organisme   code zas                         Zas  \
# 0   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 1   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR03                ZAR BESANCON
# 2   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR04                  ZAR CHALON
# 3   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR02                   ZAR DIJON
# 4   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR01     ZAR BELFORT-MONTBELIARD
# 5   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR02                   ZAR DIJON
# 6   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 7   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 8   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 9   ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 10  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR01     ZAR BELFORT-MONTBELIARD
# 11  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 12  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZAR03                ZAR BESANCON
# 13  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 14  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 15  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
# 16  ATMO BOURGOGNE-FRANCHE-COMTE  FR27ZRE01  ZR BOURGOGNE-FRANCHE-COMTE
#
#    code site type d'implantation Polluant type d'influence Réglementaire  ...  \
# 0    FR26019             Urbaine       O3             Fond           Oui  ...
# 1    FR82006             Urbaine       O3             Fond           Oui  ...
# 2    FR32002         Périurbaine       O3             Fond           Oui  ...
# 3    FR26010         Périurbaine       O3             Fond           Oui  ...
# 4    FR82012         Périurbaine       O3             Fond           Oui  ...
# 5    FR26005         Périurbaine       O3             Fond           Oui  ...
# 6    FR82040             Urbaine       O3             Fond           Oui  ...
# 7    FR82050             Urbaine       O3             Fond           Oui  ...
# 8    FR32006         Périurbaine       O3             Fond           Oui  ...
# 9    FR82030    Rurale nationale       O3             Fond           Oui  ...
# 10   FR82010             Urbaine       O3             Fond           Oui  ...
# 11   FR32005             Urbaine       O3             Fond           Oui  ...
# 12   FR82005         Périurbaine       O3             Fond           Oui  ...
# 13   FR26012    Rurale nationale       O3             Fond           Oui  ...
# 14   FR26017             Urbaine       O3             Fond           Oui  ...
# 15   FR26016             Urbaine       O3             Fond           Oui  ...
# 16   FR82060             Urbaine       O3             Fond           Oui  ...
#
#    valeur valeur brute  unité de mesure  taux de saisie couverture temporelle  \
# 0    78.4       78.400            µg-m3           100.0                   100
# 1    72.8       72.825            µg-m3           100.0                   100
# 2    64.4       64.375            µg-m3           100.0                   100
# 3    71.3       71.300            µg-m3           100.0                   100
# 4    64.3       64.250            µg-m3           100.0                   100
# 5    71.6       71.550            µg-m3           100.0                   100
# 6    70.3       70.325            µg-m3           100.0                   100
# 7    76.0       76.000            µg-m3           100.0                   100
# 8    74.8       74.750            µg-m3           100.0                   100
# 9    78.8       78.775            µg-m3           100.0                   100
# 10   53.8       53.825            µg-m3           100.0                   100
# 11   66.3       66.300            µg-m3           100.0                   100
# 12   77.7       77.650            µg-m3           100.0                   100
# 13   75.3       75.325            µg-m3           100.0                   100
# 14   68.0       67.950            µg-m3           100.0                   100
# 15   57.2       57.200            µg-m3            54.0                   100
# 16   71.4       71.375            µg-m3           100.0                   100
#
#     couverture de données  code qualité  validité   Latitude  Longitude
# 0                   100.0             A         1  47.800575   3.576189
# 1                   100.0             A         1  47.247400   6.015419
# 2                   100.0             A         1  46.821056   4.835083
# 3                   100.0             A         1  47.345600   5.002377
# 4                   100.0             A         1  47.538193   6.868361
# 5                   100.0             A         1  47.307368   5.065881
# 6                   100.0             A         1  47.096720   5.496389
# 7                   100.0             A         1  46.671321   5.556620
# 8                   100.0             A         1  46.316172   4.839994
# 9                   100.0             A         1  47.294640   6.825861
# 10                  100.0             R         1  47.510307   6.794000
# 11                  100.0             A         1  46.678785   4.366893
# 12                  100.0             A         1  47.234610   6.076472
# 13                  100.0             A         1  47.274762   4.099476
# 14                  100.0             A         1  46.996828   3.171092
# 15                   54.0             N        -1  48.200436   3.277300
# 16                  100.0             A         1  47.620022   6.157642
#
# [17 rows x 22 columns]

# %%
# Downloading the final dataframe of the annual SOMO35 Score in ATMO BOURGOGNE-FRANCE-COMTÉ to csv
result.to_csv('df_SOMO35_ATMO_BFC.csv', index=False, encoding = 'latin1')
