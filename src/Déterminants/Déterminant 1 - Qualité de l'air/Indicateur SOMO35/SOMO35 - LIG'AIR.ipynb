# %%
# Code for extracting the annual SOMO35 score for each station in LIG'AIR (Région: Centre-Val de Loire)

# %%
# Installing required packages
import pandas as pd

import os

# Base directory path
base_path = ".\data\raw\Données de la qualité de l'air (Indicateurs SOMO35 et ATMO)\"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6232\2375524138.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# O3 LIG'AIR

# File path to the data
O3_LIGAIR_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - LIG'AIR.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_LIGAIR_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Apply the function to fill in the Subscore column
df_O3['SOMO35 Subscore'] = df_O3['valeur'].apply(lambda x: max(x - 70, 0))

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR  FR24ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR  FR24ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR  FR24ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR  FR24ZAG02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR  FR24ZRE02
#
#                       Zas code site            nom site type d'implantation  \
# 0             ZAG ORLEANS   FR34017  Marigny-les-usages         Périurbaine
# 1               ZAG TOURS   FR34024      Joué lès Tours             Urbaine
# 2               ZAG TOURS   FR34026  Tours péri-urbaine         Périurbaine
# 3             ZAG ORLEANS   FR34029      La_Source-CNRS             Urbaine
# 4  ZR CENTRE-VAL-DE-LOIRE   FR34032             Leblanc             Urbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0       O3             Fond  ...   64.5       64.500           µg-m3
# 1       O3             Fond  ...   58.7       58.700           µg-m3
# 2       O3             Fond  ...   65.1       65.100           µg-m3
# 3       O3             Fond  ...   68.1       68.075           µg-m3
# 4       O3             Fond  ...   65.0       65.025           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             A
# 1           100.0                    100                 100.0             A
# 2           100.0                    100                 100.0             A
# 3           100.0                    100                 100.0             A
# 4           100.0                    100                 100.0             A
#
#    validité   Latitude Longitude
# 0         1  47.958972  2.009278
# 1         1  47.344139  0.653778
# 2         1  47.469250  0.717333
# 3         1  47.837750  1.944667
# 4         1  47.082778  2.405333
#
# [5 rows x 23 columns]
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR  FR24ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR  FR24ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR  FR24ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR  FR24ZAG02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR  FR24ZRE02
#
#                       Zas code site            nom site type d'implantation  \
# 0             ZAG ORLEANS   FR34017  Marigny-les-usages         Périurbaine
# 1               ZAG TOURS   FR34024      Joué lès Tours             Urbaine
# 2               ZAG TOURS   FR34026  Tours péri-urbaine         Périurbaine
# 3             ZAG ORLEANS   FR34029      La_Source-CNRS             Urbaine
# 4  ZR CENTRE-VAL-DE-LOIRE   FR34032             Leblanc             Urbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0       O3             Fond  ...       64.500           µg-m3          100.0
# 1       O3             Fond  ...       58.700           µg-m3          100.0
# 2       O3             Fond  ...       65.100           µg-m3          100.0
# 3       O3             Fond  ...       68.075           µg-m3          100.0
# 4       O3             Fond  ...       65.025           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude SOMO35 Subscore
# 0  47.958972   2.009278             0.0
# 1  47.344139   0.653778             0.0
# 2  47.469250   0.717333             0.0
# 3  47.837750   1.944667             0.0
# 4  47.082778   2.405333             0.0
#
# [5 rows x 24 columns]

# %%
# Compute sum of SOMO35 Subscore grouped by 'nom site'
sum_by_nom = df_O3.groupby('nom site')['SOMO35 Subscore'].sum()

print(sum_by_nom)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_O3.groupby('nom site').first().reset_index()
print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(sum_by_nom, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'SOMO35 Subscore_y'], axis = 1)
print(result)
# Out:
# nom site
# Blois nord            6109.5
# Chateauroux Sud       5388.7
# Dreux Centre          5570.1
# Faverolles            4984.5
# Fulbert               5433.3
# Joué lès Tours        4648.1
# La_Source-CNRS        5757.3
# Leblanc               5111.0
# Marigny-les-usages    4658.5
# Montargis Fond           0.0
# Montargis Fond 2      4540.5
# Montierchaume         5208.2
# Oysonville            5371.8
# Tours péri-urbaine    5388.0
# Verneuil              5614.4
# Name: SOMO35 Subscore, dtype: float64
#               nom site        Date de début          Date de fin Organisme  \
# 0           Blois nord  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 1      Chateauroux Sud  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 2         Dreux Centre  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 3           Faverolles  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 4              Fulbert  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 5       Joué lès Tours  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 6       La_Source-CNRS  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 7              Leblanc  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 8   Marigny-les-usages  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 9       Montargis Fond  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 10    Montargis Fond 2  2023/01/05 00:00:00  2023/01/05 23:59:59   LIG'AIR
# 11       Montierchaume  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 12          Oysonville  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 13  Tours péri-urbaine  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
# 14            Verneuil  2023/01/01 00:00:00  2023/01/01 23:59:59   LIG'AIR
#
#      code zas                     Zas code site type d'implantation Polluant  \
# 0   FR24ZAR02               ZAR BLOIS   FR34061             Urbaine       O3
# 1   FR24ZRE02  ZR CENTRE-VAL-DE-LOIRE   FR34051             Urbaine       O3
# 2   FR24ZRE02  ZR CENTRE-VAL-DE-LOIRE   FR34046             Urbaine       O3
# 3   FR24ZRE02  ZR CENTRE-VAL-DE-LOIRE   FR34054    Rurale régionale       O3
# 4   FR24ZRE02  ZR CENTRE-VAL-DE-LOIRE   FR34041             Urbaine       O3
# 5   FR24ZAG01               ZAG TOURS   FR34024             Urbaine       O3
# 6   FR24ZAG02             ZAG ORLEANS   FR34029             Urbaine       O3
# 7   FR24ZRE02  ZR CENTRE-VAL-DE-LOIRE   FR34032             Urbaine       O3
# 8   FR24ZAG02             ZAG ORLEANS   FR34017         Périurbaine       O3
# 9   FR24ZRE02  ZR CENTRE-VAL-DE-LOIRE   FR34065             Urbaine       O3
# 10  FR24ZRE02  ZR CENTRE-VAL-DE-LOIRE   FR34066             Urbaine       O3
# 11  FR24ZRE02  ZR CENTRE-VAL-DE-LOIRE   FR34056         Périurbaine       O3
# 12  FR24ZRE02  ZR CENTRE-VAL-DE-LOIRE   FR34043    Rurale régionale       O3
# 13  FR24ZAG01               ZAG TOURS   FR34026         Périurbaine       O3
# 14  FR24ZRE02  ZR CENTRE-VAL-DE-LOIRE   FR34038    Rurale nationale       O3
#
#    type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0              Fond  ...       64.275           µg-m3          100.0
# 1              Fond  ...       71.000           µg-m3          100.0
# 2              Fond  ...       67.500           µg-m3          100.0
# 3              Fond  ...       65.700           µg-m3          100.0
# 4              Fond  ...       59.325           µg-m3          100.0
# 5              Fond  ...       58.700           µg-m3          100.0
# 6              Fond  ...       68.075           µg-m3          100.0
# 7              Fond  ...       65.025           µg-m3          100.0
# 8              Fond  ...       64.500           µg-m3          100.0
# 9              Fond  ...       55.325           µg-m3          100.0
# 10             Fond  ...       60.750           µg-m3           54.0
# 11             Fond  ...       69.775           µg-m3          100.0
# 12             Fond  ...       56.725           µg-m3          100.0
# 13             Fond  ...       65.100           µg-m3          100.0
# 14             Fond  ...       69.000           µg-m3          100.0
#
#     couverture temporelle  couverture de données code qualité  validité  \
# 0                     100                  100.0            R         1
# 1                     100                  100.0            A         1
# 2                     100                  100.0            A         1
# 3                     100                  100.0            A         1
# 4                     100                  100.0            A         1
# 5                     100                  100.0            A         1
# 6                     100                  100.0            A         1
# 7                     100                  100.0            A         1
# 8                     100                  100.0            A         1
# 9                     100                  100.0            A         1
# 10                    100                   54.0            N        -1
# 11                    100                  100.0            A         1
# 12                    100                  100.0            A         1
# 13                    100                  100.0            A         1
# 14                    100                  100.0            A         1
#
#      Latitude  Longitude SOMO35 Subscore
# 0   47.594256   1.302667             0.0
# 1   46.798278   1.693139             1.0
# 2   48.729694   1.358472             0.0
# 3   47.170167   1.409694             0.0
# 4   48.444417   1.510139             0.0
# 5   47.344139   0.653778             0.0
# 6   47.837750   1.944667             0.0
# 7   47.082778   2.405333             0.0
# 8   47.958972   2.009278             0.0
# 9   47.996994   2.731511             0.0
# 10  48.001450   2.726180             0.0
# 11  46.864528   1.771944             0.0
# 12  48.391139   1.955611             0.0
# 13  47.469250   0.717333             0.0
# 14  46.814694   2.610069             0.0
#
# [15 rows x 24 columns]
#               nom site  SOMO35 Subscore_x Organisme   code zas  \
# 0           Blois nord             6109.5   LIG'AIR  FR24ZAR02
# 1      Chateauroux Sud             5388.7   LIG'AIR  FR24ZRE02
# 2         Dreux Centre             5570.1   LIG'AIR  FR24ZRE02
# 3           Faverolles             4984.5   LIG'AIR  FR24ZRE02
# 4              Fulbert             5433.3   LIG'AIR  FR24ZRE02
# 5       Joué lès Tours             4648.1   LIG'AIR  FR24ZAG01
# 6       La_Source-CNRS             5757.3   LIG'AIR  FR24ZAG02
# 7              Leblanc             5111.0   LIG'AIR  FR24ZRE02
# 8   Marigny-les-usages             4658.5   LIG'AIR  FR24ZAG02
# 9       Montargis Fond                0.0   LIG'AIR  FR24ZRE02
# 10    Montargis Fond 2             4540.5   LIG'AIR  FR24ZRE02
# 11       Montierchaume             5208.2   LIG'AIR  FR24ZRE02
# 12          Oysonville             5371.8   LIG'AIR  FR24ZRE02
# 13  Tours péri-urbaine             5388.0   LIG'AIR  FR24ZAG01
# 14            Verneuil             5614.4   LIG'AIR  FR24ZRE02
#
#                        Zas code site type d'implantation Polluant  \
# 0                ZAR BLOIS   FR34061             Urbaine       O3
# 1   ZR CENTRE-VAL-DE-LOIRE   FR34051             Urbaine       O3
# 2   ZR CENTRE-VAL-DE-LOIRE   FR34046             Urbaine       O3
# 3   ZR CENTRE-VAL-DE-LOIRE   FR34054    Rurale régionale       O3
# 4   ZR CENTRE-VAL-DE-LOIRE   FR34041             Urbaine       O3
# 5                ZAG TOURS   FR34024             Urbaine       O3
# 6              ZAG ORLEANS   FR34029             Urbaine       O3
# 7   ZR CENTRE-VAL-DE-LOIRE   FR34032             Urbaine       O3
# 8              ZAG ORLEANS   FR34017         Périurbaine       O3
# 9   ZR CENTRE-VAL-DE-LOIRE   FR34065             Urbaine       O3
# 10  ZR CENTRE-VAL-DE-LOIRE   FR34066             Urbaine       O3
# 11  ZR CENTRE-VAL-DE-LOIRE   FR34056         Périurbaine       O3
# 12  ZR CENTRE-VAL-DE-LOIRE   FR34043    Rurale régionale       O3
# 13               ZAG TOURS   FR34026         Périurbaine       O3
# 14  ZR CENTRE-VAL-DE-LOIRE   FR34038    Rurale nationale       O3
#
#    type d'influence Réglementaire  ... valeur valeur brute  unité de mesure  \
# 0              Fond           Oui  ...   64.3       64.275            µg-m3
# 1              Fond           Oui  ...   71.0       71.000            µg-m3
# 2              Fond           Oui  ...   67.5       67.500            µg-m3
# 3              Fond           Oui  ...   65.7       65.700            µg-m3
# 4              Fond           Oui  ...   59.3       59.325            µg-m3
# 5              Fond           Oui  ...   58.7       58.700            µg-m3
# 6              Fond           Oui  ...   68.1       68.075            µg-m3
# 7              Fond           Oui  ...   65.0       65.025            µg-m3
# 8              Fond           Oui  ...   64.5       64.500            µg-m3
# 9              Fond           Oui  ...   55.3       55.325            µg-m3
# 10             Fond           Oui  ...   60.8       60.750            µg-m3
# 11             Fond           Oui  ...   69.8       69.775            µg-m3
# 12             Fond           Oui  ...   56.7       56.725            µg-m3
# 13             Fond           Oui  ...   65.1       65.100            µg-m3
# 14             Fond           Oui  ...   69.0       69.000            µg-m3
#
#     taux de saisie couverture temporelle  couverture de données  code qualité  \
# 0            100.0                   100                  100.0             R
# 1            100.0                   100                  100.0             A
# 2            100.0                   100                  100.0             A
# 3            100.0                   100                  100.0             A
# 4            100.0                   100                  100.0             A
# 5            100.0                   100                  100.0             A
# 6            100.0                   100                  100.0             A
# 7            100.0                   100                  100.0             A
# 8            100.0                   100                  100.0             A
# 9            100.0                   100                  100.0             A
# 10            54.0                   100                   54.0             N
# 11           100.0                   100                  100.0             A
# 12           100.0                   100                  100.0             A
# 13           100.0                   100                  100.0             A
# 14           100.0                   100                  100.0             A
#
#     validité   Latitude  Longitude
# 0          1  47.594256   1.302667
# 1          1  46.798278   1.693139
# 2          1  48.729694   1.358472
# 3          1  47.170167   1.409694
# 4          1  48.444417   1.510139
# 5          1  47.344139   0.653778
# 6          1  47.837750   1.944667
# 7          1  47.082778   2.405333
# 8          1  47.958972   2.009278
# 9          1  47.996994   2.731511
# 10        -1  48.001450   2.726180
# 11         1  46.864528   1.771944
# 12         1  48.391139   1.955611
# 13         1  47.469250   0.717333
# 14         1  46.814694   2.610069
#
# [15 rows x 22 columns]

# %%
# Downloading the final dataframe of the annual SOMO35 Score in LIG'AIR to csv
result.to_csv('df_SOMO35_LIGAIR.csv', index=False, encoding = 'latin1')
