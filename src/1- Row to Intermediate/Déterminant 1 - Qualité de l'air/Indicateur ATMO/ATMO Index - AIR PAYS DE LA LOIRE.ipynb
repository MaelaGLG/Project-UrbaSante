# %%
# Code for extracting the daily ATMO score for each station in AIR PAYS DE LA LOIRE (Région: Pays de la Loire)

# %%
# Installing required packages
import pandas as pd

import os

# Base directory path
base_path = ".\data\1- Raw Data\Déterminant 1 - Qualité de l'air\"

# %%
# PM10 AIR PAYS DE LA LOIRE

# File path to the data
PM10_AIR_PAYS_DE_LA_LOIRE_file_path = os.path.join(base_path, "PM10 Moyenne Journalière\Export Moy. journalière - PM10 - AIR PAYS DE LA LOIRE.csv")
# Use read_csv function from pandas specifying the delimiter as ';'
df_PM10 = pd.read_csv(PM10_AIR_PAYS_DE_LA_LOIRE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM10.head())

# Sample ATMO subscore dictionary for PM10 (Moyenne journalière)
ATMO_subscore_PM10 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 20.0), (20.0, 40.0), (40.0, 50.0), (50.0, 100.0), (100.0, 150.0), (150.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM10 = pd.DataFrame(ATMO_subscore_PM10)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM10['Range'] = ATMO_subscore_df_PM10['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM10 measurement
def assign_subscore_PM10(valeur):
    for index, row in ATMO_subscore_df_PM10.iterrows():  
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM10['ATMO sub-score'] = df_PM10['valeur'].apply(assign_subscore_PM10)  

# Display the updated DataFrame
print(df_PM10.head())
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
#
#                         Zas code site              nom site  \
# 0  ZAG NANTES-SAINT-NAZAIRE   FR23003          LA MEGRETAIS
# 1       ZR PAYS-DE-LA-LOIRE   FR23068               FROSSAY
# 2  ZAG NANTES-SAINT-NAZAIRE   FR23070  S ETIENNE DE MONTLUC
# 3       ZR PAYS-DE-LA-LOIRE   FR23078         SAINT EXUPERY
# 4  ZAG NANTES-SAINT-NAZAIRE   FR23107        LA CHAUVINIERE
#
#       type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Périurbaine     PM10     Industrielle  ...   17.0    16.625000
# 1  Rurale près des villes     PM10     Industrielle  ...   15.0    15.120833
# 2             Périurbaine     PM10     Industrielle  ...   14.0    13.783333
# 3                 Urbaine     PM10             Fond  ...   18.0    17.875000
# 4                 Urbaine     PM10             Fond  ...   15.0    14.795833
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             A         1  47.322706 -2.039244
# 1                 100.0             A         1  47.247470 -1.936619
# 2                 100.0             A         1  47.283180 -1.783164
# 3                 100.0             A         1  47.054443 -0.886111
# 4                 100.0             A         1  47.252777 -1.573333
#
# [5 rows x 23 columns]
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
#
#                         Zas code site              nom site  \
# 0  ZAG NANTES-SAINT-NAZAIRE   FR23003          LA MEGRETAIS
# 1       ZR PAYS-DE-LA-LOIRE   FR23068               FROSSAY
# 2  ZAG NANTES-SAINT-NAZAIRE   FR23070  S ETIENNE DE MONTLUC
# 3       ZR PAYS-DE-LA-LOIRE   FR23078         SAINT EXUPERY
# 4  ZAG NANTES-SAINT-NAZAIRE   FR23107        LA CHAUVINIERE
#
#       type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Périurbaine     PM10     Industrielle  ...    16.625000
# 1  Rurale près des villes     PM10     Industrielle  ...    15.120833
# 2             Périurbaine     PM10     Industrielle  ...    13.783333
# 3                 Urbaine     PM10             Fond  ...    17.875000
# 4                 Urbaine     PM10             Fond  ...    14.795833
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  47.322706  -2.039244
# 1                  100.0            A         1  47.247470  -1.936619
# 2                  100.0            A         1  47.283180  -1.783164
# 3                  100.0            A         1  47.054443  -0.886111
# 4                  100.0            A         1  47.252777  -1.573333
#
#   ATMO sub-score
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#
# [5 rows x 24 columns]

# %%
# PM2.5 AIR PAYS DE LA LOIRE

# File path to the data
PM25_AIR_PAYS_DE_LA_LOIRE_file_path = os.path.join(base_path, "PM2.5 Moyenne Journalière\Export Moy. journalière - PM2.5 - AIR PAYS DE LA LOIRE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM25 = pd.read_csv(PM25_AIR_PAYS_DE_LA_LOIRE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM25.head())

# Sample ATMO subscore dictionary for PM2.5 (Moyenne journalière)
ATMO_subscore_PM25 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 10.0), (10.0, 20.0), (20.0, 25.0), (25.0, 50.0), (50.0, 75.0), (75.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM25 = pd.DataFrame(ATMO_subscore_PM25)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM25['Range'] = ATMO_subscore_df_PM25['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM2.5 measurement
def assign_subscore_PM25(valeur):
    for index, row in ATMO_subscore_df_PM25.iterrows(): 
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM25['ATMO sub-score'] = df_PM25['valeur'].apply(assign_subscore_PM25)  

# Display the updated DataFrame
print(df_PM25.head())
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
#
#                         Zas code site        nom site type d'implantation  \
# 0  ZAG NANTES-SAINT-NAZAIRE   FR23003    LA MEGRETAIS         Périurbaine
# 1  ZAG NANTES-SAINT-NAZAIRE   FR23107  LA CHAUVINIERE             Urbaine
# 2  ZAG NANTES-SAINT-NAZAIRE   FR23110       LEON BLUM             Urbaine
# 3          ZAR ANGERS-LOIRE   FR23120      BEAUX ARTS             Urbaine
# 4       ZR PAYS-DE-LA-LOIRE   FR23124     LA TARDIERE    Rurale nationale
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0    PM2.5     Industrielle  ...    9.2     9.150000           µg-m3
# 1    PM2.5             Fond  ...    8.8     8.754167           µg-m3
# 2    PM2.5             Fond  ...    0.0     0.000000           µg-m3
# 3    PM2.5             Fond  ...    9.9     9.887500           µg-m3
# 4    PM2.5             Fond  ...    7.6     7.608333           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             A
# 1           100.0                    100                 100.0             A
# 2             0.0                    100                   0.0             N
# 3           100.0                    100                 100.0             A
# 4           100.0                    100                 100.0             A
#
#    validité   Latitude Longitude
# 0         1  47.322706 -2.039244
# 1         1  47.252777 -1.573333
# 2        -1  47.264120 -2.249858
# 3         1  47.468513 -0.556053
# 4         1  46.656685 -0.743681
#
# [5 rows x 23 columns]
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
#
#                         Zas code site        nom site type d'implantation  \
# 0  ZAG NANTES-SAINT-NAZAIRE   FR23003    LA MEGRETAIS         Périurbaine
# 1  ZAG NANTES-SAINT-NAZAIRE   FR23107  LA CHAUVINIERE             Urbaine
# 2  ZAG NANTES-SAINT-NAZAIRE   FR23110       LEON BLUM             Urbaine
# 3          ZAR ANGERS-LOIRE   FR23120      BEAUX ARTS             Urbaine
# 4       ZR PAYS-DE-LA-LOIRE   FR23124     LA TARDIERE    Rurale nationale
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0    PM2.5     Industrielle  ...     9.150000           µg-m3          100.0
# 1    PM2.5             Fond  ...     8.754167           µg-m3          100.0
# 2    PM2.5             Fond  ...     0.000000           µg-m3            0.0
# 3    PM2.5             Fond  ...     9.887500           µg-m3          100.0
# 4    PM2.5             Fond  ...     7.608333           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                    0.0            N        -1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  47.322706  -2.039244            1.0
# 1  47.252777  -1.573333            1.0
# 2  47.264120  -2.249858            1.0
# 3  47.468513  -0.556053            1.0
# 4  46.656685  -0.743681            1.0
#
# [5 rows x 24 columns]

# %%
# NO2 AIR PAYS DE LA LOIRE

# File path to the data
NO2_AIR_PAYS_DE_LA_LOIRE_file_path = os.path.join(base_path, "NO2 Max Horaire Journalier\Export Max. journalier moy. hor. - NO2 - AIR PAYS DE LA LOIRE.csv")
# Use read_csv function from pandas specifying the delimiter as ';'
df_NO2 = pd.read_csv(NO2_AIR_PAYS_DE_LA_LOIRE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_NO2.head())

# Sample ATMO subscore dictionary for NO2 (Max horaire journalier)
ATMO_subscore_NO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 40.0), (40.0, 90.0), (90.0, 120.0), (120.0, 230.0), (230.0, 340.0), (340.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_NO2 = pd.DataFrame(ATMO_subscore_NO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_NO2['Range'] = ATMO_subscore_df_NO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of NO2 measurement
def assign_subscore_NO2(valeur):
    for index, row in ATMO_subscore_df_NO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_NO2['ATMO sub-score'] = df_NO2['valeur'].apply(assign_subscore_NO2)

# Display the updated DataFrame
print(df_NO2.head())
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
#
#                         Zas code site              nom site  \
# 0  ZAG NANTES-SAINT-NAZAIRE   FR23003          LA MEGRETAIS
# 1       ZR PAYS-DE-LA-LOIRE   FR23068               FROSSAY
# 2  ZAG NANTES-SAINT-NAZAIRE   FR23070  S ETIENNE DE MONTLUC
# 3  ZAG NANTES-SAINT-NAZAIRE   FR23075           JULES VERNE
# 4       ZR PAYS-DE-LA-LOIRE   FR23078         SAINT EXUPERY
#
#       type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Périurbaine      NO2     Industrielle  ...   11.7       11.700
# 1  Rurale près des villes      NO2     Industrielle  ...    3.3        3.300
# 2             Périurbaine      NO2     Industrielle  ...    4.7        4.650
# 3             Périurbaine      NO2     Industrielle  ...   22.1       22.125
# 4                 Urbaine      NO2             Fond  ...    3.4        3.375
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             A         1  47.322706 -2.039244
# 1                 100.0             A         1  47.247470 -1.936619
# 2                 100.0             A         1  47.283180 -1.783164
# 3                 100.0             A         1  47.315727 -2.190764
# 4                 100.0             A         1  47.054443 -0.886111
#
# [5 rows x 23 columns]
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
#
#                         Zas code site              nom site  \
# 0  ZAG NANTES-SAINT-NAZAIRE   FR23003          LA MEGRETAIS
# 1       ZR PAYS-DE-LA-LOIRE   FR23068               FROSSAY
# 2  ZAG NANTES-SAINT-NAZAIRE   FR23070  S ETIENNE DE MONTLUC
# 3  ZAG NANTES-SAINT-NAZAIRE   FR23075           JULES VERNE
# 4       ZR PAYS-DE-LA-LOIRE   FR23078         SAINT EXUPERY
#
#       type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Périurbaine      NO2     Industrielle  ...       11.700
# 1  Rurale près des villes      NO2     Industrielle  ...        3.300
# 2             Périurbaine      NO2     Industrielle  ...        4.650
# 3             Périurbaine      NO2     Industrielle  ...       22.125
# 4                 Urbaine      NO2             Fond  ...        3.375
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  47.322706  -2.039244
# 1                  100.0            A         1  47.247470  -1.936619
# 2                  100.0            A         1  47.283180  -1.783164
# 3                  100.0            A         1  47.315727  -2.190764
# 4                  100.0            A         1  47.054443  -0.886111
#
#   ATMO sub-score
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#
# [5 rows x 24 columns]

# %%
# O3 AIR PAYS DE LA LOIRE

# File path to the data
O3_AIR_PAYS_DE_LA_LOIRE_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - AIR PAYS DE LA LOIRE.csv")
# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_AIR_PAYS_DE_LA_LOIRE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Sample ATMO subscore dictionary for O3 (Max horaire journalier)
ATMO_subscore_O3 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 50.0), (50.0, 100.0), (100.0, 130.0), (130.0, 240.0), (240.0, 380.0), (380.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_O3 = pd.DataFrame(ATMO_subscore_O3)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_O3['Range'] = ATMO_subscore_df_O3['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of O3 measurement
def assign_subscore_O3(valeur):
    for index, row in ATMO_subscore_df_O3.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_O3['ATMO sub-score'] = df_O3['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAR03
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAR01
#
#                         Zas code site       nom site type d'implantation  \
# 0       ZR PAYS-DE-LA-LOIRE   FR23078  SAINT EXUPERY             Urbaine
# 1  ZAG NANTES-SAINT-NAZAIRE   FR23110      LEON BLUM             Urbaine
# 2                 ZAR LAVAL   FR23123       MAZAGRAN             Urbaine
# 3       ZR PAYS-DE-LA-LOIRE   FR23124    LA TARDIERE    Rurale nationale
# 4          ZAR ANGERS-LOIRE   FR23150       APPENTIS             Urbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0       O3             Fond  ...   73.4       73.425           µg-m3
# 1       O3             Fond  ...   80.1       80.075           µg-m3
# 2       O3             Fond  ...   73.9       73.900           µg-m3
# 3       O3             Fond  ...   60.3       60.325           µg-m3
# 4       O3             Fond  ...   70.4       70.375           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             A
# 1           100.0                    100                 100.0             A
# 2           100.0                    100                 100.0             A
# 3           100.0                    100                 100.0             A
# 4           100.0                    100                 100.0             A
#
#    validité   Latitude Longitude
# 0         1  47.054443 -0.886111
# 1         1  47.264120 -2.249858
# 2         1  48.069430 -0.767692
# 3         1  46.656685 -0.743681
# 4         1  47.447390 -0.550067
#
# [5 rows x 23 columns]
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAR03
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAR01
#
#                         Zas code site       nom site type d'implantation  \
# 0       ZR PAYS-DE-LA-LOIRE   FR23078  SAINT EXUPERY             Urbaine
# 1  ZAG NANTES-SAINT-NAZAIRE   FR23110      LEON BLUM             Urbaine
# 2                 ZAR LAVAL   FR23123       MAZAGRAN             Urbaine
# 3       ZR PAYS-DE-LA-LOIRE   FR23124    LA TARDIERE    Rurale nationale
# 4          ZAR ANGERS-LOIRE   FR23150       APPENTIS             Urbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0       O3             Fond  ...       73.425           µg-m3          100.0
# 1       O3             Fond  ...       80.075           µg-m3          100.0
# 2       O3             Fond  ...       73.900           µg-m3          100.0
# 3       O3             Fond  ...       60.325           µg-m3          100.0
# 4       O3             Fond  ...       70.375           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  47.054443  -0.886111              2
# 1  47.264120  -2.249858              2
# 2  48.069430  -0.767692              2
# 3  46.656685  -0.743681              2
# 4  47.447390  -0.550067              2
#
# [5 rows x 24 columns]

# %%
# SO2 AIR PAYS DE LA LOIRE 

# File path to the data
SO2_AIR_PAYS_DE_LA_LOIRE_file_path = os.path.join(base_path, "SO2 Max Horaire Journalier\Export Max. journalier moy. hor. - SO2 - AIR PAYS DE LA LOIRE.csv")
# Use read_csv function from pandas specifying the delimiter as ';'
df_SO2 = pd.read_csv(SO2_AIR_PAYS_DE_LA_LOIRE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_SO2.head())

# Sample ATMO subscore dictionary for SO2 (Max horaire journalier)
ATMO_subscore_SO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 100.0), (100.0, 200.0), (200.0, 350.0), (350.0, 500.0), (500.0, 750.0), (750.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_SO2 = pd.DataFrame(ATMO_subscore_SO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_SO2['Range'] = ATMO_subscore_df_SO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of SO2 measurement
def assign_subscore_SO2(valeur):
    for index, row in ATMO_subscore_df_SO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_SO2['ATMO sub-score'] = df_SO2['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_SO2.head())
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
#
#                         Zas code site      nom site     type d'implantation  \
# 0  ZAG NANTES-SAINT-NAZAIRE   FR23001        AMPERE             Périurbaine
# 1  ZAG NANTES-SAINT-NAZAIRE   FR23003  LA MEGRETAIS             Périurbaine
# 2  ZAG NANTES-SAINT-NAZAIRE   FR23004       PASTEUR             Périurbaine
# 3       ZR PAYS-DE-LA-LOIRE   FR23068       FROSSAY  Rurale près des villes
# 4  ZAG NANTES-SAINT-NAZAIRE   FR23069       SAVENAY             Périurbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0      SO2     Industrielle  ...    5.1      5.07500           µg-m3
# 1      SO2     Industrielle  ...   13.7     13.66667           µg-m3
# 2      SO2     Industrielle  ...   11.1     11.07500           µg-m3
# 3      SO2     Industrielle  ...    1.9      1.85000           µg-m3
# 4      SO2     Industrielle  ...    0.9      0.90000           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             R
# 1           100.0                    100                 100.0             R
# 2           100.0                    100                 100.0             R
# 3           100.0                    100                 100.0             R
# 4           100.0                    100                 100.0             R
#
#    validité   Latitude Longitude
# 0         1  47.324097 -2.081567
# 1         1  47.322706 -2.039244
# 2         1  47.317284 -2.073306
# 3         1  47.247470 -1.936619
# 4         1  47.360750 -1.954750
#
# [5 rows x 23 columns]
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
#
#                         Zas code site      nom site     type d'implantation  \
# 0  ZAG NANTES-SAINT-NAZAIRE   FR23001        AMPERE             Périurbaine
# 1  ZAG NANTES-SAINT-NAZAIRE   FR23003  LA MEGRETAIS             Périurbaine
# 2  ZAG NANTES-SAINT-NAZAIRE   FR23004       PASTEUR             Périurbaine
# 3       ZR PAYS-DE-LA-LOIRE   FR23068       FROSSAY  Rurale près des villes
# 4  ZAG NANTES-SAINT-NAZAIRE   FR23069       SAVENAY             Périurbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0      SO2     Industrielle  ...      5.07500           µg-m3          100.0
# 1      SO2     Industrielle  ...     13.66667           µg-m3          100.0
# 2      SO2     Industrielle  ...     11.07500           µg-m3          100.0
# 3      SO2     Industrielle  ...      1.85000           µg-m3          100.0
# 4      SO2     Industrielle  ...      0.90000           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            R         1
# 1                    100                  100.0            R         1
# 2                    100                  100.0            R         1
# 3                    100                  100.0            R         1
# 4                    100                  100.0            R         1
#
#     Latitude  Longitude ATMO sub-score
# 0  47.324097  -2.081567            1.0
# 1  47.322706  -2.039244            1.0
# 2  47.317284  -2.073306            1.0
# 3  47.247470  -1.936619            1.0
# 4  47.360750  -1.954750            1.0
#
# [5 rows x 24 columns]

# %%
# Combining 5 (if not missing) dataframes
# Concatenate DataFrames along the rows (stack them vertically)
combined_df_AIR_PAYS_DE_LA_LOIRE = pd.concat([df_PM10, df_PM25, df_NO2, df_O3, df_SO2], axis=0) #

# If you want to reset the index of the combined DataFrame
combined_df_AIR_PAYS_DE_LA_LOIRE.reset_index(drop=True, inplace=True)

# Renaming the ATMO subscore column to 'ATMO Score'
combined_df_AIR_PAYS_DE_LA_LOIRE = combined_df_AIR_PAYS_DE_LA_LOIRE.rename(columns={'ATMO sub-score': 'ATMO Score'})

# Printing the first five rows as a sanity check
print(combined_df_AIR_PAYS_DE_LA_LOIRE.head())
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
#
#                         Zas code site              nom site  \
# 0  ZAG NANTES-SAINT-NAZAIRE   FR23003          LA MEGRETAIS
# 1       ZR PAYS-DE-LA-LOIRE   FR23068               FROSSAY
# 2  ZAG NANTES-SAINT-NAZAIRE   FR23070  S ETIENNE DE MONTLUC
# 3       ZR PAYS-DE-LA-LOIRE   FR23078         SAINT EXUPERY
# 4  ZAG NANTES-SAINT-NAZAIRE   FR23107        LA CHAUVINIERE
#
#       type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Périurbaine     PM10     Industrielle  ...    16.625000
# 1  Rurale près des villes     PM10     Industrielle  ...    15.120833
# 2             Périurbaine     PM10     Industrielle  ...    13.783333
# 3                 Urbaine     PM10             Fond  ...    17.875000
# 4                 Urbaine     PM10             Fond  ...    14.795833
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  47.322706  -2.039244
# 1                  100.0            A         1  47.247470  -1.936619
# 2                  100.0            A         1  47.283180  -1.783164
# 3                  100.0            A         1  47.054443  -0.886111
# 4                  100.0            A         1  47.252777  -1.573333
#
#   ATMO Score
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#
# [5 rows x 24 columns]

# %%
# Find the index of rows with maximum 'ATMO Score' within each group
idx_max_scores = combined_df_AIR_PAYS_DE_LA_LOIRE.groupby(['nom site', 'Date de fin'])['ATMO Score'].idxmax()

# Select rows with the maximum 'ATMO Score' using the index
final_df_AIR_PAYS_DE_LA_LOIRE = combined_df_AIR_PAYS_DE_LA_LOIRE.loc[idx_max_scores]

# Reset index if needed
final_df_AIR_PAYS_DE_LA_LOIRE.reset_index(drop=True, inplace=True)

# %%
# Downloading the final dataframe of Daily ATMO Score in AIR PAYS DE LA LOIRE to csv
final_df_AIR_PAYS_DE_LA_LOIRE.to_csv('final_df_AIR_PAYS_DE_LA_LOIRE.csv', index=False, encoding = 'latin1')

# %%
# Constructing indicator for AIR PAYS DE LA LOIRE

# File path to the data
ATMO_AIR_PAYS_DE_LA_LOIRE_file_path = os.path.join(base_path, "final_df_AIR_PAYS_DE_LA_LOIRE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_ATMO = pd.read_csv(ATMO_AIR_PAYS_DE_LA_LOIRE_file_path, delimiter=',', encoding = 'latin1')

print(df_ATMO.head())

counts = df_ATMO.groupby('nom site')['ATMO Score'].value_counts().reset_index(name='counts')
#print(counts)

#result = pd.merge(counts, df_ATMO[["Organisme", "type d'implantation", "Latitude", "Longitude"]], on='nom site', how='left')
#print(result)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_ATMO.groupby('nom site').first().reset_index()
#print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(counts, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score_y'], axis = 1)
print(result)
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 1  2023/01/02 00:00:00  2023/01/02 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 2  2023/01/03 00:00:00  2023/01/03 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 3  2023/01/04 00:00:00  2023/01/04 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
# 4  2023/01/05 00:00:00  2023/01/05 23:59:59  AIR PAYS DE LA LOIRE  FR52ZAG01
#
#                         Zas code site nom site type d'implantation Polluant  \
# 0  ZAG NANTES-SAINT-NAZAIRE   FR23001   AMPERE         Périurbaine      SO2
# 1  ZAG NANTES-SAINT-NAZAIRE   FR23001   AMPERE         Périurbaine      SO2
# 2  ZAG NANTES-SAINT-NAZAIRE   FR23001   AMPERE         Périurbaine      SO2
# 3  ZAG NANTES-SAINT-NAZAIRE   FR23001   AMPERE         Périurbaine      SO2
# 4  ZAG NANTES-SAINT-NAZAIRE   FR23001   AMPERE         Périurbaine      SO2
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0     Industrielle  ...      5.07500           µg-m3          100.0
# 1     Industrielle  ...      2.30000           µg-m3          100.0
# 2     Industrielle  ...      1.37500           µg-m3          100.0
# 3     Industrielle  ...      0.86667           µg-m3          100.0
# 4     Industrielle  ...      0.82500           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            R         1
# 1                    100                  100.0            R         1
# 2                    100                  100.0            R         1
# 3                    100                  100.0            R         1
# 4                    100                  100.0            R         1
#
#     Latitude  Longitude ATMO Score
# 0  47.324097  -2.081567        1.0
# 1  47.324097  -2.081567        1.0
# 2  47.324097  -2.081567        1.0
# 3  47.324097  -2.081567        1.0
# 4  47.324097  -2.081567        1.0
#
# [5 rows x 24 columns]
#      nom site  ATMO Score_x  counts             Organisme   code zas  \
# 0      AMPERE           1.0     363  AIR PAYS DE LA LOIRE  FR52ZAG01
# 1      AMPERE           2.0       2  AIR PAYS DE LA LOIRE  FR52ZAG01
# 2    APPENTIS           2.0     297  AIR PAYS DE LA LOIRE  FR52ZAR01
# 3    APPENTIS           3.0      45  AIR PAYS DE LA LOIRE  FR52ZAR01
# 4    APPENTIS           1.0      13  AIR PAYS DE LA LOIRE  FR52ZAR01
# ..        ...           ...     ...                   ...        ...
# 111   SAVENAY           1.0     348  AIR PAYS DE LA LOIRE  FR52ZAG01
# 112   SOURCES           2.0     276  AIR PAYS DE LA LOIRE  FR52ZAR02
# 113   SOURCES           3.0      55  AIR PAYS DE LA LOIRE  FR52ZAR02
# 114   SOURCES           4.0      21  AIR PAYS DE LA LOIRE  FR52ZAR02
# 115   SOURCES           1.0      13  AIR PAYS DE LA LOIRE  FR52ZAR02
#
#                           Zas code site type d'implantation Polluant  \
# 0    ZAG NANTES-SAINT-NAZAIRE   FR23001         Périurbaine      SO2
# 1    ZAG NANTES-SAINT-NAZAIRE   FR23001         Périurbaine      SO2
# 2            ZAR ANGERS-LOIRE   FR23150             Urbaine       O3
# 3            ZAR ANGERS-LOIRE   FR23150             Urbaine       O3
# 4            ZAR ANGERS-LOIRE   FR23150             Urbaine       O3
# ..                        ...       ...                 ...      ...
# 111  ZAG NANTES-SAINT-NAZAIRE   FR23069         Périurbaine      SO2
# 112               ZAR LE-MANS   FR23182             Urbaine       O3
# 113               ZAR LE-MANS   FR23182             Urbaine       O3
# 114               ZAR LE-MANS   FR23182             Urbaine       O3
# 115               ZAR LE-MANS   FR23182             Urbaine       O3
#
#     type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0       Industrielle  ...    5.1        5.075           µg-m3           100.0
# 1       Industrielle  ...    5.1        5.075           µg-m3           100.0
# 2               Fond  ...   70.4       70.375           µg-m3           100.0
# 3               Fond  ...   70.4       70.375           µg-m3           100.0
# 4               Fond  ...   70.4       70.375           µg-m3           100.0
# ..               ...  ...    ...          ...             ...             ...
# 111     Industrielle  ...    0.9        0.900           µg-m3           100.0
# 112             Fond  ...   71.2       71.200           µg-m3           100.0
# 113             Fond  ...   71.2       71.200           µg-m3           100.0
# 114             Fond  ...   71.2       71.200           µg-m3           100.0
# 115             Fond  ...   71.2       71.200           µg-m3           100.0
#
#      couverture temporelle couverture de données  code qualité  validité  \
# 0                      100                 100.0             R         1
# 1                      100                 100.0             R         1
# 2                      100                 100.0             A         1
# 3                      100                 100.0             A         1
# 4                      100                 100.0             A         1
# ..                     ...                   ...           ...       ...
# 111                    100                 100.0             R         1
# 112                    100                 100.0             A         1
# 113                    100                 100.0             A         1
# 114                    100                 100.0             A         1
# 115                    100                 100.0             A         1
#
#       Latitude Longitude
# 0    47.324097 -2.081567
# 1    47.324097 -2.081567
# 2    47.447390 -0.550067
# 3    47.447390 -0.550067
# 4    47.447390 -0.550067
# ..         ...       ...
# 111  47.360750 -1.954750
# 112  47.971066  0.221422
# 113  47.971066  0.221422
# 114  47.971066  0.221422
# 115  47.971066  0.221422
#
# [116 rows x 23 columns]

# %%
# Group the DataFrame by 'nom' and calculate the total counts for each 'nom'
total_counts_by_nom = result.groupby('nom site')['counts'].sum()

# Filter the DataFrame to include only rows where the score is equal to or greater than 3
filtered_result = result[result['ATMO Score_x'] >= 3]

# Group the filtered DataFrame by 'nom' and calculate the counts equal to or greater than 3 for each 'nom'
counts_greater_than_3_by_nom = filtered_result.groupby('nom site')['counts'].sum()

# Calculate the ratio of counts greater than or equal to 3 over total counts for each 'nom'
ratio_counts_greater_than_3 = (counts_greater_than_3_by_nom / total_counts_by_nom).fillna(0)

# Display the resulting Series
print(ratio_counts_greater_than_3)

# Merge the site-specific information with the counts DataFrame
ratio_counts_greater_than_3_df = pd.merge(ratio_counts_greater_than_3, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score'], axis = 1)
ratio_counts_greater_than_3_df = ratio_counts_greater_than_3_df.rename(columns={'counts': 'indicator'})
print(ratio_counts_greater_than_3_df)
# Out:
# nom site
# AMPERE                  0.000000
# APPENTIS                0.150685
# BEAUX ARTS              0.087671
# CAME                    0.049315
# CAMEE                   0.172414
# CIM BOUTEILLERIE        0.186301
# CLOS DES BEAUVAIS       0.156164
# CUTULLIC2               0.000000
# DELACROIX               0.189041
# EPINETTES               0.151261
# FRERES GONCOURT         0.133144
# FROSSAY                 0.008219
# Fillé                   0.156977
# GASPARD                 0.137741
# GUEDOU                  0.000000
# JULES VERNE             0.000000
# LA CHAUVINIERE          0.065753
# LA MEGRETAIS            0.051948
# LA TARDIERE             0.145205
# LEON BLUM               0.169863
# LES COUETS              0.060274
# LEVOYER                 0.020080
# MAZAGRAN                0.134247
# PARC PAYSAGER           0.000000
# PARSCAU DU PLESSIS      0.063014
# PASTEUR                 0.008287
# ROI RENE                0.087912
# S ETIENNE DE MONTLUC    0.035616
# SAINT EXUPERY           0.161644
# SAINT-DENIS D'ANJOU     0.161644
# SAVENAY                 0.000000
# SOURCES                 0.208219
# Name: counts, dtype: float64
#                 nom site  indicator             Organisme   code zas  \
# 0                 AMPERE   0.000000  AIR PAYS DE LA LOIRE  FR52ZAG01
# 1               APPENTIS   0.150685  AIR PAYS DE LA LOIRE  FR52ZAR01
# 2             BEAUX ARTS   0.087671  AIR PAYS DE LA LOIRE  FR52ZAR01
# 3                   CAME   0.049315  AIR PAYS DE LA LOIRE  FR52ZAG01
# 4                  CAMEE   0.172414  AIR PAYS DE LA LOIRE  FR52ZAG01
# 5       CIM BOUTEILLERIE   0.186301  AIR PAYS DE LA LOIRE  FR52ZAG01
# 6      CLOS DES BEAUVAIS   0.156164  AIR PAYS DE LA LOIRE  FR52ZAR01
# 7              CUTULLIC2   0.000000  AIR PAYS DE LA LOIRE  FR52ZRE01
# 8              DELACROIX   0.189041  AIR PAYS DE LA LOIRE  FR52ZRE01
# 9              EPINETTES   0.151261  AIR PAYS DE LA LOIRE  FR52ZAG01
# 10       FRERES GONCOURT   0.133144  AIR PAYS DE LA LOIRE  FR52ZAG01
# 11               FROSSAY   0.008219  AIR PAYS DE LA LOIRE  FR52ZRE01
# 12                 Fillé   0.156977  AIR PAYS DE LA LOIRE  FR52ZRE01
# 13               GASPARD   0.137741  AIR PAYS DE LA LOIRE  FR52ZAG01
# 14                GUEDOU   0.000000  AIR PAYS DE LA LOIRE  FR52ZAR02
# 15           JULES VERNE   0.000000  AIR PAYS DE LA LOIRE  FR52ZAG01
# 16        LA CHAUVINIERE   0.065753  AIR PAYS DE LA LOIRE  FR52ZAG01
# 17          LA MEGRETAIS   0.051948  AIR PAYS DE LA LOIRE  FR52ZAG01
# 18           LA TARDIERE   0.145205  AIR PAYS DE LA LOIRE  FR52ZRE01
# 19             LEON BLUM   0.169863  AIR PAYS DE LA LOIRE  FR52ZAG01
# 20            LES COUETS   0.060274  AIR PAYS DE LA LOIRE  FR52ZAG01
# 21               LEVOYER   0.020080  AIR PAYS DE LA LOIRE  FR52ZAG01
# 22              MAZAGRAN   0.134247  AIR PAYS DE LA LOIRE  FR52ZAR03
# 23         PARC PAYSAGER   0.000000  AIR PAYS DE LA LOIRE  FR52ZAG01
# 24    PARSCAU DU PLESSIS   0.063014  AIR PAYS DE LA LOIRE  FR52ZAG01
# 25               PASTEUR   0.008287  AIR PAYS DE LA LOIRE  FR52ZAG01
# 26              ROI RENE   0.087912  AIR PAYS DE LA LOIRE  FR52ZAR01
# 27  S ETIENNE DE MONTLUC   0.035616  AIR PAYS DE LA LOIRE  FR52ZAG01
# 28         SAINT EXUPERY   0.161644  AIR PAYS DE LA LOIRE  FR52ZRE01
# 29   SAINT-DENIS D'ANJOU   0.161644  AIR PAYS DE LA LOIRE  FR52ZRE01
# 30               SAVENAY   0.000000  AIR PAYS DE LA LOIRE  FR52ZAG01
# 31               SOURCES   0.208219  AIR PAYS DE LA LOIRE  FR52ZAR02
#
#                          Zas code site     type d'implantation Polluant  \
# 0   ZAG NANTES-SAINT-NAZAIRE   FR23001             Périurbaine      SO2
# 1           ZAR ANGERS-LOIRE   FR23150                 Urbaine       O3
# 2           ZAR ANGERS-LOIRE   FR23120                 Urbaine     PM10
# 3   ZAG NANTES-SAINT-NAZAIRE   FR23249             Périurbaine     PM10
# 4   ZAG NANTES-SAINT-NAZAIRE   FR23238                 Urbaine     PM10
# 5   ZAG NANTES-SAINT-NAZAIRE   FR23188                 Urbaine       O3
# 6           ZAR ANGERS-LOIRE   FR23175             Périurbaine       O3
# 7        ZR PAYS-DE-LA-LOIRE   FR23149             Périurbaine      SO2
# 8        ZR PAYS-DE-LA-LOIRE   FR23152                 Urbaine       O3
# 9   ZAG NANTES-SAINT-NAZAIRE   FR23157             Périurbaine       O3
# 10  ZAG NANTES-SAINT-NAZAIRE   FR23251                 Urbaine      NO2
# 11       ZR PAYS-DE-LA-LOIRE   FR23068  Rurale près des villes     PM10
# 12       ZR PAYS-DE-LA-LOIRE   FR23163             Périurbaine       O3
# 13  ZAG NANTES-SAINT-NAZAIRE   FR23230             Périurbaine       O3
# 14               ZAR LE-MANS   FR23174                 Urbaine      NO2
# 15  ZAG NANTES-SAINT-NAZAIRE   FR23075             Périurbaine      NO2
# 16  ZAG NANTES-SAINT-NAZAIRE   FR23107                 Urbaine     PM10
# 17  ZAG NANTES-SAINT-NAZAIRE   FR23003             Périurbaine     PM10
# 18       ZR PAYS-DE-LA-LOIRE   FR23124        Rurale nationale       O3
# 19  ZAG NANTES-SAINT-NAZAIRE   FR23110                 Urbaine       O3
# 20  ZAG NANTES-SAINT-NAZAIRE   FR23239                 Urbaine     PM10
# 21  ZAG NANTES-SAINT-NAZAIRE   FR23238                 Urbaine     PM10
# 22                 ZAR LAVAL   FR23123                 Urbaine       O3
# 23  ZAG NANTES-SAINT-NAZAIRE   FR23181                 Urbaine      NO2
# 24  ZAG NANTES-SAINT-NAZAIRE   FR23178             Périurbaine     PM10
# 25  ZAG NANTES-SAINT-NAZAIRE   FR23004             Périurbaine      SO2
# 26          ZAR ANGERS-LOIRE   FR23242                 Urbaine     PM10
# 27  ZAG NANTES-SAINT-NAZAIRE   FR23070             Périurbaine     PM10
# 28       ZR PAYS-DE-LA-LOIRE   FR23078                 Urbaine       O3
# 29       ZR PAYS-DE-LA-LOIRE   FR23177        Rurale régionale       O3
# 30  ZAG NANTES-SAINT-NAZAIRE   FR23069             Périurbaine      SO2
# 31               ZAR LE-MANS   FR23182                 Urbaine       O3
#
#    type d'influence Réglementaire  ... valeur valeur brute  unité de mesure  \
# 0      Industrielle           Oui  ...    5.1     5.075000            µg-m3
# 1              Fond           Oui  ...   70.4    70.375000            µg-m3
# 2              Fond           Oui  ...   18.0    18.312500            µg-m3
# 3      Industrielle           Oui  ...   15.0    15.175000            µg-m3
# 4      Industrielle           Oui  ...    0.0     0.000000            µg-m3
# 5              Fond           Oui  ...   66.2    66.150000            µg-m3
# 6              Fond           Oui  ...   68.8    68.775000            µg-m3
# 7      Industrielle           Oui  ...    1.6     1.633330            µg-m3
# 8              Fond           Oui  ...   74.2    74.175000            µg-m3
# 9              Fond           Oui  ...   77.6    77.575000            µg-m3
# 10           Trafic           Oui  ...   43.7    43.675000            µg-m3
# 11     Industrielle           Oui  ...   15.0    15.120833            µg-m3
# 12             Fond           Oui  ...   69.4    69.425000            µg-m3
# 13             Fond           Oui  ...   80.0    80.000000            µg-m3
# 14             Fond           Oui  ...    8.5     8.525000            µg-m3
# 15     Industrielle           Oui  ...   22.1    22.125000            µg-m3
# 16             Fond           Oui  ...   15.0    14.795833            µg-m3
# 17     Industrielle           Oui  ...   17.0    16.625000            µg-m3
# 18             Fond           Oui  ...   60.3    60.325000            µg-m3
# 19             Fond           Oui  ...   80.1    80.075000            µg-m3
# 20     Industrielle           Oui  ...   14.0    14.183333            µg-m3
# 21     Industrielle           Oui  ...    8.0     8.470833            µg-m3
# 22             Fond           Oui  ...   73.9    73.900000            µg-m3
# 23             Fond           Oui  ...   15.2    15.150000            µg-m3
# 24     Industrielle           Oui  ...   16.0    15.600000            µg-m3
# 25     Industrielle           Oui  ...   11.1    11.075000            µg-m3
# 26           Trafic           Oui  ...   16.0    16.145833            µg-m3
# 27     Industrielle           Oui  ...   14.0    13.783333            µg-m3
# 28             Fond           Oui  ...   73.4    73.425000            µg-m3
# 29             Fond           Oui  ...   71.9    71.875000            µg-m3
# 30     Industrielle           Oui  ...    0.9     0.900000            µg-m3
# 31             Fond           Oui  ...   71.2    71.200000            µg-m3
#
#     taux de saisie couverture temporelle  couverture de données  code qualité  \
# 0            100.0                   100                  100.0             R
# 1            100.0                   100                  100.0             A
# 2            100.0                   100                  100.0             A
# 3            100.0                   100                  100.0             A
# 4              0.0                   100                    0.0             N
# 5            100.0                   100                  100.0             A
# 6            100.0                   100                  100.0             A
# 7            100.0                   100                  100.0             R
# 8            100.0                   100                  100.0             A
# 9            100.0                   100                  100.0             A
# 10           100.0                   100                  100.0             A
# 11           100.0                   100                  100.0             A
# 12           100.0                   100                  100.0             A
# 13           100.0                   100                  100.0             A
# 14           100.0                   100                  100.0             A
# 15           100.0                   100                  100.0             A
# 16           100.0                   100                  100.0             A
# 17           100.0                   100                  100.0             A
# 18           100.0                   100                  100.0             A
# 19           100.0                   100                  100.0             A
# 20           100.0                   100                  100.0             R
# 21           100.0                   100                  100.0             A
# 22           100.0                   100                  100.0             A
# 23           100.0                   100                  100.0             A
# 24           100.0                   100                  100.0             A
# 25           100.0                   100                  100.0             R
# 26           100.0                   100                  100.0             A
# 27           100.0                   100                  100.0             A
# 28           100.0                   100                  100.0             A
# 29           100.0                   100                  100.0             A
# 30           100.0                   100                  100.0             R
# 31           100.0                   100                  100.0             A
#
#     validité   Latitude  Longitude
# 0          1  47.324097  -2.081567
# 1          1  47.447390  -0.550067
# 2          1  47.468513  -0.556053
# 3          1  47.321078  -2.127322
# 4         -1  47.194147  -1.581678
# 5          1  47.222500  -1.537500
# 6          1  47.430164  -0.610064
# 7          1  47.286114  -2.032289
# 8          1  46.660700  -1.436831
# 9          1  47.146088  -1.690269
# 10         1  47.204122  -1.564811
# 11         1  47.247470  -1.936619
# 12         1  47.921920   0.151825
# 13         1  47.253056  -2.332067
# 14         1  47.988920   0.195983
# 15         1  47.315727  -2.190764
# 16         1  47.252777  -1.573333
# 17         1  47.322706  -2.039244
# 18         1  46.656685  -0.743681
# 19         1  47.264120  -2.249858
# 20         1  47.185919  -1.591497
# 21         1  47.194147  -1.581678
# 22         1  48.069430  -0.767692
# 23         1  47.273056  -2.223056
# 24         1  47.319157  -2.066953
# 25         1  47.317284  -2.073306
# 26         1  47.466992  -0.554686
# 27         1  47.283180  -1.783164
# 28         1  47.054443  -0.886111
# 29         1  47.787730  -0.444044
# 30         1  47.360750  -1.954750
# 31         1  47.971066   0.221422
#
# [32 rows x 22 columns]

# %%
# Downloading the final indicator of AIR PAYS DE LA LOIRE to csv
ratio_counts_greater_than_3_df.to_csv('indicator_AIR_PAYS_DE_LA_LOIRE.csv', index=False, encoding = 'latin1')

# %%
# -----------------------------------------------------------------------------------------------------------------------------------------------------
#                                                               Sanity Checks
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %%
print(df_PM25['valeur'].head())
# Out:
# 0    9.2
# 1    8.8
# 2    0.0
# 3    9.9
# 4    7.6
# Name: valeur, dtype: float64

# %%
df_PM25['ATMO sub-score'].describe()
# Out:
# count    5117.000000
# mean        1.324213
# std         0.676757
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         5.000000
# Name: ATMO sub-score, dtype: float64

# %%
print(df_PM25['valeur'].head())
# Out:
# 0    9.2
# 1    8.8
# 2    0.0
# 3    9.9
# 4    7.6
# Name: valeur, dtype: float64
