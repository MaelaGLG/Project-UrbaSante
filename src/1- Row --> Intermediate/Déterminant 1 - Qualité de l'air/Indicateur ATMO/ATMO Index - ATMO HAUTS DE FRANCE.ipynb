# %%
# Code for extracting the daily ATMO score for each station in ATMO HAUTS DE FRANCE (Région: HAUTS DE FRANCE)

# %%
# Installing required packages
import pandas as pd

import os

# Base directory path
base_path = ".\data\raw\Données de la qualité de l'air (Indicateurs SOMO35 et ATMO)\"

# %%
# PM10 ATMO HAUTS DE FRANCE

# File path to the data
PM10_ATMO_HAUTS_DE_FRANCE_file_path = os.path.join(base_path, "PM10 Moyenne Journalière\Export Moy. journalière - PM10 - ATMO HAUTS DE FRANCE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM10 = pd.read_csv(PM10_ATMO_HAUTS_DE_FRANCE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM10.head())

# Sample ATMO subscore dictionary for PM10 (Moyenne journalière)
ATMO_subscore_PM10 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 20.0), (20.0, 40.0), (40.0, 50.0), (50.0, 100.0), (100.0, 150.0), (150.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM10 = pd.DataFrame(ATMO_subscore_PM10)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM10['Range'] = ATMO_subscore_df_PM10['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM10 measurement
def assign_subscore_PM10(valeur):
    for index, row in ATMO_subscore_df_PM10.iterrows():  
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM10['ATMO sub-score'] = df_PM10['valeur'].apply(assign_subscore_PM10)  

# Display the updated DataFrame
print(df_PM10.head())
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
#
#                   Zas code site              nom site type d'implantation  \
# 0            ZAG BLDV   FR06001  Valenciennes Acacias             Urbaine
# 1            ZAG BLDV   FR06003        Douai Theuriet             Urbaine
# 2            ZAG BLDV   FR06006   Valenciennes Wallon             Urbaine
# 3  ZR HAUTS-DE-FRANCE   FR06007      Maubeuge Joyeuse             Urbaine
# 4            ZAG BLDV   FR06011        Denain Villars         Périurbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0     PM10             Fond  ...   10.0     9.591667           µg-m3
# 1     PM10             Fond  ...   13.0    13.033333           µg-m3
# 2     PM10           Trafic  ...   13.0    12.995833           µg-m3
# 3     PM10             Fond  ...   12.0    11.937500           µg-m3
# 4     PM10             Fond  ...    0.0     0.000000           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             A
# 1           100.0                    100                 100.0             A
# 2           100.0                    100                 100.0             A
# 3           100.0                    100                 100.0             A
# 4             0.0                    100                   0.0             N
#
#    validité  Latitude Longitude
# 0         1  50.35853   3.50804
# 1         1  50.37822   3.06586
# 2         1  50.36425   3.52273
# 3         1  50.27936   3.97691
# 4        -1  50.32276   3.39593
#
# [5 rows x 23 columns]
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
#
#                   Zas code site              nom site type d'implantation  \
# 0            ZAG BLDV   FR06001  Valenciennes Acacias             Urbaine
# 1            ZAG BLDV   FR06003        Douai Theuriet             Urbaine
# 2            ZAG BLDV   FR06006   Valenciennes Wallon             Urbaine
# 3  ZR HAUTS-DE-FRANCE   FR06007      Maubeuge Joyeuse             Urbaine
# 4            ZAG BLDV   FR06011        Denain Villars         Périurbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0     PM10             Fond  ...     9.591667           µg-m3          100.0
# 1     PM10             Fond  ...    13.033333           µg-m3          100.0
# 2     PM10           Trafic  ...    12.995833           µg-m3          100.0
# 3     PM10             Fond  ...    11.937500           µg-m3          100.0
# 4     PM10             Fond  ...     0.000000           µg-m3            0.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                    0.0            N        -1
#
#    Latitude  Longitude ATMO sub-score
# 0  50.35853    3.50804              1
# 1  50.37822    3.06586              1
# 2  50.36425    3.52273              1
# 3  50.27936    3.97691              1
# 4  50.32276    3.39593              1
#
# [5 rows x 24 columns]

# %%
# PM2.5 ATMO HAUTS DE FRANCE

# File path to the data
PM25_ATMO_HAUTS_DE_FRANCE_file_path = os.path.join(base_path, "PM2.5 Moyenne Journalière\Export Moy. journalière - PM2.5 - ATMO HAUTS DE FRANCE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM25 = pd.read_csv(PM25_ATMO_HAUTS_DE_FRANCE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM25.head())

# Sample ATMO subscore dictionary for PM2.5 (Moyenne journalière)
ATMO_subscore_PM25 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 10.0), (10.0, 20.0), (20.0, 25.0), (25.0, 50.0), (50.0, 75.0), (75.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM25 = pd.DataFrame(ATMO_subscore_PM25)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM25['Range'] = ATMO_subscore_df_PM25['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM2.5 measurement
def assign_subscore_PM25(valeur):
    for index, row in ATMO_subscore_df_PM25.iterrows(): 
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM25['ATMO sub-score'] = df_PM25['valeur'].apply(assign_subscore_PM25)  

# Display the updated DataFrame
print(df_PM25.head())
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAR01
#
#                   Zas code site             nom site     type d'implantation  \
# 0            ZAG BLDV   FR06003       Douai Theuriet                 Urbaine
# 1            ZAG BLDV   FR06006  Valenciennes Wallon                 Urbaine
# 2            ZAG BLDV   FR06011       Denain Villars             Périurbaine
# 3  ZR HAUTS-DE-FRANCE   FR06133           Cartignies  Rurale près des villes
# 4    ZAR COTE-D-OPALE   FR10004       Malo-les-Bains                 Urbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0    PM2.5             Fond  ...    7.1     7.087500           µg-m3
# 1    PM2.5           Trafic  ...    6.0     5.966667           µg-m3
# 2    PM2.5             Fond  ...    5.6     5.579167           µg-m3
# 3    PM2.5             Fond  ...    6.5     6.541667           µg-m3
# 4    PM2.5             Fond  ...    8.5     8.487500           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             A
# 1           100.0                    100                 100.0             A
# 2           100.0                    100                 100.0             A
# 3           100.0                    100                 100.0             A
# 4           100.0                    100                 100.0             A
#
#    validité  Latitude Longitude
# 0         1  50.37822   3.06586
# 1         1  50.36425   3.52273
# 2         1  50.32276   3.39593
# 3         1  50.09225   3.85003
# 4         1  51.04858   2.42004
#
# [5 rows x 23 columns]
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAR01
#
#                   Zas code site             nom site     type d'implantation  \
# 0            ZAG BLDV   FR06003       Douai Theuriet                 Urbaine
# 1            ZAG BLDV   FR06006  Valenciennes Wallon                 Urbaine
# 2            ZAG BLDV   FR06011       Denain Villars             Périurbaine
# 3  ZR HAUTS-DE-FRANCE   FR06133           Cartignies  Rurale près des villes
# 4    ZAR COTE-D-OPALE   FR10004       Malo-les-Bains                 Urbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0    PM2.5             Fond  ...     7.087500           µg-m3          100.0
# 1    PM2.5           Trafic  ...     5.966667           µg-m3          100.0
# 2    PM2.5             Fond  ...     5.579167           µg-m3          100.0
# 3    PM2.5             Fond  ...     6.541667           µg-m3          100.0
# 4    PM2.5             Fond  ...     8.487500           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#    Latitude  Longitude ATMO sub-score
# 0  50.37822    3.06586            1.0
# 1  50.36425    3.52273            1.0
# 2  50.32276    3.39593            1.0
# 3  50.09225    3.85003            1.0
# 4  51.04858    2.42004            1.0
#
# [5 rows x 24 columns]

# %%
# NO2 ATMO HAUTS DE FRANCE

# File path to the data
NO2_ATMO_HAUTS_DE_FRANCE_file_path = os.path.join(base_path, "NO2 Max Horaire Journalier\Export Max. journalier moy. hor. - NO2 - ATMO HAUTS DE FRANCE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_NO2 = pd.read_csv(NO2_ATMO_HAUTS_DE_FRANCE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_NO2.head())

# Sample ATMO subscore dictionary for NO2 (Max horaire journalier)
ATMO_subscore_NO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 40.0), (40.0, 90.0), (90.0, 120.0), (120.0, 230.0), (230.0, 340.0), (340.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_NO2 = pd.DataFrame(ATMO_subscore_NO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_NO2['Range'] = ATMO_subscore_df_NO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of NO2 measurement
def assign_subscore_NO2(valeur):
    for index, row in ATMO_subscore_df_NO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_NO2['ATMO sub-score'] = df_NO2['valeur'].apply(assign_subscore_NO2)

# Display the updated DataFrame
print(df_NO2.head())
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
#
#                   Zas code site              nom site type d'implantation  \
# 0            ZAG BLDV   FR06001  Valenciennes Acacias             Urbaine
# 1            ZAG BLDV   FR06003        Douai Theuriet             Urbaine
# 2            ZAG BLDV   FR06006   Valenciennes Wallon             Urbaine
# 3  ZR HAUTS-DE-FRANCE   FR06007      Maubeuge Joyeuse             Urbaine
# 4            ZAG BLDV   FR06011        Denain Villars         Périurbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0      NO2             Fond  ...    6.4        6.350           µg-m3
# 1      NO2             Fond  ...   10.4       10.400           µg-m3
# 2      NO2           Trafic  ...   11.5       11.475           µg-m3
# 3      NO2             Fond  ...    4.1        4.100           µg-m3
# 4      NO2             Fond  ...    7.1        7.050           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             A
# 1           100.0                    100                 100.0             A
# 2           100.0                    100                 100.0             A
# 3           100.0                    100                 100.0             A
# 4           100.0                    100                 100.0             A
#
#    validité  Latitude Longitude
# 0         1  50.35853   3.50804
# 1         1  50.37822   3.06586
# 2         1  50.36425   3.52273
# 3         1  50.27936   3.97691
# 4         1  50.32276   3.39593
#
# [5 rows x 23 columns]
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
#
#                   Zas code site              nom site type d'implantation  \
# 0            ZAG BLDV   FR06001  Valenciennes Acacias             Urbaine
# 1            ZAG BLDV   FR06003        Douai Theuriet             Urbaine
# 2            ZAG BLDV   FR06006   Valenciennes Wallon             Urbaine
# 3  ZR HAUTS-DE-FRANCE   FR06007      Maubeuge Joyeuse             Urbaine
# 4            ZAG BLDV   FR06011        Denain Villars         Périurbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0      NO2             Fond  ...        6.350           µg-m3          100.0
# 1      NO2             Fond  ...       10.400           µg-m3          100.0
# 2      NO2           Trafic  ...       11.475           µg-m3          100.0
# 3      NO2             Fond  ...        4.100           µg-m3          100.0
# 4      NO2             Fond  ...        7.050           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#    Latitude  Longitude ATMO sub-score
# 0  50.35853    3.50804              1
# 1  50.37822    3.06586              1
# 2  50.36425    3.52273              1
# 3  50.27936    3.97691              1
# 4  50.32276    3.39593              1
#
# [5 rows x 24 columns]

# %%
# O3 ATMO HAUTS DE FRANCE

# File path to the data
O3_ATMO_HAUTS_DE_FRANCE_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - ATMO HAUTS DE FRANCE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_ATMO_HAUTS_DE_FRANCE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Sample ATMO subscore dictionary for O3 (Max horaire journalier)
ATMO_subscore_O3 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 50.0), (50.0, 100.0), (100.0, 130.0), (130.0, 240.0), (240.0, 380.0), (380.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_O3 = pd.DataFrame(ATMO_subscore_O3)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_O3['Range'] = ATMO_subscore_df_O3['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of O3 measurement
def assign_subscore_O3(valeur):
    for index, row in ATMO_subscore_df_O3.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_O3['ATMO sub-score'] = df_O3['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
#
#                   Zas code site              nom site     type d'implantation  \
# 0            ZAG BLDV   FR06001  Valenciennes Acacias                 Urbaine
# 1            ZAG BLDV   FR06003        Douai Theuriet                 Urbaine
# 2  ZR HAUTS-DE-FRANCE   FR06007      Maubeuge Joyeuse                 Urbaine
# 3            ZAG BLDV   FR06011        Denain Villars             Périurbaine
# 4  ZR HAUTS-DE-FRANCE   FR06133            Cartignies  Rurale près des villes
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0       O3             Fond  ...   60.8       60.800           µg-m3
# 1       O3             Fond  ...   59.8       59.750           µg-m3
# 2       O3             Fond  ...   62.2       62.175           µg-m3
# 3       O3             Fond  ...   61.8       61.750           µg-m3
# 4       O3             Fond  ...   56.4       56.400           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             R
# 1           100.0                    100                 100.0             R
# 2           100.0                    100                 100.0             R
# 3           100.0                    100                 100.0             R
# 4           100.0                    100                 100.0             R
#
#    validité  Latitude Longitude
# 0         1  50.35853   3.50804
# 1         1  50.37822   3.06586
# 2         1  50.27936   3.97691
# 3         1  50.32276   3.39593
# 4         1  50.09225   3.85003
#
# [5 rows x 23 columns]
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
#
#                   Zas code site              nom site     type d'implantation  \
# 0            ZAG BLDV   FR06001  Valenciennes Acacias                 Urbaine
# 1            ZAG BLDV   FR06003        Douai Theuriet                 Urbaine
# 2  ZR HAUTS-DE-FRANCE   FR06007      Maubeuge Joyeuse                 Urbaine
# 3            ZAG BLDV   FR06011        Denain Villars             Périurbaine
# 4  ZR HAUTS-DE-FRANCE   FR06133            Cartignies  Rurale près des villes
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0       O3             Fond  ...       60.800           µg-m3          100.0
# 1       O3             Fond  ...       59.750           µg-m3          100.0
# 2       O3             Fond  ...       62.175           µg-m3          100.0
# 3       O3             Fond  ...       61.750           µg-m3          100.0
# 4       O3             Fond  ...       56.400           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            R         1
# 1                    100                  100.0            R         1
# 2                    100                  100.0            R         1
# 3                    100                  100.0            R         1
# 4                    100                  100.0            R         1
#
#    Latitude  Longitude ATMO sub-score
# 0  50.35853    3.50804              2
# 1  50.37822    3.06586              2
# 2  50.27936    3.97691              2
# 3  50.32276    3.39593              2
# 4  50.09225    3.85003              2
#
# [5 rows x 24 columns]

# %%
# SO2 ATMO HAUTS DE FRANCE

# File path to the data
SO2_ATMO_HAUTS_DE_FRANCE_file_path = os.path.join(base_path, "SO2 Max Horaire Journalier\Export Max. journalier moy. hor. - SO2 - ATMO HAUTS DE FRANCE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_SO2 = pd.read_csv(SO2_ATMO_HAUTS_DE_FRANCE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_SO2.head())

# Sample ATMO subscore dictionary for SO2 (Max horaire journalier)
ATMO_subscore_SO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 100.0), (100.0, 200.0), (200.0, 350.0), (350.0, 500.0), (500.0, 750.0), (750.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_SO2 = pd.DataFrame(ATMO_subscore_SO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_SO2['Range'] = ATMO_subscore_df_SO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of SO2 measurement
def assign_subscore_SO2(valeur):
    for index, row in ATMO_subscore_df_SO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_SO2['ATMO sub-score'] = df_SO2['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_SO2.head())
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAR01
#
#                 Zas code site                nom site type d'implantation  \
# 0  ZAR COTE-D-OPALE   FR10012                 Mardyck         Périurbaine
# 1  ZAR COTE-D-OPALE   FR10017  St Pol mer - cheminots             Urbaine
# 2  ZAR COTE-D-OPALE   FR10026       Calais Parmentier             Urbaine
# 3  ZAR COTE-D-OPALE   FR10028     Gravelines PC/Drire         Périurbaine
# 4  ZAR COTE-D-OPALE   FR10029      Cappelle la Grande         Périurbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0      SO2     Industrielle  ...    1.0        1.000           µg-m3
# 1      SO2             Fond  ...    0.8        0.800           µg-m3
# 2      SO2             Fond  ...    1.0        1.000           µg-m3
# 3      SO2     Industrielle  ...    3.2        3.225           µg-m3
# 4      SO2             Fond  ...    0.3        0.250           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             R
# 1           100.0                    100                 100.0             R
# 2           100.0                    100                 100.0             R
# 3           100.0                    100                 100.0             R
# 4           100.0                    100                 100.0             R
#
#    validité   Latitude Longitude
# 0         1  51.019430  2.250990
# 1         1  51.032761  2.332358
# 2         1  50.957800  1.890080
# 3         1  50.981060  2.143170
# 4         1  50.995940  2.366270
#
# [5 rows x 23 columns]
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAR01
#
#                 Zas code site                nom site type d'implantation  \
# 0  ZAR COTE-D-OPALE   FR10012                 Mardyck         Périurbaine
# 1  ZAR COTE-D-OPALE   FR10017  St Pol mer - cheminots             Urbaine
# 2  ZAR COTE-D-OPALE   FR10026       Calais Parmentier             Urbaine
# 3  ZAR COTE-D-OPALE   FR10028     Gravelines PC/Drire         Périurbaine
# 4  ZAR COTE-D-OPALE   FR10029      Cappelle la Grande         Périurbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0      SO2     Industrielle  ...        1.000           µg-m3          100.0
# 1      SO2             Fond  ...        0.800           µg-m3          100.0
# 2      SO2             Fond  ...        1.000           µg-m3          100.0
# 3      SO2     Industrielle  ...        3.225           µg-m3          100.0
# 4      SO2             Fond  ...        0.250           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            R         1
# 1                    100                  100.0            R         1
# 2                    100                  100.0            R         1
# 3                    100                  100.0            R         1
# 4                    100                  100.0            R         1
#
#     Latitude  Longitude ATMO sub-score
# 0  51.019430   2.250990            1.0
# 1  51.032761   2.332358            1.0
# 2  50.957800   1.890080            1.0
# 3  50.981060   2.143170            1.0
# 4  50.995940   2.366270            1.0
#
# [5 rows x 24 columns]

# %%
# Combining 5 (if not missing) dataframes
# Concatenate DataFrames along the rows (stack them vertically)
combined_df_ATMO_HAUTS_DE_FRANCE = pd.concat([df_PM10, df_PM25, df_NO2, df_O3, df_SO2], axis=0) #

# If you want to reset the index of the combined DataFrame
combined_df_ATMO_HAUTS_DE_FRANCE.reset_index(drop=True, inplace=True)

# Renaming the ATMO subscore column to 'ATMO Score'
combined_df_ATMO_HAUTS_DE_FRANCE = combined_df_ATMO_HAUTS_DE_FRANCE.rename(columns={'ATMO sub-score': 'ATMO Score'})

# Printing the first five rows as a sanity check
print(combined_df_ATMO_HAUTS_DE_FRANCE.head())
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZAG01
#
#                   Zas code site              nom site type d'implantation  \
# 0            ZAG BLDV   FR06001  Valenciennes Acacias             Urbaine
# 1            ZAG BLDV   FR06003        Douai Theuriet             Urbaine
# 2            ZAG BLDV   FR06006   Valenciennes Wallon             Urbaine
# 3  ZR HAUTS-DE-FRANCE   FR06007      Maubeuge Joyeuse             Urbaine
# 4            ZAG BLDV   FR06011        Denain Villars         Périurbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0     PM10             Fond  ...     9.591667           µg-m3          100.0
# 1     PM10             Fond  ...    13.033333           µg-m3          100.0
# 2     PM10           Trafic  ...    12.995833           µg-m3          100.0
# 3     PM10             Fond  ...    11.937500           µg-m3          100.0
# 4     PM10             Fond  ...     0.000000           µg-m3            0.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                    0.0            N        -1
#
#    Latitude  Longitude ATMO Score
# 0  50.35853    3.50804        1.0
# 1  50.37822    3.06586        1.0
# 2  50.36425    3.52273        1.0
# 3  50.27936    3.97691        1.0
# 4  50.32276    3.39593        1.0
#
# [5 rows x 24 columns]

# %%
# Find the index of rows with maximum 'ATMO Score' within each group
idx_max_scores = combined_df_ATMO_HAUTS_DE_FRANCE.groupby(['nom site', 'Date de fin'])['ATMO Score'].idxmax()

# Select rows with the maximum 'ATMO Score' using the index
final_df_ATMO_HAUTS_DE_FRANCE = combined_df_ATMO_HAUTS_DE_FRANCE.loc[idx_max_scores]

# Reset index if needed
final_df_ATMO_HAUTS_DE_FRANCE.reset_index(drop=True, inplace=True)

# %%
# Downloading the final dataframe of Daily ATMO Score in ATMO HAUTS DE FRANCE to csv
final_df_ATMO_HAUTS_DE_FRANCE.to_csv('final_df_ATMO_HAUTS_DE_FRANCE.csv', index=False, encoding = 'latin1')

# %%
# Constructing indicator for ATMO HAUTS DE FRANCE

# File path to the data
ATMO_HAUTS_DE_FRANCE_file_path = os.path.join(base_path, "final_df_ATMO_HAUTS_DE_FRANCE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_ATMO = pd.read_csv(ATMO_HAUTS_DE_FRANCE_file_path, delimiter=',', encoding = 'latin1')

print(df_ATMO.head())

counts = df_ATMO.groupby('nom site')['ATMO Score'].value_counts().reset_index(name='counts')
#print(counts)

#result = pd.merge(counts, df_ATMO[["Organisme", "type d'implantation", "Latitude", "Longitude"]], on='nom site', how='left')
#print(result)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_ATMO.groupby('nom site').first().reset_index()
#print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(counts, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score_y'], axis = 1)
print(result)
# Out:
#          Date de début          Date de fin             Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 1  2023/01/02 00:00:00  2023/01/02 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 2  2023/01/03 00:00:00  2023/01/03 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 3  2023/01/04 00:00:00  2023/01/04 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
# 4  2023/01/05 00:00:00  2023/01/05 23:59:59  ATMO HAUTS DE FRANCE  FR32ZRE01
#
#                   Zas code site nom site type d'implantation Polluant  \
# 0  ZR HAUTS-DE-FRANCE   FR18039   Arrest    Rurale régionale       O3
# 1  ZR HAUTS-DE-FRANCE   FR18039   Arrest    Rurale régionale       O3
# 2  ZR HAUTS-DE-FRANCE   FR18039   Arrest    Rurale régionale       O3
# 3  ZR HAUTS-DE-FRANCE   FR18039   Arrest    Rurale régionale       O3
# 4  ZR HAUTS-DE-FRANCE   FR18039   Arrest    Rurale régionale     PM10
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0             Fond  ...     73.43333           µg-m3          100.0
# 1             Fond  ...     75.96667           µg-m3          100.0
# 2             Fond  ...     69.60000           µg-m3          100.0
# 3             Fond  ...     75.95000           µg-m3          100.0
# 4             Fond  ...     22.25000           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            R         1
# 1                    100                  100.0            R         1
# 2                    100                  100.0            R         1
# 3                    100                  100.0            R         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO Score
# 0  50.129448   1.610833        2.0
# 1  50.129448   1.610833        2.0
# 2  50.129448   1.610833        2.0
# 3  50.129448   1.610833        2.0
# 4  50.129448   1.610833        2.0
#
# [5 rows x 24 columns]
#                 nom site  ATMO Score_x  counts             Organisme  \
# 0                 Arrest           2.0     288  ATMO HAUTS DE FRANCE
# 1                 Arrest           3.0      41  ATMO HAUTS DE FRANCE
# 2                 Arrest           4.0      15  ATMO HAUTS DE FRANCE
# 3                 Arrest           1.0       9  ATMO HAUTS DE FRANCE
# 4          Bethune Stade           2.0     271  ATMO HAUTS DE FRANCE
# ..                   ...           ...     ...                   ...
# 162  Valenciennes Wallon           4.0      12  ATMO HAUTS DE FRANCE
# 163           Wattignies           2.0     264  ATMO HAUTS DE FRANCE
# 164           Wattignies           1.0      39  ATMO HAUTS DE FRANCE
# 165           Wattignies           3.0      25  ATMO HAUTS DE FRANCE
# 166           Wattignies           4.0      15  ATMO HAUTS DE FRANCE
#
#       code zas                 Zas code site type d'implantation Polluant  \
# 0    FR32ZRE01  ZR HAUTS-DE-FRANCE   FR18039    Rurale régionale       O3
# 1    FR32ZRE01  ZR HAUTS-DE-FRANCE   FR18039    Rurale régionale       O3
# 2    FR32ZRE01  ZR HAUTS-DE-FRANCE   FR18039    Rurale régionale       O3
# 3    FR32ZRE01  ZR HAUTS-DE-FRANCE   FR18039    Rurale régionale       O3
# 4    FR32ZAG01            ZAG BLDV   FR28028             Urbaine     PM10
# ..         ...                 ...       ...                 ...      ...
# 162  FR32ZAG01            ZAG BLDV   FR06006             Urbaine     PM10
# 163  FR32ZAG02           ZAG LILLE   FR11114         Périurbaine       O3
# 164  FR32ZAG02           ZAG LILLE   FR11114         Périurbaine       O3
# 165  FR32ZAG02           ZAG LILLE   FR11114         Périurbaine       O3
# 166  FR32ZAG02           ZAG LILLE   FR11114         Périurbaine       O3
#
#     type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0               Fond  ...   73.4    73.433330           µg-m3           100.0
# 1               Fond  ...   73.4    73.433330           µg-m3           100.0
# 2               Fond  ...   73.4    73.433330           µg-m3           100.0
# 3               Fond  ...   73.4    73.433330           µg-m3           100.0
# 4               Fond  ...   11.0    11.283333           µg-m3           100.0
# ..               ...  ...    ...          ...             ...             ...
# 162           Trafic  ...   13.0    12.995833           µg-m3           100.0
# 163             Fond  ...   65.3    65.275000           µg-m3            42.0
# 164             Fond  ...   65.3    65.275000           µg-m3            42.0
# 165             Fond  ...   65.3    65.275000           µg-m3            42.0
# 166             Fond  ...   65.3    65.275000           µg-m3            42.0
#
#      couverture temporelle couverture de données  code qualité  validité  \
# 0                      100                 100.0             R         1
# 1                      100                 100.0             R         1
# 2                      100                 100.0             R         1
# 3                      100                 100.0             R         1
# 4                      100                 100.0             A         1
# ..                     ...                   ...           ...       ...
# 162                    100                 100.0             A         1
# 163                    100                  42.0             N        -1
# 164                    100                  42.0             N        -1
# 165                    100                  42.0             N        -1
# 166                    100                  42.0             N        -1
#
#       Latitude Longitude
# 0    50.129448  1.610833
# 1    50.129448  1.610833
# 2    50.129448  1.610833
# 3    50.129448  1.610833
# 4    50.535385  2.635692
# ..         ...       ...
# 162  50.364250  3.522730
# 163  50.597740  3.049460
# 164  50.597740  3.049460
# 165  50.597740  3.049460
# 166  50.597740  3.049460
#
# [167 rows x 23 columns]

# %%
# Group the DataFrame by 'nom' and calculate the total counts for each 'nom'
total_counts_by_nom = result.groupby('nom site')['counts'].sum()

# Filter the DataFrame to include only rows where the score is equal to or greater than 3
filtered_result = result[result['ATMO Score_x'] >= 3]

# Group the filtered DataFrame by 'nom' and calculate the counts equal to or greater than 3 for each 'nom'
counts_greater_than_3_by_nom = filtered_result.groupby('nom site')['counts'].sum()

# Calculate the ratio of counts greater than or equal to 3 over total counts for each 'nom'
ratio_counts_greater_than_3 = (counts_greater_than_3_by_nom / total_counts_by_nom).fillna(0)

# Display the resulting Series
print(ratio_counts_greater_than_3)

# Merge the site-specific information with the counts DataFrame
ratio_counts_greater_than_3_df = pd.merge(ratio_counts_greater_than_3, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score'], axis = 1)
ratio_counts_greater_than_3_df = ratio_counts_greater_than_3_df.rename(columns={'counts': 'indicator'})
print(ratio_counts_greater_than_3_df)
# Out:
# nom site
# Arrest                    0.158640
# Bethune Stade             0.156863
# Boulogne Diderot          0.030137
# Calais Berthelot          0.047009
# Calais Parmentier         0.112329
# Campagne les B.           0.110145
# Cappelle la Grande        0.112329
# Cartignies                0.170330
# Denain Villars            0.183562
# Douai Theuriet            0.205479
# Faiencerie Creil          0.198880
# Grande-synthe             0.057692
# Gravelines PC/Drire       0.030137
# Halluin stade             0.119444
# Harnes Serres             0.175487
# Lens Varsovie             0.013774
# Lille Leeds               0.052632
# Malo-les-Bains            0.090909
# Marcq CTM                 0.005698
# Mardyck                   0.035813
# Maubeuge Joyeuse          0.104396
# Neuilly-Saint-Front       0.112329
# Noeux-les-Mines           0.117808
# Outreau                   0.057534
# P. Roth St Quentin        0.139726
# Roubaix Serres            0.123288
# Roye                      0.140449
# Saint Amand               0.107735
# Salouel                   0.112329
# Sangatte                  0.063014
# St Omer Ribot             0.061111
# St Pierre Amiens          0.106849
# St Pol mer - cheminots    0.126722
# St-Laurent-Blangy         0.129477
# TRAF Saint Quent 14       0.080332
# TRAFIC AMIENS             0.071233
# Tourcoing Houpline        0.207715
# Trafic Beauvais 1         0.068493
# Valenciennes Acacias      0.134247
# Valenciennes Wallon       0.085873
# Wattignies                0.116618
# Name: counts, dtype: float64
#                   nom site  indicator             Organisme   code zas  \
# 0                   Arrest   0.158640  ATMO HAUTS DE FRANCE  FR32ZRE01
# 1            Bethune Stade   0.156863  ATMO HAUTS DE FRANCE  FR32ZAG01
# 2         Boulogne Diderot   0.030137  ATMO HAUTS DE FRANCE  FR32ZAR01
# 3         Calais Berthelot   0.047009  ATMO HAUTS DE FRANCE  FR32ZAR01
# 4        Calais Parmentier   0.112329  ATMO HAUTS DE FRANCE  FR32ZAR01
# 5          Campagne les B.   0.110145  ATMO HAUTS DE FRANCE  FR32ZRE01
# 6       Cappelle la Grande   0.112329  ATMO HAUTS DE FRANCE  FR32ZAR01
# 7               Cartignies   0.170330  ATMO HAUTS DE FRANCE  FR32ZRE01
# 8           Denain Villars   0.183562  ATMO HAUTS DE FRANCE  FR32ZAG01
# 9           Douai Theuriet   0.205479  ATMO HAUTS DE FRANCE  FR32ZAG01
# 10        Faiencerie Creil   0.198880  ATMO HAUTS DE FRANCE  FR32ZAR03
# 11           Grande-synthe   0.057692  ATMO HAUTS DE FRANCE  FR32ZAR01
# 12     Gravelines PC/Drire   0.030137  ATMO HAUTS DE FRANCE  FR32ZAR01
# 13           Halluin stade   0.119444  ATMO HAUTS DE FRANCE  FR32ZAG02
# 14           Harnes Serres   0.175487  ATMO HAUTS DE FRANCE  FR32ZAG01
# 15           Lens Varsovie   0.013774  ATMO HAUTS DE FRANCE  FR32ZAG01
# 16             Lille Leeds   0.052632  ATMO HAUTS DE FRANCE  FR32ZAG02
# 17          Malo-les-Bains   0.090909  ATMO HAUTS DE FRANCE  FR32ZAR01
# 18               Marcq CTM   0.005698  ATMO HAUTS DE FRANCE  FR32ZAG02
# 19                 Mardyck   0.035813  ATMO HAUTS DE FRANCE  FR32ZAR01
# 20        Maubeuge Joyeuse   0.104396  ATMO HAUTS DE FRANCE  FR32ZRE01
# 21     Neuilly-Saint-Front   0.112329  ATMO HAUTS DE FRANCE  FR32ZRE01
# 22         Noeux-les-Mines   0.117808  ATMO HAUTS DE FRANCE  FR32ZAG01
# 23                 Outreau   0.057534  ATMO HAUTS DE FRANCE  FR32ZAR01
# 24      P. Roth St Quentin   0.139726  ATMO HAUTS DE FRANCE  FR32ZRE01
# 25          Roubaix Serres   0.123288  ATMO HAUTS DE FRANCE  FR32ZAG02
# 26                    Roye   0.140449  ATMO HAUTS DE FRANCE  FR32ZRE01
# 27             Saint Amand   0.107735  ATMO HAUTS DE FRANCE  FR32ZAG01
# 28                 Salouel   0.112329  ATMO HAUTS DE FRANCE  FR32ZAR02
# 29                Sangatte   0.063014  ATMO HAUTS DE FRANCE  FR32ZAR01
# 30           St Omer Ribot   0.061111  ATMO HAUTS DE FRANCE  FR32ZAR01
# 31        St Pierre Amiens   0.106849  ATMO HAUTS DE FRANCE  FR32ZAR02
# 32  St Pol mer - cheminots   0.126722  ATMO HAUTS DE FRANCE  FR32ZAR01
# 33       St-Laurent-Blangy   0.129477  ATMO HAUTS DE FRANCE  FR32ZAR04
# 34     TRAF Saint Quent 14   0.080332  ATMO HAUTS DE FRANCE  FR32ZRE01
# 35           TRAFIC AMIENS   0.071233  ATMO HAUTS DE FRANCE  FR32ZAR02
# 36      Tourcoing Houpline   0.207715  ATMO HAUTS DE FRANCE  FR32ZAG02
# 37       Trafic Beauvais 1   0.068493  ATMO HAUTS DE FRANCE  FR32ZRE01
# 38    Valenciennes Acacias   0.134247  ATMO HAUTS DE FRANCE  FR32ZAG01
# 39     Valenciennes Wallon   0.085873  ATMO HAUTS DE FRANCE  FR32ZAG01
# 40              Wattignies   0.116618  ATMO HAUTS DE FRANCE  FR32ZAG02
#
#                    Zas code site     type d'implantation Polluant  \
# 0   ZR HAUTS-DE-FRANCE   FR18039        Rurale régionale       O3
# 1             ZAG BLDV   FR28028                 Urbaine     PM10
# 2     ZAR COTE-D-OPALE   FR10030                 Urbaine     PM10
# 3     ZAR COTE-D-OPALE   FR10016                 Urbaine     PM10
# 4     ZAR COTE-D-OPALE   FR10026                 Urbaine     PM10
# 5   ZR HAUTS-DE-FRANCE   FR10132        Rurale régionale       O3
# 6     ZAR COTE-D-OPALE   FR10029             Périurbaine     PM10
# 7   ZR HAUTS-DE-FRANCE   FR06133  Rurale près des villes       O3
# 8             ZAG BLDV   FR06011             Périurbaine       O3
# 9             ZAG BLDV   FR06003                 Urbaine       O3
# 10           ZAR CREIL   FR18043                 Urbaine       O3
# 11    ZAR COTE-D-OPALE   FR10034                 Urbaine     PM10
# 12    ZAR COTE-D-OPALE   FR10028             Périurbaine     PM10
# 13           ZAG LILLE   FR11026             Périurbaine       O3
# 14            ZAG BLDV   FR28010             Périurbaine       O3
# 15            ZAG BLDV   FR28115                 Urbaine     PM10
# 16           ZAG LILLE   FR11007                 Urbaine    PM2.5
# 17    ZAR COTE-D-OPALE   FR10004                 Urbaine     PM10
# 18           ZAG LILLE   FR11016                 Urbaine       O3
# 19    ZAR COTE-D-OPALE   FR10012             Périurbaine     PM10
# 20  ZR HAUTS-DE-FRANCE   FR06007                 Urbaine       O3
# 21  ZR HAUTS-DE-FRANCE   FR18057        Rurale régionale       O3
# 22            ZAG BLDV   FR28033             Périurbaine       O3
# 23    ZAR COTE-D-OPALE   FR10032             Périurbaine     PM10
# 24  ZR HAUTS-DE-FRANCE   FR18042                 Urbaine       O3
# 25           ZAG LILLE   FR11034                 Urbaine     PM10
# 26  ZR HAUTS-DE-FRANCE   FR18045  Rurale près des villes       O3
# 27            ZAG BLDV   FR06134             Périurbaine       O3
# 28          ZAR AMIENS   FR18035             Périurbaine       O3
# 29    ZAR COTE-D-OPALE   FR10025             Périurbaine     PM10
# 30    ZAR COTE-D-OPALE   FR10041                 Urbaine     PM10
# 31          ZAR AMIENS   FR18053                 Urbaine       O3
# 32    ZAR COTE-D-OPALE   FR10017                 Urbaine     PM10
# 33           ZAR ARRAS   FR28022             Périurbaine       O3
# 34  ZR HAUTS-DE-FRANCE   FR18080                 Urbaine    PM2.5
# 35          ZAR AMIENS   FR18079                 Urbaine    PM2.5
# 36           ZAG LILLE   FR11038                 Urbaine    PM2.5
# 37  ZR HAUTS-DE-FRANCE   FR18089                 Urbaine     PM10
# 38            ZAG BLDV   FR06001                 Urbaine       O3
# 39            ZAG BLDV   FR06006                 Urbaine     PM10
# 40           ZAG LILLE   FR11114             Périurbaine       O3
#
#    type d'influence Réglementaire  ... valeur valeur brute  unité de mesure  \
# 0              Fond           Oui  ...   73.4    73.433330            µg-m3
# 1              Fond           Oui  ...   11.0    11.283333            µg-m3
# 2            Trafic           Oui  ...    0.0     0.000000            µg-m3
# 3              Fond           Oui  ...   15.0    15.358333            µg-m3
# 4              Fond           Oui  ...   24.0    23.720833            µg-m3
# 5              Fond           Oui  ...   79.3    79.266670            µg-m3
# 6              Fond           Oui  ...   25.0    24.566667            µg-m3
# 7              Fond           Oui  ...   56.4    56.400000            µg-m3
# 8              Fond           Oui  ...   61.8    61.750000            µg-m3
# 9              Fond           Oui  ...   59.8    59.750000            µg-m3
# 10             Fond           Oui  ...   58.5    58.450000            µg-m3
# 11     Industrielle           Oui  ...   12.0    12.379167            µg-m3
# 12     Industrielle           Oui  ...   16.0    15.775000            µg-m3
# 13             Fond           Oui  ...   60.6    60.575000            µg-m3
# 14             Fond           Oui  ...   58.0    58.000000            µg-m3
# 15           Trafic           Oui  ...   11.0    10.525000            µg-m3
# 16           Trafic           Oui  ...    0.0     0.000000            µg-m3
# 17             Fond           Oui  ...   14.0    14.050000            µg-m3
# 18             Fond           Oui  ...   71.0    70.966670            µg-m3
# 19     Industrielle           Oui  ...   11.0    10.816667            µg-m3
# 20             Fond           Oui  ...   62.2    62.175000            µg-m3
# 21             Fond           Oui  ...   57.7    57.700000            µg-m3
# 22             Fond           Oui  ...   72.7    72.700000            µg-m3
# 23             Fond           Oui  ...   24.0    23.933333            µg-m3
# 24             Fond           Oui  ...   58.3    58.300000            µg-m3
# 25           Trafic           Oui  ...   11.0    10.826087            µg-m3
# 26             Fond           Oui  ...   60.0    60.000000            µg-m3
# 27             Fond           Oui  ...   58.9    58.875000            µg-m3
# 28             Fond           Oui  ...   65.6    65.625000            µg-m3
# 29             Fond           Oui  ...   21.0    21.450000            µg-m3
# 30             Fond           Oui  ...   11.0    11.229167            µg-m3
# 31             Fond           Oui  ...   64.7    64.650000            µg-m3
# 32             Fond           Oui  ...   23.0    22.712500            µg-m3
# 33             Fond           Oui  ...   60.4    60.375000            µg-m3
# 34           Trafic           Oui  ...    6.9     6.881818            µg-m3
# 35           Trafic           Oui  ...    8.3     8.333333            µg-m3
# 36             Fond           Oui  ...   13.0    12.733333            µg-m3
# 37           Trafic           Oui  ...   18.0    17.762500            µg-m3
# 38             Fond           Oui  ...   60.8    60.800000            µg-m3
# 39           Trafic           Oui  ...   13.0    12.995833            µg-m3
# 40             Fond           Oui  ...   65.3    65.275000            µg-m3
#
#     taux de saisie couverture temporelle  couverture de données  code qualité  \
# 0            100.0                   100                  100.0             R
# 1            100.0                   100                  100.0             A
# 2              0.0                   100                    0.0             N
# 3            100.0                   100                  100.0             A
# 4            100.0                   100                  100.0             A
# 5            100.0                   100                  100.0             R
# 6            100.0                   100                  100.0             A
# 7            100.0                   100                  100.0             R
# 8            100.0                   100                  100.0             R
# 9            100.0                   100                  100.0             R
# 10           100.0                   100                  100.0             R
# 11           100.0                   100                  100.0             R
# 12           100.0                   100                  100.0             A
# 13            50.0                   100                   50.0             N
# 14           100.0                   100                  100.0             R
# 15           100.0                   100                  100.0             A
# 16             0.0                   100                    0.0             N
# 17           100.0                   100                  100.0             A
# 18           100.0                   100                  100.0             R
# 19           100.0                   100                  100.0             R
# 20           100.0                   100                  100.0             R
# 21           100.0                   100                  100.0             R
# 22           100.0                   100                  100.0             R
# 23           100.0                   100                  100.0             A
# 24           100.0                   100                  100.0             R
# 25            96.0                   100                   96.0             A
# 26           100.0                   100                  100.0             R
# 27           100.0                   100                  100.0             R
# 28           100.0                   100                  100.0             R
# 29           100.0                   100                  100.0             A
# 30           100.0                   100                  100.0             A
# 31           100.0                   100                  100.0             R
# 32           100.0                   100                  100.0             A
# 33           100.0                   100                  100.0             R
# 34            92.0                   100                   92.0             A
# 35           100.0                   100                  100.0             A
# 36            38.0                   100                   38.0             N
# 37           100.0                   100                  100.0             A
# 38           100.0                   100                  100.0             R
# 39           100.0                   100                  100.0             A
# 40            42.0                   100                   42.0             N
#
#     validité   Latitude  Longitude
# 0          1  50.129448   1.610833
# 1          1  50.535385   2.635692
# 2         -1  50.717029   1.605913
# 3          1  50.947290   1.843080
# 4          1  50.957800   1.890080
# 5          1  50.610480   1.991450
# 6          1  50.995940   2.366270
# 7          1  50.092250   3.850030
# 8          1  50.322760   3.395930
# 9          1  50.378220   3.065860
# 10         1  49.259552   2.474397
# 11         1  51.024460   2.302150
# 12         1  50.981060   2.143170
# 13        -1  50.775482   3.125680
# 14         1  50.449140   2.900000
# 15         1  50.428604   2.836111
# 16        -1  50.640794   3.074772
# 17         1  51.048580   2.420040
# 18         1  50.670030   3.076560
# 19         1  51.019430   2.250990
# 20         1  50.279360   3.976910
# 21         1  49.174931   3.260819
# 22         1  50.489720   2.666420
# 23         1  50.694350   1.576570
# 24         1  49.851334   3.284000
# 25         1  50.706535   3.180660
# 26         1  49.696697   2.801139
# 27         1  50.456470   3.427940
# 28         1  49.868890   2.239806
# 29         1  50.949890   1.769170
# 30         1  50.748230   2.259780
# 31         1  49.901667   2.304597
# 32         1  51.032761   2.332358
# 33         1  50.308860   2.807369
# 34         1  49.842820   3.281439
# 35         1  49.877220   2.282500
# 36        -1  50.733333   3.173611
# 37         1  49.435932   2.084292
# 38         1  50.358530   3.508040
# 39         1  50.364250   3.522730
# 40        -1  50.597740   3.049460
#
# [41 rows x 22 columns]

# %%
# Downloading the final indicator of ATMO HAUTS DE FRANCE to csv
ratio_counts_greater_than_3_df.to_csv('indicator_ATMO_HAUTS_DE_FRANCE.csv', index=False, encoding = 'latin1')

# %%
# -----------------------------------------------------------------------------------------------------------------------------------------------------
#                                                               Sanity Checks
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %%
print(df_PM25['valeur'].head())
# Out:
# 0    7.1
# 1    6.0
# 2    5.6
# 3    6.5
# 4    8.5
# Name: valeur, dtype: float64

# %%
df_PM25['ATMO sub-score'].describe()
# Out:
# count    7308.000000
# mean        1.371648
# std         0.697275
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: ATMO sub-score, dtype: float64

# %%
print(df_PM25['valeur'].head())
# Out:
# 0    7.1
# 1    6.0
# 2    5.6
# 3    6.5
# 4    8.5
# Name: valeur, dtype: float64
