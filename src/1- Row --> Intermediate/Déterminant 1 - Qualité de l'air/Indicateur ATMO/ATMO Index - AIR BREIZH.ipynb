# %%
# Code for extracting the daily ATMO score for each station in AIR BREIZH (Région: Bretagne)

# %%
# Installing required packages
import pandas as pd

import os

# Base directory path
base_path = ".\data\1- Raw Data\Déterminant 1 - Qualité de l'air\"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_31704\2375524138.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# PM10 AIR BREIZH

# File path to the data
PM10_AIR_BREIZH_file_path = os.path.join(base_path, "PM10 Moyenne Journalière\Export Moy. journalière - PM10 - AIR BREIZH.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM10 = pd.read_csv(PM10_AIR_BREIZH_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM10.head())

# Sample ATMO subscore dictionary for PM10 (Moyenne journalière)
ATMO_subscore_PM10 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 20.0), (20.0, 40.0), (40.0, 50.0), (50.0, 100.0), (100.0, 150.0), (150.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM10 = pd.DataFrame(ATMO_subscore_PM10)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM10['Range'] = ATMO_subscore_df_PM10['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM10 measurement
def assign_subscore_PM10(valeur):
    for index, row in ATMO_subscore_df_PM10.iterrows():  
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM10['ATMO sub-score'] = df_PM10['valeur'].apply(assign_subscore_PM10)  

# Display the updated DataFrame
print(df_PM10.head())
# Out:
#          Date de début          Date de fin   Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
#
#            Zas code site              nom site type d'implantation Polluant  \
# 0   ZAG RENNES   FR19002        Rennes Laennec             Urbaine     PM10
# 1    ZAR BREST   FR19012            Brest Mace             Urbaine     PM10
# 2    ZAR BREST   FR19014      Brest Desmoulins             Urbaine     PM10
# 3  ZR BRETAGNE   FR19020               Kergoff    Rurale nationale     PM10
# 4  ZR BRETAGNE   FR19032  Lorient B. Bissonnet             Urbaine     PM10
#
#   type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0           Trafic  ...   14.0    13.516667           µg-m3           100.0
# 1             Fond  ...   20.0    19.816667           µg-m3           100.0
# 2           Trafic  ...   31.0    30.675000           µg-m3           100.0
# 3             Fond  ...    7.0     7.279167           µg-m3           100.0
# 4             Fond  ...   17.0    16.941667           µg-m3           100.0
#
#    couverture temporelle couverture de données  code qualité  validité  \
# 0                    100                 100.0             A         1
# 1                    100                 100.0             A         1
# 2                    100                 100.0             A         1
# 3                    100                 100.0             A         1
# 4                    100                 100.0             A         1
#
#     Latitude Longitude
# 0  48.108610 -1.665860
# 1  48.386180 -4.486600
# 2  48.397460 -4.488710
# 3  48.261963 -2.943631
# 4  47.742500 -3.395010
#
# [5 rows x 23 columns]
#          Date de début          Date de fin   Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
#
#            Zas code site              nom site type d'implantation Polluant  \
# 0   ZAG RENNES   FR19002        Rennes Laennec             Urbaine     PM10
# 1    ZAR BREST   FR19012            Brest Mace             Urbaine     PM10
# 2    ZAR BREST   FR19014      Brest Desmoulins             Urbaine     PM10
# 3  ZR BRETAGNE   FR19020               Kergoff    Rurale nationale     PM10
# 4  ZR BRETAGNE   FR19032  Lorient B. Bissonnet             Urbaine     PM10
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0           Trafic  ...    13.516667           µg-m3          100.0
# 1             Fond  ...    19.816667           µg-m3          100.0
# 2           Trafic  ...    30.675000           µg-m3          100.0
# 3             Fond  ...     7.279167           µg-m3          100.0
# 4             Fond  ...    16.941667           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  48.108610  -1.665860              1
# 1  48.386180  -4.486600              1
# 2  48.397460  -4.488710              2
# 3  48.261963  -2.943631              1
# 4  47.742500  -3.395010              1
#
# [5 rows x 24 columns]

# %%
# PM2.5 AIR BREIZH

# File path to the data
PM25_AIR_BREIZH_file_path = os.path.join(base_path, "PM2.5 Moyenne Journalière\Export Moy. journalière - PM2.5 - AIR BREIZH.csv.csv")
# Use read_csv function from pandas specifying the delimiter as ';'
df_PM25 = pd.read_csv(PM25_AIR_BREIZH_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM25.head())

# Sample ATMO subscore dictionary for PM2.5 (Moyenne journalière)
ATMO_subscore_PM25 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 10.0), (10.0, 20.0), (20.0, 25.0), (25.0, 50.0), (50.0, 75.0), (75.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM25 = pd.DataFrame(ATMO_subscore_PM25)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM25['Range'] = ATMO_subscore_df_PM25['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM2.5 measurement
def assign_subscore_PM25(valeur):
    for index, row in ATMO_subscore_df_PM25.iterrows(): 
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM25['ATMO sub-score'] = df_PM25['valeur'].apply(assign_subscore_PM25)  

# Display the updated DataFrame
print(df_PM25.head())
# Out:
#          Date de début          Date de fin   Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
#
#            Zas code site              nom site type d'implantation Polluant  \
# 0   ZAG RENNES   FR19002        Rennes Laennec             Urbaine    PM2.5
# 1    ZAR BREST   FR19012            Brest Mace             Urbaine    PM2.5
# 2    ZAR BREST   FR19014      Brest Desmoulins             Urbaine    PM2.5
# 3  ZR BRETAGNE   FR19020               Kergoff    Rurale nationale    PM2.5
# 4  ZR BRETAGNE   FR19032  Lorient B. Bissonnet             Urbaine    PM2.5
#
#   type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0           Trafic  ...    7.7     7.650000           µg-m3           100.0
# 1             Fond  ...    0.0     0.000000           µg-m3             0.0
# 2           Trafic  ...   10.0    10.183333           µg-m3           100.0
# 3             Fond  ...    4.5     4.475000           µg-m3           100.0
# 4             Fond  ...    9.1     9.100000           µg-m3           100.0
#
#    couverture temporelle couverture de données  code qualité  validité  \
# 0                    100                 100.0             A         1
# 1                    100                   0.0             N        -1
# 2                    100                 100.0             A         1
# 3                    100                 100.0             A         1
# 4                    100                 100.0             A         1
#
#     Latitude Longitude
# 0  48.108610 -1.665860
# 1  48.386180 -4.486600
# 2  48.397460 -4.488710
# 3  48.261963 -2.943631
# 4  47.742500 -3.395010
#
# [5 rows x 23 columns]
#          Date de début          Date de fin   Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
#
#            Zas code site              nom site type d'implantation Polluant  \
# 0   ZAG RENNES   FR19002        Rennes Laennec             Urbaine    PM2.5
# 1    ZAR BREST   FR19012            Brest Mace             Urbaine    PM2.5
# 2    ZAR BREST   FR19014      Brest Desmoulins             Urbaine    PM2.5
# 3  ZR BRETAGNE   FR19020               Kergoff    Rurale nationale    PM2.5
# 4  ZR BRETAGNE   FR19032  Lorient B. Bissonnet             Urbaine    PM2.5
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0           Trafic  ...     7.650000           µg-m3          100.0
# 1             Fond  ...     0.000000           µg-m3            0.0
# 2           Trafic  ...    10.183333           µg-m3          100.0
# 3             Fond  ...     4.475000           µg-m3          100.0
# 4             Fond  ...     9.100000           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                    0.0            N        -1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  48.108610  -1.665860            1.0
# 1  48.386180  -4.486600            1.0
# 2  48.397460  -4.488710            1.0
# 3  48.261963  -2.943631            1.0
# 4  47.742500  -3.395010            1.0
#
# [5 rows x 24 columns]

# %%
# NO2 AIR BREIZH

# File path to the data
NO2_AIR_BREIZH_file_path =  os.path.join(base_path, "NO2 Max Horaire Journalier\Export Max. journalier moy. hor. - NO2 - AIR BREIZH.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_NO2 = pd.read_csv(NO2_AIR_BREIZH_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_NO2.head())

# Sample ATMO subscore dictionary for NO2 (Max horaire journalier)
ATMO_subscore_NO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 40.0), (40.0, 90.0), (90.0, 120.0), (120.0, 230.0), (230.0, 340.0), (340.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_NO2 = pd.DataFrame(ATMO_subscore_NO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_NO2['Range'] = ATMO_subscore_df_NO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of NO2 measurement
def assign_subscore_NO2(valeur):
    for index, row in ATMO_subscore_df_NO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_NO2['ATMO sub-score'] = df_NO2['valeur'].apply(assign_subscore_NO2)

# Display the updated DataFrame
print(df_NO2.head())
# Out:
#          Date de début          Date de fin   Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
#
#            Zas code site           nom site type d'implantation Polluant  \
# 0   ZAG RENNES   FR19002     Rennes Laennec             Urbaine      NO2
# 1   ZAG RENNES   FR19007  Rennes Les Halles             Urbaine      NO2
# 2    ZAR BREST   FR19012         Brest Mace             Urbaine      NO2
# 3    ZAR BREST   FR19014   Brest Desmoulins             Urbaine      NO2
# 4  ZR BRETAGNE   FR19020            Kergoff    Rurale nationale      NO2
#
#   type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0           Trafic  ...   15.7       15.675           µg-m3           100.0
# 1           Trafic  ...   25.9       25.850           µg-m3           100.0
# 2             Fond  ...   15.5       15.525           µg-m3           100.0
# 3           Trafic  ...   56.1       56.075           µg-m3           100.0
# 4             Fond  ...    8.8        8.815           µg-m3           100.0
#
#    couverture temporelle couverture de données  code qualité  validité  \
# 0                    100                 100.0             A         1
# 1                    100                 100.0             A         1
# 2                    100                 100.0             A         1
# 3                    100                 100.0             A         1
# 4                    100                 100.0             A         1
#
#     Latitude Longitude
# 0  48.108610 -1.665860
# 1  48.107510 -1.679840
# 2  48.386180 -4.486600
# 3  48.397460 -4.488710
# 4  48.261963 -2.943631
#
# [5 rows x 23 columns]
#          Date de début          Date de fin   Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
#
#            Zas code site           nom site type d'implantation Polluant  \
# 0   ZAG RENNES   FR19002     Rennes Laennec             Urbaine      NO2
# 1   ZAG RENNES   FR19007  Rennes Les Halles             Urbaine      NO2
# 2    ZAR BREST   FR19012         Brest Mace             Urbaine      NO2
# 3    ZAR BREST   FR19014   Brest Desmoulins             Urbaine      NO2
# 4  ZR BRETAGNE   FR19020            Kergoff    Rurale nationale      NO2
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0           Trafic  ...       15.675           µg-m3          100.0
# 1           Trafic  ...       25.850           µg-m3          100.0
# 2             Fond  ...       15.525           µg-m3          100.0
# 3           Trafic  ...       56.075           µg-m3          100.0
# 4             Fond  ...        8.815           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  48.108610  -1.665860              1
# 1  48.107510  -1.679840              1
# 2  48.386180  -4.486600              1
# 3  48.397460  -4.488710              2
# 4  48.261963  -2.943631              1
#
# [5 rows x 24 columns]

# %%
# O3 AIR BREIZH

# File path to the data
O3_AIR_BREIZH_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - AIR BREIZH.csv")
# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_AIR_BREIZH_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Sample ATMO subscore dictionary for NO2 (Max horaire journalier)
ATMO_subscore_O3 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 50.0), (50.0, 100.0), (100.0, 130.0), (130.0, 240.0), (240.0, 380.0), (380.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_O3 = pd.DataFrame(ATMO_subscore_O3)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_O3['Range'] = ATMO_subscore_df_O3['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of O3 measurement
def assign_subscore_O3(valeur):
    for index, row in ATMO_subscore_df_O3.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_O3['ATMO sub-score'] = df_O3['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin   Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
#
#            Zas code site              nom site type d'implantation Polluant  \
# 0    ZAR BREST   FR19012            Brest Mace             Urbaine       O3
# 1    ZAR BREST   FR19016        BREST Plouzané         Périurbaine       O3
# 2   ZAG RENNES   FR19018     MORDELLES BELLAIS         Périurbaine       O3
# 3  ZR BRETAGNE   FR19020               Kergoff    Rurale nationale       O3
# 4  ZR BRETAGNE   FR19032  Lorient B. Bissonnet             Urbaine       O3
#
#   type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0             Fond  ...   83.6       83.625           µg-m3           100.0
# 1             Fond  ...   81.9       81.850           µg-m3           100.0
# 2             Fond  ...   68.5       68.475           µg-m3           100.0
# 3             Fond  ...   75.4       75.375           µg-m3           100.0
# 4             Fond  ...   83.1       83.100           µg-m3           100.0
#
#    couverture temporelle couverture de données  code qualité  validité  \
# 0                    100                 100.0             A         1
# 1                    100                 100.0             A         1
# 2                    100                 100.0             A         1
# 3                    100                 100.0             A         1
# 4                    100                 100.0             A         1
#
#     Latitude Longitude
# 0  48.386180 -4.486600
# 1  48.359444 -4.568055
# 2  48.082883 -1.834583
# 3  48.261963 -2.943631
# 4  47.742500 -3.395010
#
# [5 rows x 23 columns]
#          Date de début          Date de fin   Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
#
#            Zas code site              nom site type d'implantation Polluant  \
# 0    ZAR BREST   FR19012            Brest Mace             Urbaine       O3
# 1    ZAR BREST   FR19016        BREST Plouzané         Périurbaine       O3
# 2   ZAG RENNES   FR19018     MORDELLES BELLAIS         Périurbaine       O3
# 3  ZR BRETAGNE   FR19020               Kergoff    Rurale nationale       O3
# 4  ZR BRETAGNE   FR19032  Lorient B. Bissonnet             Urbaine       O3
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0             Fond  ...       83.625           µg-m3          100.0
# 1             Fond  ...       81.850           µg-m3          100.0
# 2             Fond  ...       68.475           µg-m3          100.0
# 3             Fond  ...       75.375           µg-m3          100.0
# 4             Fond  ...       83.100           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO sub-score
# 0  48.386180  -4.486600              2
# 1  48.359444  -4.568055              2
# 2  48.082883  -1.834583              2
# 3  48.261963  -2.943631              2
# 4  47.742500  -3.395010              2
#
# [5 rows x 24 columns]

# %%
# SO2 AIR BREIZH (missing for AIR BREIZH)

# %%
# Combining 5 (if not missing) dataframes
# Concatenate DataFrames along the rows (stack them vertically)
combined_df_AIR_BREIZH = pd.concat([df_PM10, df_PM25, df_NO2, df_O3], axis=0) #, df_SO2

# If you want to reset the index of the combined DataFrame
combined_df_AIR_BREIZH.reset_index(drop=True, inplace=True)

# Renaming the ATMO subscore column to 'ATMO Score'
combined_df_AIR_BREIZH = combined_df_AIR_BREIZH.rename(columns={'ATMO sub-score': 'ATMO Score'})

# Printing the first five rows as a sanity check
print(combined_df_AIR_BREIZH.head())
# Out:
#          Date de début          Date de fin   Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
#
#            Zas code site              nom site type d'implantation Polluant  \
# 0   ZAG RENNES   FR19002        Rennes Laennec             Urbaine     PM10
# 1    ZAR BREST   FR19012            Brest Mace             Urbaine     PM10
# 2    ZAR BREST   FR19014      Brest Desmoulins             Urbaine     PM10
# 3  ZR BRETAGNE   FR19020               Kergoff    Rurale nationale     PM10
# 4  ZR BRETAGNE   FR19032  Lorient B. Bissonnet             Urbaine     PM10
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0           Trafic  ...    13.516667           µg-m3          100.0
# 1             Fond  ...    19.816667           µg-m3          100.0
# 2           Trafic  ...    30.675000           µg-m3          100.0
# 3             Fond  ...     7.279167           µg-m3          100.0
# 4             Fond  ...    16.941667           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO Score
# 0  48.108610  -1.665860        1.0
# 1  48.386180  -4.486600        1.0
# 2  48.397460  -4.488710        2.0
# 3  48.261963  -2.943631        1.0
# 4  47.742500  -3.395010        1.0
#
# [5 rows x 24 columns]

# %%
# Find the index of rows with maximum 'ATMO Score' within each group
idx_max_scores = combined_df_AIR_BREIZH.groupby(['nom site', 'Date de fin'])['ATMO Score'].idxmax()

# Select rows with the maximum 'ATMO Score' using the index
final_df_AIR_BREIZH = combined_df_AIR_BREIZH.loc[idx_max_scores]

# Reset index if needed
final_df_AIR_BREIZH.reset_index(drop=True, inplace=True)

# %%
# Downloading the final dataframe of Daily ATMO Score in AIR BREIZH to csv
final_df_AIR_BREIZH.to_csv('final_df_AIR_BREIZH.csv', index=False, encoding = 'latin1')

# %%
# Constructing indicator for AIR BREIZH

# File path to the data
ATMO_AIR_BREIZH_file_path = os.path.join(base_path, "final_df_AIR_BREIZH.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_ATMO = pd.read_csv(ATMO_AIR_BREIZH_file_path, delimiter=',', encoding = 'latin1')

print(df_ATMO.head())

counts = df_ATMO.groupby('nom site')['ATMO Score'].value_counts().reset_index(name='counts')
#print(counts)

#result = pd.merge(counts, df_ATMO[["Organisme", "type d'implantation", "Latitude", "Longitude"]], on='nom site', how='left')
#print(result)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_ATMO.groupby('nom site').first().reset_index()
#print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(counts, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score_y'], axis = 1)
print(result)
# Out:
#          Date de début          Date de fin   Organisme   code zas        Zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01  ZAR BREST
# 1  2023/01/02 00:00:00  2023/01/02 23:59:59  AIR BREIZH  FR53ZAR01  ZAR BREST
# 2  2023/01/03 00:00:00  2023/01/03 23:59:59  AIR BREIZH  FR53ZAR01  ZAR BREST
# 3  2023/01/04 00:00:00  2023/01/04 23:59:59  AIR BREIZH  FR53ZAR01  ZAR BREST
# 4  2023/01/05 00:00:00  2023/01/05 23:59:59  AIR BREIZH  FR53ZAR01  ZAR BREST
#
#   code site        nom site type d'implantation Polluant type d'influence  \
# 0   FR19016  BREST Plouzané         Périurbaine       O3             Fond
# 1   FR19016  BREST Plouzané         Périurbaine       O3             Fond
# 2   FR19016  BREST Plouzané         Périurbaine       O3             Fond
# 3   FR19016  BREST Plouzané         Périurbaine       O3             Fond
# 4   FR19016  BREST Plouzané         Périurbaine       O3             Fond
#
#    ... valeur brute unité de mesure taux de saisie  couverture temporelle  \
# 0  ...       81.850           µg-m3          100.0                    100
# 1  ...       82.100           µg-m3           96.0                    100
# 2  ...       83.225           µg-m3          100.0                    100
# 3  ...       78.500           µg-m3          100.0                    100
# 4  ...       77.475           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  48.359444  -4.568055
# 1                   96.0            A         1  48.359444  -4.568055
# 2                  100.0            A         1  48.359444  -4.568055
# 3                  100.0            A         1  48.359444  -4.568055
# 4                  100.0            A         1  48.359444  -4.568055
#
#   ATMO Score
# 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#
# [5 rows x 24 columns]
#                 nom site  ATMO Score_x  counts   Organisme   code zas  \
# 0         BREST Plouzané           2.0     324  AIR BREIZH  FR53ZAR01
# 1         BREST Plouzané           3.0      28  AIR BREIZH  FR53ZAR01
# 2         BREST Plouzané           1.0       3  AIR BREIZH  FR53ZAR01
# 3         BREST Plouzané           4.0       1  AIR BREIZH  FR53ZAR01
# 4       Brest Desmoulins           2.0     211  AIR BREIZH  FR53ZAR01
# 5       Brest Desmoulins           1.0     128  AIR BREIZH  FR53ZAR01
# 6       Brest Desmoulins           3.0      19  AIR BREIZH  FR53ZAR01
# 7       Brest Desmoulins           4.0       3  AIR BREIZH  FR53ZAR01
# 8             Brest Mace           2.0     313  AIR BREIZH  FR53ZAR01
# 9             Brest Mace           3.0      30  AIR BREIZH  FR53ZAR01
# 10            Brest Mace           4.0       5  AIR BREIZH  FR53ZAR01
# 11            Brest Mace           1.0       4  AIR BREIZH  FR53ZAR01
# 12               Kergoff           2.0     297  AIR BREIZH  FR53ZRE01
# 13               Kergoff           3.0      39  AIR BREIZH  FR53ZRE01
# 14               Kergoff           1.0      11  AIR BREIZH  FR53ZRE01
# 15               Kergoff           4.0       6  AIR BREIZH  FR53ZRE01
# 16  Lorient B. Bissonnet           2.0     307  AIR BREIZH  FR53ZRE01
# 17  Lorient B. Bissonnet           3.0      48  AIR BREIZH  FR53ZRE01
# 18  Lorient B. Bissonnet           4.0       6  AIR BREIZH  FR53ZRE01
# 19  Lorient B. Bissonnet           1.0       2  AIR BREIZH  FR53ZRE01
# 20     Lorient Normandie           1.0     196  AIR BREIZH  FR53ZRE01
# 21     Lorient Normandie           2.0     147  AIR BREIZH  FR53ZRE01
# 22     Lorient Normandie           3.0      16  AIR BREIZH  FR53ZRE01
# 23     Lorient Normandie           4.0       6  AIR BREIZH  FR53ZRE01
# 24     MORDELLES BELLAIS           2.0     317  AIR BREIZH  FR53ZAG01
# 25     MORDELLES BELLAIS           1.0      24  AIR BREIZH  FR53ZAG01
# 26     MORDELLES BELLAIS           3.0      15  AIR BREIZH  FR53ZAG01
# 27     MORDELLES BELLAIS           4.0       4  AIR BREIZH  FR53ZAG01
# 28          Quimper Zola           2.0     323  AIR BREIZH  FR53ZRE01
# 29          Quimper Zola           3.0      33  AIR BREIZH  FR53ZRE01
# 30          Quimper Zola           1.0       3  AIR BREIZH  FR53ZRE01
# 31          Quimper Zola           4.0       3  AIR BREIZH  FR53ZRE01
# 32        Rennes Laennec           1.0     195  AIR BREIZH  FR53ZAG01
# 33        Rennes Laennec           2.0     141  AIR BREIZH  FR53ZAG01
# 34        Rennes Laennec           4.0      16  AIR BREIZH  FR53ZAG01
# 35        Rennes Laennec           3.0      11  AIR BREIZH  FR53ZAG01
# 36     Rennes Les Halles           1.0     183  AIR BREIZH  FR53ZAG01
# 37     Rennes Les Halles           2.0     158  AIR BREIZH  FR53ZAG01
# 38     Rennes Les Halles           3.0       5  AIR BREIZH  FR53ZAG01
# 39     Rennes Les Halles           4.0       2  AIR BREIZH  FR53ZAG01
# 40         Rennes Thabor           2.0     306  AIR BREIZH  FR53ZAG01
# 41         Rennes Thabor           3.0      35  AIR BREIZH  FR53ZAG01
# 42         Rennes Thabor           4.0      22  AIR BREIZH  FR53ZAG01
# 43         Rennes Thabor           1.0       2  AIR BREIZH  FR53ZAG01
# 44   Saint Brieuc Balzac           2.0     343  AIR BREIZH  FR53ZRE01
# 45   Saint Brieuc Balzac           3.0      14  AIR BREIZH  FR53ZRE01
# 46   Saint Brieuc Balzac           1.0       4  AIR BREIZH  FR53ZRE01
# 47   Saint Brieuc Balzac           4.0       4  AIR BREIZH  FR53ZRE01
# 48        StMalo Rocabey           2.0     311  AIR BREIZH  FR53ZRE01
# 49        StMalo Rocabey           3.0      37  AIR BREIZH  FR53ZRE01
# 50        StMalo Rocabey           4.0      10  AIR BREIZH  FR53ZRE01
# 51        StMalo Rocabey           1.0       3  AIR BREIZH  FR53ZRE01
# 52        StMalo Rocabey           5.0       1  AIR BREIZH  FR53ZRE01
# 53            Vannes UTA           2.0     289  AIR BREIZH  FR53ZRE01
# 54            Vannes UTA           3.0      53  AIR BREIZH  FR53ZRE01
# 55            Vannes UTA           4.0      11  AIR BREIZH  FR53ZRE01
# 56            Vannes UTA           1.0       4  AIR BREIZH  FR53ZRE01
#
#             Zas code site type d'implantation Polluant type d'influence  ...  \
# 0     ZAR BREST   FR19016         Périurbaine       O3             Fond  ...
# 1     ZAR BREST   FR19016         Périurbaine       O3             Fond  ...
# 2     ZAR BREST   FR19016         Périurbaine       O3             Fond  ...
# 3     ZAR BREST   FR19016         Périurbaine       O3             Fond  ...
# 4     ZAR BREST   FR19014             Urbaine     PM10           Trafic  ...
# 5     ZAR BREST   FR19014             Urbaine     PM10           Trafic  ...
# 6     ZAR BREST   FR19014             Urbaine     PM10           Trafic  ...
# 7     ZAR BREST   FR19014             Urbaine     PM10           Trafic  ...
# 8     ZAR BREST   FR19012             Urbaine       O3             Fond  ...
# 9     ZAR BREST   FR19012             Urbaine       O3             Fond  ...
# 10    ZAR BREST   FR19012             Urbaine       O3             Fond  ...
# 11    ZAR BREST   FR19012             Urbaine       O3             Fond  ...
# 12  ZR BRETAGNE   FR19020    Rurale nationale       O3             Fond  ...
# 13  ZR BRETAGNE   FR19020    Rurale nationale       O3             Fond  ...
# 14  ZR BRETAGNE   FR19020    Rurale nationale       O3             Fond  ...
# 15  ZR BRETAGNE   FR19020    Rurale nationale       O3             Fond  ...
# 16  ZR BRETAGNE   FR19032             Urbaine       O3             Fond  ...
# 17  ZR BRETAGNE   FR19032             Urbaine       O3             Fond  ...
# 18  ZR BRETAGNE   FR19032             Urbaine       O3             Fond  ...
# 19  ZR BRETAGNE   FR19032             Urbaine       O3             Fond  ...
# 20  ZR BRETAGNE   FR19037             Urbaine     PM10           Trafic  ...
# 21  ZR BRETAGNE   FR19037             Urbaine     PM10           Trafic  ...
# 22  ZR BRETAGNE   FR19037             Urbaine     PM10           Trafic  ...
# 23  ZR BRETAGNE   FR19037             Urbaine     PM10           Trafic  ...
# 24   ZAG RENNES   FR19018         Périurbaine       O3             Fond  ...
# 25   ZAG RENNES   FR19018         Périurbaine       O3             Fond  ...
# 26   ZAG RENNES   FR19018         Périurbaine       O3             Fond  ...
# 27   ZAG RENNES   FR19018         Périurbaine       O3             Fond  ...
# 28  ZR BRETAGNE   FR19053             Urbaine       O3             Fond  ...
# 29  ZR BRETAGNE   FR19053             Urbaine       O3             Fond  ...
# 30  ZR BRETAGNE   FR19053             Urbaine       O3             Fond  ...
# 31  ZR BRETAGNE   FR19053             Urbaine       O3             Fond  ...
# 32   ZAG RENNES   FR19002             Urbaine     PM10           Trafic  ...
# 33   ZAG RENNES   FR19002             Urbaine     PM10           Trafic  ...
# 34   ZAG RENNES   FR19002             Urbaine     PM10           Trafic  ...
# 35   ZAG RENNES   FR19002             Urbaine     PM10           Trafic  ...
# 36   ZAG RENNES   FR19007             Urbaine      NO2           Trafic  ...
# 37   ZAG RENNES   FR19007             Urbaine      NO2           Trafic  ...
# 38   ZAG RENNES   FR19007             Urbaine      NO2           Trafic  ...
# 39   ZAG RENNES   FR19007             Urbaine      NO2           Trafic  ...
# 40   ZAG RENNES   FR19039             Urbaine       O3             Fond  ...
# 41   ZAG RENNES   FR19039             Urbaine       O3             Fond  ...
# 42   ZAG RENNES   FR19039             Urbaine       O3             Fond  ...
# 43   ZAG RENNES   FR19039             Urbaine       O3             Fond  ...
# 44  ZR BRETAGNE   FR19061             Urbaine       O3             Fond  ...
# 45  ZR BRETAGNE   FR19061             Urbaine       O3             Fond  ...
# 46  ZR BRETAGNE   FR19061             Urbaine       O3             Fond  ...
# 47  ZR BRETAGNE   FR19061             Urbaine       O3             Fond  ...
# 48  ZR BRETAGNE   FR19082         Périurbaine       O3             Fond  ...
# 49  ZR BRETAGNE   FR19082         Périurbaine       O3             Fond  ...
# 50  ZR BRETAGNE   FR19082         Périurbaine       O3             Fond  ...
# 51  ZR BRETAGNE   FR19082         Périurbaine       O3             Fond  ...
# 52  ZR BRETAGNE   FR19082         Périurbaine       O3             Fond  ...
# 53  ZR BRETAGNE   FR19033             Urbaine       O3             Fond  ...
# 54  ZR BRETAGNE   FR19033             Urbaine       O3             Fond  ...
# 55  ZR BRETAGNE   FR19033             Urbaine       O3             Fond  ...
# 56  ZR BRETAGNE   FR19033             Urbaine       O3             Fond  ...
#
#    valeur valeur brute unité de mesure  taux de saisie  couverture temporelle  \
# 0    81.9    81.850000           µg-m3           100.0                    100
# 1    81.9    81.850000           µg-m3           100.0                    100
# 2    81.9    81.850000           µg-m3           100.0                    100
# 3    81.9    81.850000           µg-m3           100.0                    100
# 4    31.0    30.675000           µg-m3           100.0                    100
# 5    31.0    30.675000           µg-m3           100.0                    100
# 6    31.0    30.675000           µg-m3           100.0                    100
# 7    31.0    30.675000           µg-m3           100.0                    100
# 8    83.6    83.625000           µg-m3           100.0                    100
# 9    83.6    83.625000           µg-m3           100.0                    100
# 10   83.6    83.625000           µg-m3           100.0                    100
# 11   83.6    83.625000           µg-m3           100.0                    100
# 12   75.4    75.375000           µg-m3           100.0                    100
# 13   75.4    75.375000           µg-m3           100.0                    100
# 14   75.4    75.375000           µg-m3           100.0                    100
# 15   75.4    75.375000           µg-m3           100.0                    100
# 16   83.1    83.100000           µg-m3           100.0                    100
# 17   83.1    83.100000           µg-m3           100.0                    100
# 18   83.1    83.100000           µg-m3           100.0                    100
# 19   83.1    83.100000           µg-m3           100.0                    100
# 20   16.0    16.141667           µg-m3           100.0                    100
# 21   16.0    16.141667           µg-m3           100.0                    100
# 22   16.0    16.141667           µg-m3           100.0                    100
# 23   16.0    16.141667           µg-m3           100.0                    100
# 24   68.5    68.475000           µg-m3           100.0                    100
# 25   68.5    68.475000           µg-m3           100.0                    100
# 26   68.5    68.475000           µg-m3           100.0                    100
# 27   68.5    68.475000           µg-m3           100.0                    100
# 28   80.1    80.125000           µg-m3           100.0                    100
# 29   80.1    80.125000           µg-m3           100.0                    100
# 30   80.1    80.125000           µg-m3           100.0                    100
# 31   80.1    80.125000           µg-m3           100.0                    100
# 32   14.0    13.516667           µg-m3           100.0                    100
# 33   14.0    13.516667           µg-m3           100.0                    100
# 34   14.0    13.516667           µg-m3           100.0                    100
# 35   14.0    13.516667           µg-m3           100.0                    100
# 36   25.9    25.850000           µg-m3           100.0                    100
# 37   25.9    25.850000           µg-m3           100.0                    100
# 38   25.9    25.850000           µg-m3           100.0                    100
# 39   25.9    25.850000           µg-m3           100.0                    100
# 40   78.5    78.500000           µg-m3           100.0                    100
# 41   78.5    78.500000           µg-m3           100.0                    100
# 42   78.5    78.500000           µg-m3           100.0                    100
# 43   78.5    78.500000           µg-m3           100.0                    100
# 44   74.2    74.200000           µg-m3           100.0                    100
# 45   74.2    74.200000           µg-m3           100.0                    100
# 46   74.2    74.200000           µg-m3           100.0                    100
# 47   74.2    74.200000           µg-m3           100.0                    100
# 48   83.2    83.200000           µg-m3           100.0                    100
# 49   83.2    83.200000           µg-m3           100.0                    100
# 50   83.2    83.200000           µg-m3           100.0                    100
# 51   83.2    83.200000           µg-m3           100.0                    100
# 52   83.2    83.200000           µg-m3           100.0                    100
# 53   78.9    78.850000           µg-m3           100.0                    100
# 54   78.9    78.850000           µg-m3           100.0                    100
# 55   78.9    78.850000           µg-m3           100.0                    100
# 56   78.9    78.850000           µg-m3           100.0                    100
#
#    couverture de données  code qualité  validité   Latitude Longitude
# 0                  100.0             A         1  48.359444 -4.568055
# 1                  100.0             A         1  48.359444 -4.568055
# 2                  100.0             A         1  48.359444 -4.568055
# 3                  100.0             A         1  48.359444 -4.568055
# 4                  100.0             A         1  48.397460 -4.488710
# 5                  100.0             A         1  48.397460 -4.488710
# 6                  100.0             A         1  48.397460 -4.488710
# 7                  100.0             A         1  48.397460 -4.488710
# 8                  100.0             A         1  48.386180 -4.486600
# 9                  100.0             A         1  48.386180 -4.486600
# 10                 100.0             A         1  48.386180 -4.486600
# 11                 100.0             A         1  48.386180 -4.486600
# 12                 100.0             A         1  48.261963 -2.943631
# 13                 100.0             A         1  48.261963 -2.943631
# 14                 100.0             A         1  48.261963 -2.943631
# 15                 100.0             A         1  48.261963 -2.943631
# 16                 100.0             A         1  47.742500 -3.395010
# 17                 100.0             A         1  47.742500 -3.395010
# 18                 100.0             A         1  47.742500 -3.395010
# 19                 100.0             A         1  47.742500 -3.395010
# 20                 100.0             A         1  47.758947 -3.369380
# 21                 100.0             A         1  47.758947 -3.369380
# 22                 100.0             A         1  47.758947 -3.369380
# 23                 100.0             A         1  47.758947 -3.369380
# 24                 100.0             A         1  48.082883 -1.834583
# 25                 100.0             A         1  48.082883 -1.834583
# 26                 100.0             A         1  48.082883 -1.834583
# 27                 100.0             A         1  48.082883 -1.834583
# 28                 100.0             A         1  47.986606 -4.097658
# 29                 100.0             A         1  47.986606 -4.097658
# 30                 100.0             A         1  47.986606 -4.097658
# 31                 100.0             A         1  47.986606 -4.097658
# 32                 100.0             A         1  48.108610 -1.665860
# 33                 100.0             A         1  48.108610 -1.665860
# 34                 100.0             A         1  48.108610 -1.665860
# 35                 100.0             A         1  48.108610 -1.665860
# 36                 100.0             A         1  48.107510 -1.679840
# 37                 100.0             A         1  48.107510 -1.679840
# 38                 100.0             A         1  48.107510 -1.679840
# 39                 100.0             A         1  48.107510 -1.679840
# 40                 100.0             A         1  48.115210 -1.673088
# 41                 100.0             A         1  48.115210 -1.673088
# 42                 100.0             A         1  48.115210 -1.673088
# 43                 100.0             A         1  48.115210 -1.673088
# 44                 100.0             A         1  48.513510 -2.749530
# 45                 100.0             A         1  48.513510 -2.749530
# 46                 100.0             A         1  48.513510 -2.749530
# 47                 100.0             A         1  48.513510 -2.749530
# 48                 100.0             A         1  48.653060 -2.002680
# 49                 100.0             A         1  48.653060 -2.002680
# 50                 100.0             A         1  48.653060 -2.002680
# 51                 100.0             A         1  48.653060 -2.002680
# 52                 100.0             A         1  48.653060 -2.002680
# 53                 100.0             R         1  47.648920 -2.763990
# 54                 100.0             R         1  47.648920 -2.763990
# 55                 100.0             R         1  47.648920 -2.763990
# 56                 100.0             R         1  47.648920 -2.763990
#
# [57 rows x 23 columns]

# %%
# Group the DataFrame by 'nom' and calculate the total counts for each 'nom'
total_counts_by_nom = result.groupby('nom site')['counts'].sum()

# Filter the DataFrame to include only rows where the score is equal to or greater than 3
filtered_result = result[result['ATMO Score_x'] >= 3]

# Group the filtered DataFrame by 'nom' and calculate the counts equal to or greater than 3 for each 'nom'
counts_greater_than_3_by_nom = filtered_result.groupby('nom site')['counts'].sum()

# Calculate the ratio of counts greater than or equal to 3 over total counts for each 'nom'
ratio_counts_greater_than_3 = (counts_greater_than_3_by_nom / total_counts_by_nom).fillna(0)

# Display the resulting Series
print(ratio_counts_greater_than_3)

# Merge the site-specific information with the counts DataFrame
ratio_counts_greater_than_3_df = pd.merge(ratio_counts_greater_than_3, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score'], axis = 1)
ratio_counts_greater_than_3_df = ratio_counts_greater_than_3_df.rename(columns={'counts': 'indicator'})
print(ratio_counts_greater_than_3_df)
# Out:
# nom site
# BREST Plouzané          0.081461
# Brest Desmoulins        0.060942
# Brest Mace              0.099432
# Kergoff                 0.127479
# Lorient B. Bissonnet    0.148760
# Lorient Normandie       0.060274
# MORDELLES BELLAIS       0.052778
# Quimper Zola            0.099448
# Rennes Laennec          0.074380
# Rennes Les Halles       0.020115
# Rennes Thabor           0.156164
# Saint Brieuc Balzac     0.049315
# StMalo Rocabey          0.132597
# Vannes UTA              0.179272
# Name: counts, dtype: float64
#                 nom site  indicator   Organisme   code zas          Zas  \
# 0         BREST Plouzané   0.081461  AIR BREIZH  FR53ZAR01    ZAR BREST
# 1       Brest Desmoulins   0.060942  AIR BREIZH  FR53ZAR01    ZAR BREST
# 2             Brest Mace   0.099432  AIR BREIZH  FR53ZAR01    ZAR BREST
# 3                Kergoff   0.127479  AIR BREIZH  FR53ZRE01  ZR BRETAGNE
# 4   Lorient B. Bissonnet   0.148760  AIR BREIZH  FR53ZRE01  ZR BRETAGNE
# 5      Lorient Normandie   0.060274  AIR BREIZH  FR53ZRE01  ZR BRETAGNE
# 6      MORDELLES BELLAIS   0.052778  AIR BREIZH  FR53ZAG01   ZAG RENNES
# 7           Quimper Zola   0.099448  AIR BREIZH  FR53ZRE01  ZR BRETAGNE
# 8         Rennes Laennec   0.074380  AIR BREIZH  FR53ZAG01   ZAG RENNES
# 9      Rennes Les Halles   0.020115  AIR BREIZH  FR53ZAG01   ZAG RENNES
# 10         Rennes Thabor   0.156164  AIR BREIZH  FR53ZAG01   ZAG RENNES
# 11   Saint Brieuc Balzac   0.049315  AIR BREIZH  FR53ZRE01  ZR BRETAGNE
# 12        StMalo Rocabey   0.132597  AIR BREIZH  FR53ZRE01  ZR BRETAGNE
# 13            Vannes UTA   0.179272  AIR BREIZH  FR53ZRE01  ZR BRETAGNE
#
#    code site type d'implantation Polluant type d'influence Réglementaire  ...  \
# 0    FR19016         Périurbaine       O3             Fond           Oui  ...
# 1    FR19014             Urbaine     PM10           Trafic           Oui  ...
# 2    FR19012             Urbaine       O3             Fond           Oui  ...
# 3    FR19020    Rurale nationale       O3             Fond           Oui  ...
# 4    FR19032             Urbaine       O3             Fond           Oui  ...
# 5    FR19037             Urbaine     PM10           Trafic           Oui  ...
# 6    FR19018         Périurbaine       O3             Fond           Oui  ...
# 7    FR19053             Urbaine       O3             Fond           Oui  ...
# 8    FR19002             Urbaine     PM10           Trafic           Oui  ...
# 9    FR19007             Urbaine      NO2           Trafic           Oui  ...
# 10   FR19039             Urbaine       O3             Fond           Oui  ...
# 11   FR19061             Urbaine       O3             Fond           Oui  ...
# 12   FR19082         Périurbaine       O3             Fond           Oui  ...
# 13   FR19033             Urbaine       O3             Fond           Oui  ...
#
#    valeur valeur brute  unité de mesure  taux de saisie couverture temporelle  \
# 0    81.9    81.850000            µg-m3           100.0                   100
# 1    31.0    30.675000            µg-m3           100.0                   100
# 2    83.6    83.625000            µg-m3           100.0                   100
# 3    75.4    75.375000            µg-m3           100.0                   100
# 4    83.1    83.100000            µg-m3           100.0                   100
# 5    16.0    16.141667            µg-m3           100.0                   100
# 6    68.5    68.475000            µg-m3           100.0                   100
# 7    80.1    80.125000            µg-m3           100.0                   100
# 8    14.0    13.516667            µg-m3           100.0                   100
# 9    25.9    25.850000            µg-m3           100.0                   100
# 10   78.5    78.500000            µg-m3           100.0                   100
# 11   74.2    74.200000            µg-m3           100.0                   100
# 12   83.2    83.200000            µg-m3           100.0                   100
# 13   78.9    78.850000            µg-m3           100.0                   100
#
#     couverture de données  code qualité  validité   Latitude  Longitude
# 0                   100.0             A         1  48.359444  -4.568055
# 1                   100.0             A         1  48.397460  -4.488710
# 2                   100.0             A         1  48.386180  -4.486600
# 3                   100.0             A         1  48.261963  -2.943631
# 4                   100.0             A         1  47.742500  -3.395010
# 5                   100.0             A         1  47.758947  -3.369380
# 6                   100.0             A         1  48.082883  -1.834583
# 7                   100.0             A         1  47.986606  -4.097658
# 8                   100.0             A         1  48.108610  -1.665860
# 9                   100.0             A         1  48.107510  -1.679840
# 10                  100.0             A         1  48.115210  -1.673088
# 11                  100.0             A         1  48.513510  -2.749530
# 12                  100.0             A         1  48.653060  -2.002680
# 13                  100.0             R         1  47.648920  -2.763990
#
# [14 rows x 22 columns]

# %%
# Downloading the final indicator of AIR BREIZH to csv
ratio_counts_greater_than_3_df.to_csv('indicator_AIR_BREIZH.csv', index=False, encoding = 'latin1')

# %%
# -----------------------------------------------------------------------------------------------------------------------------------------------------
#                                                               Sanity Checks
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %%
print(df_PM25['valeur'].head())
# Out:
# 0     7.7
# 1     0.0
# 2    10.0
# 3     4.5
# 4     9.1
# Name: valeur, dtype: float64

# %%
df_PM25['ATMO sub-score'].describe()
# Out:
# count    3628.000000
# mean        1.290243
# std         0.585029
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         5.000000
# Name: ATMO sub-score, dtype: float64

# %%
print(df_PM25['valeur'].head())
# Out:
# 0     7.7
# 1     0.0
# 2    10.0
# 3     4.5
# 4     9.1
# Name: valeur, dtype: float64

# %%
combined_df_AIR_BREIZH.columns
# Out:
# Index(['Date de début', 'Date de fin', 'Organisme', 'code zas', 'Zas',
#        'code site', 'nom site', 'type d'implantation', 'Polluant',
#        'type d'influence', 'Réglementaire', 'type d'évaluation',
#        'type de valeur', 'valeur', 'valeur brute', 'unité de mesure',
#        'taux de saisie', 'couverture temporelle', 'couverture de données',
#        'code qualité', 'validité', 'Latitude', 'Longitude', 'ATMO sub-score'],
#       dtype='object')

# %%
array = [df_PM10['nom site'].unique(),df_PM25['nom site'].unique(),df_NO2['nom site'].unique(),df_O3['nom site'].unique()]

# %%
import numpy as np
# Concatenate all arrays into a single array
combined_array = np.concatenate(array)

# Get unique elements from the combined array
unique_elements = np.unique(combined_array)

print(unique_elements)
len(unique_elements)
# Out:
# ['BREST Plouzané' 'Brest Desmoulins' 'Brest Mace' 'Kergoff'
#  'Lorient B. Bissonnet' 'Lorient Normandie' 'MORDELLES BELLAIS'
#  'Quimper Zola' 'Rennes Laennec' 'Rennes Les Halles' 'Rennes Thabor'
#  'Saint Brieuc Balzac' 'StMalo Rocabey' 'Vannes UTA']
# 14

# %%
len(counts)
# Out:
# 17

# %%
print(len(final_df_AIR_BREIZH['nom site'].unique()))
print(len(final_df_AIR_BREIZH))

print(result['counts'].sum())
print(len(result['nom site'].unique()))
# matches
# Out:
# 14
# 1095
# 1095
# 14
