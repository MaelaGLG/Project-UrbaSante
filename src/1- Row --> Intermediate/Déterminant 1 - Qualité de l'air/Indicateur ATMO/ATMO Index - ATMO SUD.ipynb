# %%
# Code for extracting the daily ATMO score for each station in ATMO SUD (Région: Provence-Alpes-Côte d'Azur)

# %%
# Installing required packages
import pandas as pd

import os

# Base directory path
base_path = ".\data\1- Raw Data\Déterminant 1 - Qualité de l'air\"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_29328\2375524138.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# PM10 ATMO SUD

# File path to the data
PM10_ATMO_SUD_file_path = os.path.join(base_path, "PM10 Moyenne Journalière\Export Moy. journalière - PM10 - ATMO SUD.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM10 = pd.read_csv(PM10_ATMO_SUD_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM10.head())

# Sample ATMO subscore dictionary for PM10 (Moyenne journalière)
ATMO_subscore_PM10 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 20.0), (20.0, 40.0), (40.0, 50.0), (50.0, 100.0), (100.0, 150.0), (150.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM10 = pd.DataFrame(ATMO_subscore_PM10)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM10['Range'] = ATMO_subscore_df_PM10['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM10 measurement
def assign_subscore_PM10(valeur):
    for index, row in ATMO_subscore_df_PM10.iterrows():  
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM10['ATMO sub-score'] = df_PM10['valeur'].apply(assign_subscore_PM10)  

# Display the updated DataFrame
print(df_PM10.head())
# Out:
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZRE02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
#
#                              Zas code site             nom site  \
# 0              ZAG MARSEILLE-AIX   FR02008   Port de Bouc Leque
# 1              ZAG MARSEILLE-AIX   FR02009     Port Saint Louis
# 2  ZR PROVENCE-ALPES-COTE-D-AZUR   FR02022                Arles
# 3              ZAG MARSEILLE-AIX   FR02029  Chateauneuf La Mede
# 4              ZAG MARSEILLE-AIX   FR02041                SALON
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Urbaine     PM10     Industrielle  ...   28.0    27.966667
# 1         Périurbaine     PM10     Industrielle  ...   31.0    30.841667
# 2             Urbaine     PM10             Fond  ...   22.0    22.187500
# 3         Périurbaine     PM10     Industrielle  ...   26.0    25.604167
# 4             Urbaine     PM10             Fond  ...   19.0    19.033333
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             A         1  43.401952  4.981919
# 1                 100.0             A         1  43.393780  4.801024
# 2                 100.0             A         1  43.675114  4.629210
# 3                 100.0             A         1  43.399546  5.113214
# 4                 100.0             A         1  43.639002  5.101097
#
# [5 rows x 23 columns]
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZRE02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
#
#                              Zas code site             nom site  \
# 0              ZAG MARSEILLE-AIX   FR02008   Port de Bouc Leque
# 1              ZAG MARSEILLE-AIX   FR02009     Port Saint Louis
# 2  ZR PROVENCE-ALPES-COTE-D-AZUR   FR02022                Arles
# 3              ZAG MARSEILLE-AIX   FR02029  Chateauneuf La Mede
# 4              ZAG MARSEILLE-AIX   FR02041                SALON
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Urbaine     PM10     Industrielle  ...    27.966667
# 1         Périurbaine     PM10     Industrielle  ...    30.841667
# 2             Urbaine     PM10             Fond  ...    22.187500
# 3         Périurbaine     PM10     Industrielle  ...    25.604167
# 4             Urbaine     PM10             Fond  ...    19.033333
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  43.401952   4.981919
# 1                  100.0            A         1  43.393780   4.801024
# 2                  100.0            A         1  43.675114   4.629210
# 3                  100.0            A         1  43.399546   5.113214
# 4                  100.0            A         1  43.639002   5.101097
#
#   ATMO sub-score
# 0              2
# 1              2
# 2              2
# 3              2
# 4              1
#
# [5 rows x 24 columns]

# %%
# PM2.5 ATMO SUD

# File path to the data
PM25_ATMO_SUD_file_path = os.path.join(base_path, "PM2.5 Moyenne Journalière\Export Moy. journalière - PM2.5 - ATMO SUD.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM25 = pd.read_csv(PM25_ATMO_SUD_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM25.head())

# Sample ATMO subscore dictionary for PM2.5 (Moyenne journalière)
ATMO_subscore_PM25 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 10.0), (10.0, 20.0), (20.0, 25.0), (25.0, 50.0), (50.0, 75.0), (75.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM25 = pd.DataFrame(ATMO_subscore_PM25)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM25['Range'] = ATMO_subscore_df_PM25['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM2.5 measurement
def assign_subscore_PM25(valeur):
    for index, row in ATMO_subscore_df_PM25.iterrows(): 
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM25['ATMO sub-score'] = df_PM25['valeur'].apply(assign_subscore_PM25)  

# Display the updated DataFrame
print(df_PM25.head())
# Out:
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZRE02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
#
#                              Zas code site            nom site  \
# 0              ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque
# 1              ZAG MARSEILLE-AIX   FR02013    Fos Les Carabins
# 2              ZAG MARSEILLE-AIX   FR02020    Rognac les Brets
# 3  ZR PROVENCE-ALPES-COTE-D-AZUR   FR02022               Arles
# 4              ZAG MARSEILLE-AIX   FR02041               SALON
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Urbaine    PM2.5     Industrielle  ...    9.4     9.354167
# 1         Périurbaine    PM2.5     Industrielle  ...   10.0    10.354167
# 2         Périurbaine    PM2.5     Industrielle  ...   10.0    10.029167
# 3             Urbaine    PM2.5             Fond  ...   12.0    12.025000
# 4             Urbaine    PM2.5             Fond  ...   11.0    10.850000
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             A         1  43.401952  4.981919
# 1                 100.0             A         1  43.458927  4.934572
# 2                 100.0             A         1  43.510802  5.220046
# 3                 100.0             A         1  43.675114  4.629210
# 4                 100.0             A         1  43.639002  5.101097
#
# [5 rows x 23 columns]
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZRE02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
#
#                              Zas code site            nom site  \
# 0              ZAG MARSEILLE-AIX   FR02008  Port de Bouc Leque
# 1              ZAG MARSEILLE-AIX   FR02013    Fos Les Carabins
# 2              ZAG MARSEILLE-AIX   FR02020    Rognac les Brets
# 3  ZR PROVENCE-ALPES-COTE-D-AZUR   FR02022               Arles
# 4              ZAG MARSEILLE-AIX   FR02041               SALON
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Urbaine    PM2.5     Industrielle  ...     9.354167
# 1         Périurbaine    PM2.5     Industrielle  ...    10.354167
# 2         Périurbaine    PM2.5     Industrielle  ...    10.029167
# 3             Urbaine    PM2.5             Fond  ...    12.025000
# 4             Urbaine    PM2.5             Fond  ...    10.850000
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  43.401952   4.981919
# 1                  100.0            A         1  43.458927   4.934572
# 2                  100.0            A         1  43.510802   5.220046
# 3                  100.0            A         1  43.675114   4.629210
# 4                  100.0            A         1  43.639002   5.101097
#
#   ATMO sub-score
# 0            1.0
# 1            1.0
# 2            1.0
# 3            2.0
# 4            2.0
#
# [5 rows x 24 columns]

# %%
# NO2 ATMO SUD

# File path to the data
NO2_ATMO_SUD_file_path = os.path.join(base_path, "NO2 Max Horaire Journalier\Export Max. journalier moy. hor. - NO2 - ATMO SUD.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_NO2 = pd.read_csv(NO2_ATMO_SUD_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_NO2.head())

# Sample ATMO subscore dictionary for NO2 (Max horaire journalier)
ATMO_subscore_NO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 40.0), (40.0, 90.0), (90.0, 120.0), (120.0, 230.0), (230.0, 340.0), (340.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_NO2 = pd.DataFrame(ATMO_subscore_NO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_NO2['Range'] = ATMO_subscore_df_NO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of NO2 measurement
def assign_subscore_NO2(valeur):
    for index, row in ATMO_subscore_df_NO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_NO2['ATMO sub-score'] = df_NO2['valeur'].apply(assign_subscore_NO2)

# Display the updated DataFrame
print(df_NO2.head())
# Out:
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZRE02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
#
#                              Zas code site            nom site  \
# 0  ZR PROVENCE-ALPES-COTE-D-AZUR   FR02022               Arles
# 1              ZAG MARSEILLE-AIX   FR02041               SALON
# 2              ZAG MARSEILLE-AIX   FR02043           Marignane
# 3              ZAG MARSEILLE-AIX   FR03006   MARSEILLE RABATAU
# 4              ZAG MARSEILLE-AIX   FR03014  MARSEILLE ST LOUIS
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Urbaine      NO2             Fond  ...   21.9       21.850
# 1             Urbaine      NO2             Fond  ...   15.5       15.450
# 2             Urbaine      NO2             Fond  ...   13.6       13.575
# 3             Urbaine      NO2           Trafic  ...   17.8       17.800
# 4             Urbaine      NO2             Fond  ...   28.1       28.100
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             R         1  43.675114  4.629210
# 1                 100.0             R         1  43.639002  5.101097
# 2                 100.0             R         1  43.416531  5.222281
# 3                 100.0             R         1  43.276451  5.397360
# 4                 100.0             R         1  43.348048  5.360119
#
# [5 rows x 23 columns]
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZRE02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
#
#                              Zas code site            nom site  \
# 0  ZR PROVENCE-ALPES-COTE-D-AZUR   FR02022               Arles
# 1              ZAG MARSEILLE-AIX   FR02041               SALON
# 2              ZAG MARSEILLE-AIX   FR02043           Marignane
# 3              ZAG MARSEILLE-AIX   FR03006   MARSEILLE RABATAU
# 4              ZAG MARSEILLE-AIX   FR03014  MARSEILLE ST LOUIS
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Urbaine      NO2             Fond  ...       21.850
# 1             Urbaine      NO2             Fond  ...       15.450
# 2             Urbaine      NO2             Fond  ...       13.575
# 3             Urbaine      NO2           Trafic  ...       17.800
# 4             Urbaine      NO2             Fond  ...       28.100
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            R         1  43.675114   4.629210
# 1                  100.0            R         1  43.639002   5.101097
# 2                  100.0            R         1  43.416531   5.222281
# 3                  100.0            R         1  43.276451   5.397360
# 4                  100.0            R         1  43.348048   5.360119
#
#   ATMO sub-score
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
#
# [5 rows x 24 columns]

# %%
# O3 ATMO SUD

# File path to the data
O3_ATMO_SUD_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - ATMO SUD.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_ATMO_SUD_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Sample ATMO subscore dictionary for O3 (Max horaire journalier)
ATMO_subscore_O3 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 50.0), (50.0, 100.0), (100.0, 130.0), (130.0, 240.0), (240.0, 380.0), (380.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_O3 = pd.DataFrame(ATMO_subscore_O3)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_O3['Range'] = ATMO_subscore_df_O3['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of O3 measurement
def assign_subscore_O3(valeur):
    for index, row in ATMO_subscore_df_O3.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_O3['ATMO sub-score'] = df_O3['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZRE02
#
#                              Zas code site              nom site  \
# 0              ZAG MARSEILLE-AIX   FR02001         Berre l'Etang
# 1              ZAG MARSEILLE-AIX   FR02004  Martigues P. Central
# 2              ZAG MARSEILLE-AIX   FR02012                Istres
# 3              ZAG MARSEILLE-AIX   FR02021      Sausset les Pins
# 4  ZR PROVENCE-ALPES-COTE-D-AZUR   FR02022                 Arles
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0         Périurbaine       O3             Fond  ...   70.7       70.700
# 1             Urbaine       O3             Fond  ...   72.8       72.825
# 2             Urbaine       O3             Fond  ...   65.9       65.900
# 3         Périurbaine       O3             Fond  ...   73.4       73.350
# 4             Urbaine       O3             Fond  ...   67.0       66.950
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             R         1  43.486234  5.171939
# 1                 100.0             R         1  43.416661  5.042731
# 2                 100.0             R         1  43.506149  4.982898
# 3                 100.0             R         1  43.331245  5.117696
# 4                 100.0             R         1  43.675114  4.629210
#
# [5 rows x 23 columns]
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZRE02
#
#                              Zas code site              nom site  \
# 0              ZAG MARSEILLE-AIX   FR02001         Berre l'Etang
# 1              ZAG MARSEILLE-AIX   FR02004  Martigues P. Central
# 2              ZAG MARSEILLE-AIX   FR02012                Istres
# 3              ZAG MARSEILLE-AIX   FR02021      Sausset les Pins
# 4  ZR PROVENCE-ALPES-COTE-D-AZUR   FR02022                 Arles
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0         Périurbaine       O3             Fond  ...       70.700
# 1             Urbaine       O3             Fond  ...       72.825
# 2             Urbaine       O3             Fond  ...       65.900
# 3         Périurbaine       O3             Fond  ...       73.350
# 4             Urbaine       O3             Fond  ...       66.950
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            R         1  43.486234   5.171939
# 1                  100.0            R         1  43.416661   5.042731
# 2                  100.0            R         1  43.506149   4.982898
# 3                  100.0            R         1  43.331245   5.117696
# 4                  100.0            R         1  43.675114   4.629210
#
#   ATMO sub-score
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2
#
# [5 rows x 24 columns]

# %%
# SO2 ATMO SUD

# File path to the data
SO2_ATMO_SUD_file_path = os.path.join(base_path, "SO2 Max Horaire Journalier\Export Max. journalier moy. hor. - SO2 - ATMO SUD.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_SO2 = pd.read_csv(SO2_ATMO_SUD_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_SO2.head())

# Sample ATMO subscore dictionary for SO2 (Max horaire journalier)
ATMO_subscore_SO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 100.0), (100.0, 200.0), (200.0, 350.0), (350.0, 500.0), (500.0, 750.0), (750.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_SO2 = pd.DataFrame(ATMO_subscore_SO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_SO2['Range'] = ATMO_subscore_df_SO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of SO2 measurement
def assign_subscore_SO2(valeur):
    for index, row in ATMO_subscore_df_SO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_SO2['ATMO sub-score'] = df_SO2['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_SO2.head())
# Out:
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
#
#                  Zas code site              nom site type d'implantation  \
# 0  ZAG MARSEILLE-AIX   FR02004  Martigues P. Central             Urbaine
# 1  ZAG MARSEILLE-AIX   FR02006     Martigues Laurons         Périurbaine
# 2  ZAG MARSEILLE-AIX   FR02007  Martigues La Gatasse         Périurbaine
# 3  ZAG MARSEILLE-AIX   FR02008    Port de Bouc Leque             Urbaine
# 4  ZAG MARSEILLE-AIX   FR02011           Fos sur Mer         Périurbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0      SO2     Industrielle  ...    1.0        1.000           µg-m3
# 1      SO2     Industrielle  ...    1.9        1.900           µg-m3
# 2      SO2     Industrielle  ...    1.3        1.275           µg-m3
# 3      SO2     Industrielle  ...    3.8        3.825           µg-m3
# 4      SO2     Industrielle  ...    2.9        2.900           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             R
# 1           100.0                    100                 100.0             R
# 2           100.0                    100                 100.0             R
# 3            92.0                    100                  92.0             R
# 4           100.0                    100                 100.0             R
#
#    validité   Latitude Longitude
# 0         1  43.416661  5.042731
# 1         1  43.358982  5.023388
# 2         1  43.360692  5.058139
# 3         1  43.401952  4.981919
# 4         1  43.437858  4.945116
#
# [5 rows x 23 columns]
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
#
#                  Zas code site              nom site type d'implantation  \
# 0  ZAG MARSEILLE-AIX   FR02004  Martigues P. Central             Urbaine
# 1  ZAG MARSEILLE-AIX   FR02006     Martigues Laurons         Périurbaine
# 2  ZAG MARSEILLE-AIX   FR02007  Martigues La Gatasse         Périurbaine
# 3  ZAG MARSEILLE-AIX   FR02008    Port de Bouc Leque             Urbaine
# 4  ZAG MARSEILLE-AIX   FR02011           Fos sur Mer         Périurbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0      SO2     Industrielle  ...        1.000           µg-m3          100.0
# 1      SO2     Industrielle  ...        1.900           µg-m3          100.0
# 2      SO2     Industrielle  ...        1.275           µg-m3          100.0
# 3      SO2     Industrielle  ...        3.825           µg-m3           92.0
# 4      SO2     Industrielle  ...        2.900           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            R         1
# 1                    100                  100.0            R         1
# 2                    100                  100.0            R         1
# 3                    100                   92.0            R         1
# 4                    100                  100.0            R         1
#
#     Latitude  Longitude ATMO sub-score
# 0  43.416661   5.042731            1.0
# 1  43.358982   5.023388            1.0
# 2  43.360692   5.058139            1.0
# 3  43.401952   4.981919            1.0
# 4  43.437858   4.945116            1.0
#
# [5 rows x 24 columns]

# %%
# Combining 5 (if not missing) dataframes
# Concatenate DataFrames along the rows (stack them vertically)
combined_df_ATMO_SUD = pd.concat([df_PM10, df_PM25, df_NO2, df_O3, df_SO2], axis=0) #

# If you want to reset the index of the combined DataFrame
combined_df_ATMO_SUD.reset_index(drop=True, inplace=True)

# Renaming the ATMO subscore column to 'ATMO Score'
combined_df_ATMO_SUD = combined_df_ATMO_SUD.rename(columns={'ATMO sub-score': 'ATMO Score'})

# Printing the first five rows as a sanity check
print(combined_df_ATMO_SUD.head())
# Out:
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZRE02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
#
#                              Zas code site             nom site  \
# 0              ZAG MARSEILLE-AIX   FR02008   Port de Bouc Leque
# 1              ZAG MARSEILLE-AIX   FR02009     Port Saint Louis
# 2  ZR PROVENCE-ALPES-COTE-D-AZUR   FR02022                Arles
# 3              ZAG MARSEILLE-AIX   FR02029  Chateauneuf La Mede
# 4              ZAG MARSEILLE-AIX   FR02041                SALON
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Urbaine     PM10     Industrielle  ...    27.966667
# 1         Périurbaine     PM10     Industrielle  ...    30.841667
# 2             Urbaine     PM10             Fond  ...    22.187500
# 3         Périurbaine     PM10     Industrielle  ...    25.604167
# 4             Urbaine     PM10             Fond  ...    19.033333
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  43.401952   4.981919
# 1                  100.0            A         1  43.393780   4.801024
# 2                  100.0            A         1  43.675114   4.629210
# 3                  100.0            A         1  43.399546   5.113214
# 4                  100.0            A         1  43.639002   5.101097
#
#   ATMO Score
# 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        1.0
#
# [5 rows x 24 columns]

# %%
# Find the index of rows with maximum 'ATMO Score' within each group
idx_max_scores = combined_df_ATMO_SUD.groupby(['nom site', 'Date de fin'])['ATMO Score'].idxmax()

# Select rows with the maximum 'ATMO Score' using the index
final_df_ATMO_SUD = combined_df_ATMO_SUD.loc[idx_max_scores]

# Reset index if needed
final_df_ATMO_SUD.reset_index(drop=True, inplace=True)

# %%
# Downloading the final dataframe of Daily ATMO Score in ATMO SUD to csv
final_df_ATMO_SUD.to_csv('final_df_ATMO_SUD.csv', index=False, encoding = 'latin1')

# %%
# Constructing indicator for ATMO SUD

# File path to the data
ATMO_SUD_file_path = os.path.join(base_path, "final_df_ATMO_SUD.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_ATMO = pd.read_csv(ATMO_SUD_file_path, delimiter=',', encoding = 'latin1')

print(df_ATMO.head())

counts = df_ATMO.groupby('nom site')['ATMO Score'].value_counts().reset_index(name='counts')
#print(counts)

#result = pd.merge(counts, df_ATMO[["Organisme", "type d'implantation", "Latitude", "Longitude"]], on='nom site', how='left')
#print(result)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_ATMO.groupby('nom site').first().reset_index()
#print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(counts, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score_y'], axis = 1)
print(result)
# Out:
#          Date de début          Date de fin Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO SUD  FR93ZAG01
# 1  2023/01/02 00:00:00  2023/01/02 23:59:59  ATMO SUD  FR93ZAG01
# 2  2023/01/03 00:00:00  2023/01/03 23:59:59  ATMO SUD  FR93ZAG01
# 3  2023/01/04 00:00:00  2023/01/04 23:59:59  ATMO SUD  FR93ZAG01
# 4  2023/01/05 00:00:00  2023/01/05 23:59:59  ATMO SUD  FR93ZAG01
#
#                  Zas code site              nom site type d'implantation  \
# 0  ZAG MARSEILLE-AIX   FR03029  AIX CENTRE ECOLE ART             Urbaine
# 1  ZAG MARSEILLE-AIX   FR03029  AIX CENTRE ECOLE ART             Urbaine
# 2  ZAG MARSEILLE-AIX   FR03029  AIX CENTRE ECOLE ART             Urbaine
# 3  ZAG MARSEILLE-AIX   FR03029  AIX CENTRE ECOLE ART             Urbaine
# 4  ZAG MARSEILLE-AIX   FR03029  AIX CENTRE ECOLE ART             Urbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0     PM10             Fond  ...    21.145833           µg-m3          100.0
# 1     PM10             Fond  ...    20.570833           µg-m3          100.0
# 2     PM10             Fond  ...    26.291667           µg-m3          100.0
# 3     PM10             Fond  ...    28.325000           µg-m3          100.0
# 4     PM10             Fond  ...    23.145833           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO Score
# 0  43.530285   5.440912        2.0
# 1  43.530285   5.440912        2.0
# 2  43.530285   5.440912        2.0
# 3  43.530285   5.440912        2.0
# 4  43.530285   5.440912        2.0
#
# [5 rows x 24 columns]
#                  nom site  ATMO Score_x  counts Organisme   code zas  \
# 0    AIX CENTRE ECOLE ART           2.0     174  ATMO SUD  FR93ZAG01
# 1    AIX CENTRE ECOLE ART           1.0     167  ATMO SUD  FR93ZAG01
# 2    AIX CENTRE ECOLE ART           4.0      13  ATMO SUD  FR93ZAG01
# 3    AIX CENTRE ECOLE ART           3.0      11  ATMO SUD  FR93ZAG01
# 4            AIX PLATANES           2.0     220  ATMO SUD  FR93ZAG01
# ..                    ...           ...     ...       ...        ...
# 196           TOULON FOCH           4.0       8  ATMO SUD  FR93ZAG03
# 197       VALLEE HUVEAUNE           2.0     205  ATMO SUD  FR93ZAG01
# 198       VALLEE HUVEAUNE           3.0     101  ATMO SUD  FR93ZAG01
# 199       VALLEE HUVEAUNE           4.0      33  ATMO SUD  FR93ZAG01
# 200       VALLEE HUVEAUNE           1.0      26  ATMO SUD  FR93ZAG01
#
#                    Zas code site type d'implantation Polluant  \
# 0    ZAG MARSEILLE-AIX   FR03029             Urbaine     PM10
# 1    ZAG MARSEILLE-AIX   FR03029             Urbaine     PM10
# 2    ZAG MARSEILLE-AIX   FR03029             Urbaine     PM10
# 3    ZAG MARSEILLE-AIX   FR03029             Urbaine     PM10
# 4    ZAG MARSEILLE-AIX   FR03048         Périurbaine       O3
# ..                 ...       ...                 ...      ...
# 196         ZAG TOULON   FR03068             Urbaine     PM10
# 197  ZAG MARSEILLE-AIX   FR03037         Périurbaine       O3
# 198  ZAG MARSEILLE-AIX   FR03037         Périurbaine       O3
# 199  ZAG MARSEILLE-AIX   FR03037         Périurbaine       O3
# 200  ZAG MARSEILLE-AIX   FR03037         Périurbaine       O3
#
#     type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0               Fond  ...   21.0    21.145833           µg-m3           100.0
# 1               Fond  ...   21.0    21.145833           µg-m3           100.0
# 2               Fond  ...   21.0    21.145833           µg-m3           100.0
# 3               Fond  ...   21.0    21.145833           µg-m3           100.0
# 4               Fond  ...   68.9    68.925000           µg-m3           100.0
# ..               ...  ...    ...          ...             ...             ...
# 196           Trafic  ...    0.0     0.000000           µg-m3             0.0
# 197             Fond  ...   72.2    72.225000           µg-m3           100.0
# 198             Fond  ...   72.2    72.225000           µg-m3           100.0
# 199             Fond  ...   72.2    72.225000           µg-m3           100.0
# 200             Fond  ...   72.2    72.225000           µg-m3           100.0
#
#      couverture temporelle couverture de données  code qualité  validité  \
# 0                      100                 100.0             A         1
# 1                      100                 100.0             A         1
# 2                      100                 100.0             A         1
# 3                      100                 100.0             A         1
# 4                      100                 100.0             R         1
# ..                     ...                   ...           ...       ...
# 196                    100                   0.0             N        -1
# 197                    100                 100.0             R         1
# 198                    100                 100.0             R         1
# 199                    100                 100.0             R         1
# 200                    100                 100.0             R         1
#
#       Latitude Longitude
# 0    43.530285  5.440912
# 1    43.530285  5.440912
# 2    43.530285  5.440912
# 3    43.530285  5.440912
# 4    43.555777  5.461232
# ..         ...       ...
# 196  43.126821  5.921605
# 197  43.283341  5.511384
# 198  43.283341  5.511384
# 199  43.283341  5.511384
# 200  43.283341  5.511384
#
# [201 rows x 23 columns]

# %%
# Group the DataFrame by 'nom' and calculate the total counts for each 'nom'
total_counts_by_nom = result.groupby('nom site')['counts'].sum()

# Filter the DataFrame to include only rows where the score is equal to or greater than 3
filtered_result = result[result['ATMO Score_x'] >= 3]

# Group the filtered DataFrame by 'nom' and calculate the counts equal to or greater than 3 for each 'nom'
counts_greater_than_3_by_nom = filtered_result.groupby('nom site')['counts'].sum()

# Calculate the ratio of counts greater than or equal to 3 over total counts for each 'nom'
ratio_counts_greater_than_3 = (counts_greater_than_3_by_nom / total_counts_by_nom).fillna(0)

# Display the resulting Series
print(ratio_counts_greater_than_3)

# Merge the site-specific information with the counts DataFrame
ratio_counts_greater_than_3_df = pd.merge(ratio_counts_greater_than_3, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score'], axis = 1)
ratio_counts_greater_than_3_df = ratio_counts_greater_than_3_df.rename(columns={'counts': 'indicator'})
print(ratio_counts_greater_than_3_df)
# Out:
# nom site
# AIX CENTRE ECOLE ART        0.065753
# AIX PLATANES                0.350685
# AIX ROY RENE                0.030137
# ANTIBES JEAN MOULIN         0.456825
# APT                         0.292818
# AUBAGNE LES PASSONS         0.412088
# AVIGNON   MAIRIE            0.430137
# Arles                       0.348066
# Avignon Rocade De Gaulle    0.228022
# Avignon Semard              0.108108
# BRIGNOLES                   0.430137
# Berre l'Etang               0.380822
# CANNES BROUSSAILLES         0.429775
# CARPENTRAS                  0.349862
# CIANS                       0.389503
# CONTES 2                    0.027397
# Chateauneuf La Mede         0.028090
# Cheiron                     0.468493
# ESTEREL                     0.399449
# Fos Les Carabins            0.054795
# Fos sur Mer                 0.005666
# GAP COMMANDERIE             0.239011
# GAP JEAN JAURES             0.065753
# GARDANNE                    0.147945
# HYERES                      0.000000
# Istres                      0.316804
# LA SEYNE GENOUD             0.000000
# LA VALETTE/LA GARDE         0.320548
# LE PONTET                   0.013736
# Le Casset2                  0.544379
# MANOSQUE                    0.408219
# MARSEILLE 5 AVENUES         0.318681
# MARSEILLE RABATAU           0.421918
# MARSEILLE ST LOUIS          0.224189
# Marignane                   0.156164
# Martigues La Gatasse        0.002755
# Martigues Laurons           0.000000
# Martigues Lavera            0.022346
# Martigues P. Central        0.354396
# NICE ARSON                  0.406077
# NICE OUEST BOTANIQUE        0.459155
# NICE PROMENADE              0.071625
# Obs Haute-Provence          0.386740
# PEILLON                     0.087671
# PLAN AUPS/STE  BAUME        0.501377
# Port Saint Louis            0.016529
# Port de Bouc Leque          0.078283
# Rognac les Brets            0.098630
# SALON                       0.394521
# Sausset les Pins            0.345205
# TOULON CLARET               0.405479
# TOULON FOCH                 0.126027
# VALLEE HUVEAUNE             0.367123
# Name: counts, dtype: float64
#                     nom site  indicator                  Organisme   code zas  \
# 0       AIX CENTRE ECOLE ART   0.065753                   ATMO SUD  FR93ZAG01
# 1               AIX PLATANES   0.350685                   ATMO SUD  FR93ZAG01
# 2               AIX ROY RENE   0.030137                   ATMO SUD  FR93ZAG01
# 3        ANTIBES JEAN MOULIN   0.456825                   ATMO SUD  FR93ZAG02
# 4                        APT   0.292818                   ATMO SUD  FR93ZRE02
# 5        AUBAGNE LES PASSONS   0.412088                   ATMO SUD  FR93ZAG01
# 6           AVIGNON   MAIRIE   0.430137                   ATMO SUD  FR93ZAG04
# 7                      Arles   0.348066                   ATMO SUD  FR93ZRE02
# 8   Avignon Rocade De Gaulle   0.228022                   ATMO SUD  FR93ZAG04
# 9             Avignon Semard   0.108108                   ATMO SUD  FR93ZAG04
# 10                 BRIGNOLES   0.430137                   ATMO SUD  FR93ZRE02
# 11             Berre l'Etang   0.380822                   ATMO SUD  FR93ZAG01
# 12       CANNES BROUSSAILLES   0.429775                   ATMO SUD  FR93ZAG02
# 13                CARPENTRAS   0.349862                   ATMO SUD  FR93ZAG04
# 14                     CIANS   0.389503                   ATMO SUD  FR93ZRE02
# 15                  CONTES 2   0.027397                   ATMO SUD  FR93ZAG02
# 16       Chateauneuf La Mede   0.028090                   ATMO SUD  FR93ZAG01
# 17                   Cheiron   0.468493                   ATMO SUD  FR93ZRE02
# 18                   ESTEREL   0.399449                   ATMO SUD  FR93ZRE02
# 19          Fos Les Carabins   0.054795                   ATMO SUD  FR93ZAG01
# 20               Fos sur Mer   0.005666                   ATMO SUD  FR93ZAG01
# 21           GAP COMMANDERIE   0.239011                   ATMO SUD  FR93ZRE02
# 22           GAP JEAN JAURES   0.065753                   ATMO SUD  FR93ZRE02
# 23                  GARDANNE   0.147945                   ATMO SUD  FR93ZAG01
# 24                    HYERES   0.000000                   ATMO SUD  FR93ZAG03
# 25                    Istres   0.316804                   ATMO SUD  FR93ZAG01
# 26           LA SEYNE GENOUD   0.000000                   ATMO SUD  FR93ZAG03
# 27       LA VALETTE/LA GARDE   0.320548                   ATMO SUD  FR93ZAG03
# 28                 LE PONTET   0.013736                   ATMO SUD  FR93ZAG04
# 29                Le Casset2   0.544379  ATMO AUVERGNE-RHÔNE-ALPES  FR93ZRE02
# 30                  MANOSQUE   0.408219                   ATMO SUD  FR93ZRE02
# 31       MARSEILLE 5 AVENUES   0.318681                   ATMO SUD  FR93ZAG01
# 32         MARSEILLE RABATAU   0.421918                   ATMO SUD  FR93ZAG01
# 33        MARSEILLE ST LOUIS   0.224189                   ATMO SUD  FR93ZAG01
# 34                 Marignane   0.156164                   ATMO SUD  FR93ZAG01
# 35      Martigues La Gatasse   0.002755                   ATMO SUD  FR93ZAG01
# 36         Martigues Laurons   0.000000                   ATMO SUD  FR93ZAG01
# 37          Martigues Lavera   0.022346                   ATMO SUD  FR93ZAG01
# 38      Martigues P. Central   0.354396                   ATMO SUD  FR93ZAG01
# 39                NICE ARSON   0.406077                   ATMO SUD  FR93ZAG02
# 40      NICE OUEST BOTANIQUE   0.459155                   ATMO SUD  FR93ZAG02
# 41            NICE PROMENADE   0.071625                   ATMO SUD  FR93ZAG02
# 42        Obs Haute-Provence   0.386740                   ATMO SUD  FR93ZRE02
# 43                   PEILLON   0.087671                   ATMO SUD  FR93ZAG02
# 44      PLAN AUPS/STE  BAUME   0.501377                   ATMO SUD  FR93ZRE02
# 45          Port Saint Louis   0.016529                   ATMO SUD  FR93ZAG01
# 46        Port de Bouc Leque   0.078283                   ATMO SUD  FR93ZAG01
# 47          Rognac les Brets   0.098630                   ATMO SUD  FR93ZAG01
# 48                     SALON   0.394521                   ATMO SUD  FR93ZAG01
# 49          Sausset les Pins   0.345205                   ATMO SUD  FR93ZAG01
# 50             TOULON CLARET   0.405479                   ATMO SUD  FR93ZAG03
# 51               TOULON FOCH   0.126027                   ATMO SUD  FR93ZAG03
# 52           VALLEE HUVEAUNE   0.367123                   ATMO SUD  FR93ZAG01
#
#                               Zas code site     type d'implantation Polluant  \
# 0               ZAG MARSEILLE-AIX   FR03029                 Urbaine     PM10
# 1               ZAG MARSEILLE-AIX   FR03048             Périurbaine       O3
# 2               ZAG MARSEILLE-AIX   FR03021                 Urbaine     PM10
# 3                        ZAG NICE   FR24007             Périurbaine      NO2
# 4   ZR PROVENCE-ALPES-COTE-D-AZUR   FR03086             Périurbaine       O3
# 5               ZAG MARSEILLE-AIX   FR03032                 Urbaine       O3
# 6                     ZAG AVIGNON   FR03080                 Urbaine     PM10
# 7   ZR PROVENCE-ALPES-COTE-D-AZUR   FR02022                 Urbaine     PM10
# 8                     ZAG AVIGNON   FR03091                 Urbaine    PM2.5
# 9                     ZAG AVIGNON   FR03087                 Urbaine     PM10
# 10  ZR PROVENCE-ALPES-COTE-D-AZUR   FR03067             Périurbaine     PM10
# 11              ZAG MARSEILLE-AIX   FR02001             Périurbaine       O3
# 12                       ZAG NICE   FR24009                 Urbaine     PM10
# 13                    ZAG AVIGNON   FR03088             Périurbaine       O3
# 14  ZR PROVENCE-ALPES-COTE-D-AZUR   FR24014        Rurale régionale       O3
# 15                       ZAG NICE   FR24023             Périurbaine     PM10
# 16              ZAG MARSEILLE-AIX   FR02029             Périurbaine     PM10
# 17  ZR PROVENCE-ALPES-COTE-D-AZUR   FR24040        Rurale régionale       O3
# 18  ZR PROVENCE-ALPES-COTE-D-AZUR   FR03070             Périurbaine    PM2.5
# 19              ZAG MARSEILLE-AIX   FR02013             Périurbaine    PM2.5
# 20              ZAG MARSEILLE-AIX   FR02011             Périurbaine      SO2
# 21  ZR PROVENCE-ALPES-COTE-D-AZUR   FR24033                 Urbaine     PM10
# 22  ZR PROVENCE-ALPES-COTE-D-AZUR   FR24038                 Urbaine     PM10
# 23              ZAG MARSEILLE-AIX   FR03030             Périurbaine     PM10
# 24                     ZAG TOULON   FR03069                 Urbaine     PM10
# 25              ZAG MARSEILLE-AIX   FR02012                 Urbaine       O3
# 26                     ZAG TOULON   FR03060                 Urbaine      NO2
# 27                     ZAG TOULON   FR03064             Périurbaine       O3
# 28                    ZAG AVIGNON   FR03084             Périurbaine    PM2.5
# 29  ZR PROVENCE-ALPES-COTE-D-AZUR   FR15031        Rurale nationale       O3
# 30  ZR PROVENCE-ALPES-COTE-D-AZUR   FR24018                 Urbaine       O3
# 31              ZAG MARSEILLE-AIX   FR03043                 Urbaine       O3
# 32              ZAG MARSEILLE-AIX   FR03006                 Urbaine     PM10
# 33              ZAG MARSEILLE-AIX   FR03014                 Urbaine     PM10
# 34              ZAG MARSEILLE-AIX   FR02043                 Urbaine     PM10
# 35              ZAG MARSEILLE-AIX   FR02007             Périurbaine      SO2
# 36              ZAG MARSEILLE-AIX   FR02006             Périurbaine      SO2
# 37              ZAG MARSEILLE-AIX   FR02028             Périurbaine      SO2
# 38              ZAG MARSEILLE-AIX   FR02004                 Urbaine       O3
# 39                       ZAG NICE   FR24036                 Urbaine     PM10
# 40                       ZAG NICE   FR24011             Périurbaine       O3
# 41                       ZAG NICE   FR24035                 Urbaine     PM10
# 42  ZR PROVENCE-ALPES-COTE-D-AZUR   FR24039  Rurale près des villes       O3
# 43                       ZAG NICE   FR24021             Périurbaine     PM10
# 44  ZR PROVENCE-ALPES-COTE-D-AZUR   FR03027  Rurale près des villes       O3
# 45              ZAG MARSEILLE-AIX   FR02009             Périurbaine     PM10
# 46              ZAG MARSEILLE-AIX   FR02008                 Urbaine     PM10
# 47              ZAG MARSEILLE-AIX   FR02020             Périurbaine    PM2.5
# 48              ZAG MARSEILLE-AIX   FR02041                 Urbaine    PM2.5
# 49              ZAG MARSEILLE-AIX   FR02021             Périurbaine       O3
# 50                     ZAG TOULON   FR03071                 Urbaine     PM10
# 51                     ZAG TOULON   FR03068                 Urbaine     PM10
# 52              ZAG MARSEILLE-AIX   FR03037             Périurbaine       O3
#
#    type d'influence Réglementaire  ... valeur valeur brute  unité de mesure  \
# 0              Fond           Oui  ...   21.0    21.145833            µg-m3
# 1              Fond           Oui  ...   68.9    68.925000            µg-m3
# 2            Trafic           Oui  ...   21.0    20.866667            µg-m3
# 3              Fond           Oui  ...   48.8    48.775000            µg-m3
# 4              Fond           Oui  ...   64.5    64.450000            µg-m3
# 5              Fond           Oui  ...   72.2    72.175000            µg-m3
# 6              Fond           Oui  ...   26.0    26.162500            µg-m3
# 7              Fond           Oui  ...   22.0    22.187500            µg-m3
# 8            Trafic           Oui  ...   30.0    30.395833            µg-m3
# 9            Trafic           Oui  ...   41.0    40.895833            µg-m3
# 10             Fond           Oui  ...   26.0    26.229167            µg-m3
# 11             Fond           Oui  ...   70.7    70.700000            µg-m3
# 12             Fond           Oui  ...   24.0    24.387500            µg-m3
# 13             Fond           Oui  ...   66.8    66.766670            µg-m3
# 14             Fond           Oui  ...   51.7    51.700000            µg-m3
# 15     Industrielle           Oui  ...   32.0    31.829167            µg-m3
# 16     Industrielle           Oui  ...   26.0    25.604167            µg-m3
# 17             Fond           Oui  ...   69.2    69.150000            µg-m3
# 18             Fond           Oui  ...   24.0    24.470833            µg-m3
# 19     Industrielle           Oui  ...   10.0    10.354167            µg-m3
# 20     Industrielle           Oui  ...    2.9     2.900000            µg-m3
# 21             Fond           Oui  ...   25.0    24.512500            µg-m3
# 22           Trafic           Oui  ...   29.0    28.841667            µg-m3
# 23     Industrielle           Oui  ...   17.0    17.350000            µg-m3
# 24             Fond           Oui  ...   23.0    23.100000            µg-m3
# 25             Fond           Oui  ...   65.9    65.900000            µg-m3
# 26             Fond           Oui  ...   13.5    13.475000            µg-m3
# 27             Fond           Oui  ...   60.0    59.975000            µg-m3
# 28             Fond           Oui  ...   23.0    23.100000            µg-m3
# 29             Fond           Oui  ...   68.4    68.350000            µg-m3
# 30             Fond           Oui  ...   73.3    73.300000            µg-m3
# 31             Fond           Oui  ...   64.6    64.600000            µg-m3
# 32           Trafic           Oui  ...   31.0    31.404167            µg-m3
# 33             Fond           Oui  ...   21.0    21.462500            µg-m3
# 34             Fond           Oui  ...   21.0    21.441667            µg-m3
# 35     Industrielle           Oui  ...    1.3     1.275000            µg-m3
# 36     Industrielle           Oui  ...    1.9     1.900000            µg-m3
# 37     Industrielle           Oui  ...    2.6     2.575000            µg-m3
# 38             Fond           Oui  ...   72.8    72.825000            µg-m3
# 39             Fond           Oui  ...   27.0    26.533333            µg-m3
# 40             Fond           Oui  ...   51.1    51.125000            µg-m3
# 41           Trafic           Oui  ...   30.0    30.258333            µg-m3
# 42             Fond           Oui  ...   66.4    66.425000            µg-m3
# 43     Industrielle           Oui  ...   27.0    26.737500            µg-m3
# 44             Fond           Oui  ...   70.4    70.350000            µg-m3
# 45     Industrielle           Oui  ...   31.0    30.841667            µg-m3
# 46     Industrielle           Oui  ...   28.0    27.966667            µg-m3
# 47     Industrielle           Oui  ...   10.0    10.029167            µg-m3
# 48             Fond           Oui  ...   11.0    10.850000            µg-m3
# 49             Fond           Oui  ...   73.4    73.350000            µg-m3
# 50             Fond           Oui  ...   26.0    25.604167            µg-m3
# 51           Trafic           Oui  ...    0.0     0.000000            µg-m3
# 52             Fond           Oui  ...   72.2    72.225000            µg-m3
#
#     taux de saisie couverture temporelle  couverture de données  code qualité  \
# 0            100.0                   100                  100.0             A
# 1            100.0                   100                  100.0             R
# 2            100.0                   100                  100.0             A
# 3            100.0                   100                  100.0             R
# 4            100.0                   100                  100.0             R
# 5            100.0                   100                  100.0             R
# 6            100.0                   100                  100.0             A
# 7            100.0                   100                  100.0             A
# 8            100.0                   100                  100.0             A
# 9            100.0                   100                  100.0             A
# 10           100.0                   100                  100.0             A
# 11           100.0                   100                  100.0             R
# 12           100.0                   100                  100.0             A
# 13           100.0                   100                  100.0             R
# 14           100.0                   100                  100.0             R
# 15           100.0                   100                  100.0             A
# 16           100.0                   100                  100.0             A
# 17           100.0                   100                  100.0             R
# 18           100.0                   100                  100.0             A
# 19           100.0                   100                  100.0             A
# 20           100.0                   100                  100.0             R
# 21           100.0                   100                  100.0             A
# 22           100.0                   100                  100.0             A
# 23           100.0                   100                  100.0             A
# 24           100.0                   100                  100.0             A
# 25           100.0                   100                  100.0             R
# 26           100.0                   100                  100.0             R
# 27           100.0                   100                  100.0             R
# 28           100.0                   100                  100.0             A
# 29           100.0                   100                  100.0             A
# 30           100.0                   100                  100.0             R
# 31           100.0                   100                  100.0             R
# 32           100.0                   100                  100.0             A
# 33           100.0                   100                  100.0             A
# 34           100.0                   100                  100.0             A
# 35           100.0                   100                  100.0             R
# 36           100.0                   100                  100.0             R
# 37           100.0                   100                  100.0             R
# 38           100.0                   100                  100.0             R
# 39           100.0                   100                  100.0             A
# 40           100.0                   100                  100.0             R
# 41           100.0                   100                  100.0             A
# 42           100.0                   100                  100.0             R
# 43           100.0                   100                  100.0             A
# 44           100.0                   100                  100.0             R
# 45           100.0                   100                  100.0             A
# 46           100.0                   100                  100.0             A
# 47           100.0                   100                  100.0             A
# 48           100.0                   100                  100.0             A
# 49           100.0                   100                  100.0             R
# 50           100.0                   100                  100.0             A
# 51             0.0                   100                    0.0             N
# 52           100.0                   100                  100.0             R
#
#     validité   Latitude  Longitude
# 0          1  43.530285   5.440912
# 1          1  43.555777   5.461232
# 2          1  43.524075   5.448164
# 3          1  43.598803   7.093153
# 4          1  43.880120   5.362038
# 5          1  43.293138   5.574184
# 6          1  43.949673   4.804341
# 7          1  43.675114   4.629210
# 8          1  43.931400   4.826875
# 9          1  43.937060   4.824909
# 10         1  43.398731   6.075611
# 11         1  43.486234   5.171939
# 12         1  43.558389   7.005919
# 13         1  44.060347   5.067413
# 14         1  44.094688   6.988978
# 15         1  43.788748   7.332382
# 16         1  43.399546   5.113214
# 17         1  43.791911   7.048276
# 18         1  43.437874   6.768390
# 19         1  43.458927   4.934572
# 20         1  43.437858   4.945116
# 21         1  44.555193   6.073015
# 22         1  44.548647   6.067237
# 23         1  43.453584   5.466672
# 24         1  43.119737   6.131319
# 25         1  43.506149   4.982898
# 26         1  43.101565   5.875404
# 27         1  43.135902   6.011513
# 28         1  43.960144   4.856731
# 29         1  44.997000   6.469400
# 30         1  43.835784   5.786131
# 31         1  43.305287   5.394716
# 32         1  43.276451   5.397360
# 33         1  43.348048   5.360119
# 34         1  43.416531   5.222281
# 35         1  43.360692   5.058139
# 36         1  43.358982   5.023388
# 37         1  43.386564   5.026868
# 38         1  43.416661   5.042731
# 39         1  43.702075   7.286256
# 40         1  43.685188   7.211174
# 41         1  43.689291   7.242074
# 42         1  43.933476   5.711809
# 43         1  43.786583   7.373283
# 44         1  43.335201   5.727365
# 45         1  43.393780   4.801024
# 46         1  43.401952   4.981919
# 47         1  43.510802   5.220046
# 48         1  43.639002   5.101097
# 49         1  43.331245   5.117696
# 50         1  43.131113   5.924184
# 51        -1  43.126821   5.921605
# 52         1  43.283341   5.511384
#
# [53 rows x 22 columns]

# %%
# Downloading the final indicator of ATMO SUD to csv
ratio_counts_greater_than_3_df.to_csv('indicator_ATMO_SUD.csv', index=False, encoding = 'latin1')

# %%
# -----------------------------------------------------------------------------------------------------------------------------------------------------
#                                                               Sanity Checks
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %%
print(df_PM25['valeur'].head())
# Out:
# 0     9.4
# 1    10.0
# 2    10.0
# 3    12.0
# 4    11.0
# Name: valeur, dtype: float64

# %%
df_PM25['ATMO sub-score'].describe()
# Out:
# count    9004.000000
# mean        1.457463
# std         0.731293
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: ATMO sub-score, dtype: float64

# %%
print(df_PM25['valeur'].head())
# Out:
# 0     9.4
# 1    10.0
# 2    10.0
# 3    12.0
# 4    11.0
# Name: valeur, dtype: float64
