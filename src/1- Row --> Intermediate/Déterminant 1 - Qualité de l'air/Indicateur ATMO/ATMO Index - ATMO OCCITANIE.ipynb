# %%
# Code for extracting the daily ATMO score for each station in ATMO OCCITANIE (Région: OCCITANIE)

# %%
# Installing required packages
import pandas as pd

import os

# Base directory path
base_path = ".\data\1- Raw Data\Déterminant 1 - Qualité de l'air\"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22100\1556868776.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# PM10 ATMO OCCITANIE

# File path to the data
PM10_ATMO_OCCITANIE_file_path = os.path.join(base_path, "PM10 Moyenne Journalière\Export Moy. journalière - PM10 - ATMO OCCITANIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM10 = pd.read_csv(PM10_ATMO_OCCITANIE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM10.head())

# Sample ATMO subscore dictionary for PM10 (Moyenne journalière)
ATMO_subscore_PM10 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 20.0), (20.0, 40.0), (40.0, 50.0), (50.0, 100.0), (100.0, 150.0), (150.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM10 = pd.DataFrame(ATMO_subscore_PM10)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM10['Range'] = ATMO_subscore_df_PM10['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM10 measurement
def assign_subscore_PM10(valeur):
    for index, row in ATMO_subscore_df_PM10.iterrows():  
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM10['ATMO sub-score'] = df_PM10['valeur'].apply(assign_subscore_PM10)  

# Display the updated DataFrame
print(df_PM10.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR02
#
#                Zas code site                   nom site type d'implantation  \
# 0  ZAG MONTPELLIER   FR08016  Montpellier Prés d'Arènes             Urbaine
# 1     ZR OCCITANIE   FR08020                 Lunel Viel         Périurbaine
# 2  ZAG MONTPELLIER   FR08030                 Pompignane             Urbaine
# 3        ZAR NIMES   FR08614                Nimes Gauzy             Urbaine
# 4        ZAR NIMES   FR08616               Nimes Planas             Urbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0     PM10             Fond  ...   26.0    25.766667           µg-m3
# 1     PM10     Industrielle  ...   26.0    26.495833           µg-m3
# 2     PM10           Trafic  ...   35.0    34.620833           µg/m3
# 3     PM10             Fond  ...   23.0    23.387500           µg-m3
# 4     PM10           Trafic  ...   31.0    30.504167           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             A
# 1           100.0                    100                 100.0             A
# 2           100.0                    100                 100.0             A
# 3           100.0                    100                 100.0             A
# 4           100.0                    100                 100.0             A
#
#    validité  Latitude Longitude
# 0         1   43.5915   3.88681
# 1         1   43.6758   4.08838
# 2         1   43.6096   3.89878
# 3         1   43.8344   4.37440
# 4         1   43.8299   4.36199
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR02
#
#                Zas code site                   nom site type d'implantation  \
# 0  ZAG MONTPELLIER   FR08016  Montpellier Prés d'Arènes             Urbaine
# 1     ZR OCCITANIE   FR08020                 Lunel Viel         Périurbaine
# 2  ZAG MONTPELLIER   FR08030                 Pompignane             Urbaine
# 3        ZAR NIMES   FR08614                Nimes Gauzy             Urbaine
# 4        ZAR NIMES   FR08616               Nimes Planas             Urbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0     PM10             Fond  ...    25.766667           µg-m3          100.0
# 1     PM10     Industrielle  ...    26.495833           µg-m3          100.0
# 2     PM10           Trafic  ...    34.620833           µg/m3          100.0
# 3     PM10             Fond  ...    23.387500           µg-m3          100.0
# 4     PM10           Trafic  ...    30.504167           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#    Latitude  Longitude ATMO sub-score
# 0   43.5915    3.88681              2
# 1   43.6758    4.08838              2
# 2   43.6096    3.89878              2
# 3   43.8344    4.37440              2
# 4   43.8299    4.36199              2
#
# [5 rows x 24 columns]

# %%
# PM2.5 ATMO OCCITANIE

# File path to the data
PM25_ATMO_OCCITANIE_file_path = os.path.join(base_path, "PM2.5 Moyenne Journalière\Export Moy. journalière - PM2.5 - ATMO OCCITANIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM25 = pd.read_csv(PM25_ATMO_OCCITANIE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM25.head())

# Sample ATMO subscore dictionary for PM2.5 (Moyenne journalière)
ATMO_subscore_PM25 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 10.0), (10.0, 20.0), (20.0, 25.0), (25.0, 50.0), (50.0, 75.0), (75.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM25 = pd.DataFrame(ATMO_subscore_PM25)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM25['Range'] = ATMO_subscore_df_PM25['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM2.5 measurement
def assign_subscore_PM25(valeur):
    for index, row in ATMO_subscore_df_PM25.iterrows(): 
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM25['ATMO sub-score'] = df_PM25['valeur'].apply(assign_subscore_PM25)  

# Display the updated DataFrame
print(df_PM25.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR01
#
#                Zas code site                   nom site type d'implantation  \
# 0  ZAG MONTPELLIER   FR08016  Montpellier Prés d'Arènes             Urbaine
# 1     ZR OCCITANIE   FR08020                 Lunel Viel         Périurbaine
# 2  ZAG MONTPELLIER   FR08030                 Pompignane             Urbaine
# 3        ZAR NIMES   FR08614                Nimes Gauzy             Urbaine
# 4    ZAR PERPIGNAN   FR08714       Perpignan Les Carmes             Urbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0    PM2.5             Fond  ...   14.0    13.704167           µg-m3
# 1    PM2.5     Industrielle  ...   13.0    13.154167           µg-m3
# 2    PM2.5           Trafic  ...   12.0    11.900000           µg/m3
# 3    PM2.5             Fond  ...   12.0    11.845833           µg/m3
# 4    PM2.5             Fond  ...   21.0    21.270833           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             A
# 1           100.0                    100                 100.0             A
# 2           100.0                    100                 100.0             A
# 3           100.0                    100                 100.0             A
# 4           100.0                    100                 100.0             A
#
#    validité  Latitude Longitude
# 0         1   43.5915   3.88681
# 1         1   43.6758   4.08838
# 2         1   43.6096   3.89878
# 3         1   43.8344   4.37440
# 4         1   42.6955   2.90053
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR01
#
#                Zas code site                   nom site type d'implantation  \
# 0  ZAG MONTPELLIER   FR08016  Montpellier Prés d'Arènes             Urbaine
# 1     ZR OCCITANIE   FR08020                 Lunel Viel         Périurbaine
# 2  ZAG MONTPELLIER   FR08030                 Pompignane             Urbaine
# 3        ZAR NIMES   FR08614                Nimes Gauzy             Urbaine
# 4    ZAR PERPIGNAN   FR08714       Perpignan Les Carmes             Urbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0    PM2.5             Fond  ...    13.704167           µg-m3          100.0
# 1    PM2.5     Industrielle  ...    13.154167           µg-m3          100.0
# 2    PM2.5           Trafic  ...    11.900000           µg/m3          100.0
# 3    PM2.5             Fond  ...    11.845833           µg/m3          100.0
# 4    PM2.5             Fond  ...    21.270833           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#    Latitude  Longitude ATMO sub-score
# 0   43.5915    3.88681            2.0
# 1   43.6758    4.08838            2.0
# 2   43.6096    3.89878            2.0
# 3   43.8344    4.37440            2.0
# 4   42.6955    2.90053            3.0
#
# [5 rows x 24 columns]

# %%
# NO2 ATMO OCCITANIE

# File path to the data
NO2_ATMO_OCCITANIE_file_path = os.path.join(base_path, "NO2 Max Horaire Journalier\Export Max. journalier moy. hor. - NO2 - ATMO OCCITANIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_NO2 = pd.read_csv(NO2_ATMO_OCCITANIE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_NO2.head())

# Sample ATMO subscore dictionary for NO2 (Max horaire journalier)
ATMO_subscore_NO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 40.0), (40.0, 90.0), (90.0, 120.0), (120.0, 230.0), (230.0, 340.0), (340.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_NO2 = pd.DataFrame(ATMO_subscore_NO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_NO2['Range'] = ATMO_subscore_df_NO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of NO2 measurement
def assign_subscore_NO2(valeur):
    for index, row in ATMO_subscore_df_NO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_NO2['ATMO sub-score'] = df_NO2['valeur'].apply(assign_subscore_NO2)

# Display the updated DataFrame
print(df_NO2.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
#
#                Zas code site                   nom site type d'implantation  \
# 0  ZAG MONTPELLIER   FR08003        Montpellier Chaptal             Urbaine
# 1  ZAG MONTPELLIER   FR08004       Montpellier St Denis             Urbaine
# 2  ZAG MONTPELLIER   FR08016  Montpellier Prés d'Arènes             Urbaine
# 3     ZR OCCITANIE   FR08020                 Lunel Viel         Périurbaine
# 4     ZR OCCITANIE   FR08022         Agathois-piscénois         Périurbaine
#
#   Polluant type d'influence  ... valeur valeur brute unité de mesure  \
# 0      NO2             Fond  ...   11.9       11.875           µg-m3
# 1      NO2           Trafic  ...   15.4       15.425           µg-m3
# 2      NO2             Fond  ...   10.4       10.350           µg-m3
# 3      NO2     Industrielle  ...    5.3        5.275           µg-m3
# 4      NO2             Fond  ...    5.7        5.725           µg-m3
#
#    taux de saisie  couverture temporelle couverture de données  code qualité  \
# 0           100.0                    100                 100.0             R
# 1           100.0                    100                 100.0             R
# 2           100.0                    100                 100.0             R
# 3           100.0                    100                 100.0             A
# 4           100.0                    100                 100.0             R
#
#    validité   Latitude Longitude
# 0         1  43.611302   3.86626
# 1         1  43.605100   3.87464
# 2         1  43.591500   3.88681
# 3         1  43.675800   4.08838
# 4         1  43.287500   3.50484
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
#
#                Zas code site                   nom site type d'implantation  \
# 0  ZAG MONTPELLIER   FR08003        Montpellier Chaptal             Urbaine
# 1  ZAG MONTPELLIER   FR08004       Montpellier St Denis             Urbaine
# 2  ZAG MONTPELLIER   FR08016  Montpellier Prés d'Arènes             Urbaine
# 3     ZR OCCITANIE   FR08020                 Lunel Viel         Périurbaine
# 4     ZR OCCITANIE   FR08022         Agathois-piscénois         Périurbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0      NO2             Fond  ...       11.875           µg-m3          100.0
# 1      NO2           Trafic  ...       15.425           µg-m3          100.0
# 2      NO2             Fond  ...       10.350           µg-m3          100.0
# 3      NO2     Industrielle  ...        5.275           µg-m3          100.0
# 4      NO2             Fond  ...        5.725           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            R         1
# 1                    100                  100.0            R         1
# 2                    100                  100.0            R         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            R         1
#
#     Latitude  Longitude ATMO sub-score
# 0  43.611302    3.86626              1
# 1  43.605100    3.87464              1
# 2  43.591500    3.88681              1
# 3  43.675800    4.08838              1
# 4  43.287500    3.50484              1
#
# [5 rows x 24 columns]

# %%
# O3 ATMO OCCITANIE

# File path to the data
O3_ATMO_OCCITANIE_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - ATMO OCCITANIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_ATMO_OCCITANIE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Sample ATMO subscore dictionary for O3 (Max horaire journalier)
ATMO_subscore_O3 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 50.0), (50.0, 100.0), (100.0, 130.0), (130.0, 240.0), (240.0, 380.0), (380.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_O3 = pd.DataFrame(ATMO_subscore_O3)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_O3['Range'] = ATMO_subscore_df_O3['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of O3 measurement
def assign_subscore_O3(valeur):
    for index, row in ATMO_subscore_df_O3.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_O3['ATMO sub-score'] = df_O3['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
#
#                Zas code site                              nom site  \
# 0  ZAG MONTPELLIER   FR08016             Montpellier Prés d'Arènes
# 1  ZAG MONTPELLIER   FR08017  Montpellier Périurbaine Sud (Lattes)
# 2  ZAG MONTPELLIER   FR08018                   Montpellier St Gely
# 3     ZR OCCITANIE   FR08022                    Agathois-piscénois
# 4     ZR OCCITANIE   FR08023                  Biterrois-Narbonnais
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Urbaine       O3             Fond  ...   84.1       84.050
# 1         Périurbaine       O3             Fond  ...   83.4       83.375
# 2         Périurbaine       O3             Fond  ...   79.7       79.675
# 3         Périurbaine       O3             Fond  ...   90.8       90.800
# 4    Rurale régionale       O3             Fond  ...   80.9       80.900
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3            96.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité  Latitude Longitude
# 0                 100.0             R         1   43.5915   3.88681
# 1                  96.0             R         1   43.5705   3.91180
# 2                 100.0             A         1   43.6926   3.80021
# 3                 100.0             A         1   43.2875   3.50484
# 4                 100.0             R         1   43.4068   3.18878
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
#
#                Zas code site                              nom site  \
# 0  ZAG MONTPELLIER   FR08016             Montpellier Prés d'Arènes
# 1  ZAG MONTPELLIER   FR08017  Montpellier Périurbaine Sud (Lattes)
# 2  ZAG MONTPELLIER   FR08018                   Montpellier St Gely
# 3     ZR OCCITANIE   FR08022                    Agathois-piscénois
# 4     ZR OCCITANIE   FR08023                  Biterrois-Narbonnais
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Urbaine       O3             Fond  ...       84.050
# 1         Périurbaine       O3             Fond  ...       83.375
# 2         Périurbaine       O3             Fond  ...       79.675
# 3         Périurbaine       O3             Fond  ...       90.800
# 4    Rurale régionale       O3             Fond  ...       80.900
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3           96.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité  Latitude  Longitude  \
# 0                  100.0            R         1   43.5915    3.88681
# 1                   96.0            R         1   43.5705    3.91180
# 2                  100.0            A         1   43.6926    3.80021
# 3                  100.0            A         1   43.2875    3.50484
# 4                  100.0            R         1   43.4068    3.18878
#
#   ATMO sub-score
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2
#
# [5 rows x 24 columns]

# %%
# SO2 ATMO OCCITANIE

# File path to the data
SO2_ATMO_OCCITANIE_file_path = os.path.join(base_path, "SO2 Max Horaire Journalier\Export Max. journalier moy. hor. - SO2 - ATMO OCCITANIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_SO2 = pd.read_csv(SO2_ATMO_OCCITANIE_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_SO2.head())

# Sample ATMO subscore dictionary for SO2 (Max horaire journalier)
ATMO_subscore_SO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 100.0), (100.0, 200.0), (200.0, 350.0), (350.0, 500.0), (500.0, 750.0), (750.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_SO2 = pd.DataFrame(ATMO_subscore_SO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_SO2['Range'] = ATMO_subscore_df_SO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of SO2 measurement
def assign_subscore_SO2(valeur):
    for index, row in ATMO_subscore_df_SO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_SO2['ATMO sub-score'] = df_SO2['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_SO2.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 2  2023/01/02 00:00:00  2023/01/02 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 3  2023/01/02 00:00:00  2023/01/02 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 4  2023/01/03 00:00:00  2023/01/03 23:59:59  ATMO OCCITANIE  FR76ZRE01
#
#             Zas code site           nom site type d'implantation Polluant  \
# 0  ZR OCCITANIE   FR12015           MIRAMONT             Urbaine      SO2
# 1  ZR OCCITANIE   FR12016  DAURAT ST GAUDENS             Urbaine      SO2
# 2  ZR OCCITANIE   FR12015           MIRAMONT             Urbaine      SO2
# 3  ZR OCCITANIE   FR12016  DAURAT ST GAUDENS             Urbaine      SO2
# 4  ZR OCCITANIE   FR12015           MIRAMONT             Urbaine      SO2
#
#   type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0     Industrielle  ...    1.9        1.875           µg-m3           100.0
# 1     Industrielle  ...    0.8        0.825           µg-m3           100.0
# 2     Industrielle  ...    2.1        2.100           µg-m3           100.0
# 3     Industrielle  ...    6.5        6.475           µg-m3           100.0
# 4     Industrielle  ...    1.3        1.250           µg-m3           100.0
#
#    couverture temporelle couverture de données  code qualité  validité  \
# 0                    100                 100.0             R         1
# 1                    100                 100.0             R         1
# 2                    100                 100.0             R         1
# 3                    100                 100.0             R         1
# 4                    100                 100.0             R         1
#
#     Latitude Longitude
# 0  43.093611  0.743611
# 1  43.106156  0.719550
# 2  43.093611  0.743611
# 3  43.106156  0.719550
# 4  43.093611  0.743611
#
# [5 rows x 23 columns]
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 2  2023/01/02 00:00:00  2023/01/02 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 3  2023/01/02 00:00:00  2023/01/02 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 4  2023/01/03 00:00:00  2023/01/03 23:59:59  ATMO OCCITANIE  FR76ZRE01
#
#             Zas code site           nom site type d'implantation Polluant  \
# 0  ZR OCCITANIE   FR12015           MIRAMONT             Urbaine      SO2
# 1  ZR OCCITANIE   FR12016  DAURAT ST GAUDENS             Urbaine      SO2
# 2  ZR OCCITANIE   FR12015           MIRAMONT             Urbaine      SO2
# 3  ZR OCCITANIE   FR12016  DAURAT ST GAUDENS             Urbaine      SO2
# 4  ZR OCCITANIE   FR12015           MIRAMONT             Urbaine      SO2
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0     Industrielle  ...        1.875           µg-m3          100.0
# 1     Industrielle  ...        0.825           µg-m3          100.0
# 2     Industrielle  ...        2.100           µg-m3          100.0
# 3     Industrielle  ...        6.475           µg-m3          100.0
# 4     Industrielle  ...        1.250           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            R         1
# 1                    100                  100.0            R         1
# 2                    100                  100.0            R         1
# 3                    100                  100.0            R         1
# 4                    100                  100.0            R         1
#
#     Latitude  Longitude ATMO sub-score
# 0  43.093611   0.743611            1.0
# 1  43.106156   0.719550            1.0
# 2  43.093611   0.743611            1.0
# 3  43.106156   0.719550            1.0
# 4  43.093611   0.743611            1.0
#
# [5 rows x 24 columns]

# %%
# Combining 5 (if not missing) dataframes
# Concatenate DataFrames along the rows (stack them vertically)
combined_df_ATMO_OCCITANIE = pd.concat([df_PM10, df_PM25, df_NO2, df_O3, df_SO2], axis=0) #

# If you want to reset the index of the combined DataFrame
combined_df_ATMO_OCCITANIE.reset_index(drop=True, inplace=True)

# Renaming the ATMO subscore column to 'ATMO Score'
combined_df_ATMO_OCCITANIE = combined_df_ATMO_OCCITANIE.rename(columns={'ATMO sub-score': 'ATMO Score'})

# Printing the first five rows as a sanity check
print(combined_df_ATMO_OCCITANIE.head())
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAG02
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR02
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZAR02
#
#                Zas code site                   nom site type d'implantation  \
# 0  ZAG MONTPELLIER   FR08016  Montpellier Prés d'Arènes             Urbaine
# 1     ZR OCCITANIE   FR08020                 Lunel Viel         Périurbaine
# 2  ZAG MONTPELLIER   FR08030                 Pompignane             Urbaine
# 3        ZAR NIMES   FR08614                Nimes Gauzy             Urbaine
# 4        ZAR NIMES   FR08616               Nimes Planas             Urbaine
#
#   Polluant type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0     PM10             Fond  ...    25.766667           µg-m3          100.0
# 1     PM10     Industrielle  ...    26.495833           µg-m3          100.0
# 2     PM10           Trafic  ...    34.620833           µg/m3          100.0
# 3     PM10             Fond  ...    23.387500           µg-m3          100.0
# 4     PM10           Trafic  ...    30.504167           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#    Latitude  Longitude ATMO Score
# 0   43.5915    3.88681        2.0
# 1   43.6758    4.08838        2.0
# 2   43.6096    3.89878        2.0
# 3   43.8344    4.37440        2.0
# 4   43.8299    4.36199        2.0
#
# [5 rows x 24 columns]

# %%
# Find the index of rows with maximum 'ATMO Score' within each group
idx_max_scores = combined_df_ATMO_OCCITANIE.groupby(['nom site', 'Date de fin'])['ATMO Score'].idxmax()

# Select rows with the maximum 'ATMO Score' using the index
final_df_ATMO_OCCITANIE = combined_df_ATMO_OCCITANIE.loc[idx_max_scores]

# Reset index if needed
final_df_ATMO_OCCITANIE.reset_index(drop=True, inplace=True)

# %%
# Downloading the final dataframe of Daily ATMO Score in ATMO OCCITANIE to csv
final_df_ATMO_OCCITANIE.to_csv('final_df_ATMO_OCCITANIE.csv', index=False, encoding = 'latin1')

# %%
# Constructing indicator for ATMO OCCITANIE

# File path to the data
ATMO_OCCITANIE_file_path = os.path.join(base_path, "final_df_ATMO_OCCITANIE.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_ATMO = pd.read_csv(ATMO_OCCITANIE_file_path, delimiter=',', encoding = 'latin1')

print(df_ATMO.head())

counts = df_ATMO.groupby('nom site')['ATMO Score'].value_counts().reset_index(name='counts')
#print(counts)

#result = pd.merge(counts, df_ATMO[["Organisme", "type d'implantation", "Latitude", "Longitude"]], on='nom site', how='left')
#print(result)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_ATMO.groupby('nom site').first().reset_index()
#print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(counts, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score_y'], axis = 1)
print(result)
# Out:
#          Date de début          Date de fin       Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 1  2023/01/02 00:00:00  2023/01/02 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 2  2023/01/03 00:00:00  2023/01/03 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 3  2023/01/04 00:00:00  2023/01/04 23:59:59  ATMO OCCITANIE  FR76ZRE01
# 4  2023/01/05 00:00:00  2023/01/05 23:59:59  ATMO OCCITANIE  FR76ZRE01
#
#             Zas code site     nom site type d'implantation Polluant  \
# 0  ZR OCCITANIE   FR12026  ALBI DELMAS             Urbaine     PM10
# 1  ZR OCCITANIE   FR12026  ALBI DELMAS             Urbaine      NO2
# 2  ZR OCCITANIE   FR12026  ALBI DELMAS             Urbaine     PM10
# 3  ZR OCCITANIE   FR12026  ALBI DELMAS             Urbaine     PM10
# 4  ZR OCCITANIE   FR12026  ALBI DELMAS             Urbaine     PM10
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0             Fond  ...    18.258333           µg-m3          100.0
# 1             Fond  ...    65.750000           µg-m3          100.0
# 2             Fond  ...    20.218182           µg-m3           46.0
# 3             Fond  ...    19.758333           µg-m3          100.0
# 4             Fond  ...    30.391667           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                   46.0            N        -1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude ATMO Score
# 0  43.927769   2.145897        1.0
# 1  43.927769   2.145897        2.0
# 2  43.927769   2.145897        1.0
# 3  43.927769   2.145897        1.0
# 4  43.927769   2.145897        2.0
#
# [5 rows x 24 columns]
#                           nom site  ATMO Score_x  counts       Organisme  \
# 0                      ALBI DELMAS           1.0     270  ATMO OCCITANIE
# 1                      ALBI DELMAS           2.0      93  ATMO OCCITANIE
# 2                      ALBI DELMAS           3.0       2  ATMO OCCITANIE
# 3               Agathois-piscénois           2.0     264  ATMO OCCITANIE
# 4               Agathois-piscénois           3.0      82  ATMO OCCITANIE
# ..                             ...           ...     ...             ...
# 137  Toulouse Port de l'Embouchure           4.0      16  ATMO OCCITANIE
# 138  Toulouse Port de l'Embouchure           5.0       1  ATMO OCCITANIE
# 139  Toulouse aéroport côté trafic           1.0     198  ATMO OCCITANIE
# 140  Toulouse aéroport côté trafic           2.0     153  ATMO OCCITANIE
# 141  Toulouse aéroport côté trafic           3.0      14  ATMO OCCITANIE
#
#       code zas           Zas code site type d'implantation Polluant  \
# 0    FR76ZRE01  ZR OCCITANIE   FR12026             Urbaine     PM10
# 1    FR76ZRE01  ZR OCCITANIE   FR12026             Urbaine     PM10
# 2    FR76ZRE01  ZR OCCITANIE   FR12026             Urbaine     PM10
# 3    FR76ZRE01  ZR OCCITANIE   FR08022         Périurbaine       O3
# 4    FR76ZRE01  ZR OCCITANIE   FR08022         Périurbaine       O3
# ..         ...           ...       ...                 ...      ...
# 137  FR76ZAG01  ZAG TOULOUSE   FR12085             Urbaine     PM10
# 138  FR76ZAG01  ZAG TOULOUSE   FR12085             Urbaine     PM10
# 139  FR76ZAG01  ZAG TOULOUSE   FR12044             Urbaine     PM10
# 140  FR76ZAG01  ZAG TOULOUSE   FR12044             Urbaine     PM10
# 141  FR76ZAG01  ZAG TOULOUSE   FR12044             Urbaine     PM10
#
#     type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0               Fond  ...   18.0    18.258333           µg-m3           100.0
# 1               Fond  ...   18.0    18.258333           µg-m3           100.0
# 2               Fond  ...   18.0    18.258333           µg-m3           100.0
# 3               Fond  ...   90.8    90.800000           µg-m3           100.0
# 4               Fond  ...   90.8    90.800000           µg-m3           100.0
# ..               ...  ...    ...          ...             ...             ...
# 137           Trafic  ...   23.0    22.995833           µg-m3           100.0
# 138           Trafic  ...   23.0    22.995833           µg-m3           100.0
# 139     Industrielle  ...   22.0    21.887500           µg-m3           100.0
# 140     Industrielle  ...   22.0    21.887500           µg-m3           100.0
# 141     Industrielle  ...   22.0    21.887500           µg-m3           100.0
#
#      couverture temporelle couverture de données  code qualité  validité  \
# 0                      100                 100.0             A         1
# 1                      100                 100.0             A         1
# 2                      100                 100.0             A         1
# 3                      100                 100.0             A         1
# 4                      100                 100.0             A         1
# ..                     ...                   ...           ...       ...
# 137                    100                 100.0             A         1
# 138                    100                 100.0             A         1
# 139                    100                 100.0             A         1
# 140                    100                 100.0             A         1
# 141                    100                 100.0             A         1
#
#       Latitude Longitude
# 0    43.927769  2.145897
# 1    43.927769  2.145897
# 2    43.927769  2.145897
# 3    43.287500  3.504840
# 4    43.287500  3.504840
# ..         ...       ...
# 137  43.610386  1.415200
# 138  43.610386  1.415200
# 139  43.633478  1.375717
# 140  43.633478  1.375717
# 141  43.633478  1.375717
#
# [142 rows x 23 columns]

# %%
# Group the DataFrame by 'nom' and calculate the total counts for each 'nom'
total_counts_by_nom = result.groupby('nom site')['counts'].sum()

# Filter the DataFrame to include only rows where the score is equal to or greater than 3
filtered_result = result[result['ATMO Score_x'] >= 3]

# Group the filtered DataFrame by 'nom' and calculate the counts equal to or greater than 3 for each 'nom'
counts_greater_than_3_by_nom = filtered_result.groupby('nom site')['counts'].sum()

# Calculate the ratio of counts greater than or equal to 3 over total counts for each 'nom'
ratio_counts_greater_than_3 = (counts_greater_than_3_by_nom / total_counts_by_nom).fillna(0)

# Display the resulting Series
print(ratio_counts_greater_than_3)

# Merge the site-specific information with the counts DataFrame
ratio_counts_greater_than_3_df = pd.merge(ratio_counts_greater_than_3, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score'], axis = 1)
ratio_counts_greater_than_3_df = ratio_counts_greater_than_3_df.rename(columns={'counts': 'indicator'})
print(ratio_counts_greater_than_3_df)
# Out:
# nom site
# ALBI DELMAS                             0.005479
# Agathois-piscénois                      0.263014
# BELESTA EN LAURAGAIS                    0.200000
# BESSIERES ECONOTRE                      0.000000
# Biterrois-Narbonnais                    0.249315
# CHAPITRE SETMI                          0.021978
# DAURAT ST GAUDENS                       0.000000
# ECOLE M.JACQUIER                        0.241096
# EISENHOWER SETMI                        0.019178
# GAUDONVILLE                             0.203297
# Gard Rhodanien2                         0.356354
# LOURDES LAPACCA                         0.243836
# Lunel Viel                              0.052055
# MIRAMONT                                0.000000
# Montauban                               0.282192
# Montpellier Chaptal                     0.008310
# Montpellier Liberté                     0.512329
# Montpellier Prés d'Arènes               0.160000
# Montpellier Périurbaine Sud (Lattes)    0.323204
# Montpellier St Denis                    0.033426
# Montpellier St Gely                     0.301370
# Nimes Gauzy                             0.387363
# Nimes La Calmette                       0.298630
# Nimes Planas                            0.073973
# PEYRUSSE                                0.115068
# Perpignan Les Carmes                    0.287671
# Perpignan St Esteve                     0.252747
# Perpignan bd Pyrénées                   0.221918
# Pompignane                              0.063014
# Rodez                                   0.246575
# SICOVAL                                 0.216438
# Stade Travet CASTRES                    0.279452
# TRAFIC_TOULOUSE                         0.216438
# Tarbes lycée Dupuy                      0.260274
# Toulouse Berthelot                      0.249315
# Toulouse Mazades                        0.068493
# Toulouse Port de l'Embouchure           0.162088
# Toulouse aéroport côté trafic           0.038356
# Name: counts, dtype: float64
#                                 nom site  indicator       Organisme  \
# 0                            ALBI DELMAS   0.005479  ATMO OCCITANIE
# 1                     Agathois-piscénois   0.263014  ATMO OCCITANIE
# 2                   BELESTA EN LAURAGAIS   0.200000  ATMO OCCITANIE
# 3                     BESSIERES ECONOTRE   0.000000  ATMO OCCITANIE
# 4                   Biterrois-Narbonnais   0.249315  ATMO OCCITANIE
# 5                         CHAPITRE SETMI   0.021978  ATMO OCCITANIE
# 6                      DAURAT ST GAUDENS   0.000000  ATMO OCCITANIE
# 7                       ECOLE M.JACQUIER   0.241096  ATMO OCCITANIE
# 8                       EISENHOWER SETMI   0.019178  ATMO OCCITANIE
# 9                            GAUDONVILLE   0.203297  ATMO OCCITANIE
# 10                       Gard Rhodanien2   0.356354  ATMO OCCITANIE
# 11                       LOURDES LAPACCA   0.243836  ATMO OCCITANIE
# 12                            Lunel Viel   0.052055  ATMO OCCITANIE
# 13                              MIRAMONT   0.000000  ATMO OCCITANIE
# 14                             Montauban   0.282192  ATMO OCCITANIE
# 15                   Montpellier Chaptal   0.008310  ATMO OCCITANIE
# 16                   Montpellier Liberté   0.512329  ATMO OCCITANIE
# 17             Montpellier Prés d'Arènes   0.160000  ATMO OCCITANIE
# 18  Montpellier Périurbaine Sud (Lattes)   0.323204  ATMO OCCITANIE
# 19                  Montpellier St Denis   0.033426  ATMO OCCITANIE
# 20                   Montpellier St Gely   0.301370  ATMO OCCITANIE
# 21                           Nimes Gauzy   0.387363  ATMO OCCITANIE
# 22                     Nimes La Calmette   0.298630  ATMO OCCITANIE
# 23                          Nimes Planas   0.073973  ATMO OCCITANIE
# 24                              PEYRUSSE   0.115068  ATMO OCCITANIE
# 25                  Perpignan Les Carmes   0.287671  ATMO OCCITANIE
# 26                   Perpignan St Esteve   0.252747  ATMO OCCITANIE
# 27                 Perpignan bd Pyrénées   0.221918  ATMO OCCITANIE
# 28                            Pompignane   0.063014  ATMO OCCITANIE
# 29                                 Rodez   0.246575  ATMO OCCITANIE
# 30                               SICOVAL   0.216438  ATMO OCCITANIE
# 31                  Stade Travet CASTRES   0.279452  ATMO OCCITANIE
# 32                       TRAFIC_TOULOUSE   0.216438  ATMO OCCITANIE
# 33                    Tarbes lycée Dupuy   0.260274  ATMO OCCITANIE
# 34                    Toulouse Berthelot   0.249315  ATMO OCCITANIE
# 35                      Toulouse Mazades   0.068493  ATMO OCCITANIE
# 36         Toulouse Port de l'Embouchure   0.162088  ATMO OCCITANIE
# 37         Toulouse aéroport côté trafic   0.038356  ATMO OCCITANIE
#
#      code zas              Zas code site     type d'implantation Polluant  \
# 0   FR76ZRE01     ZR OCCITANIE   FR12026                 Urbaine     PM10
# 1   FR76ZRE01     ZR OCCITANIE   FR08022             Périurbaine       O3
# 2   FR76ZRE01     ZR OCCITANIE   FR12031        Rurale régionale       O3
# 3   FR76ZRE01     ZR OCCITANIE   FR12047  Rurale près des villes     PM10
# 4   FR76ZRE01     ZR OCCITANIE   FR08023        Rurale régionale       O3
# 5   FR76ZAG01     ZAG TOULOUSE   FR12040                 Urbaine     PM10
# 6   FR76ZRE01     ZR OCCITANIE   FR12016                 Urbaine      SO2
# 7   FR76ZAG01     ZAG TOULOUSE   FR12004                 Urbaine     PM10
# 8   FR76ZAG01     ZAG TOULOUSE   FR12039                 Urbaine     PM10
# 9   FR76ZRE01     ZR OCCITANIE   FR12029        Rurale régionale       O3
# 10  FR76ZRE01     ZR OCCITANIE   FR08209  Rurale près des villes       O3
# 11  FR76ZRE01     ZR OCCITANIE   FR12042                 Urbaine    PM2.5
# 12  FR76ZRE01     ZR OCCITANIE   FR08020             Périurbaine     PM10
# 13  FR76ZRE01     ZR OCCITANIE   FR12015                 Urbaine      SO2
# 14  FR76ZRE01     ZR OCCITANIE   FR50060                 Urbaine    PM2.5
# 15  FR76ZAG02  ZAG MONTPELLIER   FR08003                 Urbaine      NO2
# 16  FR76ZAG02  ZAG MONTPELLIER   FR50225                 Urbaine     PM10
# 17  FR76ZAG02  ZAG MONTPELLIER   FR08016                 Urbaine     PM10
# 18  FR76ZAG02  ZAG MONTPELLIER   FR08017             Périurbaine       O3
# 19  FR76ZAG02  ZAG MONTPELLIER   FR08004                 Urbaine      NO2
# 20  FR76ZAG02  ZAG MONTPELLIER   FR08018             Périurbaine       O3
# 21  FR76ZAR02        ZAR NIMES   FR08614                 Urbaine     PM10
# 22  FR76ZAR02        ZAR NIMES   FR08617             Périurbaine       O3
# 23  FR76ZAR02        ZAR NIMES   FR08616                 Urbaine     PM10
# 24  FR76ZRE01     ZR OCCITANIE   FR12020        Rurale nationale       O3
# 25  FR76ZAR01    ZAR PERPIGNAN   FR08714                 Urbaine    PM2.5
# 26  FR76ZAR01    ZAR PERPIGNAN   FR08712             Périurbaine       O3
# 27  FR76ZAR01    ZAR PERPIGNAN   FR50224                 Urbaine     PM10
# 28  FR76ZAG02  ZAG MONTPELLIER   FR08030                 Urbaine     PM10
# 29  FR76ZRE01     ZR OCCITANIE   FR12095                 Urbaine       O3
# 30  FR76ZAG01     ZAG TOULOUSE   FR12041             Périurbaine       O3
# 31  FR76ZRE01     ZR OCCITANIE   FR12053                 Urbaine       O3
# 32  FR76ZAG01     ZAG TOULOUSE   FR12054                 Urbaine     PM10
# 33  FR76ZRE01     ZR OCCITANIE   FR12052                 Urbaine     PM10
# 34  FR76ZAG01     ZAG TOULOUSE   FR12030                 Urbaine     PM10
# 35  FR76ZAG01     ZAG TOULOUSE   FR12021                 Urbaine    PM2.5
# 36  FR76ZAG01     ZAG TOULOUSE   FR12085                 Urbaine     PM10
# 37  FR76ZAG01     ZAG TOULOUSE   FR12044                 Urbaine     PM10
#
#    type d'influence Réglementaire  ... valeur valeur brute  unité de mesure  \
# 0              Fond           Oui  ...   18.0    18.258333            µg-m3
# 1              Fond           Oui  ...   90.8    90.800000            µg-m3
# 2              Fond           Oui  ...   77.1    77.100000            µg-m3
# 3      Industrielle           Oui  ...   21.0    20.820833            µg/m3
# 4              Fond           Oui  ...   80.9    80.900000            µg-m3
# 5      Industrielle           Oui  ...   24.0    23.533333            µg-m3
# 6      Industrielle           Oui  ...    0.8     0.825000            µg-m3
# 7              Fond           Oui  ...   22.0    22.216667            µg/m3
# 8      Industrielle           Oui  ...   24.0    23.858333            µg-m3
# 9              Fond           Oui  ...   63.4    63.400000            µg-m3
# 10             Fond           Oui  ...   69.0    69.025000            µg-m3
# 11             Fond           Oui  ...   12.0    11.866667            µg-m3
# 12     Industrielle           Oui  ...   26.0    26.495833            µg-m3
# 13     Industrielle           Oui  ...    1.9     1.875000            µg-m3
# 14             Fond           Oui  ...   11.0    10.912500            µg/m3
# 15             Fond           Oui  ...   11.9    11.875000            µg-m3
# 16             Fond           Oui  ...   31.0    30.512500            µg-m3
# 17             Fond           Oui  ...   26.0    25.766667            µg-m3
# 18             Fond           Oui  ...   83.4    83.375000            µg-m3
# 19           Trafic           Oui  ...   15.4    15.425000            µg-m3
# 20             Fond           Oui  ...   79.7    79.675000            µg-m3
# 21             Fond           Oui  ...   23.0    23.387500            µg-m3
# 22             Fond           Oui  ...   71.2    71.175000            µg-m3
# 23           Trafic           Oui  ...   31.0    30.504167            µg-m3
# 24             Fond           Oui  ...   53.9    53.875000            µg-m3
# 25             Fond           Oui  ...   21.0    21.270833            µg-m3
# 26             Fond           Oui  ...   47.7    47.650000            µg-m3
# 27           Trafic           Oui  ...   28.0    27.625000            µg-m3
# 28           Trafic           Oui  ...   35.0    34.620833            µg/m3
# 29             Fond           Oui  ...   82.0    82.025000            µg-m3
# 30             Fond           Oui  ...   75.7    75.675000            µg-m3
# 31             Fond           Oui  ...   81.2    81.225000            µg-m3
# 32           Trafic           Oui  ...   22.0    21.937500            µg-m3
# 33             Fond           Oui  ...   26.0    26.241667            µg-m3
# 34             Fond           Oui  ...   23.0    22.958333            µg-m3
# 35             Fond           Oui  ...   11.0    10.637500            µg-m3
# 36           Trafic           Oui  ...   23.0    22.995833            µg-m3
# 37     Industrielle           Oui  ...   22.0    21.887500            µg-m3
#
#     taux de saisie couverture temporelle  couverture de données  code qualité  \
# 0            100.0                   100                  100.0             A
# 1            100.0                   100                  100.0             A
# 2            100.0                   100                  100.0             A
# 3            100.0                   100                  100.0             R
# 4            100.0                   100                  100.0             R
# 5            100.0                   100                  100.0             A
# 6            100.0                   100                  100.0             R
# 7            100.0                   100                  100.0             A
# 8            100.0                   100                  100.0             A
# 9            100.0                   100                  100.0             A
# 10           100.0                   100                  100.0             R
# 11           100.0                   100                  100.0             A
# 12           100.0                   100                  100.0             A
# 13           100.0                   100                  100.0             R
# 14           100.0                   100                  100.0             A
# 15           100.0                   100                  100.0             R
# 16           100.0                   100                  100.0             A
# 17           100.0                   100                  100.0             A
# 18            96.0                   100                   96.0             R
# 19           100.0                   100                  100.0             R
# 20           100.0                   100                  100.0             A
# 21           100.0                   100                  100.0             A
# 22           100.0                   100                  100.0             R
# 23           100.0                   100                  100.0             A
# 24           100.0                   100                  100.0             A
# 25           100.0                   100                  100.0             A
# 26           100.0                   100                  100.0             R
# 27           100.0                   100                  100.0             A
# 28           100.0                   100                  100.0             A
# 29           100.0                   100                  100.0             A
# 30           100.0                   100                  100.0             R
# 31           100.0                   100                  100.0             R
# 32           100.0                   100                  100.0             A
# 33           100.0                   100                  100.0             A
# 34           100.0                   100                  100.0             A
# 35           100.0                   100                  100.0             A
# 36           100.0                   100                  100.0             A
# 37           100.0                   100                  100.0             A
#
#     validité   Latitude  Longitude
# 0          1  43.927769   2.145897
# 1          1  43.287500   3.504840
# 2          1  43.441390   1.821944
# 3          1  43.803139   1.595475
# 4          1  43.406800   3.188780
# 5          1  43.556375   1.403964
# 6          1  43.106156   0.719550
# 7          1  43.575694   1.418064
# 8          1  43.561581   1.393261
# 9          1  43.883933   0.845617
# 10         1  43.942600   4.679580
# 11         1  43.096247  -0.040497
# 12         1  43.675800   4.088380
# 13         1  43.093611   0.743611
# 14         1  44.012857   1.375305
# 15         1  43.611302   3.866260
# 16         1  43.611606   3.827868
# 17         1  43.591500   3.886810
# 18         1  43.570500   3.911800
# 19         1  43.605100   3.874640
# 20         1  43.692600   3.800210
# 21         1  43.834400   4.374400
# 22         1  43.925400   4.265810
# 23         1  43.829900   4.361990
# 24         1  43.628700   0.179069
# 25         1  42.695500   2.900530
# 26         1  42.719800   2.839880
# 27         1  42.695870   2.888483
# 28         1  43.609600   3.898780
# 29         1  44.356992   2.570704
# 30         1  43.457306   1.571469
# 31         1  43.610497   2.230150
# 32         1  43.643944   1.468244
# 33         1  43.230297   0.062339
# 34         1  43.587344   1.444003
# 35         1  43.623606   1.438531
# 36         1  43.610386   1.415200
# 37         1  43.633478   1.375717
#
# [38 rows x 22 columns]

# %%
# Downloading the final indicator of ATMO OCCITANIE to csv
ratio_counts_greater_than_3_df.to_csv('indicator_ATMO_OCCITANIE.csv', index=False, encoding = 'latin1')

# %%
# -----------------------------------------------------------------------------------------------------------------------------------------------------
#                                                               Sanity Checks
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %%
print(df_PM25['valeur'].head())
# Out:
# 0    14.0
# 1    13.0
# 2    12.0
# 3    12.0
# 4    21.0
# Name: valeur, dtype: float64

# %%
df_PM25['ATMO sub-score'].describe()
# Out:
# count    5758.000000
# mean        1.326329
# std         0.663946
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         5.000000
# Name: ATMO sub-score, dtype: float64

# %%
print(df_PM25['valeur'].head())
# Out:
# 0    14.0
# 1    13.0
# 2    12.0
# 3    12.0
# 4    21.0
# Name: valeur, dtype: float64
