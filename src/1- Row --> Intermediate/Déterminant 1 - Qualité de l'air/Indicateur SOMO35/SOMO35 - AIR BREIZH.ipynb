# %%
# Code for extracting the annual SOMO35 score for each station in AIR BREIZH (Région: Bretagne)

# %%
# Installing required packages
import pandas as pd

import os

# Base directory path
base_path = ".\data\1- Raw Data\Déterminant 1 - Qualité de l'air\"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10440\2375524138.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# O3 AIR BREIZH

# File path to the data
O3_AIR_BREIZH_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - AIR BREIZH.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_AIR_BREIZH_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Apply the function to fill in the Subscore column
df_O3['SOMO35 Subscore'] = df_O3['valeur'].apply(lambda x: max(x - 70, 0))

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin   Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
#
#            Zas code site              nom site type d'implantation Polluant  \
# 0    ZAR BREST   FR19012            Brest Mace             Urbaine       O3
# 1    ZAR BREST   FR19016        BREST Plouzané         Périurbaine       O3
# 2   ZAG RENNES   FR19018     MORDELLES BELLAIS         Périurbaine       O3
# 3  ZR BRETAGNE   FR19020               Kergoff    Rurale nationale       O3
# 4  ZR BRETAGNE   FR19032  Lorient B. Bissonnet             Urbaine       O3
#
#   type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0             Fond  ...   83.6       83.625           µg-m3           100.0
# 1             Fond  ...   81.9       81.850           µg-m3           100.0
# 2             Fond  ...   68.5       68.475           µg-m3           100.0
# 3             Fond  ...   75.4       75.375           µg-m3           100.0
# 4             Fond  ...   83.1       83.100           µg-m3           100.0
#
#    couverture temporelle couverture de données  code qualité  validité  \
# 0                    100                 100.0             A         1
# 1                    100                 100.0             A         1
# 2                    100                 100.0             A         1
# 3                    100                 100.0             A         1
# 4                    100                 100.0             A         1
#
#     Latitude Longitude
# 0  48.386180 -4.486600
# 1  48.359444 -4.568055
# 2  48.082883 -1.834583
# 3  48.261963 -2.943631
# 4  47.742500 -3.395010
#
# [5 rows x 23 columns]
#          Date de début          Date de fin   Organisme   code zas  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAR01
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZAG01
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH  FR53ZRE01
#
#            Zas code site              nom site type d'implantation Polluant  \
# 0    ZAR BREST   FR19012            Brest Mace             Urbaine       O3
# 1    ZAR BREST   FR19016        BREST Plouzané         Périurbaine       O3
# 2   ZAG RENNES   FR19018     MORDELLES BELLAIS         Périurbaine       O3
# 3  ZR BRETAGNE   FR19020               Kergoff    Rurale nationale       O3
# 4  ZR BRETAGNE   FR19032  Lorient B. Bissonnet             Urbaine       O3
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0             Fond  ...       83.625           µg-m3          100.0
# 1             Fond  ...       81.850           µg-m3          100.0
# 2             Fond  ...       68.475           µg-m3          100.0
# 3             Fond  ...       75.375           µg-m3          100.0
# 4             Fond  ...       83.100           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
#
#     Latitude  Longitude SOMO35 Subscore
# 0  48.386180  -4.486600            13.6
# 1  48.359444  -4.568055            11.9
# 2  48.082883  -1.834583             0.0
# 3  48.261963  -2.943631             5.4
# 4  47.742500  -3.395010            13.1
#
# [5 rows x 24 columns]

# %%
# Compute sum of SOMO35 Subscore grouped by 'nom site'
sum_by_nom = df_O3.groupby('nom site')['SOMO35 Subscore'].sum()

print(sum_by_nom)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_O3.groupby('nom site').first().reset_index()
print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(sum_by_nom, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'SOMO35 Subscore_y'], axis = 1)
print(result)
# Out:
# nom site
# BREST Plouzané          4879.3
# Brest Mace              4484.3
# Kergoff                 3522.8
# Lorient B. Bissonnet    5152.1
# MORDELLES BELLAIS       2961.4
# Quimper Zola            4951.5
# Rennes Thabor           4249.2
# Saint Brieuc Balzac     2482.2
# StMalo Rocabey          3921.3
# Vannes UTA              4854.3
# Name: SOMO35 Subscore, dtype: float64
#                nom site        Date de début          Date de fin   Organisme  \
# 0        BREST Plouzané  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH
# 1            Brest Mace  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH
# 2               Kergoff  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH
# 3  Lorient B. Bissonnet  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH
# 4     MORDELLES BELLAIS  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH
# 5          Quimper Zola  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH
# 6         Rennes Thabor  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH
# 7   Saint Brieuc Balzac  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH
# 8        StMalo Rocabey  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH
# 9            Vannes UTA  2023/01/01 00:00:00  2023/01/01 23:59:59  AIR BREIZH
#
#     code zas          Zas code site type d'implantation Polluant  \
# 0  FR53ZAR01    ZAR BREST   FR19016         Périurbaine       O3
# 1  FR53ZAR01    ZAR BREST   FR19012             Urbaine       O3
# 2  FR53ZRE01  ZR BRETAGNE   FR19020    Rurale nationale       O3
# 3  FR53ZRE01  ZR BRETAGNE   FR19032             Urbaine       O3
# 4  FR53ZAG01   ZAG RENNES   FR19018         Périurbaine       O3
# 5  FR53ZRE01  ZR BRETAGNE   FR19053             Urbaine       O3
# 6  FR53ZAG01   ZAG RENNES   FR19039             Urbaine       O3
# 7  FR53ZRE01  ZR BRETAGNE   FR19061             Urbaine       O3
# 8  FR53ZRE01  ZR BRETAGNE   FR19082         Périurbaine       O3
# 9  FR53ZRE01  ZR BRETAGNE   FR19033             Urbaine       O3
#
#   type d'influence  ... valeur brute unité de mesure taux de saisie  \
# 0             Fond  ...       81.850           µg-m3          100.0
# 1             Fond  ...       83.625           µg-m3          100.0
# 2             Fond  ...       75.375           µg-m3          100.0
# 3             Fond  ...       83.100           µg-m3          100.0
# 4             Fond  ...       68.475           µg-m3          100.0
# 5             Fond  ...       80.125           µg-m3          100.0
# 6             Fond  ...       78.500           µg-m3          100.0
# 7             Fond  ...       74.200           µg-m3          100.0
# 8             Fond  ...       83.200           µg-m3          100.0
# 9             Fond  ...       78.850           µg-m3          100.0
#
#    couverture temporelle  couverture de données code qualité  validité  \
# 0                    100                  100.0            A         1
# 1                    100                  100.0            A         1
# 2                    100                  100.0            A         1
# 3                    100                  100.0            A         1
# 4                    100                  100.0            A         1
# 5                    100                  100.0            A         1
# 6                    100                  100.0            A         1
# 7                    100                  100.0            A         1
# 8                    100                  100.0            A         1
# 9                    100                  100.0            R         1
#
#     Latitude  Longitude SOMO35 Subscore
# 0  48.359444  -4.568055            11.9
# 1  48.386180  -4.486600            13.6
# 2  48.261963  -2.943631             5.4
# 3  47.742500  -3.395010            13.1
# 4  48.082883  -1.834583             0.0
# 5  47.986606  -4.097658            10.1
# 6  48.115210  -1.673088             8.5
# 7  48.513510  -2.749530             4.2
# 8  48.653060  -2.002680            13.2
# 9  47.648920  -2.763990             8.9
#
# [10 rows x 24 columns]
#                nom site  SOMO35 Subscore_x   Organisme   code zas  \
# 0        BREST Plouzané             4879.3  AIR BREIZH  FR53ZAR01
# 1            Brest Mace             4484.3  AIR BREIZH  FR53ZAR01
# 2               Kergoff             3522.8  AIR BREIZH  FR53ZRE01
# 3  Lorient B. Bissonnet             5152.1  AIR BREIZH  FR53ZRE01
# 4     MORDELLES BELLAIS             2961.4  AIR BREIZH  FR53ZAG01
# 5          Quimper Zola             4951.5  AIR BREIZH  FR53ZRE01
# 6         Rennes Thabor             4249.2  AIR BREIZH  FR53ZAG01
# 7   Saint Brieuc Balzac             2482.2  AIR BREIZH  FR53ZRE01
# 8        StMalo Rocabey             3921.3  AIR BREIZH  FR53ZRE01
# 9            Vannes UTA             4854.3  AIR BREIZH  FR53ZRE01
#
#            Zas code site type d'implantation Polluant type d'influence  \
# 0    ZAR BREST   FR19016         Périurbaine       O3             Fond
# 1    ZAR BREST   FR19012             Urbaine       O3             Fond
# 2  ZR BRETAGNE   FR19020    Rurale nationale       O3             Fond
# 3  ZR BRETAGNE   FR19032             Urbaine       O3             Fond
# 4   ZAG RENNES   FR19018         Périurbaine       O3             Fond
# 5  ZR BRETAGNE   FR19053             Urbaine       O3             Fond
# 6   ZAG RENNES   FR19039             Urbaine       O3             Fond
# 7  ZR BRETAGNE   FR19061             Urbaine       O3             Fond
# 8  ZR BRETAGNE   FR19082         Périurbaine       O3             Fond
# 9  ZR BRETAGNE   FR19033             Urbaine       O3             Fond
#
#   Réglementaire  ... valeur valeur brute  unité de mesure  taux de saisie  \
# 0           Oui  ...   81.9       81.850            µg-m3           100.0
# 1           Oui  ...   83.6       83.625            µg-m3           100.0
# 2           Oui  ...   75.4       75.375            µg-m3           100.0
# 3           Oui  ...   83.1       83.100            µg-m3           100.0
# 4           Oui  ...   68.5       68.475            µg-m3           100.0
# 5           Oui  ...   80.1       80.125            µg-m3           100.0
# 6           Oui  ...   78.5       78.500            µg-m3           100.0
# 7           Oui  ...   74.2       74.200            µg-m3           100.0
# 8           Oui  ...   83.2       83.200            µg-m3           100.0
# 9           Oui  ...   78.9       78.850            µg-m3           100.0
#
#   couverture temporelle  couverture de données  code qualité  validité  \
# 0                   100                  100.0             A         1
# 1                   100                  100.0             A         1
# 2                   100                  100.0             A         1
# 3                   100                  100.0             A         1
# 4                   100                  100.0             A         1
# 5                   100                  100.0             A         1
# 6                   100                  100.0             A         1
# 7                   100                  100.0             A         1
# 8                   100                  100.0             A         1
# 9                   100                  100.0             R         1
#
#     Latitude  Longitude
# 0  48.359444  -4.568055
# 1  48.386180  -4.486600
# 2  48.261963  -2.943631
# 3  47.742500  -3.395010
# 4  48.082883  -1.834583
# 5  47.986606  -4.097658
# 6  48.115210  -1.673088
# 7  48.513510  -2.749530
# 8  48.653060  -2.002680
# 9  47.648920  -2.763990
#
# [10 rows x 22 columns]

# %%
# Downloading the final dataframe of annual SOMO35 Score in AIR BREIZH to csv
result.to_csv('df_SOMO35_AIRBREIZH.csv', index=False, encoding = 'latin1')
