# %%
# Code for extracting the annual SOMO35 Score for each station in ATMO NOUVELLE-AQUITAINE (Région: NOUVELLE-AQUITAINE)

# Using ATMO NA as abbreviation

# %%
# Installing required packages
import pandas as pd


import os

# Base directory path
base_path = ".\data\raw\Données de la qualité de l'air (Indicateurs SOMO35 et ATMO)\"

# %%
# O3 ATMO NOUVELLE-AQUITAINE

# File path to the data
O3_ATMO_NA_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - ATMO NA.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_ATMO_NA_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Apply the function to fill in the Subscore column
df_O3['SOMO35 Subscore'] = df_O3['valeur'].apply(lambda x: max(x - 70, 0))

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site             nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003      place de VERDUN
# 1  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09008                Aytré
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09015     Les Couronneries
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103  Square Pablo Casals
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09302      Zoodyssée Chizé
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Urbaine       O3             Fond  ...   72.0       72.025
# 1         Périurbaine       O3             Fond  ...   72.6       72.600
# 2             Urbaine       O3             Fond  ...   65.5       65.500
# 3             Urbaine       O3             Fond  ...   60.9       60.850
# 4    Rurale régionale       O3             Fond  ...   68.6       68.600
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3            96.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             A         1  46.162647 -1.153684
# 1                 100.0             R         1  46.135134 -1.117086
# 2                 100.0             A         1  46.586958  0.358458
# 3                 100.0             A         1  45.647428  0.167162
# 4                  96.0             R         1  46.143234 -0.395913
#
# [5 rows x 23 columns]
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site             nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003      place de VERDUN
# 1  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09008                Aytré
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09015     Les Couronneries
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103  Square Pablo Casals
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09302      Zoodyssée Chizé
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Urbaine       O3             Fond  ...       72.025
# 1         Périurbaine       O3             Fond  ...       72.600
# 2             Urbaine       O3             Fond  ...       65.500
# 3             Urbaine       O3             Fond  ...       60.850
# 4    Rurale régionale       O3             Fond  ...       68.600
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3           96.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  46.162647  -1.153684
# 1                  100.0            R         1  46.135134  -1.117086
# 2                  100.0            A         1  46.586958   0.358458
# 3                  100.0            A         1  45.647428   0.167162
# 4                   96.0            R         1  46.143234  -0.395913
#
#   SOMO35 Subscore
# 0             2.0
# 1             2.6
# 2             0.0
# 3             0.0
# 4             0.0
#
# [5 rows x 24 columns]

# %%
# Compute sum of SOMO35 Subscore grouped by 'nom site'
sum_by_nom = df_O3.groupby('nom site')['SOMO35 Subscore'].sum()

print(sum_by_nom)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_O3.groupby('nom site').first().reset_index()
print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(sum_by_nom, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'SOMO35 Subscore_y'], axis = 1)
print(result)
# Out:
# nom site
# AIRVAULT - Stade Laillé      3908.3
# AIRVAULT 3                    745.3
# AMBES                        5827.2
# Aytré                        5484.4
# BASSENS                      5575.9
# BILLERE                      5871.6
# BRIVE - Dalton               4727.4
# Biarritz-hippodrome          5223.5
# DAX                          4028.7
# GRAND PARC                   5876.2
# GUERET - Nicolas             5244.7
# LA NOUAILLE - MERA           5501.2
# LABASTIDE CEZERACQ           5279.5
# LE TEMPLE                    5597.6
# LIMOGES - BERLAND            4488.6
# Les Couronneries             5487.6
# MONT-DE-MARSAN - MIDOUZE     4349.1
# Niort Venise                 5378.8
# PALAIS S/ V.- Garros         4353.4
# PERIGUEUX                    5314.4
# Poitiers Centre  Augouard    4319.2
# SAINT-CROUTS                 4947.0
# ST JUNIEN - Fontaine         5583.5
# Square Pablo Casals          4059.8
# TALENCE                      5457.3
# TULLE - Hugo                 5249.5
# Zoodyssée Chizé              4171.6
# place de VERDUN              3724.0
# Name: SOMO35 Subscore, dtype: float64
#                      nom site        Date de début          Date de fin  \
# 0     AIRVAULT - Stade Laillé  2023/04/12 00:00:00  2023/04/12 23:59:59
# 1                  AIRVAULT 3  2023/01/01 00:00:00  2023/01/01 23:59:59
# 2                       AMBES  2023/01/01 00:00:00  2023/01/01 23:59:59
# 3                       Aytré  2023/01/01 00:00:00  2023/01/01 23:59:59
# 4                     BASSENS  2023/01/01 00:00:00  2023/01/01 23:59:59
# 5                     BILLERE  2023/01/01 00:00:00  2023/01/01 23:59:59
# 6              BRIVE - Dalton  2023/01/01 00:00:00  2023/01/01 23:59:59
# 7         Biarritz-hippodrome  2023/01/01 00:00:00  2023/01/01 23:59:59
# 8                         DAX  2023/01/01 00:00:00  2023/01/01 23:59:59
# 9                  GRAND PARC  2023/01/01 00:00:00  2023/01/01 23:59:59
# 10           GUERET - Nicolas  2023/01/01 00:00:00  2023/01/01 23:59:59
# 11         LA NOUAILLE - MERA  2023/01/01 00:00:00  2023/01/01 23:59:59
# 12         LABASTIDE CEZERACQ  2023/01/01 00:00:00  2023/01/01 23:59:59
# 13                  LE TEMPLE  2023/01/01 00:00:00  2023/01/01 23:59:59
# 14          LIMOGES - BERLAND  2023/01/01 00:00:00  2023/01/01 23:59:59
# 15           Les Couronneries  2023/01/01 00:00:00  2023/01/01 23:59:59
# 16   MONT-DE-MARSAN - MIDOUZE  2023/02/13 00:00:00  2023/02/13 23:59:59
# 17               Niort Venise  2023/01/01 00:00:00  2023/01/01 23:59:59
# 18       PALAIS S/ V.- Garros  2023/01/01 00:00:00  2023/01/01 23:59:59
# 19                  PERIGUEUX  2023/01/01 00:00:00  2023/01/01 23:59:59
# 20  Poitiers Centre  Augouard  2023/01/01 00:00:00  2023/01/01 23:59:59
# 21               SAINT-CROUTS  2023/01/01 00:00:00  2023/01/01 23:59:59
# 22       ST JUNIEN - Fontaine  2023/01/01 00:00:00  2023/01/01 23:59:59
# 23        Square Pablo Casals  2023/01/01 00:00:00  2023/01/01 23:59:59
# 24                    TALENCE  2023/01/03 00:00:00  2023/01/03 23:59:59
# 25               TULLE - Hugo  2023/01/01 00:00:00  2023/01/01 23:59:59
# 26            Zoodyssée Chizé  2023/01/01 00:00:00  2023/01/01 23:59:59
# 27            place de VERDUN  2023/01/01 00:00:00  2023/01/01 23:59:59
#
#                   Organisme   code zas                    Zas code site  \
# 0   ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304
# 1   ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304
# 2   ATMO NOUVELLE-AQUITAINE  FR75ZAG01           ZAG BORDEAUX   FR31010
# 3   ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09008
# 4   ATMO NOUVELLE-AQUITAINE  FR75ZAG01           ZAG BORDEAUX   FR31007
# 5   ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31013
# 6   ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR35004
# 7   ATMO NOUVELLE-AQUITAINE  FR75ZAG02            ZAG BAYONNE   FR31043
# 8   ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31036
# 9   ATMO NOUVELLE-AQUITAINE  FR75ZAG01           ZAG BORDEAUX   FR31001
# 10  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR35005
# 11  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR35012
# 12  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31021
# 13  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31008
# 14  ATMO NOUVELLE-AQUITAINE  FR75ZAR01            ZAR LIMOGES   FR35027
# 15  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09015
# 16  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31055
# 17  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09303
# 18  ATMO NOUVELLE-AQUITAINE  FR75ZAR01            ZAR LIMOGES   FR35007
# 19  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31033
# 20  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09404
# 21  ATMO NOUVELLE-AQUITAINE  FR75ZAG02            ZAG BAYONNE   FR31016
# 22  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR35002
# 23  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103
# 24  ATMO NOUVELLE-AQUITAINE  FR75ZAG01           ZAG BORDEAUX   FR31002
# 25  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR35006
# 26  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09302
# 27  ATMO NOUVELLE-AQUITAINE  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003
#
#        type d'implantation Polluant type d'influence  ... valeur brute  \
# 0              Périurbaine       O3             Fond  ...       94.650
# 1              Périurbaine       O3             Fond  ...       68.050
# 2              Périurbaine       O3             Fond  ...       50.725
# 3              Périurbaine       O3             Fond  ...       72.600
# 4                  Urbaine       O3             Fond  ...       51.250
# 5                  Urbaine       O3             Fond  ...       73.625
# 6                  Urbaine       O3             Fond  ...       72.225
# 7              Périurbaine       O3             Fond  ...       78.575
# 8                  Urbaine       O3             Fond  ...       72.875
# 9                  Urbaine       O3             Fond  ...       47.325
# 10                 Urbaine       O3             Fond  ...       75.625
# 11        Rurale nationale       O3             Fond  ...       74.775
# 12  Rurale près des villes       O3             Fond  ...       80.950
# 13        Rurale régionale       O3             Fond  ...       60.175
# 14                 Urbaine       O3             Fond  ...       68.650
# 15                 Urbaine       O3             Fond  ...       65.500
# 16                 Urbaine       O3             Fond  ...       78.275
# 17                 Urbaine       O3             Fond  ...       67.800
# 18             Périurbaine       O3             Fond  ...       66.025
# 19                 Urbaine       O3             Fond  ...       63.600
# 20                 Urbaine       O3             Fond  ...       63.700
# 21                 Urbaine       O3             Fond  ...       78.275
# 22                 Urbaine       O3             Fond  ...       67.750
# 23                 Urbaine       O3             Fond  ...       60.850
# 24                 Urbaine       O3             Fond  ...       66.400
# 25                 Urbaine       O3             Fond  ...       66.775
# 26        Rurale régionale       O3             Fond  ...       68.600
# 27                 Urbaine       O3             Fond  ...       72.025
#
#    unité de mesure taux de saisie  couverture temporelle  \
# 0            µg-m3           96.0                    100
# 1            µg-m3          100.0                    100
# 2            µg-m3          100.0                    100
# 3            µg-m3          100.0                    100
# 4            µg-m3          100.0                    100
# 5            µg-m3          100.0                    100
# 6            µg-m3          100.0                    100
# 7            µg-m3          100.0                    100
# 8            µg-m3          100.0                    100
# 9            µg-m3          100.0                    100
# 10           µg-m3          100.0                    100
# 11           µg-m3          100.0                    100
# 12           µg-m3          100.0                    100
# 13           µg-m3          100.0                    100
# 14           µg-m3          100.0                    100
# 15           µg-m3          100.0                    100
# 16           µg-m3           38.0                    100
# 17           µg-m3          100.0                    100
# 18           µg-m3          100.0                    100
# 19           µg-m3          100.0                    100
# 20           µg-m3          100.0                    100
# 21           µg-m3          100.0                    100
# 22           µg-m3          100.0                    100
# 23           µg-m3          100.0                    100
# 24           µg-m3           38.0                    100
# 25           µg-m3          100.0                    100
# 26           µg-m3           96.0                    100
# 27           µg-m3          100.0                    100
#
#     couverture de données code qualité  validité   Latitude  Longitude  \
# 0                    96.0            R         1  46.823796  -0.135634
# 1                   100.0            R         1  46.823796  -0.135634
# 2                   100.0            R         1  45.014777  -0.533942
# 3                   100.0            R         1  46.135134  -1.117086
# 4                   100.0            A         1  44.900296  -0.515835
# 5                   100.0            R         1  43.310797  -0.391543
# 6                   100.0            R         1  45.158738   1.537259
# 7                   100.0            R         1  43.470237  -1.553876
# 8                   100.0            A         1  43.704643  -1.038557
# 9                   100.0            A         1  44.861210  -0.580370
# 10                  100.0            R         1  46.173620   1.873024
# 11                  100.0            A         1  45.805090   2.062333
# 12                  100.0            A         1  43.376279  -0.538206
# 13                  100.0            R         1  44.865810  -0.940000
# 14                  100.0            A         1  45.842204   1.259689
# 15                  100.0            A         1  46.586958   0.358458
# 16                   38.0            N        -1  43.888972  -0.507028
# 17                  100.0            A         1  46.320028  -0.482861
# 18                  100.0            A         1  45.873311   1.307916
# 19                  100.0            A         1  45.189825   0.727184
# 20                  100.0            R         1  46.583998   0.345582
# 21                  100.0            R         1  43.479820  -1.489157
# 22                  100.0            R         1  45.884851   0.898431
# 23                  100.0            A         1  45.647428   0.167162
# 24                   38.0            N        -1  44.800462  -0.589398
# 25                  100.0            A         1  45.262665   1.762752
# 26                   96.0            R         1  46.143234  -0.395913
# 27                  100.0            A         1  46.162647  -1.153684
#
#    SOMO35 Subscore
# 0             24.7
# 1              0.0
# 2              0.0
# 3              2.6
# 4              0.0
# 5              3.6
# 6              2.2
# 7              8.6
# 8              2.9
# 9              0.0
# 10             5.6
# 11             4.8
# 12            11.0
# 13             0.0
# 14             0.0
# 15             0.0
# 16             8.3
# 17             0.0
# 18             0.0
# 19             0.0
# 20             0.0
# 21             8.3
# 22             0.0
# 23             0.0
# 24             0.0
# 25             0.0
# 26             0.0
# 27             2.0
#
# [28 rows x 24 columns]
#                      nom site  SOMO35 Subscore_x                Organisme  \
# 0     AIRVAULT - Stade Laillé             3908.3  ATMO NOUVELLE-AQUITAINE
# 1                  AIRVAULT 3              745.3  ATMO NOUVELLE-AQUITAINE
# 2                       AMBES             5827.2  ATMO NOUVELLE-AQUITAINE
# 3                       Aytré             5484.4  ATMO NOUVELLE-AQUITAINE
# 4                     BASSENS             5575.9  ATMO NOUVELLE-AQUITAINE
# 5                     BILLERE             5871.6  ATMO NOUVELLE-AQUITAINE
# 6              BRIVE - Dalton             4727.4  ATMO NOUVELLE-AQUITAINE
# 7         Biarritz-hippodrome             5223.5  ATMO NOUVELLE-AQUITAINE
# 8                         DAX             4028.7  ATMO NOUVELLE-AQUITAINE
# 9                  GRAND PARC             5876.2  ATMO NOUVELLE-AQUITAINE
# 10           GUERET - Nicolas             5244.7  ATMO NOUVELLE-AQUITAINE
# 11         LA NOUAILLE - MERA             5501.2  ATMO NOUVELLE-AQUITAINE
# 12         LABASTIDE CEZERACQ             5279.5  ATMO NOUVELLE-AQUITAINE
# 13                  LE TEMPLE             5597.6  ATMO NOUVELLE-AQUITAINE
# 14          LIMOGES - BERLAND             4488.6  ATMO NOUVELLE-AQUITAINE
# 15           Les Couronneries             5487.6  ATMO NOUVELLE-AQUITAINE
# 16   MONT-DE-MARSAN - MIDOUZE             4349.1  ATMO NOUVELLE-AQUITAINE
# 17               Niort Venise             5378.8  ATMO NOUVELLE-AQUITAINE
# 18       PALAIS S/ V.- Garros             4353.4  ATMO NOUVELLE-AQUITAINE
# 19                  PERIGUEUX             5314.4  ATMO NOUVELLE-AQUITAINE
# 20  Poitiers Centre  Augouard             4319.2  ATMO NOUVELLE-AQUITAINE
# 21               SAINT-CROUTS             4947.0  ATMO NOUVELLE-AQUITAINE
# 22       ST JUNIEN - Fontaine             5583.5  ATMO NOUVELLE-AQUITAINE
# 23        Square Pablo Casals             4059.8  ATMO NOUVELLE-AQUITAINE
# 24                    TALENCE             5457.3  ATMO NOUVELLE-AQUITAINE
# 25               TULLE - Hugo             5249.5  ATMO NOUVELLE-AQUITAINE
# 26            Zoodyssée Chizé             4171.6  ATMO NOUVELLE-AQUITAINE
# 27            place de VERDUN             3724.0  ATMO NOUVELLE-AQUITAINE
#
#      code zas                    Zas code site     type d'implantation  \
# 0   FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304             Périurbaine
# 1   FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304             Périurbaine
# 2   FR75ZAG01           ZAG BORDEAUX   FR31010             Périurbaine
# 3   FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09008             Périurbaine
# 4   FR75ZAG01           ZAG BORDEAUX   FR31007                 Urbaine
# 5   FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31013                 Urbaine
# 6   FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR35004                 Urbaine
# 7   FR75ZAG02            ZAG BAYONNE   FR31043             Périurbaine
# 8   FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31036                 Urbaine
# 9   FR75ZAG01           ZAG BORDEAUX   FR31001                 Urbaine
# 10  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR35005                 Urbaine
# 11  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR35012        Rurale nationale
# 12  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31021  Rurale près des villes
# 13  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31008        Rurale régionale
# 14  FR75ZAR01            ZAR LIMOGES   FR35027                 Urbaine
# 15  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09015                 Urbaine
# 16  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31055                 Urbaine
# 17  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09303                 Urbaine
# 18  FR75ZAR01            ZAR LIMOGES   FR35007             Périurbaine
# 19  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31033                 Urbaine
# 20  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09404                 Urbaine
# 21  FR75ZAG02            ZAG BAYONNE   FR31016                 Urbaine
# 22  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR35002                 Urbaine
# 23  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103                 Urbaine
# 24  FR75ZAG01           ZAG BORDEAUX   FR31002                 Urbaine
# 25  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR35006                 Urbaine
# 26  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09302        Rurale régionale
# 27  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003                 Urbaine
#
#    Polluant type d'influence Réglementaire  ... valeur valeur brute  \
# 0        O3             Fond           Oui  ...   94.7       94.650
# 1        O3             Fond           Oui  ...   68.1       68.050
# 2        O3             Fond           Oui  ...   50.7       50.725
# 3        O3             Fond           Oui  ...   72.6       72.600
# 4        O3             Fond           Oui  ...   51.3       51.250
# 5        O3             Fond           Oui  ...   73.6       73.625
# 6        O3             Fond           Oui  ...   72.2       72.225
# 7        O3             Fond           Oui  ...   78.6       78.575
# 8        O3             Fond           Oui  ...   72.9       72.875
# 9        O3             Fond           Oui  ...   47.3       47.325
# 10       O3             Fond           Oui  ...   75.6       75.625
# 11       O3             Fond           Oui  ...   74.8       74.775
# 12       O3             Fond           Oui  ...   81.0       80.950
# 13       O3             Fond           Oui  ...   60.2       60.175
# 14       O3             Fond           Oui  ...   68.7       68.650
# 15       O3             Fond           Oui  ...   65.5       65.500
# 16       O3             Fond           Oui  ...   78.3       78.275
# 17       O3             Fond           Oui  ...   67.8       67.800
# 18       O3             Fond           Oui  ...   66.0       66.025
# 19       O3             Fond           Oui  ...   63.6       63.600
# 20       O3             Fond           Oui  ...   63.7       63.700
# 21       O3             Fond           Oui  ...   78.3       78.275
# 22       O3             Fond           Oui  ...   67.8       67.750
# 23       O3             Fond           Oui  ...   60.9       60.850
# 24       O3             Fond           Oui  ...   66.4       66.400
# 25       O3             Fond           Oui  ...   66.8       66.775
# 26       O3             Fond           Oui  ...   68.6       68.600
# 27       O3             Fond           Oui  ...   72.0       72.025
#
#     unité de mesure  taux de saisie couverture temporelle  \
# 0             µg-m3            96.0                   100
# 1             µg-m3           100.0                   100
# 2             µg-m3           100.0                   100
# 3             µg-m3           100.0                   100
# 4             µg-m3           100.0                   100
# 5             µg-m3           100.0                   100
# 6             µg-m3           100.0                   100
# 7             µg-m3           100.0                   100
# 8             µg-m3           100.0                   100
# 9             µg-m3           100.0                   100
# 10            µg-m3           100.0                   100
# 11            µg-m3           100.0                   100
# 12            µg-m3           100.0                   100
# 13            µg-m3           100.0                   100
# 14            µg-m3           100.0                   100
# 15            µg-m3           100.0                   100
# 16            µg-m3            38.0                   100
# 17            µg-m3           100.0                   100
# 18            µg-m3           100.0                   100
# 19            µg-m3           100.0                   100
# 20            µg-m3           100.0                   100
# 21            µg-m3           100.0                   100
# 22            µg-m3           100.0                   100
# 23            µg-m3           100.0                   100
# 24            µg-m3            38.0                   100
# 25            µg-m3           100.0                   100
# 26            µg-m3            96.0                   100
# 27            µg-m3           100.0                   100
#
#     couverture de données  code qualité  validité   Latitude  Longitude
# 0                    96.0             R         1  46.823796  -0.135634
# 1                   100.0             R         1  46.823796  -0.135634
# 2                   100.0             R         1  45.014777  -0.533942
# 3                   100.0             R         1  46.135134  -1.117086
# 4                   100.0             A         1  44.900296  -0.515835
# 5                   100.0             R         1  43.310797  -0.391543
# 6                   100.0             R         1  45.158738   1.537259
# 7                   100.0             R         1  43.470237  -1.553876
# 8                   100.0             A         1  43.704643  -1.038557
# 9                   100.0             A         1  44.861210  -0.580370
# 10                  100.0             R         1  46.173620   1.873024
# 11                  100.0             A         1  45.805090   2.062333
# 12                  100.0             A         1  43.376279  -0.538206
# 13                  100.0             R         1  44.865810  -0.940000
# 14                  100.0             A         1  45.842204   1.259689
# 15                  100.0             A         1  46.586958   0.358458
# 16                   38.0             N        -1  43.888972  -0.507028
# 17                  100.0             A         1  46.320028  -0.482861
# 18                  100.0             A         1  45.873311   1.307916
# 19                  100.0             A         1  45.189825   0.727184
# 20                  100.0             R         1  46.583998   0.345582
# 21                  100.0             R         1  43.479820  -1.489157
# 22                  100.0             R         1  45.884851   0.898431
# 23                  100.0             A         1  45.647428   0.167162
# 24                   38.0             N        -1  44.800462  -0.589398
# 25                  100.0             A         1  45.262665   1.762752
# 26                   96.0             R         1  46.143234  -0.395913
# 27                  100.0             A         1  46.162647  -1.153684
#
# [28 rows x 22 columns]

# %%
# Downloading the final dataframe of annual SOMO35 Score in ATMO NOUVELLE-AQUITAINE to csv
result.to_csv('df_SOMO35_ATMO_NA.csv', index=False, encoding = 'latin1')
