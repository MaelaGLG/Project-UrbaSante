# %%
# Code for extracting the daily ATMO score for each station in ATMO NOUVELLE-AQUITAINE (Région: NOUVELLE-AQUITAINE)

# Note: to use ATMO NA as an abbreviation

# %%
# Installing required packages
import pandas as pd

import os

# Base directory path
base_path = ".\data\1- Raw Data\Déterminant 1 - Qualité de l'air\"
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22268\2375524138.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# PM10 ATMO NOUVELLE-AQUITAINE

# File path to the data
PM10_ATMO_NA_file_path = os.path.join(base_path, "PM10 Moyenne Journalière\Export Moy. journalière - PM10 - ATMO NA.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM10 = pd.read_csv(PM10_ATMO_NA_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM10.head())

# Sample ATMO subscore dictionary for PM10 (Moyenne journalière)
ATMO_subscore_PM10 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 20.0), (20.0, 40.0), (40.0, 50.0), (50.0, 100.0), (100.0, 150.0), (150.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM10 = pd.DataFrame(ATMO_subscore_PM10)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM10['Range'] = ATMO_subscore_df_PM10['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM10 measurement
def assign_subscore_PM10(valeur):
    for index, row in ATMO_subscore_df_PM10.iterrows():  
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM10['ATMO sub-score'] = df_PM10['valeur'].apply(assign_subscore_PM10)  

# Display the updated DataFrame
print(df_PM10.head())
# Out:
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site             nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003      place de VERDUN
# 1  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09008                Aytré
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09015     Les Couronneries
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103  Square Pablo Casals
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09106   ANGOULEME-GAMBETTA
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Urbaine     PM10             Fond  ...   25.0    24.570833
# 1         Périurbaine     PM10             Fond  ...   22.0    22.083333
# 2             Urbaine     PM10             Fond  ...   14.0    14.000000
# 3             Urbaine     PM10             Fond  ...   15.0    15.229167
# 4             Urbaine     PM10           Trafic  ...   16.0    16.425000
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             A         1  46.162647 -1.153684
# 1                 100.0             A         1  46.135134 -1.117086
# 2                 100.0             A         1  46.586958  0.358458
# 3                 100.0             A         1  45.647428  0.167162
# 4                 100.0             A         1  45.651464  0.162391
#
# [5 rows x 23 columns]
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site             nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003      place de VERDUN
# 1  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09008                Aytré
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09015     Les Couronneries
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103  Square Pablo Casals
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09106   ANGOULEME-GAMBETTA
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Urbaine     PM10             Fond  ...    24.570833
# 1         Périurbaine     PM10             Fond  ...    22.083333
# 2             Urbaine     PM10             Fond  ...    14.000000
# 3             Urbaine     PM10             Fond  ...    15.229167
# 4             Urbaine     PM10           Trafic  ...    16.425000
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  46.162647  -1.153684
# 1                  100.0            A         1  46.135134  -1.117086
# 2                  100.0            A         1  46.586958   0.358458
# 3                  100.0            A         1  45.647428   0.167162
# 4                  100.0            A         1  45.651464   0.162391
#
#   ATMO sub-score
# 0            2.0
# 1            2.0
# 2            1.0
# 3            1.0
# 4            1.0
#
# [5 rows x 24 columns]

# %%
# PM2.5 ATMO NOUVELLE-AQUITAINE

# File path to the data
PM25_ATMO_NA_file_path = os.path.join(base_path, "PM2.5 Moyenne Journalière\Export Moy. journalière - PM2.5 - ATMO NA.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_PM25 = pd.read_csv(PM25_ATMO_NA_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_PM25.head())

# Sample ATMO subscore dictionary for PM2.5 (Moyenne journalière)
ATMO_subscore_PM25 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 10.0), (10.0, 20.0), (20.0, 25.0), (25.0, 50.0), (50.0, 75.0), (75.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_PM25 = pd.DataFrame(ATMO_subscore_PM25)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_PM25['Range'] = ATMO_subscore_df_PM25['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of PM2.5 measurement
def assign_subscore_PM25(valeur):
    for index, row in ATMO_subscore_df_PM25.iterrows(): 
        if valeur in row['Range']:
            return row['Subscore']
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column while ensuring the values in the 'valeur' column are recognised as numeric
df_PM25['ATMO sub-score'] = df_PM25['valeur'].apply(assign_subscore_PM25)  

# Display the updated DataFrame
print(df_PM25.head())
# Out:
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site             nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003      place de VERDUN
# 1  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103  Square Pablo Casals
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09203       La Pallice3 LR
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09302      Zoodyssée Chizé
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09303         Niort Venise
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Urbaine    PM2.5             Fond  ...    9.3     9.291667
# 1             Urbaine    PM2.5             Fond  ...    9.2     9.179167
# 2             Urbaine    PM2.5     Industrielle  ...    8.7     8.712500
# 3    Rurale régionale    PM2.5             Fond  ...    8.3     8.254167
# 4             Urbaine    PM2.5             Fond  ...    9.0     8.979167
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             A         1  46.162647 -1.153684
# 1                 100.0             A         1  45.647428  0.167162
# 2                 100.0             A         1  46.161632 -1.211229
# 3                 100.0             A         1  46.143234 -0.395913
# 4                 100.0             A         1  46.320028 -0.482861
#
# [5 rows x 23 columns]
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site             nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003      place de VERDUN
# 1  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103  Square Pablo Casals
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09203       La Pallice3 LR
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09302      Zoodyssée Chizé
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09303         Niort Venise
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Urbaine    PM2.5             Fond  ...     9.291667
# 1             Urbaine    PM2.5             Fond  ...     9.179167
# 2             Urbaine    PM2.5     Industrielle  ...     8.712500
# 3    Rurale régionale    PM2.5             Fond  ...     8.254167
# 4             Urbaine    PM2.5             Fond  ...     8.979167
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  46.162647  -1.153684
# 1                  100.0            A         1  45.647428   0.167162
# 2                  100.0            A         1  46.161632  -1.211229
# 3                  100.0            A         1  46.143234  -0.395913
# 4                  100.0            A         1  46.320028  -0.482861
#
#   ATMO sub-score
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
#
# [5 rows x 24 columns]

# %%
# NO2 ATMO NOUVELLE-AQUITAINE

# File path to the data
NO2_ATMO_NA_file_path = os.path.join(base_path, "NO2 Max Horaire Journalier\Export Max. journalier moy. hor. - NO2 - ATMO NA.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_NO2 = pd.read_csv(NO2_ATMO_NA_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_NO2.head())

# Sample ATMO subscore dictionary for NO2 (Max horaire journalier)
ATMO_subscore_NO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 40.0), (40.0, 90.0), (90.0, 120.0), (120.0, 230.0), (230.0, 340.0), (340.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_NO2 = pd.DataFrame(ATMO_subscore_NO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_NO2['Range'] = ATMO_subscore_df_NO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of NO2 measurement
def assign_subscore_NO2(valeur):
    for index, row in ATMO_subscore_df_NO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_NO2['ATMO sub-score'] = df_NO2['valeur'].apply(assign_subscore_NO2)

# Display the updated DataFrame
print(df_NO2.head())
# Out:
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site             nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003      place de VERDUN
# 1  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09008                Aytré
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09015     Les Couronneries
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103  Square Pablo Casals
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09106   ANGOULEME-GAMBETTA
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Urbaine      NO2             Fond  ...    7.6        7.625
# 1         Périurbaine      NO2             Fond  ...    4.4        4.350
# 2             Urbaine      NO2             Fond  ...    2.8        2.750
# 3             Urbaine      NO2             Fond  ...    5.7        5.675
# 4             Urbaine      NO2           Trafic  ...   11.9       11.925
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             A         1  46.162647 -1.153684
# 1                 100.0             A         1  46.135134 -1.117086
# 2                 100.0             A         1  46.586958  0.358458
# 3                 100.0             R         1  45.647428  0.167162
# 4                 100.0             A         1  45.651464  0.162391
#
# [5 rows x 23 columns]
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site             nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003      place de VERDUN
# 1  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09008                Aytré
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09015     Les Couronneries
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103  Square Pablo Casals
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09106   ANGOULEME-GAMBETTA
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Urbaine      NO2             Fond  ...        7.625
# 1         Périurbaine      NO2             Fond  ...        4.350
# 2             Urbaine      NO2             Fond  ...        2.750
# 3             Urbaine      NO2             Fond  ...        5.675
# 4             Urbaine      NO2           Trafic  ...       11.925
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  46.162647  -1.153684
# 1                  100.0            A         1  46.135134  -1.117086
# 2                  100.0            A         1  46.586958   0.358458
# 3                  100.0            R         1  45.647428   0.167162
# 4                  100.0            A         1  45.651464   0.162391
#
#   ATMO sub-score
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
#
# [5 rows x 24 columns]

# %%
# O3 ATMO NOUVELLE-AQUITAINE

# File path to the data
O3_ATMO_NA_file_path = os.path.join(base_path, "O3 Max Horaire Journalier\Export Max. journalier moy. hor. - O3 - ATMO NA.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_O3 = pd.read_csv(O3_ATMO_NA_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_O3.head())

# Sample ATMO subscore dictionary for O3 (Max horaire journalier)
ATMO_subscore_O3 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 50.0), (50.0, 100.0), (100.0, 130.0), (130.0, 240.0), (240.0, 380.0), (380.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_O3 = pd.DataFrame(ATMO_subscore_O3)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_O3['Range'] = ATMO_subscore_df_O3['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of O3 measurement
def assign_subscore_O3(valeur):
    for index, row in ATMO_subscore_df_O3.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_O3['ATMO sub-score'] = df_O3['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_O3.head())
# Out:
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site             nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003      place de VERDUN
# 1  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09008                Aytré
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09015     Les Couronneries
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103  Square Pablo Casals
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09302      Zoodyssée Chizé
#
#   type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Urbaine       O3             Fond  ...   72.0       72.025
# 1         Périurbaine       O3             Fond  ...   72.6       72.600
# 2             Urbaine       O3             Fond  ...   65.5       65.500
# 3             Urbaine       O3             Fond  ...   60.9       60.850
# 4    Rurale régionale       O3             Fond  ...   68.6       68.600
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3           100.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3            96.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             A         1  46.162647 -1.153684
# 1                 100.0             R         1  46.135134 -1.117086
# 2                 100.0             A         1  46.586958  0.358458
# 3                 100.0             A         1  45.647428  0.167162
# 4                  96.0             R         1  46.143234 -0.395913
#
# [5 rows x 23 columns]
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site             nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003      place de VERDUN
# 1  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09008                Aytré
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09015     Les Couronneries
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103  Square Pablo Casals
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09302      Zoodyssée Chizé
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Urbaine       O3             Fond  ...       72.025
# 1         Périurbaine       O3             Fond  ...       72.600
# 2             Urbaine       O3             Fond  ...       65.500
# 3             Urbaine       O3             Fond  ...       60.850
# 4    Rurale régionale       O3             Fond  ...       68.600
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3           96.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  46.162647  -1.153684
# 1                  100.0            R         1  46.135134  -1.117086
# 2                  100.0            A         1  46.586958   0.358458
# 3                  100.0            A         1  45.647428   0.167162
# 4                   96.0            R         1  46.143234  -0.395913
#
#   ATMO sub-score
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2
#
# [5 rows x 24 columns]

# %%
# SO2 ATMO NOUVELLE-AQUITAINE

# File path to the data
SO2_ATMO_NA_file_path = os.path.join(base_path, "SO2 Max Horaire Journalier\Export Max. journalier moy. hor. - SO2 - ATMO NA.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_SO2 = pd.read_csv(SO2_ATMO_NA_file_path, delimiter=';')

# Display the first few rows of the DataFrame
print(df_SO2.head())

# Sample ATMO subscore dictionary for SO2 (Max horaire journalier)
ATMO_subscore_SO2 = {
    'Subscore': [1, 2, 3, 4, 5, 6],
    'Range': [(0.0, 100.0), (100.0, 200.0), (200.0, 350.0), (350.0, 500.0), (500.0, 750.0), (750.0,10000.0)]
}

# Convert the ATMO_subscore dictionary to a DataFrame
ATMO_subscore_df_SO2 = pd.DataFrame(ATMO_subscore_SO2)

# Convert the range tuples to ranges of numbers for easy comparison
ATMO_subscore_df_SO2['Range'] = ATMO_subscore_df_SO2['Range'].apply(lambda x: [round(i / 10, 1) for i in range(int(x[0] * 10), int(x[1] * 10) + 1)])

# Function to assign subscore based on value of SO2 measurement
def assign_subscore_SO2(valeur):
    for index, row in ATMO_subscore_df_SO2.iterrows():  # Corrected variable name
        if valeur in row['Range']:
            return int(row['Subscore'])
    return None  # Return None if no matching subscore found

# Apply the function to fill in the Subscore column
df_SO2['ATMO sub-score'] = df_SO2['valeur'].apply(assign_subscore_O3)

# Display the updated DataFrame
print(df_SO2.head())
# Out:
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site            nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304          AIRVAULT 3
# 1  FR75ZAG01           ZAG BORDEAUX   FR31007             BASSENS
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31020                LACQ
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31021  LABASTIDE CEZERACQ
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31022               LAGOR
#
#       type d'implantation Polluant type d'influence  ... valeur valeur brute  \
# 0             Périurbaine      SO2     Industrielle  ...   80.7       80.675
# 1                 Urbaine      SO2     Industrielle  ...    0.4        0.350
# 2  Rurale près des villes      SO2     Industrielle  ...    6.7        6.675
# 3  Rurale près des villes      SO2     Industrielle  ...    3.2        3.150
# 4  Rurale près des villes      SO2     Industrielle  ...   67.5       67.500
#
#   unité de mesure  taux de saisie  couverture temporelle  \
# 0           µg-m3           100.0                    100
# 1           µg-m3            96.0                    100
# 2           µg-m3           100.0                    100
# 3           µg-m3           100.0                    100
# 4           µg-m3           100.0                    100
#
#   couverture de données  code qualité  validité   Latitude Longitude
# 0                 100.0             R         1  46.823796 -0.135634
# 1                  96.0             R         1  44.900296 -0.515835
# 2                 100.0             R         1  43.411230 -0.617728
# 3                 100.0             R         1  43.376279 -0.538206
# 4                 100.0             R         1  43.409857 -0.673155
#
# [5 rows x 23 columns]
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site            nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304          AIRVAULT 3
# 1  FR75ZAG01           ZAG BORDEAUX   FR31007             BASSENS
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31020                LACQ
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31021  LABASTIDE CEZERACQ
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR31022               LAGOR
#
#       type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Périurbaine      SO2     Industrielle  ...       80.675
# 1                 Urbaine      SO2     Industrielle  ...        0.350
# 2  Rurale près des villes      SO2     Industrielle  ...        6.675
# 3  Rurale près des villes      SO2     Industrielle  ...        3.150
# 4  Rurale près des villes      SO2     Industrielle  ...       67.500
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3           96.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            R         1  46.823796  -0.135634
# 1                   96.0            R         1  44.900296  -0.515835
# 2                  100.0            R         1  43.411230  -0.617728
# 3                  100.0            R         1  43.376279  -0.538206
# 4                  100.0            R         1  43.409857  -0.673155
#
#   ATMO sub-score
# 0            2.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            2.0
#
# [5 rows x 24 columns]

# %%
# Combining 5 (if not missing) dataframes
# Concatenate DataFrames along the rows (stack them vertically)
combined_df_ATMO_NA = pd.concat([df_PM10, df_PM25, df_NO2, df_O3, df_SO2], axis=0) #

# If you want to reset the index of the combined DataFrame
combined_df_ATMO_NA.reset_index(drop=True, inplace=True)

# Renaming the ATMO subscore column to 'ATMO Score'
combined_df_ATMO_NA = combined_df_ATMO_NA.rename(columns={'ATMO sub-score': 'ATMO Score'})

# Printing the first five rows as a sanity check
print(combined_df_ATMO_NA.head())
# Out:
#          Date de début          Date de fin                Organisme  \
# 0  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/01/01 00:00:00  2023/01/01 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site             nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003      place de VERDUN
# 1  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09008                Aytré
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09015     Les Couronneries
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09103  Square Pablo Casals
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09106   ANGOULEME-GAMBETTA
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0             Urbaine     PM10             Fond  ...    24.570833
# 1         Périurbaine     PM10             Fond  ...    22.083333
# 2             Urbaine     PM10             Fond  ...    14.000000
# 3             Urbaine     PM10             Fond  ...    15.229167
# 4             Urbaine     PM10           Trafic  ...    16.425000
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3          100.0                    100
# 1           µg-m3          100.0                    100
# 2           µg-m3          100.0                    100
# 3           µg-m3          100.0                    100
# 4           µg-m3          100.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                  100.0            A         1  46.162647  -1.153684
# 1                  100.0            A         1  46.135134  -1.117086
# 2                  100.0            A         1  46.586958   0.358458
# 3                  100.0            A         1  45.647428   0.167162
# 4                  100.0            A         1  45.651464   0.162391
#
#   ATMO Score
# 0        2.0
# 1        2.0
# 2        1.0
# 3        1.0
# 4        1.0
#
# [5 rows x 24 columns]

# %%
# Find the index of rows with maximum 'ATMO Score' within each group
idx_max_scores = combined_df_ATMO_NA.groupby(['nom site', 'Date de fin'])['ATMO Score'].idxmax()

# Select rows with the maximum 'ATMO Score' using the index
final_df_ATMO_NA = combined_df_ATMO_NA.loc[idx_max_scores]

# Reset index if needed
final_df_ATMO_NA.reset_index(drop=True, inplace=True)

# %%
# Downloading the final dataframe of Daily ATMO Score in ATMO NA to csv
final_df_ATMO_NA.to_csv('final_df_ATMO_NA.csv', index=False, encoding = 'latin1')

# %%
# Constructing indicator for ATMO NOUVELLE-AQUITAINE

# File path to the data
ATMO_NA_file_path = os.path.join(base_path, "final_df_ATMO_NA.csv")

# Use read_csv function from pandas specifying the delimiter as ';'
df_ATMO = pd.read_csv(ATMO_NA_file_path, delimiter=',', encoding = 'latin1')

print(df_ATMO.head())

counts = df_ATMO.groupby('nom site')['ATMO Score'].value_counts().reset_index(name='counts')
#print(counts)

#result = pd.merge(counts, df_ATMO[["Organisme", "type d'implantation", "Latitude", "Longitude"]], on='nom site', how='left')
#print(result)

# Getting a df of the site-specific information e.g., code, latitude, longitude
first_row_per_nom_site = df_ATMO.groupby('nom site').first().reset_index()
#print(first_row_per_nom_site)

# Merge the site-specific information with the counts DataFrame
result = pd.merge(counts, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score_y'], axis = 1)
print(result)
# Out:
#          Date de début          Date de fin                Organisme  \
# 0  2023/04/12 00:00:00  2023/04/12 23:59:59  ATMO NOUVELLE-AQUITAINE
# 1  2023/04/13 00:00:00  2023/04/13 23:59:59  ATMO NOUVELLE-AQUITAINE
# 2  2023/04/14 00:00:00  2023/04/14 23:59:59  ATMO NOUVELLE-AQUITAINE
# 3  2023/04/15 00:00:00  2023/04/15 23:59:59  ATMO NOUVELLE-AQUITAINE
# 4  2023/04/16 00:00:00  2023/04/16 23:59:59  ATMO NOUVELLE-AQUITAINE
#
#     code zas                    Zas code site                 nom site  \
# 0  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304  AIRVAULT - Stade Laillé
# 1  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304  AIRVAULT - Stade Laillé
# 2  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304  AIRVAULT - Stade Laillé
# 3  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304  AIRVAULT - Stade Laillé
# 4  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304  AIRVAULT - Stade Laillé
#
#   type d'implantation Polluant type d'influence  ... valeur brute  \
# 0         Périurbaine       O3             Fond  ...       94.650
# 1         Périurbaine       O3             Fond  ...       88.700
# 2         Périurbaine       O3             Fond  ...       82.975
# 3         Périurbaine       O3             Fond  ...       94.000
# 4         Périurbaine       O3             Fond  ...      100.025
#
#   unité de mesure taux de saisie  couverture temporelle  \
# 0           µg-m3           96.0                    100
# 1           µg-m3           83.0                    100
# 2           µg-m3           96.0                    100
# 3           µg-m3           96.0                    100
# 4           µg-m3           96.0                    100
#
#    couverture de données code qualité  validité   Latitude  Longitude  \
# 0                   96.0            R         1  46.823796  -0.135634
# 1                   83.0            R         1  46.823796  -0.135634
# 2                   96.0            R         1  46.823796  -0.135634
# 3                   96.0            R         1  46.823796  -0.135634
# 4                   96.0            R         1  46.823796  -0.135634
#
#   ATMO Score
# 0        2.0
# 1        2.0
# 2        2.0
# 3        2.0
# 4        2.0
#
# [5 rows x 24 columns]
#                     nom site  ATMO Score_x  counts                Organisme  \
# 0    AIRVAULT - Stade Laillé           2.0     212  ATMO NOUVELLE-AQUITAINE
# 1    AIRVAULT - Stade Laillé           3.0      30  ATMO NOUVELLE-AQUITAINE
# 2    AIRVAULT - Stade Laillé           4.0      10  ATMO NOUVELLE-AQUITAINE
# 3    AIRVAULT - Stade Laillé           1.0       9  ATMO NOUVELLE-AQUITAINE
# 4                 AIRVAULT 3           2.0      93  ATMO NOUVELLE-AQUITAINE
# ..                       ...           ...     ...                      ...
# 193          Zoodyssée Chizé           5.0       1  ATMO NOUVELLE-AQUITAINE
# 194          place de VERDUN           2.0     373  ATMO NOUVELLE-AQUITAINE
# 195          place de VERDUN           3.0      34  ATMO NOUVELLE-AQUITAINE
# 196          place de VERDUN           4.0       9  ATMO NOUVELLE-AQUITAINE
# 197          place de VERDUN           1.0       6  ATMO NOUVELLE-AQUITAINE
#
#       code zas                    Zas code site type d'implantation Polluant  \
# 0    FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304         Périurbaine       O3
# 1    FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304         Périurbaine       O3
# 2    FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304         Périurbaine       O3
# 3    FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304         Périurbaine       O3
# 4    FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09304         Périurbaine      NO2
# ..         ...                    ...       ...                 ...      ...
# 193  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09302    Rurale régionale       O3
# 194  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003             Urbaine     PM10
# 195  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003             Urbaine     PM10
# 196  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003             Urbaine     PM10
# 197  FR75ZRE02  ZR NOUVELLE-AQUITAINE   FR09003             Urbaine     PM10
#
#     type d'influence  ... valeur valeur brute unité de mesure  taux de saisie  \
# 0               Fond  ...   94.7    94.650000           µg-m3            96.0
# 1               Fond  ...   94.7    94.650000           µg-m3            96.0
# 2               Fond  ...   94.7    94.650000           µg-m3            96.0
# 3               Fond  ...   94.7    94.650000           µg-m3            96.0
# 4               Fond  ...   48.9    48.875000           µg-m3           100.0
# ..               ...  ...    ...          ...             ...             ...
# 193             Fond  ...   68.6    68.600000           µg-m3            96.0
# 194             Fond  ...   25.0    24.570833           µg-m3           100.0
# 195             Fond  ...   25.0    24.570833           µg-m3           100.0
# 196             Fond  ...   25.0    24.570833           µg-m3           100.0
# 197             Fond  ...   25.0    24.570833           µg-m3           100.0
#
#      couverture temporelle couverture de données  code qualité  validité  \
# 0                      100                  96.0             R         1
# 1                      100                  96.0             R         1
# 2                      100                  96.0             R         1
# 3                      100                  96.0             R         1
# 4                      100                 100.0             A         1
# ..                     ...                   ...           ...       ...
# 193                    100                  96.0             R         1
# 194                    100                 100.0             A         1
# 195                    100                 100.0             A         1
# 196                    100                 100.0             A         1
# 197                    100                 100.0             A         1
#
#       Latitude Longitude
# 0    46.823796 -0.135634
# 1    46.823796 -0.135634
# 2    46.823796 -0.135634
# 3    46.823796 -0.135634
# 4    46.823796 -0.135634
# ..         ...       ...
# 193  46.143234 -0.395913
# 194  46.162647 -1.153684
# 195  46.162647 -1.153684
# 196  46.162647 -1.153684
# 197  46.162647 -1.153684
#
# [198 rows x 23 columns]

# %%
# Group the DataFrame by 'nom' and calculate the total counts for each 'nom'
total_counts_by_nom = result.groupby('nom site')['counts'].sum()

# Filter the DataFrame to include only rows where the score is equal to or greater than 3
filtered_result = result[result['ATMO Score_x'] >= 3]

# Group the filtered DataFrame by 'nom' and calculate the counts equal to or greater than 3 for each 'nom'
counts_greater_than_3_by_nom = filtered_result.groupby('nom site')['counts'].sum()

# Calculate the ratio of counts greater than or equal to 3 over total counts for each 'nom'
ratio_counts_greater_than_3 = (counts_greater_than_3_by_nom / total_counts_by_nom).fillna(0)

# Display the resulting Series
print(ratio_counts_greater_than_3)

# Merge the site-specific information with the counts DataFrame
ratio_counts_greater_than_3_df = pd.merge(ratio_counts_greater_than_3, first_row_per_nom_site, on='nom site', how = 'inner').drop(['Date de fin', 'Date de début', 'ATMO Score'], axis = 1)
ratio_counts_greater_than_3_df = ratio_counts_greater_than_3_df.rename(columns={'counts': 'indicator'})
print(ratio_counts_greater_than_3_df)
# Out:
# nom site
# AIRVAULT - Stade Laillé      0.153257
# AIRVAULT 3                   0.030612
# AMBES                        0.197802
# ANGLET                       0.071233
# ANGOULEME-GAMBETTA           0.095890
# Aytré                        0.167123
# BASSENS                      0.241096
# BILLERE                      0.238356
# BORDEAUX-BASTIDE             0.046575
# BRIVE - Dalton               0.153425
# Biarritz-hippodrome          0.172603
# Bordeaux_GAUTIER             0.093151
# DAX                          0.231579
# GRAND PARC                   0.210959
# GUERET - Nicolas             0.156164
# LA NOUAILLE - MERA           0.148368
# LABASTIDE CEZERACQ           0.161644
# LACQ                         0.085165
# LAGOR                        0.032070
# LE TEMPLE                    0.184066
# LIMOGES - Aine               0.057534
# LIMOGES - BERLAND            0.167123
# La Pallice3 LR               0.048338
# Les Couronneries             0.158904
# MARMANDE                     0.049133
# MASLACQ                      0.067485
# MERIGNAC                     0.030137
# MONT DE MARSAN               0.032895
# MONT-DE-MARSAN - MIDOUZE     0.170807
# MOURENX                      0.008219
# Niort - Tassigny             0.044568
# Niort Venise                 0.219178
# PALAIS S/ V.- Garros         0.134247
# PAU TOURASSE                 0.054795
# PERIGUEUX                    0.228650
# Poitiers Centre  Augouard    0.164384
# Poitiers-Le Nain             0.077562
# SAILLAT - Ipaper             0.013699
# SAINT-CROUTS                 0.134247
# ST JUNIEN - Fontaine         0.180822
# Square Pablo Casals          0.158904
# TALENCE                      0.255495
# TARTAS Pelletrin             0.010959
# TULLE - Hugo                 0.145205
# Zoodyssée Chizé              0.142466
# place de VERDUN              0.101896
# Name: counts, dtype: float64
#                      nom site  indicator                Organisme   code zas  \
# 0     AIRVAULT - Stade Laillé   0.153257  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 1                  AIRVAULT 3   0.030612  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 2                       AMBES   0.197802  ATMO NOUVELLE-AQUITAINE  FR75ZAG01
# 3                      ANGLET   0.071233  ATMO NOUVELLE-AQUITAINE  FR75ZAG02
# 4          ANGOULEME-GAMBETTA   0.095890  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 5                       Aytré   0.167123  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 6                     BASSENS   0.241096  ATMO NOUVELLE-AQUITAINE  FR75ZAG01
# 7                     BILLERE   0.238356  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 8            BORDEAUX-BASTIDE   0.046575  ATMO NOUVELLE-AQUITAINE  FR75ZAG01
# 9              BRIVE - Dalton   0.153425  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 10        Biarritz-hippodrome   0.172603  ATMO NOUVELLE-AQUITAINE  FR75ZAG02
# 11           Bordeaux_GAUTIER   0.093151  ATMO NOUVELLE-AQUITAINE  FR75ZAG01
# 12                        DAX   0.231579  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 13                 GRAND PARC   0.210959  ATMO NOUVELLE-AQUITAINE  FR75ZAG01
# 14           GUERET - Nicolas   0.156164  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 15         LA NOUAILLE - MERA   0.148368  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 16         LABASTIDE CEZERACQ   0.161644  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 17                       LACQ   0.085165  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 18                      LAGOR   0.032070  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 19                  LE TEMPLE   0.184066  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 20             LIMOGES - Aine   0.057534  ATMO NOUVELLE-AQUITAINE  FR75ZAR01
# 21          LIMOGES - BERLAND   0.167123  ATMO NOUVELLE-AQUITAINE  FR75ZAR01
# 22             La Pallice3 LR   0.048338  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 23           Les Couronneries   0.158904  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 24                   MARMANDE   0.049133  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 25                    MASLACQ   0.067485  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 26                   MERIGNAC   0.030137  ATMO NOUVELLE-AQUITAINE  FR75ZAG01
# 27             MONT DE MARSAN   0.032895  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 28   MONT-DE-MARSAN - MIDOUZE   0.170807  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 29                    MOURENX   0.008219  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 30           Niort - Tassigny   0.044568  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 31               Niort Venise   0.219178  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 32       PALAIS S/ V.- Garros   0.134247  ATMO NOUVELLE-AQUITAINE  FR75ZAR01
# 33               PAU TOURASSE   0.054795  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 34                  PERIGUEUX   0.228650  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 35  Poitiers Centre  Augouard   0.164384  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 36           Poitiers-Le Nain   0.077562  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 37           SAILLAT - Ipaper   0.013699  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 38               SAINT-CROUTS   0.134247  ATMO NOUVELLE-AQUITAINE  FR75ZAG02
# 39       ST JUNIEN - Fontaine   0.180822  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 40        Square Pablo Casals   0.158904  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 41                    TALENCE   0.255495  ATMO NOUVELLE-AQUITAINE  FR75ZAG01
# 42           TARTAS Pelletrin   0.010959  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 43               TULLE - Hugo   0.145205  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 44            Zoodyssée Chizé   0.142466  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
# 45            place de VERDUN   0.101896  ATMO NOUVELLE-AQUITAINE  FR75ZRE02
#
#                       Zas code site     type d'implantation Polluant  \
# 0   ZR NOUVELLE-AQUITAINE   FR09304             Périurbaine       O3
# 1   ZR NOUVELLE-AQUITAINE   FR09304             Périurbaine      NO2
# 2            ZAG BORDEAUX   FR31010             Périurbaine       O3
# 3             ZAG BAYONNE   FR31017                 Urbaine     PM10
# 4   ZR NOUVELLE-AQUITAINE   FR09106                 Urbaine     PM10
# 5   ZR NOUVELLE-AQUITAINE   FR09008             Périurbaine     PM10
# 6            ZAG BORDEAUX   FR31007                 Urbaine       O3
# 7   ZR NOUVELLE-AQUITAINE   FR31013                 Urbaine    PM2.5
# 8            ZAG BORDEAUX   FR31003                 Urbaine     PM10
# 9   ZR NOUVELLE-AQUITAINE   FR35004                 Urbaine       O3
# 10            ZAG BAYONNE   FR31043             Périurbaine       O3
# 11           ZAG BORDEAUX   FR31045                 Urbaine     PM10
# 12  ZR NOUVELLE-AQUITAINE   FR31036                 Urbaine       O3
# 13           ZAG BORDEAUX   FR31001                 Urbaine     PM10
# 14  ZR NOUVELLE-AQUITAINE   FR35005                 Urbaine       O3
# 15  ZR NOUVELLE-AQUITAINE   FR35012        Rurale nationale       O3
# 16  ZR NOUVELLE-AQUITAINE   FR31021  Rurale près des villes       O3
# 17  ZR NOUVELLE-AQUITAINE   FR31020  Rurale près des villes      NO2
# 18  ZR NOUVELLE-AQUITAINE   FR31022  Rurale près des villes      SO2
# 19  ZR NOUVELLE-AQUITAINE   FR31008        Rurale régionale       O3
# 20            ZAR LIMOGES   FR35010                 Urbaine     PM10
# 21            ZAR LIMOGES   FR35027                 Urbaine       O3
# 22  ZR NOUVELLE-AQUITAINE   FR09203                 Urbaine     PM10
# 23  ZR NOUVELLE-AQUITAINE   FR09015                 Urbaine       O3
# 24  ZR NOUVELLE-AQUITAINE   FR31040             Périurbaine     PM10
# 25  ZR NOUVELLE-AQUITAINE   FR31023  Rurale près des villes      SO2
# 26           ZAG BORDEAUX   FR31006                 Urbaine     PM10
# 27  ZR NOUVELLE-AQUITAINE   FR31041                 Urbaine     PM10
# 28  ZR NOUVELLE-AQUITAINE   FR31055                 Urbaine      NO2
# 29  ZR NOUVELLE-AQUITAINE   FR31024  Rurale près des villes      NO2
# 30  ZR NOUVELLE-AQUITAINE   FR09305                 Urbaine     PM10
# 31  ZR NOUVELLE-AQUITAINE   FR09303                 Urbaine       O3
# 32            ZAR LIMOGES   FR35007             Périurbaine       O3
# 33  ZR NOUVELLE-AQUITAINE   FR31039                 Urbaine     PM10
# 34  ZR NOUVELLE-AQUITAINE   FR31033                 Urbaine       O3
# 35  ZR NOUVELLE-AQUITAINE   FR09404                 Urbaine       O3
# 36  ZR NOUVELLE-AQUITAINE   FR09403                 Urbaine     PM10
# 37  ZR NOUVELLE-AQUITAINE   FR35019  Rurale près des villes     PM10
# 38            ZAG BAYONNE   FR31016                 Urbaine       O3
# 39  ZR NOUVELLE-AQUITAINE   FR35002                 Urbaine       O3
# 40  ZR NOUVELLE-AQUITAINE   FR09103                 Urbaine       O3
# 41           ZAG BORDEAUX   FR31002                 Urbaine    PM2.5
# 42  ZR NOUVELLE-AQUITAINE   FR31026             Périurbaine     PM10
# 43  ZR NOUVELLE-AQUITAINE   FR35006                 Urbaine       O3
# 44  ZR NOUVELLE-AQUITAINE   FR09302        Rurale régionale       O3
# 45  ZR NOUVELLE-AQUITAINE   FR09003                 Urbaine     PM10
#
#    type d'influence Réglementaire  ... valeur valeur brute  unité de mesure  \
# 0              Fond           Oui  ...   94.7    94.650000            µg-m3
# 1              Fond           Oui  ...   48.9    48.875000            µg-m3
# 2              Fond           Oui  ...   50.7    50.725000            µg-m3
# 3            Trafic           Oui  ...   13.0    13.250000            µg-m3
# 4            Trafic           Oui  ...   16.0    16.425000            µg-m3
# 5              Fond           Oui  ...   22.0    22.083333            µg-m3
# 6              Fond           Oui  ...   51.3    51.250000            µg-m3
# 7              Fond           Oui  ...   11.0    10.762500            µg-m3
# 8            Trafic           Oui  ...   17.0    17.116667            µg-m3
# 9              Fond           Oui  ...   72.2    72.225000            µg-m3
# 10             Fond           Oui  ...   78.6    78.575000            µg-m3
# 11           Trafic           Oui  ...   22.0    22.058333            µg-m3
# 12             Fond           Oui  ...   72.9    72.875000            µg-m3
# 13             Fond           Oui  ...   17.0    17.458333            µg-m3
# 14             Fond           Oui  ...   75.6    75.625000            µg-m3
# 15             Fond           Oui  ...   74.8    74.775000            µg-m3
# 16             Fond           Oui  ...   81.0    80.950000            µg-m3
# 17     Industrielle           Oui  ...   19.6    19.550000            µg-m3
# 18     Industrielle           Oui  ...   67.5    67.500000            µg-m3
# 19             Fond           Oui  ...   60.2    60.175000            µg-m3
# 20           Trafic           Oui  ...   15.0    14.508333            µg-m3
# 21             Fond           Oui  ...   68.7    68.650000            µg-m3
# 22     Industrielle           Oui  ...   24.0    24.395833            µg-m3
# 23             Fond           Oui  ...   65.5    65.500000            µg-m3
# 24           Trafic           Oui  ...   21.0    20.741667            µg-m3
# 25     Industrielle           Oui  ...   70.5    70.525000            µg-m3
# 26           Trafic           Oui  ...   13.0    13.420833            µg-m3
# 27           Trafic           Oui  ...   15.0    14.870833            µg-m3
# 28             Fond           Oui  ...   61.6    61.625000            µg-m3
# 29     Industrielle           Oui  ...   10.8    10.800000            µg-m3
# 30           Trafic           Oui  ...   19.0    19.154167            µg-m3
# 31             Fond           Oui  ...   67.8    67.800000            µg-m3
# 32             Fond           Oui  ...   66.0    66.025000            µg-m3
# 33           Trafic           Oui  ...   22.0    21.516667            µg-m3
# 34             Fond           Oui  ...   63.6    63.600000            µg-m3
# 35             Fond           Oui  ...   63.7    63.700000            µg-m3
# 36           Trafic           Oui  ...   18.0    17.979167            µg-m3
# 37     Industrielle           Oui  ...   15.0    15.195833            µg-m3
# 38             Fond           Oui  ...   78.3    78.275000            µg-m3
# 39             Fond           Oui  ...   67.8    67.750000            µg-m3
# 40             Fond           Oui  ...   60.9    60.850000            µg-m3
# 41             Fond           Oui  ...   14.0    13.630000            µg-m3
# 42     Industrielle           Oui  ...   14.0    13.575000            µg-m3
# 43             Fond           Oui  ...   66.8    66.775000            µg-m3
# 44             Fond           Oui  ...   68.6    68.600000            µg-m3
# 45             Fond           Oui  ...   25.0    24.570833            µg-m3
#
#     taux de saisie couverture temporelle  couverture de données  code qualité  \
# 0             96.0                   100                   96.0             R
# 1            100.0                   100                  100.0             A
# 2            100.0                   100                  100.0             R
# 3            100.0                   100                  100.0             A
# 4            100.0                   100                  100.0             A
# 5            100.0                   100                  100.0             A
# 6            100.0                   100                  100.0             A
# 7            100.0                   100                  100.0             A
# 8            100.0                   100                  100.0             A
# 9            100.0                   100                  100.0             R
# 10           100.0                   100                  100.0             R
# 11           100.0                   100                  100.0             A
# 12           100.0                   100                  100.0             A
# 13           100.0                   100                  100.0             A
# 14           100.0                   100                  100.0             R
# 15           100.0                   100                  100.0             A
# 16           100.0                   100                  100.0             A
# 17           100.0                   100                  100.0             R
# 18           100.0                   100                  100.0             R
# 19           100.0                   100                  100.0             R
# 20           100.0                   100                  100.0             A
# 21           100.0                   100                  100.0             A
# 22           100.0                   100                  100.0             A
# 23           100.0                   100                  100.0             A
# 24           100.0                   100                  100.0             A
# 25            96.0                   100                   96.0             R
# 26           100.0                   100                  100.0             A
# 27           100.0                   100                  100.0             A
# 28            38.0                   100                   38.0             N
# 29            96.0                   100                   96.0             R
# 30           100.0                   100                  100.0             A
# 31           100.0                   100                  100.0             A
# 32           100.0                   100                  100.0             A
# 33           100.0                   100                  100.0             A
# 34           100.0                   100                  100.0             A
# 35           100.0                   100                  100.0             R
# 36           100.0                   100                  100.0             A
# 37           100.0                   100                  100.0             A
# 38           100.0                   100                  100.0             R
# 39           100.0                   100                  100.0             R
# 40           100.0                   100                  100.0             A
# 41            42.0                   100                   42.0             N
# 42           100.0                   100                  100.0             A
# 43           100.0                   100                  100.0             A
# 44            96.0                   100                   96.0             R
# 45           100.0                   100                  100.0             A
#
#     validité   Latitude  Longitude
# 0          1  46.823796  -0.135634
# 1          1  46.823796  -0.135634
# 2          1  45.014777  -0.533942
# 3          1  43.494041  -1.528753
# 4          1  45.651464   0.162391
# 5          1  46.135134  -1.117086
# 6          1  44.900296  -0.515835
# 7          1  43.310797  -0.391543
# 8          1  44.849647  -0.544995
# 9          1  45.158738   1.537259
# 10         1  43.470237  -1.553876
# 11         1  44.833825  -0.598525
# 12         1  43.704643  -1.038557
# 13         1  44.861210  -0.580370
# 14         1  46.173620   1.873024
# 15         1  45.805090   2.062333
# 16         1  43.376279  -0.538206
# 17         1  43.411230  -0.617728
# 18         1  43.409857  -0.673155
# 19         1  44.865810  -0.940000
# 20         1  45.829975   1.254772
# 21         1  45.842204   1.259689
# 22         1  46.161632  -1.211229
# 23         1  46.586958   0.358458
# 24         1  44.508782   0.142695
# 25         1  43.436455  -0.695041
# 26         1  44.841373  -0.651068
# 27         1  43.896100  -0.491403
# 28        -1  43.888972  -0.507028
# 29         1  43.377194  -0.610278
# 30         1  46.333881  -0.471878
# 31         1  46.320028  -0.482861
# 32         1  45.873311   1.307916
# 33         1  43.311091  -0.352116
# 34         1  45.189825   0.727184
# 35         1  46.583998   0.345582
# 36         1  46.591231   0.340390
# 37         1  45.875834   0.823951
# 38         1  43.479820  -1.489157
# 39         1  45.884851   0.898431
# 40         1  45.647428   0.167162
# 41        -1  44.800462  -0.589398
# 42         1  43.838876  -0.812030
# 43         1  45.262665   1.762752
# 44         1  46.143234  -0.395913
# 45         1  46.162647  -1.153684
#
# [46 rows x 22 columns]

# %%
# Downloading the final indicator of ATMO NOUVELLE-AQUITAINE to csv
ratio_counts_greater_than_3_df.to_csv('indicator_ATMO_NA.csv', index=False, encoding = 'latin1')

# %%
# -----------------------------------------------------------------------------------------------------------------------------------------------------
#                                                               Sanity Checks
# -----------------------------------------------------------------------------------------------------------------------------------------------------

# %%
print(df_PM25['valeur'].head())
# Out:
# 0    9.3
# 1    9.2
# 2    8.7
# 3    8.3
# 4    9.0
# Name: valeur, dtype: float64

# %%
df_PM25['ATMO sub-score'].describe()
# Out:
# count    5625.000000
# mean        1.277689
# std         0.650835
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         5.000000
# Name: ATMO sub-score, dtype: float64

# %%
print(df_PM25['valeur'].head())
# Out:
# 0    9.3
# 1    9.2
# 2    8.7
# 3    8.3
# 4    9.0
# Name: valeur, dtype: float64
